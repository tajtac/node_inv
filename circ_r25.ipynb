# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
def coords_2_params_gt(xy):
    x, y = xy
    r = jnp.sqrt((x-0.5)**2 + (y-0.5)**2)
    r = r/0.6698906348083082
    r_transition = 0.25
    s = 5 #controls (inversely) the smoothness of the transition. 
    sigmoid = 1/(1+jnp.exp(-s*(r-r_transition)))
    C10 = 0.5 + 0.2*sigmoid
    k1  = 0.1 + 0.02*sigmoid
    k2  = 0.2 + 0.04*sigmoid
    kappa = 0.1
    theta = 0.0

    return jnp.stack([C10,k1,k2,kappa,theta])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
node_x_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    params = vmap(coords_2_params_gt)(elem_X)
    params = np.expand_dims(params, 1)

    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    node_x_hist_goh.append(node_x)
    P_hist_goh.append(P)
node_x_hist_goh = np.array(node_x_hist_goh)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [01-30 12:49:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-30 12:49:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-30 12:49:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-30 12:49:03][DEBUG] jax_fem: Done pre-computations, took 0.05507683753967285 [s]
# [01-30 12:49:03][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-30 12:49:03][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-30 12:49:03][DEBUG] jax_fem: Start timing
# [01-30 12:49:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:04][DEBUG] jax_fem: Function split_and_compute_cell took 1.0042 seconds
# [01-30 12:49:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:04][DEBUG] jax_fem: Linear guess solve...
# [01-30 12:49:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:04][DEBUG] jax_fem: PETSc linear solve res = 7.851800929256492e-07
# [01-30 12:49:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0058 seconds
# [01-30 12:49:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:04][DEBUG] jax_fem: Before, res l_2 = 0.0005140588834596416
# [01-30 12:49:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:04][DEBUG] jax_fem: PETSc linear solve res = 9.024619253281187e-10
# [01-30 12:49:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0051 seconds
# [01-30 12:49:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:04][DEBUG] jax_fem: res l_2 = 4.486078256466956e-07
# [01-30 12:49:04][INFO] jax_fem: Solve took 1.0616750717163086 [s]
# [01-30 12:49:04][DEBUG] jax_fem: max of sol = 0.05000000000000163
# [01-30 12:49:04][DEBUG] jax_fem: min of sol = 0.0
# [01-30 12:49:04][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-30 12:49:04][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-30 12:49:04][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-30 12:49:04][DEBUG] jax_fem: Done pre-computations, took 0.04513096809387207 [s]
# [01-30 12:49:04][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-30 12:49:04][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-30 12:49:04][DEBUG] jax_fem: Start timing
# [01-30 12:49:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:05][DEBUG] jax_fem: Function split_and_compute_cell took 1.0622 seconds
# [01-30 12:49:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:05][DEBUG] jax_fem: Linear guess solve...
# [01-30 12:49:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:05][DEBUG] jax_fem: PETSc linear solve res = 1.5703601858512983e-06
# [01-30 12:49:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0076 seconds
# [01-30 12:49:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:05][DEBUG] jax_fem: Before, res l_2 = 0.0016350807919124606
# [01-30 12:49:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:05][DEBUG] jax_fem: PETSc linear solve res = 1.8513584181326967e-09
# [01-30 12:49:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0072 seconds
# [01-30 12:49:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:05][DEBUG] jax_fem: res l_2 = 4.43100943501053e-06
# [01-30 12:49:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:05][DEBUG] jax_fem: PETSc linear solve res = 2.499150418583605e-13
# [01-30 12:49:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0052 seconds
# [01-30 12:49:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:05][DEBUG] jax_fem: res l_2 = 4.240660316380921e-11
# [01-30 12:49:05][INFO] jax_fem: Solve took 1.152359962463379 [s]
# [01-30 12:49:05][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [01-30 12:49:05][DEBUG] jax_fem: min of sol = 0.0
# [01-30 12:49:05][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-30 12:49:05][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-30 12:49:05][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-30 12:49:05][DEBUG] jax_fem: Done pre-computations, took 0.04611802101135254 [s]
# [01-30 12:49:05][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-30 12:49:05][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-30 12:49:05][DEBUG] jax_fem: Start timing
# [01-30 12:49:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.9873 seconds
# [01-30 12:49:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:06][DEBUG] jax_fem: Linear guess solve...
# [01-30 12:49:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:06][DEBUG] jax_fem: PETSc linear solve res = 2.355540278990269e-06
# [01-30 12:49:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0061 seconds
# [01-30 12:49:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:06][DEBUG] jax_fem: Before, res l_2 = 0.0028990772262540076
# [01-30 12:49:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:06][DEBUG] jax_fem: PETSc linear solve res = 3.519375350453575e-10
# [01-30 12:49:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0056 seconds
# [01-30 12:49:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:06][DEBUG] jax_fem: res l_2 = 1.3062822845116301e-05
# [01-30 12:49:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:06][DEBUG] jax_fem: PETSc linear solve res = 8.660317391238797e-13
# [01-30 12:49:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [01-30 12:49:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:06][DEBUG] jax_fem: res l_2 = 3.3688020910117286e-10
# [01-30 12:49:06][INFO] jax_fem: Solve took 1.0629918575286865 [s]
# [01-30 12:49:06][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [01-30 12:49:06][DEBUG] jax_fem: min of sol = 0.0
# [01-30 12:49:06][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-30 12:49:06][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-30 12:49:06][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-30 12:49:06][DEBUG] jax_fem: Done pre-computations, took 0.045953989028930664 [s]
# [01-30 12:49:06][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-30 12:49:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-30 12:49:06][DEBUG] jax_fem: Start timing
# [01-30 12:49:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.9931 seconds
# [01-30 12:49:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:07][DEBUG] jax_fem: Linear guess solve...
# [01-30 12:49:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:07][DEBUG] jax_fem: PETSc linear solve res = 3.1407203729959647e-06
# [01-30 12:49:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0079 seconds
# [01-30 12:49:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:07][DEBUG] jax_fem: Before, res l_2 = 0.0040620834230836525
# [01-30 12:49:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:07][DEBUG] jax_fem: PETSc linear solve res = 1.4835351372567904e-09
# [01-30 12:49:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0055 seconds
# [01-30 12:49:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:07][DEBUG] jax_fem: res l_2 = 2.3251181669064278e-05
# [01-30 12:49:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-30 12:49:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-30 12:49:07][DEBUG] jax_fem: PETSc linear solve res = 4.20098531521027e-12
# [01-30 12:49:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-30 12:49:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0051 seconds
# [01-30 12:49:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-30 12:49:07][DEBUG] jax_fem: res l_2 = 9.203100961299445e-10
# [01-30 12:49:07][INFO] jax_fem: Solve took 1.0752661228179932 [s]
# [01-30 12:49:07][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [01-30 12:49:07][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, P, ax in zip(t_hist, node_x_hist_goh, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 


    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,20,20,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 50000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 2.559001e-04
# it 2000, train loss = 7.853638e-05
# it 3000, train loss = 3.495503e-05
# it 4000, train loss = 1.729296e-05
# it 5000, train loss = 9.413097e-06
# it 6000, train loss = 5.522775e-06
# it 7000, train loss = 3.587401e-06
# it 8000, train loss = 1.977028e-06
# it 9000, train loss = 1.189429e-06
# it 10000, train loss = 8.626600e-07
# it 11000, train loss = 7.575668e-07
# it 12000, train loss = 4.633567e-07
# it 13000, train loss = 5.639299e-07
# it 14000, train loss = 9.705161e-07
# it 15000, train loss = 8.102209e-07
# it 16000, train loss = 3.172952e-07
# it 17000, train loss = 3.810914e-07
# it 18000, train loss = 2.080990e-07
# it 19000, train loss = 2.418762e-07
# it 20000, train loss = 2.289035e-07
# it 21000, train loss = 1.894782e-07
# it 22000, train loss = 3.352168e-07
# it 23000, train loss = 1.918360e-07
# it 24000, train loss = 3.553988e-07
# it 25000, train loss = 1.400702e-07
# it 26000, train loss = 2.139473e-07
# it 27000, train loss = 1.975501e-07
# it 28000, train loss = 4.821520e-07
# it 29000, train loss = 1.396110e-07
# it 30000, train loss = 2.009626e-07
# it 31000, train loss = 2.288678e-07
# it 32000, train loss = 1.556853e-07
# it 33000, train loss = 1.431208e-07
# it 34000, train loss = 1.146850e-07
# it 35000, train loss = 2.910557e-07
# it 36000, train loss = 1.138090e-07
# it 37000, train loss = 1.304301e-07
# it 38000, train loss = 1.704875e-07
# it 39000, train loss = 2.315465e-07
# it 40000, train loss = 1.129174e-07
# it 41000, train loss = 1.559978e-06
# it 42000, train loss = 2.687538e-07
# it 43000, train loss = 9.099054e-08
# it 44000, train loss = 1.044873e-07
# it 45000, train loss = 1.519586e-07
# it 46000, train loss = 2.111189e-07
# it 47000, train loss = 1.204418e-07
# it 48000, train loss = 3.493397e-07
# it 49000, train loss = 9.658864e-08
# it 50000, train loss = 2.041977e-07

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, node_x, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.013686e-01
# it 2000, train loss = 6.043655e-02
# it 3000, train loss = 3.515472e-02
# it 4000, train loss = 2.321290e-02
# it 5000, train loss = 1.152791e-03
# it 6000, train loss = 3.753507e-05
# it 7000, train loss = 3.378524e-05
# it 8000, train loss = 2.539563e-05
# it 9000, train loss = 1.351981e-05
# it 10000, train loss = 7.750826e-06
# it 11000, train loss = 6.597513e-06
# it 12000, train loss = 6.525993e-06
# it 13000, train loss = 6.497558e-06
# it 14000, train loss = 6.461782e-06
# it 15000, train loss = 6.425010e-06
# it 16000, train loss = 6.383893e-06
# it 17000, train loss = 6.363389e-06
# it 18000, train loss = 6.285546e-06
# it 19000, train loss = 6.231463e-06
# it 20000, train loss = 6.178879e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.3699  0.67136 0.92468 1.1442 ] [0.35707 0.64284 0.87736 1.07454]
# pr P_xx & P_yy:  [0.36853 0.67384 0.9227  1.14478] [0.35577 0.64531 0.87529 1.07518]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 2.508799e-04
# it 2000, train loss = 7.621663e-05
# it 3000, train loss = 3.283644e-05
# it 4000, train loss = 1.616157e-05
# it 5000, train loss = 8.498764e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/circ_r15_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, node_x_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/circ_r15_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, node_x_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)
    loss_F = []
    for t in t_hist:
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        loss_F.append(a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2))
    loss_F = jnp.mean(jnp.array(loss_F))
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, X, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 10000, print_freq=1000, metric_fns=[metric1, metric2])

with open('params/circ_r15_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics], f)
# Out:
# 2024-01-22 14:11:08.227550: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-01-22 14:11:23.988054: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m15.762174s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1000, val loss = 7.316632e-02
# it 2000, val loss = 8.336913e-02
# it 3000, val loss = 2.205036e-02
# it 4000, val loss = 6.913285e-02
# it 5000, val loss = 3.820569e-02
# it 6000, val loss = 8.848674e-02
# it 7000, val loss = 6.677128e-02
# it 8000, val loss = 7.974054e-02
# it 9000, val loss = 4.995495e-02
# it 10000, val loss = 5.930680e-02

# %% [markdown]
# ## 3. Test

# %%
with open('params/circ_r15_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
forces = []
div = []
for i in range(len(metrics)):
    forces.append(metrics[i][0])
    div.append(metrics[i][1])
forces = np.array(forces)
div = np.array(div)

fig, ax = plt.subplots(2,2,figsize=(10,8))
plt.subplots_adjust(hspace=0.3)
ax[0,0].plot(val_loss)
ax[0,1].plot(div[:,0], label='Divergence in x')
ax[0,1].plot(div[:,1], label='Divergence in y')

ax[1,0].plot(forces[:,0], label='right')
ax[1,1].plot(forces[:,1], label='top')
ax[1,0].plot(forces[:,2], label='left')
ax[1,1].plot(forces[:,3], label='bottom')

ax[1,0].axhline(Force_x[-1], linestyle='--', label='Reaction force x')
ax[1,1].axhline(Force_y[-1], linestyle='--', label='Reaction force y')

# ax[0,0].set(yscale='log')
ax[0,0].set(title='Validation loss = ' + str(val_loss[-1]), yscale = 'log')
ax[0,1].set(title='Divergence')
ax[1,0].set(title='Forces on right & left')
ax[1,1].set(title='Forces on top & bottom')
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = vmap(coords_2_params_gt)(elem_X)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1]);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [01-29 12:03:29][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:03:29][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:03:29][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:03:30][DEBUG] jax_fem: Done pre-computations, took 0.3440439701080322 [s]
# [01-29 12:03:30][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:03:30][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:03:30][DEBUG] jax_fem: Start timing
# [01-29 12:03:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:33][DEBUG] jax_fem: Function split_and_compute_cell took 2.9808 seconds
# [01-29 12:03:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:33][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:03:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:33][DEBUG] jax_fem: PETSc linear solve res = 0.00026159460492823953
# [01-29 12:03:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0308 seconds
# [01-29 12:03:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:33][DEBUG] jax_fem: Before, res l_2 = 0.0009476351016725269
# [01-29 12:03:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:33][DEBUG] jax_fem: PETSc linear solve res = 7.368038737660054e-10
# [01-29 12:03:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0292 seconds
# [01-29 12:03:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:33][DEBUG] jax_fem: res l_2 = 7.800413369896731e-06
# [01-29 12:03:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:33][DEBUG] jax_fem: PETSc linear solve res = 1.234995393615435e-12
# [01-29 12:03:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [01-29 12:03:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:34][DEBUG] jax_fem: res l_2 = 1.326753607533878e-10
# [01-29 12:03:34][INFO] jax_fem: Solve took 3.7914130687713623 [s]
# [01-29 12:03:34][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [01-29 12:03:34][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:03:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:03:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:03:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:03:34][DEBUG] jax_fem: Done pre-computations, took 0.04387998580932617 [s]
# [01-29 12:03:34][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:03:34][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:03:34][DEBUG] jax_fem: Start timing
# [01-29 12:03:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:37][DEBUG] jax_fem: Function split_and_compute_cell took 2.4457 seconds
# [01-29 12:03:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:37][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:03:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:37][DEBUG] jax_fem: PETSc linear solve res = 0.0005231892098564791
# [01-29 12:03:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [01-29 12:03:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:37][DEBUG] jax_fem: Before, res l_2 = 0.002814580117186409
# [01-29 12:03:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:37][DEBUG] jax_fem: PETSc linear solve res = 4.4810295653831275e-09
# [01-29 12:03:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [01-29 12:03:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:37][DEBUG] jax_fem: res l_2 = 2.2787019317089036e-05
# [01-29 12:03:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:37][DEBUG] jax_fem: PETSc linear solve res = 2.0819059222317424e-12
# [01-29 12:03:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [01-29 12:03:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:37][DEBUG] jax_fem: res l_2 = 8.758604723029062e-10
# [01-29 12:03:37][INFO] jax_fem: Solve took 2.6215901374816895 [s]
# [01-29 12:03:37][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [01-29 12:03:37][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:03:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:03:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:03:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:03:37][DEBUG] jax_fem: Done pre-computations, took 0.04106497764587402 [s]
# [01-29 12:03:37][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:03:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:03:37][DEBUG] jax_fem: Start timing
# [01-29 12:03:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:40][DEBUG] jax_fem: Function split_and_compute_cell took 2.4434 seconds
# [01-29 12:03:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:40][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:03:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:40][DEBUG] jax_fem: PETSc linear solve res = 0.0004449234056330344
# [01-29 12:03:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [01-29 12:03:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:40][DEBUG] jax_fem: Before, res l_2 = 0.0037185397187296577
# [01-29 12:03:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:40][DEBUG] jax_fem: PETSc linear solve res = 3.521352550413323e-09
# [01-29 12:03:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [01-29 12:03:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:40][DEBUG] jax_fem: res l_2 = 2.213587709125112e-05
# [01-29 12:03:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:40][DEBUG] jax_fem: PETSc linear solve res = 9.187299588223528e-13
# [01-29 12:03:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [01-29 12:03:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:40][DEBUG] jax_fem: res l_2 = 3.7922166685822494e-10
# [01-29 12:03:40][INFO] jax_fem: Solve took 2.6203179359436035 [s]
# [01-29 12:03:40][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [01-29 12:03:40][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:03:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:03:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:03:40][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:03:40][DEBUG] jax_fem: Done pre-computations, took 0.04167008399963379 [s]
# [01-29 12:03:40][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:03:40][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:03:40][DEBUG] jax_fem: Start timing
# [01-29 12:03:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:42][DEBUG] jax_fem: Function split_and_compute_cell took 2.5027 seconds
# [01-29 12:03:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:42][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:03:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:42][DEBUG] jax_fem: PETSc linear solve res = 0.0007309515320468345
# [01-29 12:03:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [01-29 12:03:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:43][DEBUG] jax_fem: Before, res l_2 = 0.0060427854866820455
# [01-29 12:03:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:43][DEBUG] jax_fem: PETSc linear solve res = 1.6218186735614223e-08
# [01-29 12:03:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0300 seconds
# [01-29 12:03:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:43][DEBUG] jax_fem: res l_2 = 3.525931022906548e-05
# [01-29 12:03:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:03:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:03:43][DEBUG] jax_fem: PETSc linear solve res = 4.0913769421804716e-11
# [01-29 12:03:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:03:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [01-29 12:03:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:03:43][DEBUG] jax_fem: res l_2 = 1.0015001711058603e-09
# [01-29 12:03:43][INFO] jax_fem: Solve took 2.6820178031921387 [s]
# [01-29 12:03:43][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [01-29 12:03:43][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
