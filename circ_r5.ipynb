# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax.config import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, eval_Cauchy_aniso, eval_Cauchy_aniso_vmap
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_node import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jaxinterp2d import interp2d
# Out:
# /var/folders/1f/rngrmz8x3lsd60h6dd90ncwm0000gr/T/ipykernel_55683/1914414784.py:5: DeprecationWarning: Accessing jax.config via the jax.config submodule is deprecated.
#   from jax.config import config

# %%
from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
# Do the FEM with jax-fem instead
def GOH_PK1(u_grad, params, dim):
    C10, k1, k2 = params
    kappa = 0.1
    theta = 0.0
    #Kinematics
    F_2D = u_grad + jnp.eye(dim)
    C_2D = F_2D.T @ F_2D
    Cinv_2D = jnp.linalg.inv(C_2D)
    detC_2D = jnp.linalg.det(C_2D)
    C33 = 1/detC_2D
    C = jnp.array([  [C_2D[0,0], C_2D[0,1], 0],\
                    [C_2D[1,0], C_2D[1,1], 0],\
                    [0,         0,       C33]])
    C2 = C @ C
    Cinv = jnp.linalg.inv(C)
    I1 = C[0,0] + C[1,1] + C[2,2]
    trC2 = C2[0,0] + C2[1,1] + C2[2,2]
    I2 = 0.5*(I1**2 - trC2)
    v0 = jnp.array([ jnp.cos(theta), jnp.sin(theta), 0])
    V0 = jnp.outer(v0, v0)
    Iv = jnp.einsum('ij,ij',C,V0)


    # Energy/Stress
    E = kappa*(I1-3.0) + (1-3*kappa)*(Iv-1.0)
    E = jnp.maximum(E, 0.0)

    Psi1 = C10 + k1*kappa*E*jnp.exp(k2*E**2)
    Psiv = k1*(1-3*kappa)*E*jnp.exp(k2*E**2)
    Psi2 = 0.0

    p = -C[2,2]*(2*Psi1 + 2*Psi2*(I1 - C[2,2]) + 2*Psiv*V0[2,2])
    S = p*Cinv + 2*Psi1*jnp.eye(3) + 2*Psi2*(I1*jnp.eye(3)-C) + 2*Psiv*V0
    S_2D = S[:2,:2]
    P_2D = F_2D @ S_2D
    return P_2D
GOH_vmap = vmap(GOH_PK1, in_axes=(0,0,None))
def GOH_sigma(u_grad, params, dim):
    F_2D = u_grad + jnp.eye(dim)
    P_2D = GOH_PK1(u_grad, params, dim)
    return P_2D @ F_2D.T
GOH_sigma_vmap = vmap(GOH_sigma, in_axes=(0,0,None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: GOH_PK1(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist_goh = []
node_x_hist_goh = []
sigma_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)


    # GOH Material parameters
    r = np.sqrt((elem_X[:,0]-0.5)**2 + (elem_X[:,1]-0.5)**2)
    r = r/np.max(r)
    r_transition = 0.05
    s = 5 #controls (inversely) the smoothness of the transition. 
    sigmoid = 1/(1+np.exp(-s*(r-r_transition)))
    C10 = 0.5 + 0.2*sigmoid
    k1  = 0.1 + 0.02*sigmoid
    k2  = 0.2 + 0.04*sigmoid
    params = np.stack([C10,k1,k2]).T.reshape([-1,1,3])
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    sigma = GOH_sigma_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    node_x_hist_goh.append(node_x)
    sigma_hist_goh.append(sigma)
node_x_hist_goh = np.array(node_x_hist_goh)
F_hist_goh = np.array(F_hist_goh)
sigma_hist_goh = np.array(sigma_hist_goh)
# Out:
# [12-06 18:24:13][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 18:24:13][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 18:24:13][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 18:24:13][DEBUG] jax_fem: Done pre-computations, took 0.06422996520996094 [s]
# [12-06 18:24:13][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 18:24:13][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 18:24:13][DEBUG] jax_fem: Start timing
# [12-06 18:24:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:14][DEBUG] jax_fem: Function split_and_compute_cell took 1.0065 seconds
# [12-06 18:24:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:14][DEBUG] jax_fem: Linear guess solve...
# [12-06 18:24:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:14][DEBUG] jax_fem: PETSc linear solve res = 1.074182381523633e-06
# [12-06 18:24:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0056 seconds
# [12-06 18:24:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:14][DEBUG] jax_fem: Before, res l_2 = 0.0003500764265561766
# [12-06 18:24:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:14][DEBUG] jax_fem: PETSc linear solve res = 2.200901460750132e-10
# [12-06 18:24:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0051 seconds
# [12-06 18:24:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:14][DEBUG] jax_fem: res l_2 = 2.549909608944833e-07
# [12-06 18:24:14][INFO] jax_fem: Solve took 1.060962200164795 [s]
# [12-06 18:24:14][DEBUG] jax_fem: max of sol = 0.04999999999999928
# [12-06 18:24:14][DEBUG] jax_fem: min of sol = 0.0
# [12-06 18:24:14][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 18:24:14][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 18:24:14][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 18:24:14][DEBUG] jax_fem: Done pre-computations, took 0.06281495094299316 [s]
# [12-06 18:24:14][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 18:24:14][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 18:24:14][DEBUG] jax_fem: Start timing
# [12-06 18:24:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:15][DEBUG] jax_fem: Function split_and_compute_cell took 1.0008 seconds
# [12-06 18:24:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:15][DEBUG] jax_fem: Linear guess solve...
# [12-06 18:24:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:15][DEBUG] jax_fem: PETSc linear solve res = 2.148364763047266e-06
# [12-06 18:24:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0061 seconds
# [12-06 18:24:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:15][DEBUG] jax_fem: Before, res l_2 = 0.0011112081952682539
# [12-06 18:24:15][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:15][DEBUG] jax_fem: PETSc linear solve res = 3.0308552473525164e-09
# [12-06 18:24:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [12-06 18:24:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:15][DEBUG] jax_fem: res l_2 = 2.53448603964358e-06
# [12-06 18:24:15][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:15][DEBUG] jax_fem: PETSc linear solve res = 1.517807625962785e-13
# [12-06 18:24:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0047 seconds
# [12-06 18:24:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:15][DEBUG] jax_fem: res l_2 = 1.644217074142048e-11
# [12-06 18:24:15][INFO] jax_fem: Solve took 1.0758509635925293 [s]
# [12-06 18:24:15][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [12-06 18:24:15][DEBUG] jax_fem: min of sol = 0.0
# [12-06 18:24:15][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 18:24:15][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 18:24:15][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 18:24:15][DEBUG] jax_fem: Done pre-computations, took 0.049761056900024414 [s]
# [12-06 18:24:15][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 18:24:15][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 18:24:15][DEBUG] jax_fem: Start timing
# [12-06 18:24:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:16][DEBUG] jax_fem: Function split_and_compute_cell took 1.0030 seconds
# [12-06 18:24:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:16][DEBUG] jax_fem: Linear guess solve...
# [12-06 18:24:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:16][DEBUG] jax_fem: PETSc linear solve res = 3.2225471445242172e-06
# [12-06 18:24:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0058 seconds
# [12-06 18:24:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:16][DEBUG] jax_fem: Before, res l_2 = 0.001970104545938356
# [12-06 18:24:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:16][DEBUG] jax_fem: PETSc linear solve res = 3.331440591027605e-10
# [12-06 18:24:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [12-06 18:24:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:16][DEBUG] jax_fem: res l_2 = 7.504665402491467e-06
# [12-06 18:24:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:16][DEBUG] jax_fem: PETSc linear solve res = 5.409646527675828e-13
# [12-06 18:24:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [12-06 18:24:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:16][DEBUG] jax_fem: res l_2 = 1.3706786978266465e-10
# [12-06 18:24:16][INFO] jax_fem: Solve took 1.0748369693756104 [s]
# [12-06 18:24:16][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [12-06 18:24:16][DEBUG] jax_fem: min of sol = 0.0
# [12-06 18:24:17][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 18:24:17][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 18:24:17][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 18:24:17][DEBUG] jax_fem: Done pre-computations, took 0.056870222091674805 [s]
# [12-06 18:24:17][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 18:24:17][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 18:24:17][DEBUG] jax_fem: Start timing
# [12-06 18:24:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:18][DEBUG] jax_fem: Function split_and_compute_cell took 1.0458 seconds
# [12-06 18:24:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:18][DEBUG] jax_fem: Linear guess solve...
# [12-06 18:24:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:18][DEBUG] jax_fem: PETSc linear solve res = 4.296729526302513e-06
# [12-06 18:24:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0056 seconds
# [12-06 18:24:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:18][DEBUG] jax_fem: Before, res l_2 = 0.0027618722023021063
# [12-06 18:24:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:18][DEBUG] jax_fem: PETSc linear solve res = 1.524199911106911e-09
# [12-06 18:24:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0051 seconds
# [12-06 18:24:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:18][DEBUG] jax_fem: res l_2 = 1.3349461622934446e-05
# [12-06 18:24:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 18:24:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 18:24:18][DEBUG] jax_fem: PETSc linear solve res = 1.1241992340404019e-12
# [12-06 18:24:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 18:24:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [12-06 18:24:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 18:24:18][DEBUG] jax_fem: res l_2 = 3.947074305277536e-10
# [12-06 18:24:18][INFO] jax_fem: Solve took 1.1202080249786377 [s]
# [12-06 18:24:18][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [12-06 18:24:18][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, sigma, ax in zip(t_hist, node_x_hist_goh, F_hist_goh, sigma_hist_goh, axes):
    eps_xx = F[:,0,0]-1.0
    eps_yy = F[:,1,1]-1.0

    mps = np.maximum(eps_xx, eps_yy)
    strains.append(np.array([t*np.ones_like(eps_xx), eps_xx, eps_yy]))

    plotmesh(mesh.cells, node_x, mps, title='Max. Princip. Strain [-]', ax=ax); 
strains = np.hstack(strains)

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = ff_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 3 # x, y, lmb
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])
nn_layers = [2*n_ff,20,20,2]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss, inp, get_params, opt_update, opt_state, key, nIter = 40000, print_freq=1000, batch_size=1000)


fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    eps_xx_pr, eps_yy_pr = ff_nn(aux, coord_2_strain_params).T
    mps_pr = np.maximum(eps_xx_pr, eps_yy_pr)

    plotmesh(mesh.cells, node_x, mps_pr, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(sigma_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(sigma_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(sigma_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(sigma_hist_goh[:,bot_bd_elems,1,1], axis=1)
Fx = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Fy = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
eps_xx_mean = np.mean(F_hist_goh[:,:,0,0]-1.0, axis=1)
eps_yy_mean = np.mean(F_hist_goh[:,:,1,1]-1.0, axis=1)
# eps_xy_mean = np.mean(0.5*(F_hist_goh[:,:,0,1]+F_hist_goh[:,:,1,0]), axis=1)
sgmx_mean = Fx/len(rgt_bd_elems)
sgmy_mean = Fy/len(top_bd_elems)
lamb_sigma_m = np.array([eps_xx_mean+1.0, eps_yy_mean+1.0, sgmx_mean, sgmy_mean]).reshape([len(lmb_hist),-1]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_sig_all(params, lamb_sigma, key):
    model   = NODE_model_aniso(params)
    lambx   = lamb_sigma[:,0]
    lamby   = lamb_sigma[:,1]
    sgmx_gt  = lamb_sigma[:,2]
    sgmy_gt  = lamb_sigma[:,3]
    sgm = eval_Cauchy_aniso_vmap(lambx,lamby, model)
    sgmx_pr, sgmy_pr = sgm[:,0,0], sgm[:,1,1]
    return np.mean((sgmx_pr-sgmx_gt)**2+(sgmy_pr-sgmy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_sig_all, lamb_sigma_m, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.316850e-01
# it 2000, train loss = 8.160049e-02
# it 3000, train loss = 4.816714e-02
# it 4000, train loss = 3.277665e-02
# it 5000, train loss = 6.009383e-03
# it 6000, train loss = 5.162072e-05
# it 7000, train loss = 4.617465e-05
# it 8000, train loss = 3.645571e-05
# it 9000, train loss = 1.932327e-05
# it 10000, train loss = 1.062979e-05
# it 11000, train loss = 8.615067e-06
# it 12000, train loss = 8.378097e-06
# it 13000, train loss = 8.261127e-06
# it 14000, train loss = 8.180212e-06
# it 15000, train loss = 8.317525e-06
# it 16000, train loss = 8.071440e-06
# it 17000, train loss = 8.021146e-06
# it 18000, train loss = 7.967013e-06
# it 19000, train loss = 7.910307e-06
# it 20000, train loss = 7.854640e-06

# %%
mymodel = NODE_model_aniso(node_params)
sgm = eval_Cauchy_aniso_vmap(eps_xx_mean+1.0,eps_yy_mean+1.0, mymodel)
sgmx, sgmy = sgm[:,0,0], sgm[:,1,1]
print('gt sgmx & sgmy: ', sgmx_mean, sgmy_mean)
print('pr sgmx & sgmy: ', sgmx, sgmy)
# Out:
# gt sgmx & sgmy:  [0.39336 0.74656 1.07306 1.38325] [0.37977 0.71488 1.01799 1.29841]
# pr sgmx & sgmy:  [0.39171 0.74937 1.07093 1.38385] [0.37824 0.71769 1.01571 1.29909]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 3.110762e-04
# it 2000, train loss = 8.736686e-05
# it 3000, train loss = 3.648796e-05
# it 4000, train loss = 1.775885e-05
# it 5000, train loss = 9.265289e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/circ_r5_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Fx, Fy, strains,
                 bd_X, lmb_hist, sigma_hist_goh, F_hist_goh, node_x_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/circ_r5_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Fx, Fy, strains, \
                 bd_X, lmb_hist, sigma_hist_goh, F_hist_goh, node_x_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
@jit
def loss(Lambda_params, X):
    div_x, div_y = divergence(Lambda_params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
    F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
    t = X[1] # a scalar
    fx = Fx[jnp.array(t, int)]
    fy = Fy[jnp.array(t, int)]
    return a1*(div_x**2 + div_y**2) + a2*((F_rgt-fx)**2 + (F_top-fy)**2 + (F_lft-fx)**2 + (F_bot-fy)**2)

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

metric1 = lambda params, X:  bd_forces(params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, X, bd_X, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 10000, print_freq=1000, metric_fns=[metric1, metric2])

with open('params/circ_r5_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Fx, Fy, node_params, Lambda_params, val_loss, metrics], f)
# Out:
# it 1000, val loss = 1.807056e+00
# it 2000, val loss = 3.583454e+00
# it 3000, val loss = 2.507494e+00
# it 4000, val loss = 2.580615e+00
# it 5000, val loss = 2.329758e+00
# it 6000, val loss = 2.054892e+00
# it 7000, val loss = 2.289393e+00
# it 8000, val loss = 2.245287e+00
# it 9000, val loss = 2.279848e+00
# it 10000, val loss = 2.698849e+00

# %% [markdown]
# ## 3. Test

# %%
with open('params/circ_r5_post.npy', 'rb') as f:
    mesh, elem_X, strains, Fx, Fy, node_params, Lambda_params, val_loss, metrics = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
forces = []
div = []
for i in range(len(metrics)):
    forces.append(metrics[i][0])
    div.append(metrics[i][1])
forces = np.array(forces)
div = np.array(div)

fig, ax = plt.subplots(2,2,figsize=(10,8))
plt.subplots_adjust(hspace=0.3)
ax[0,0].plot(val_loss)
ax[0,1].plot(div[:,0], label='Divergence in x')
ax[0,1].plot(div[:,1], label='Divergence in y')

ax[1,0].plot(forces[:,0], label='right')
ax[1,1].plot(forces[:,1], label='top')
ax[1,0].plot(forces[:,2], label='left')
ax[1,1].plot(forces[:,3], label='bottom')

ax[1,0].axhline(Fx[-1], linestyle='--', label='Reaction force x')
ax[1,1].axhline(Fy[-1], linestyle='--', label='Reaction force y')

# ax[0,0].set(yscale='log')
ax[0,0].set(title='Validation loss = ' + str(val_loss[-1]), yscale = 'log')
ax[0,1].set(title='Divergence')
ax[1,0].set(title='Forces on right & left')
ax[1,1].set(title='Forces on top & bottom')
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()

# %%
# Stiffness across the domain
fig, axes = plt.subplots(1,4,figsize=(20,4))
for lmb, ax in zip(lmb_hist, axes):
    c_elem = []
    for x, y in elem_X:
        Lambda_inp = jnp.array([x,y]).reshape([-1,2])
        phi = ff_nn(Lambda_inp, Lambda_params).flatten()
        mymodel = NODE_w_unravel(phi)
        c_elem.append(eval_Cauchy_aniso(lmb, lmb, mymodel)[0,0])
    c_elem = np.array(c_elem)
    plotmesh(mesh.cells, mesh.points, c_elem, title='Stress at {}'.format(str(lmb)), ax=ax);

# %%
# Do the FEM with jax-fem instead
def NODE_PK1(u_grad, params, dim):
    theta = 0.0
    #Kinematics
    F_2D = u_grad + jnp.eye(dim)
    C_2D = F_2D.T @ F_2D
    Cinv_2D = jnp.linalg.inv(C_2D)
    detC_2D = jnp.linalg.det(C_2D)
    C33 = 1/detC_2D
    C = jnp.array([  [C_2D[0,0], C_2D[0,1], 0],\
                    [C_2D[1,0], C_2D[1,1], 0],\
                    [0,         0,       C33]])
    C2 = C @ C
    Cinv = jnp.linalg.inv(C)
    I1 = C[0,0] + C[1,1] + C[2,2]
    trC2 = C2[0,0] + C2[1,1] + C2[2,2]
    I2 = 0.5*(I1**2 - trC2)
    v0 = jnp.array([ jnp.cos(theta), jnp.sin(theta), 0])
    w0 = jnp.array([-jnp.sin(theta), jnp.cos(theta), 0])
    V0 = jnp.outer(v0, v0)
    W0 = jnp.outer(w0, w0)
    Iv = jnp.einsum('ij,ij',C,V0)
    Iw = jnp.einsum('ij,ij',C,W0)

    # Energy/Stress
    model = NODE_w_unravel(params)
    Psi1 = model.Psi1(I1,I2,Iv,Iw)
    Psi2 = model.Psi2(I1,I2,Iv,Iw)
    Psiv = model.Psiv(I1,I2,Iv,Iw)
    Psiw = model.Psiw(I1,I2,Iv,Iw)
    
    p = -C[2,2]*(2*Psi1 + 2*Psi2*(I1 - C[2,2]) + 2*Psiv*V0[2,2] + 2*Psiw*W0[2,2])
    S = p*Cinv + 2*Psi1*jnp.eye(3) + 2*Psi2*(I1*jnp.eye(3)-C) + 2*Psiv*V0 + 2*Psiw*W0
    S_2D = S[:2,:2]
    P_2D = F_2D @ S_2D
    return P_2D
NODE_vmap = vmap(NODE_PK1, in_axes=(0,0,None))
def NODE_sigma(u_grad, params, dim):
    F_2D = u_grad + jnp.eye(dim)
    P_2D = NODE_PK1(u_grad, params, dim)
    return P_2D @ F_2D.T
NODE_sigma_vmap = vmap(NODE_sigma, in_axes=(0,0,None))
class NODE_HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: NODE_PK1(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
sigma_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = NODE_HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    sigma = NODE_sigma_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    sigma_hist.append(sigma)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
sigma_hist = np.array(sigma_hist)
# Out:
# [12-07 13:37:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-07 13:37:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-07 13:37:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-07 13:37:35][DEBUG] jax_fem: Done pre-computations, took 0.14293289184570312 [s]
# [12-07 13:37:35][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-07 13:37:35][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-07 13:37:35][DEBUG] jax_fem: Start timing
# [12-07 13:37:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 2.5616 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: Linear guess solve...
# [12-07 13:37:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:37][DEBUG] jax_fem: PETSc linear solve res = 0.007353503617906416
# [12-07 13:37:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: Before, res l_2 = 0.03128822559795689
# [12-07 13:37:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:37][DEBUG] jax_fem: PETSc linear solve res = 5.076566114135388e-09
# [12-07 13:37:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0295 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: res l_2 = 0.008357768153487028
# [12-07 13:37:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:37][DEBUG] jax_fem: PETSc linear solve res = 1.0159602289986916e-08
# [12-07 13:37:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0280 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: res l_2 = 0.00026842609580336393
# [12-07 13:37:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:37][DEBUG] jax_fem: PETSc linear solve res = 8.56405431375714e-11
# [12-07 13:37:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0283 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: res l_2 = 1.4879479611224481e-06
# [12-07 13:37:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:37][DEBUG] jax_fem: PETSc linear solve res = 9.590697059872578e-13
# [12-07 13:37:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0308 seconds
# [12-07 13:37:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:37][DEBUG] jax_fem: res l_2 = 5.808254085554179e-12
# [12-07 13:37:37][INFO] jax_fem: Solve took 2.890199899673462 [s]
# [12-07 13:37:37][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [12-07 13:37:37][DEBUG] jax_fem: min of sol = 0.0
# [12-07 13:37:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-07 13:37:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-07 13:37:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-07 13:37:38][DEBUG] jax_fem: Done pre-computations, took 0.04534125328063965 [s]
# [12-07 13:37:38][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-07 13:37:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-07 13:37:38][DEBUG] jax_fem: Start timing
# [12-07 13:37:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 2.4313 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: Linear guess solve...
# [12-07 13:37:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:40][DEBUG] jax_fem: PETSc linear solve res = 0.014707007235812832
# [12-07 13:37:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0301 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: Before, res l_2 = 0.09704694900604835
# [12-07 13:37:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:40][DEBUG] jax_fem: PETSc linear solve res = 3.0126145317988144e-07
# [12-07 13:37:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0283 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: res l_2 = 0.021094979420268153
# [12-07 13:37:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:40][DEBUG] jax_fem: PETSc linear solve res = 4.454140006702914e-09
# [12-07 13:37:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: res l_2 = 0.0015354796587408756
# [12-07 13:37:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:40][DEBUG] jax_fem: PETSc linear solve res = 1.7929894640287936e-09
# [12-07 13:37:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0279 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: res l_2 = 7.106242275821964e-06
# [12-07 13:37:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:40][DEBUG] jax_fem: PETSc linear solve res = 5.060865479195854e-12
# [12-07 13:37:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0300 seconds
# [12-07 13:37:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:40][DEBUG] jax_fem: res l_2 = 3.070249694316216e-10
# [12-07 13:37:40][INFO] jax_fem: Solve took 2.757115125656128 [s]
# [12-07 13:37:40][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [12-07 13:37:40][DEBUG] jax_fem: min of sol = 0.0
# [12-07 13:37:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-07 13:37:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-07 13:37:41][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-07 13:37:41][DEBUG] jax_fem: Done pre-computations, took 0.0641636848449707 [s]
# [12-07 13:37:41][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-07 13:37:41][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-07 13:37:41][DEBUG] jax_fem: Start timing
# [12-07 13:37:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 2.4466 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: Linear guess solve...
# [12-07 13:37:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:43][DEBUG] jax_fem: PETSc linear solve res = 0.019190847802051946
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0304 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: Before, res l_2 = 0.16123465517115695
# [12-07 13:37:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:43][DEBUG] jax_fem: PETSc linear solve res = 6.995782520434003e-08
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: res l_2 = 0.03679266807501748
# [12-07 13:37:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:43][DEBUG] jax_fem: PETSc linear solve res = 4.836076852084073e-08
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: res l_2 = 0.0028765933432746576
# [12-07 13:37:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:43][DEBUG] jax_fem: PETSc linear solve res = 2.4207232296949346e-09
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: res l_2 = 1.4959450923027042e-05
# [12-07 13:37:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:43][DEBUG] jax_fem: PETSc linear solve res = 2.9150013521712e-12
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [12-07 13:37:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:43][DEBUG] jax_fem: res l_2 = 7.15577250248444e-10
# [12-07 13:37:43][INFO] jax_fem: Solve took 2.781592845916748 [s]
# [12-07 13:37:43][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [12-07 13:37:43][DEBUG] jax_fem: min of sol = 0.0
# [12-07 13:37:43][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-07 13:37:43][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-07 13:37:43][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-07 13:37:43][DEBUG] jax_fem: Done pre-computations, took 0.07227897644042969 [s]
# [12-07 13:37:43][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-07 13:37:43][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-07 13:37:43][DEBUG] jax_fem: Start timing
# [12-07 13:37:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 2.4963 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: Linear guess solve...
# [12-07 13:37:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:46][DEBUG] jax_fem: PETSc linear solve res = 0.030416266983839757
# [12-07 13:37:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0295 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: Before, res l_2 = 0.29840406724579344
# [12-07 13:37:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:46][DEBUG] jax_fem: PETSc linear solve res = 1.3413997740546398e-07
# [12-07 13:37:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0314 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: res l_2 = 0.09883501650895883
# [12-07 13:37:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:46][DEBUG] jax_fem: PETSc linear solve res = 2.4361537706169308e-08
# [12-07 13:37:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0304 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: res l_2 = 0.01200219560956281
# [12-07 13:37:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:46][DEBUG] jax_fem: PETSc linear solve res = 1.0493556194624474e-08
# [12-07 13:37:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: res l_2 = 0.0002014377315446454
# [12-07 13:37:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-07 13:37:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-07 13:37:46][DEBUG] jax_fem: PETSc linear solve res = 2.8772147223562563e-11
# [12-07 13:37:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-07 13:37:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0316 seconds
# [12-07 13:37:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-07 13:37:46][DEBUG] jax_fem: res l_2 = 9.541915645521924e-08
# [12-07 13:37:46][INFO] jax_fem: Solve took 2.8299641609191895 [s]
# [12-07 13:37:46][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [12-07 13:37:46][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
for t, node_x, F, sigma, ax in zip(t_hist, node_x_hist, F_hist, sigma_hist, axes):
    eps_xx = F[:,0,0]-1.0
    eps_yy = F[:,1,1]-1.0

    mps = np.maximum(eps_xx, eps_yy)
    strains.append(np.array([t*np.ones_like(eps_xx), eps_xx, eps_yy]))

    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 
strains = np.hstack(strains)
