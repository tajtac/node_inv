# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax.config import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, eval_Cauchy_aniso, eval_Cauchy_aniso_vmap
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_node import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jaxinterp2d import interp2d
# Out:
# /var/folders/1f/rngrmz8x3lsd60h6dd90ncwm0000gr/T/ipykernel_93789/1914414784.py:5: DeprecationWarning: Accessing jax.config via the jax.config submodule is deprecated.
#   from jax.config import config

# %%
from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
# Do the FEM with jax-fem instead
def GOH_PK1(u_grad, params, dim):
    C10, k1, k2 = params
    kappa = 0.1
    theta = 0.0
    #Kinematics
    F_2D = u_grad + jnp.eye(dim)
    C_2D = F_2D.T @ F_2D
    Cinv_2D = jnp.linalg.inv(C_2D)
    detC_2D = jnp.linalg.det(C_2D)
    C33 = 1/detC_2D
    C = jnp.array([  [C_2D[0,0], C_2D[0,1], 0],\
                    [C_2D[1,0], C_2D[1,1], 0],\
                    [0,         0,       C33]])
    C2 = C @ C
    Cinv = jnp.linalg.inv(C)
    I1 = C[0,0] + C[1,1] + C[2,2]
    trC2 = C2[0,0] + C2[1,1] + C2[2,2]
    I2 = 0.5*(I1**2 - trC2)
    v0 = jnp.array([ jnp.cos(theta), jnp.sin(theta), 0])
    V0 = jnp.outer(v0, v0)
    Iv = jnp.einsum('ij,ij',C,V0)


    # Energy/Stress
    E = kappa*(I1-3.0) + (1-3*kappa)*(Iv-1.0)
    E = jnp.maximum(E, 0.0)

    Psi1 = C10 + k1*kappa*E*jnp.exp(k2*E**2)
    Psiv = k1*(1-3*kappa)*E*jnp.exp(k2*E**2)
    Psi2 = 0.0

    p = -C[2,2]*(2*Psi1 + 2*Psi2*(I1 - C[2,2]) + 2*Psiv*V0[2,2])
    S = p*Cinv + 2*Psi1*jnp.eye(3) + 2*Psi2*(I1*jnp.eye(3)-C) + 2*Psiv*V0
    S_2D = S[:2,:2]
    P_2D = F_2D @ S_2D
    return P_2D
GOH_vmap = vmap(GOH_PK1, in_axes=(0,0,None))
def GOH_sigma(u_grad, params, dim):
    F_2D = u_grad + jnp.eye(dim)
    P_2D = GOH_PK1(u_grad, params, dim)
    return P_2D @ F_2D.T
GOH_sigma_vmap = vmap(GOH_sigma, in_axes=(0,0,None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: GOH_PK1(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist_goh = []
node_x_hist_goh = []
sigma_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)


    # GOH Material parameters
    r = np.sqrt((elem_X[:,0]-0.5)**2 + (elem_X[:,1]-0.5)**2)
    r = r/np.max(r)
    r_transition = 0.35
    s = 100 #controls (inversely) the smoothness of the transition. 
    sigmoid = 1/(1+np.exp(-s*(r-r_transition)))
    C10 = 0.5 + 0.2*sigmoid
    k1  = 0.1 + 0.02*sigmoid
    k2  = 0.2 + 0.04*sigmoid
    params = np.stack([C10,k1,k2]).T.reshape([-1,1,3])
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    sigma = GOH_sigma_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    node_x_hist_goh.append(node_x)
    sigma_hist_goh.append(sigma)
node_x_hist_goh = np.array(node_x_hist_goh)
F_hist_goh = np.array(F_hist_goh)
sigma_hist_goh = np.array(sigma_hist_goh)
# Out:
# [12-11 15:27:33][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-11 15:27:33][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-11 15:27:33][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-11 15:27:33][DEBUG] jax_fem: Done pre-computations, took 0.346541166305542 [s]
# [12-11 15:27:33][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-11 15:27:33][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-11 15:27:33][DEBUG] jax_fem: Start timing
# [12-11 15:27:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:35][DEBUG] jax_fem: Function split_and_compute_cell took 1.2664 seconds
# [12-11 15:27:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:35][DEBUG] jax_fem: Linear guess solve...
# [12-11 15:27:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:35][DEBUG] jax_fem: PETSc linear solve res = 1.492573203863954e-06
# [12-11 15:27:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0054 seconds
# [12-11 15:27:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:35][DEBUG] jax_fem: Before, res l_2 = 0.0018960515021120739
# [12-11 15:27:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:35][DEBUG] jax_fem: PETSc linear solve res = 1.0269741134051663e-09
# [12-11 15:27:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0048 seconds
# [12-11 15:27:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:35][DEBUG] jax_fem: res l_2 = 1.6998975097586211e-06
# [12-11 15:27:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:35][DEBUG] jax_fem: PETSc linear solve res = 1.3383348478514488e-12
# [12-11 15:27:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0048 seconds
# [12-11 15:27:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:35][DEBUG] jax_fem: res l_2 = 2.1042196047682878e-12
# [12-11 15:27:35][INFO] jax_fem: Solve took 1.8986248970031738 [s]
# [12-11 15:27:35][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [12-11 15:27:35][DEBUG] jax_fem: min of sol = 0.0
# [12-11 15:27:36][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-11 15:27:36][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-11 15:27:36][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-11 15:27:36][DEBUG] jax_fem: Done pre-computations, took 0.05731630325317383 [s]
# [12-11 15:27:36][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-11 15:27:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-11 15:27:36][DEBUG] jax_fem: Start timing
# [12-11 15:27:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:37][DEBUG] jax_fem: Function split_and_compute_cell took 1.0002 seconds
# [12-11 15:27:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:37][DEBUG] jax_fem: Linear guess solve...
# [12-11 15:27:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:37][DEBUG] jax_fem: PETSc linear solve res = 2.985146407727908e-06
# [12-11 15:27:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0068 seconds
# [12-11 15:27:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:37][DEBUG] jax_fem: Before, res l_2 = 0.00597238940858381
# [12-11 15:27:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:37][DEBUG] jax_fem: PETSc linear solve res = 1.3047911212630566e-09
# [12-11 15:27:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0052 seconds
# [12-11 15:27:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:37][DEBUG] jax_fem: res l_2 = 1.6066955722909296e-05
# [12-11 15:27:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:37][DEBUG] jax_fem: PETSc linear solve res = 6.050360792902679e-12
# [12-11 15:27:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0049 seconds
# [12-11 15:27:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:37][DEBUG] jax_fem: res l_2 = 1.2541757260640359e-10
# [12-11 15:27:37][INFO] jax_fem: Solve took 1.0810906887054443 [s]
# [12-11 15:27:37][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [12-11 15:27:37][DEBUG] jax_fem: min of sol = 0.0
# [12-11 15:27:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-11 15:27:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-11 15:27:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-11 15:27:37][DEBUG] jax_fem: Done pre-computations, took 0.03958582878112793 [s]
# [12-11 15:27:37][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-11 15:27:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-11 15:27:37][DEBUG] jax_fem: Start timing
# [12-11 15:27:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:38][DEBUG] jax_fem: Function split_and_compute_cell took 1.0749 seconds
# [12-11 15:27:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:38][DEBUG] jax_fem: Linear guess solve...
# [12-11 15:27:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:38][DEBUG] jax_fem: PETSc linear solve res = 4.477719611553153e-06
# [12-11 15:27:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0057 seconds
# [12-11 15:27:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:38][DEBUG] jax_fem: Before, res l_2 = 0.01049301065621602
# [12-11 15:27:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:38][DEBUG] jax_fem: PETSc linear solve res = 1.7401329533380638e-09
# [12-11 15:27:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0052 seconds
# [12-11 15:27:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:38][DEBUG] jax_fem: res l_2 = 4.671764026950122e-05
# [12-11 15:27:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:38][DEBUG] jax_fem: PETSc linear solve res = 4.688917552866932e-12
# [12-11 15:27:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0048 seconds
# [12-11 15:27:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:38][DEBUG] jax_fem: res l_2 = 9.266939807836686e-10
# [12-11 15:27:38][INFO] jax_fem: Solve took 1.1475770473480225 [s]
# [12-11 15:27:38][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [12-11 15:27:38][DEBUG] jax_fem: min of sol = 0.0
# [12-11 15:27:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-11 15:27:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-11 15:27:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-11 15:27:38][DEBUG] jax_fem: Done pre-computations, took 0.04125618934631348 [s]
# [12-11 15:27:38][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-11 15:27:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-11 15:27:38][DEBUG] jax_fem: Start timing
# [12-11 15:27:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:39][DEBUG] jax_fem: Function split_and_compute_cell took 1.0640 seconds
# [12-11 15:27:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:39][DEBUG] jax_fem: Linear guess solve...
# [12-11 15:27:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:39][DEBUG] jax_fem: PETSc linear solve res = 5.970292815271937e-06
# [12-11 15:27:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0075 seconds
# [12-11 15:27:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:39][DEBUG] jax_fem: Before, res l_2 = 0.014562664446794275
# [12-11 15:27:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:39][DEBUG] jax_fem: PETSc linear solve res = 5.040984896892863e-09
# [12-11 15:27:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0057 seconds
# [12-11 15:27:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:39][DEBUG] jax_fem: res l_2 = 8.578349677881215e-05
# [12-11 15:27:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-11 15:27:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-11 15:27:39][DEBUG] jax_fem: PETSc linear solve res = 1.751799632250955e-11
# [12-11 15:27:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-11 15:27:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0058 seconds
# [12-11 15:27:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-11 15:27:39][DEBUG] jax_fem: res l_2 = 2.6695330697964075e-09
# [12-11 15:27:39][INFO] jax_fem: Solve took 1.1590120792388916 [s]
# [12-11 15:27:39][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [12-11 15:27:39][DEBUG] jax_fem: min of sol = 0.0

# %%
with open('test.npy','wb') as f:
    pickle.dump([C10,k1,k2,np.ones_like(k1)*0.1, np.ones_like(k1)*0.0], f)

# %%
fig, axes = plt.subplots(1,5,figsize=(25,4))

plotmesh(mesh.cells, mesh.points, C10, title='C10', ax=axes[0]); 
plotmesh(mesh.cells, mesh.points, k1, title='k1', ax=axes[1]); 
plotmesh(mesh.cells, mesh.points, k2, title='k2', ax=axes[2]); 
plotmesh(mesh.cells, mesh.points, np.ones_like(k1)*0.1, title='kappa', ax=axes[3]); 
plotmesh(mesh.cells, mesh.points, np.ones_like(k1)*0.0, title='theta', ax=axes[4]);

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, sigma, ax in zip(t_hist, node_x_hist_goh, F_hist_goh, sigma_hist_goh, axes):
    eps_xx = F[:,0,0]-1.0
    eps_yy = F[:,1,1]-1.0

    mps = np.maximum(eps_xx, eps_yy)
    strains.append(np.array([t*np.ones_like(eps_xx), eps_xx, eps_yy]))

    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 
strains = np.hstack(strains)

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = ff_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 3 # x, y, lmb
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])
nn_layers = [2*n_ff,20,20,2]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss, inp, get_params, opt_update, opt_state, key, nIter = 40000, print_freq=1000, batch_size=1000)


fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    eps_xx_pr, eps_yy_pr = ff_nn(aux, coord_2_strain_params).T
    mps_pr = np.maximum(eps_xx_pr, eps_yy_pr)

    plotmesh(mesh.cells, node_x, mps_pr, title='MPS Reconstructed using NN', ax=ax);
# Out:
# it 1000, train loss = 4.552647e-04
# it 2000, train loss = 1.566171e-04
# it 3000, train loss = 7.434798e-05
# it 4000, train loss = 4.089175e-05
# it 5000, train loss = 2.461869e-05
# it 6000, train loss = 1.576406e-05
# it 7000, train loss = 1.056844e-05
# it 8000, train loss = 7.390443e-06
# it 9000, train loss = 5.557759e-06
# it 10000, train loss = 4.451430e-06
# it 11000, train loss = 3.663215e-06
# it 12000, train loss = 3.173514e-06
# it 13000, train loss = 2.923376e-06
# it 14000, train loss = 2.613173e-06
# it 15000, train loss = 2.454183e-06
# it 16000, train loss = 2.359244e-06
# it 17000, train loss = 2.262937e-06
# it 18000, train loss = 2.248310e-06
# it 19000, train loss = 2.110778e-06
# it 20000, train loss = 2.096919e-06
# it 21000, train loss = 2.023673e-06
# it 22000, train loss = 1.950865e-06
# it 23000, train loss = 1.958156e-06
# it 24000, train loss = 1.833520e-06
# it 25000, train loss = 1.837241e-06
# it 26000, train loss = 1.805092e-06
# it 27000, train loss = 1.854180e-06
# it 28000, train loss = 1.710560e-06
# it 29000, train loss = 1.708005e-06
# it 30000, train loss = 1.746798e-06
# it 31000, train loss = 1.683680e-06
# it 32000, train loss = 1.661152e-06
# it 33000, train loss = 1.680929e-06
# it 34000, train loss = 1.567520e-06
# it 35000, train loss = 1.581546e-06
# it 36000, train loss = 1.614730e-06
# it 37000, train loss = 1.527949e-06
# it 38000, train loss = 1.604436e-06
# it 39000, train loss = 1.477266e-06
# it 40000, train loss = 1.423936e-06

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(sigma_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(sigma_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(sigma_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(sigma_hist_goh[:,bot_bd_elems,1,1], axis=1)
Fx = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Fy = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
eps_xx_mean = np.mean(F_hist_goh[:,:,0,0]-1.0, axis=1)
eps_yy_mean = np.mean(F_hist_goh[:,:,1,1]-1.0, axis=1)
# eps_xy_mean = np.mean(0.5*(F_hist_goh[:,:,0,1]+F_hist_goh[:,:,1,0]), axis=1)
sgmx_mean = Fx/len(rgt_bd_elems)
sgmy_mean = Fy/len(top_bd_elems)
lamb_sigma_m = np.array([eps_xx_mean+1.0, eps_yy_mean+1.0, sgmx_mean, sgmy_mean]).reshape([len(lmb_hist),-1]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_sig_all(params, lamb_sigma, key):
    model   = NODE_model_aniso(params)
    lambx   = lamb_sigma[:,0]
    lamby   = lamb_sigma[:,1]
    sgmx_gt  = lamb_sigma[:,2]
    sgmy_gt  = lamb_sigma[:,3]
    sgm = eval_Cauchy_aniso_vmap(lambx,lamby, model)
    sgmx_pr, sgmy_pr = sgm[:,0,0], sgm[:,1,1]
    return np.mean((sgmx_pr-sgmx_gt)**2+(sgmy_pr-sgmy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_sig_all, lamb_sigma_m, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.246291e-01
# it 2000, train loss = 7.905161e-02
# it 3000, train loss = 4.794076e-02
# it 4000, train loss = 3.353948e-02
# it 5000, train loss = 1.779893e-02
# it 6000, train loss = 5.948129e-05
# it 7000, train loss = 5.099887e-05
# it 8000, train loss = 4.434279e-05
# it 9000, train loss = 2.500415e-05
# it 10000, train loss = 1.185560e-05
# it 11000, train loss = 7.993011e-06
# it 12000, train loss = 7.708283e-06
# it 13000, train loss = 7.671238e-06
# it 14000, train loss = 7.634710e-06
# it 15000, train loss = 7.597667e-06
# it 16000, train loss = 7.558142e-06
# it 17000, train loss = 7.516088e-06
# it 18000, train loss = 7.470829e-06
# it 19000, train loss = 7.423881e-06
# it 20000, train loss = 7.378056e-06

# %%
mymodel = NODE_model_aniso(node_params)
sgm = eval_Cauchy_aniso_vmap(eps_xx_mean+1.0,eps_yy_mean+1.0, mymodel)
sgmx, sgmy = sgm[:,0,0], sgm[:,1,1]
print('gt sgmx & sgmy: ', sgmx_mean, sgmy_mean)
print('pr sgmx & sgmy: ', sgmx, sgmy)
# Out:
# gt sgmx & sgmy:  [0.37999 0.719   1.03082 1.32629] [0.36656 0.68755 0.97576 1.24078]
# pr sgmx & sgmy:  [0.37836 0.72172 1.02879 1.32685] [0.36514 0.69027 0.9735  1.24146]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 3.760391e-04
# it 2000, train loss = 9.789408e-05
# it 3000, train loss = 3.964199e-05
# it 4000, train loss = 1.912970e-05
# it 5000, train loss = 9.968079e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/circ_s100_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Fx, Fy, strains,
                 bd_X, lmb_hist, sigma_hist_goh, F_hist_goh, node_x_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/circ_s100_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Fx, Fy, strains, \
                 bd_X, lmb_hist, sigma_hist_goh, F_hist_goh, node_x_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
@jit
def loss(Lambda_params, X):
    div_x, div_y = divergence(Lambda_params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
    F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
    t = X[1] # a scalar
    fx = Fx[jnp.array(t, int)]
    fy = Fy[jnp.array(t, int)]
    return a1*(div_x**2 + div_y**2) + a2*((F_rgt-fx)**2 + (F_top-fy)**2 + (F_lft-fx)**2 + (F_bot-fy)**2)

lr = 5e-5
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

metric1 = lambda params, X:  bd_forces(params, X, bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, X, bd_X, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 10000, print_freq=1000, metric_fns=[metric1, metric2])

with open('params/circ_s100_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Fx, Fy, node_params, Lambda_params, val_loss, metrics], f)
# Out:
# it 1000, val loss = 7.682763e+00
# it 2000, val loss = 7.354529e+00
# it 3000, val loss = 7.488258e+00
# it 4000, val loss = 6.612275e+00
# it 5000, val loss = 9.768499e+00
# it 6000, val loss = 7.054600e+00
# it 7000, val loss = 8.310439e+00
# it 8000, val loss = 7.996390e+00
# it 9000, val loss = 8.933954e+00
# it 10000, val loss = 9.829582e+00

# %% [markdown]
# ## 3. Test

# %%
with open('params/circ_s100_post.npy', 'rb') as f:
    mesh, elem_X, strains, Fx, Fy, node_params, Lambda_params, val_loss, metrics = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
forces = []
div = []
for i in range(len(metrics)):
    forces.append(metrics[i][0])
    div.append(metrics[i][1])
forces = np.array(forces)
div = np.array(div)

fig, ax = plt.subplots(2,2,figsize=(10,8))
plt.subplots_adjust(hspace=0.3)
ax[0,0].plot(val_loss)
ax[0,1].plot(div[:,0], label='Divergence in x')
ax[0,1].plot(div[:,1], label='Divergence in y')

ax[1,0].plot(forces[:,0], label='right')
ax[1,1].plot(forces[:,1], label='top')
ax[1,0].plot(forces[:,2], label='left')
ax[1,1].plot(forces[:,3], label='bottom')

ax[1,0].axhline(Fx[-1], linestyle='--', label='Reaction force x')
ax[1,1].axhline(Fy[-1], linestyle='--', label='Reaction force y')

# ax[0,0].set(yscale='log')
ax[0,0].set(title='Validation loss = ' + str(val_loss[-1]), yscale = 'log')
ax[0,1].set(title='Divergence')
ax[1,0].set(title='Forces on right & left')
ax[1,1].set(title='Forces on top & bottom')
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()

# %%
# Stiffness across the domain
fig, axes = plt.subplots(1,4,figsize=(20,4))
for lmb, ax in zip(lmb_hist, axes):
    c_elem = []
    for x, y in elem_X:
        Lambda_inp = jnp.array([x,y]).reshape([-1,2])
        phi = ff_nn(Lambda_inp, Lambda_params).flatten()
        mymodel = NODE_w_unravel(phi)
        c_elem.append(eval_Cauchy_aniso(lmb, lmb, mymodel)[0,0])
    c_elem = np.array(c_elem)
    plotmesh(mesh.cells, mesh.points, c_elem, title='Stress at {}'.format(str(lmb)), ax=ax);

# %%
# Do the FEM with jax-fem instead
def NODE_PK1(u_grad, params, dim):
    theta = 0.0
    #Kinematics
    F_2D = u_grad + jnp.eye(dim)
    C_2D = F_2D.T @ F_2D
    Cinv_2D = jnp.linalg.inv(C_2D)
    detC_2D = jnp.linalg.det(C_2D)
    C33 = 1/detC_2D
    C = jnp.array([  [C_2D[0,0], C_2D[0,1], 0],\
                    [C_2D[1,0], C_2D[1,1], 0],\
                    [0,         0,       C33]])
    C2 = C @ C
    Cinv = jnp.linalg.inv(C)
    I1 = C[0,0] + C[1,1] + C[2,2]
    trC2 = C2[0,0] + C2[1,1] + C2[2,2]
    I2 = 0.5*(I1**2 - trC2)
    v0 = jnp.array([ jnp.cos(theta), jnp.sin(theta), 0])
    w0 = jnp.array([-jnp.sin(theta), jnp.cos(theta), 0])
    V0 = jnp.outer(v0, v0)
    W0 = jnp.outer(w0, w0)
    Iv = jnp.einsum('ij,ij',C,V0)
    Iw = jnp.einsum('ij,ij',C,W0)

    # Energy/Stress
    model = NODE_w_unravel(params)
    Psi1 = model.Psi1(I1,I2,Iv,Iw)
    Psi2 = model.Psi2(I1,I2,Iv,Iw)
    Psiv = model.Psiv(I1,I2,Iv,Iw)
    Psiw = model.Psiw(I1,I2,Iv,Iw)
    
    p = -C[2,2]*(2*Psi1 + 2*Psi2*(I1 - C[2,2]) + 2*Psiv*V0[2,2] + 2*Psiw*W0[2,2])
    S = p*Cinv + 2*Psi1*jnp.eye(3) + 2*Psi2*(I1*jnp.eye(3)-C) + 2*Psiv*V0 + 2*Psiw*W0
    S_2D = S[:2,:2]
    P_2D = F_2D @ S_2D
    return P_2D
NODE_vmap = vmap(NODE_PK1, in_axes=(0,0,None))
def NODE_sigma(u_grad, params, dim):
    F_2D = u_grad + jnp.eye(dim)
    P_2D = NODE_PK1(u_grad, params, dim)
    return P_2D @ F_2D.T
NODE_sigma_vmap = vmap(NODE_sigma, in_axes=(0,0,None))
class NODE_HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: NODE_PK1(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
sigma_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = NODE_HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    sigma = NODE_sigma_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    sigma_hist.append(sigma)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
sigma_hist = np.array(sigma_hist)
# Out:
# [12-06 11:44:41][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 11:44:41][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 11:44:41][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 11:44:42][DEBUG] jax_fem: Done pre-computations, took 0.39388108253479004 [s]
# [12-06 11:44:42][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 11:44:42][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 11:44:42][DEBUG] jax_fem: Start timing
# [12-06 11:44:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:45][DEBUG] jax_fem: Function split_and_compute_cell took 2.7074 seconds
# [12-06 11:44:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:45][DEBUG] jax_fem: Linear guess solve...
# [12-06 11:44:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:45][DEBUG] jax_fem: PETSc linear solve res = 0.007510655729380787
# [12-06 11:44:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0290 seconds
# [12-06 11:44:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:45][DEBUG] jax_fem: Before, res l_2 = 0.02771551917590942
# [12-06 11:44:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:45][DEBUG] jax_fem: PETSc linear solve res = 7.1645162236052536e-09
# [12-06 11:44:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0269 seconds
# [12-06 11:44:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:45][DEBUG] jax_fem: res l_2 = 0.006353427541398021
# [12-06 11:44:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:45][DEBUG] jax_fem: PETSc linear solve res = 2.2995095217864615e-09
# [12-06 11:44:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0260 seconds
# [12-06 11:44:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:45][DEBUG] jax_fem: res l_2 = 0.00014451449565232812
# [12-06 11:44:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:45][DEBUG] jax_fem: PETSc linear solve res = 1.730119061269583e-11
# [12-06 11:44:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0268 seconds
# [12-06 11:44:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:45][DEBUG] jax_fem: res l_2 = 4.776071181206187e-07
# [12-06 11:44:46][INFO] jax_fem: Solve took 3.7422780990600586 [s]
# [12-06 11:44:46][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [12-06 11:44:46][DEBUG] jax_fem: min of sol = 0.0
# [12-06 11:44:46][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 11:44:46][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 11:44:46][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 11:44:47][DEBUG] jax_fem: Done pre-computations, took 0.06290197372436523 [s]
# [12-06 11:44:47][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 11:44:47][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 11:44:47][DEBUG] jax_fem: Start timing
# [12-06 11:44:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 2.4570 seconds
# [12-06 11:44:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:49][DEBUG] jax_fem: Linear guess solve...
# [12-06 11:44:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:49][DEBUG] jax_fem: PETSc linear solve res = 0.015021311458761575
# [12-06 11:44:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0276 seconds
# [12-06 11:44:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:49][DEBUG] jax_fem: Before, res l_2 = 0.0809368608754052
# [12-06 11:44:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:49][DEBUG] jax_fem: PETSc linear solve res = 1.5921523949208793e-07
# [12-06 11:44:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0268 seconds
# [12-06 11:44:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:49][DEBUG] jax_fem: res l_2 = 0.015004540745822746
# [12-06 11:44:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:49][DEBUG] jax_fem: PETSc linear solve res = 2.2359719203758146e-08
# [12-06 11:44:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0253 seconds
# [12-06 11:44:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:49][DEBUG] jax_fem: res l_2 = 0.0007275174445715631
# [12-06 11:44:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:49][DEBUG] jax_fem: PETSc linear solve res = 9.43660700611151e-11
# [12-06 11:44:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [12-06 11:44:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:49][DEBUG] jax_fem: res l_2 = 1.7901041419191867e-06
# [12-06 11:44:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:49][DEBUG] jax_fem: PETSc linear solve res = 3.1385881807202624e-13
# [12-06 11:44:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0282 seconds
# [12-06 11:44:50][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:50][DEBUG] jax_fem: res l_2 = 1.4339515944010047e-11
# [12-06 11:44:50][INFO] jax_fem: Solve took 2.946180820465088 [s]
# [12-06 11:44:50][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [12-06 11:44:50][DEBUG] jax_fem: min of sol = 0.0
# [12-06 11:44:50][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 11:44:50][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 11:44:50][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 11:44:50][DEBUG] jax_fem: Done pre-computations, took 0.04497718811035156 [s]
# [12-06 11:44:50][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 11:44:50][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 11:44:50][DEBUG] jax_fem: Start timing
# [12-06 11:44:50][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 2.3965 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: Linear guess solve...
# [12-06 11:44:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:52][DEBUG] jax_fem: PETSc linear solve res = 0.02816564246574703
# [12-06 11:44:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: Before, res l_2 = 0.24593656605524417
# [12-06 11:44:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:52][DEBUG] jax_fem: PETSc linear solve res = 6.546530681870198e-08
# [12-06 11:44:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0279 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: res l_2 = 0.0627543297254207
# [12-06 11:44:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:52][DEBUG] jax_fem: PETSc linear solve res = 6.56044938791247e-09
# [12-06 11:44:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0259 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: res l_2 = 0.009630902540148567
# [12-06 11:44:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:52][DEBUG] jax_fem: PETSc linear solve res = 7.735424922809563e-10
# [12-06 11:44:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0259 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: res l_2 = 0.0001907440634610557
# [12-06 11:44:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:52][DEBUG] jax_fem: PETSc linear solve res = 9.606091583106607e-12
# [12-06 11:44:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0263 seconds
# [12-06 11:44:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:52][DEBUG] jax_fem: res l_2 = 1.5322150855882063e-07
# [12-06 11:44:52][INFO] jax_fem: Solve took 2.884437084197998 [s]
# [12-06 11:44:52][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [12-06 11:44:52][DEBUG] jax_fem: min of sol = 0.0
# [12-06 11:44:53][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [12-06 11:44:53][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [12-06 11:44:53][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [12-06 11:44:53][DEBUG] jax_fem: Done pre-computations, took 0.046378135681152344 [s]
# [12-06 11:44:53][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [12-06 11:44:53][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [12-06 11:44:53][DEBUG] jax_fem: Start timing
# [12-06 11:44:53][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:55][DEBUG] jax_fem: Function split_and_compute_cell took 2.4508 seconds
# [12-06 11:44:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:55][DEBUG] jax_fem: Linear guess solve...
# [12-06 11:44:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:55][DEBUG] jax_fem: PETSc linear solve res = 0.037110612778546784
# [12-06 11:44:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0268 seconds
# [12-06 11:44:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:55][DEBUG] jax_fem: Before, res l_2 = 0.297869410000591
# [12-06 11:44:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:55][DEBUG] jax_fem: PETSc linear solve res = 9.899548165753428e-08
# [12-06 11:44:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0261 seconds
# [12-06 11:44:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:55][DEBUG] jax_fem: res l_2 = 0.07583445386010378
# [12-06 11:44:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:55][DEBUG] jax_fem: PETSc linear solve res = 4.5053711768647564e-08
# [12-06 11:44:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [12-06 11:44:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:55][DEBUG] jax_fem: res l_2 = 0.007164459120090935
# [12-06 11:44:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:55][DEBUG] jax_fem: PETSc linear solve res = 4.018054532729166e-09
# [12-06 11:44:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [12-06 11:44:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:55][DEBUG] jax_fem: res l_2 = 6.410582329453145e-05
# [12-06 11:44:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [12-06 11:44:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [12-06 11:44:55][DEBUG] jax_fem: PETSc linear solve res = 3.2064387192856597e-12
# [12-06 11:44:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [12-06 11:44:56][DEBUG] jax_fem: Function split_and_compute_cell took 0.0322 seconds
# [12-06 11:44:56][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [12-06 11:44:56][DEBUG] jax_fem: res l_2 = 6.823112708700799e-09
# [12-06 11:44:56][INFO] jax_fem: Solve took 2.9519460201263428 [s]
# [12-06 11:44:56][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [12-06 11:44:56][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
for t, node_x, F, sigma, ax in zip(t_hist, node_x_hist, F_hist, sigma_hist, axes):
    eps_xx = F[:,0,0]-1.0
    eps_yy = F[:,1,1]-1.0

    mps = np.maximum(eps_xx, eps_yy)
    strains.append(np.array([t*np.ones_like(eps_xx), eps_xx, eps_yy]))

    plotmesh(mesh.cells, node_x, mps, title='Max. Princip. Strain [-]', ax=ax); 
strains = np.hstack(strains)

# %%
from matplotlib.cm import get_cmap
cmap = get_cmap('viridis')
# Out:
# /var/folders/1f/rngrmz8x3lsd60h6dd90ncwm0000gr/T/ipykernel_90381/2277699238.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')

# %%
# Stiffness across the domain
fig, axes = plt.subplots(3,4,figsize=(20,12))
sgm_line_goh = []
sgm_line_node = []
for lmb, goh_ax, node_ax in zip(lmb_hist, axes[0], axes[1]):
    #Plot GOH contours
    sgm_list = []
    for x, y in node_X:
        X_C10    = interp2d(x, y, pts_x, pts_y,   C10.reshape([nrow,ncol]))
        X_k1     = interp2d(x, y, pts_x, pts_y,    k1.reshape([nrow,ncol]))
        X_k2     = interp2d(x, y, pts_x, pts_y,    k2.reshape([nrow,ncol]))
        X_kappa  = 0.1
        mymodel = GOH_model([X_C10, X_k1, X_k2, X_kappa])
        mymodel.theta=0.0
        sgm = eval_Cauchy_aniso(lmb, lmb, mymodel)[0,0]
        sgm_list.append(sgm)
    sgm_list = np.array(sgm_list)
    c_elem = 0.25*(sgm_list[elements[:,0]] + 
                   sgm_list[elements[:,1]] + 
                   sgm_list[elements[:,2]] + 
                   sgm_list[elements[:,3]])
    plotmesh(elements, node_X, c_elem, title='GOH stress at {}'.format(str(lmb)), ax=goh_ax); 
    sgm_line_goh.append(sgm_list[210:220])


    #Plot NODE contours
    sgm_list = []
    for x, y in node_X:
        Lambda_inp = jnp.array([x,y]).reshape([-1,2])
        phi = ff_nn(Lambda_inp, Lambda_params).flatten()
        mymodel = NODE_w_unravel(phi)
        sgm = eval_Cauchy_aniso(lmb, lmb, mymodel)[0,0]
        sgm_list.append(sgm)
    sgm_list = np.array(sgm_list)
    c_elem = 0.25*(sgm_list[elements[:,0]] + 
                   sgm_list[elements[:,1]] + 
                   sgm_list[elements[:,2]] + 
                   sgm_list[elements[:,3]])
    plotmesh(elements, node_X, c_elem, title='Pred. stress at {}'.format(str(lmb)), ax=node_ax); 
    sgm_line_node.append(sgm_list[210:220])
    for i, (x, y) in enumerate(node_X[210:220]):
        color = cmap(i / (len(node_X[210:220]) - 1))
        node_ax.plot(x, y, '.', markersize=10, color=color)


# line plots
sgm_line_goh = np.array(sgm_line_goh).T
for i, sgm in enumerate(sgm_line_goh):
    color = cmap(i / (len(node_X[210:220]) - 1))
    axes[2,0].plot([1]+lmb_hist, np.insert(sgm,0,0), marker='.', color=color)
axes[2,0].set(xlabel='$\lambda$', ylabel='$\sigma_{xx}$', title='Ground truth'); 


sgm_line_node = np.array(sgm_line_node).T
for i, sgm in enumerate(sgm_line_node):
    color = cmap(i / (len(node_X[210:220]) - 1))
    axes[2,1].plot([1]+lmb_hist, np.insert(sgm,0,0), marker='.', color=color)
axes[2,1].set(xlabel='$\lambda$', ylabel='$\sigma_{xx}$', title='Predictions'); 
axes[2,1].set_xlim(axes[2,0].get_xlim())
axes[2,1].set_ylim(axes[2,0].get_ylim())
# Out:
# (-0.06887870601465894, 1.4464528263078378)

# %% [markdown]
# Comments:
# 1. Look into nonlinearity of GOH
# 2. Look into virtual fields method
# 3. Make the circle smaller and smaller to see what is the limit of detection.
