# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/+.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [05-23 01:56:32][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:56:32][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:56:32][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:56:33][DEBUG] jax_fem: Done pre-computations, took 0.9565000534057617 [s]
# [05-23 01:56:33][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:56:35][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:56:35][DEBUG] jax_fem: Start timing
# [05-23 01:56:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.9087 seconds
# [05-23 01:56:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:37][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:56:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:37][DEBUG] jax_fem: PETSc linear solve res = 2.5612274469648145e-06
# [05-23 01:56:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0242 seconds
# [05-23 01:56:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:37][DEBUG] jax_fem: Before, res l_2 = 0.0023376686078116844
# [05-23 01:56:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:37][DEBUG] jax_fem: PETSc linear solve res = 5.500733564982614e-09
# [05-23 01:56:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0277 seconds
# [05-23 01:56:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:37][DEBUG] jax_fem: res l_2 = 4.917586780291496e-06
# [05-23 01:56:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:37][DEBUG] jax_fem: PETSc linear solve res = 9.885335317976672e-12
# [05-23 01:56:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [05-23 01:56:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:37][DEBUG] jax_fem: res l_2 = 3.925371732503502e-11
# [05-23 01:56:37][INFO] jax_fem: Solve took 1.832669973373413 [s]
# [05-23 01:56:37][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [05-23 01:56:37][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:56:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:56:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:56:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:56:39][DEBUG] jax_fem: Done pre-computations, took 0.4967060089111328 [s]
# [05-23 01:56:39][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:56:41][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:56:41][DEBUG] jax_fem: Start timing
# [05-23 01:56:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.6044 seconds
# [05-23 01:56:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:42][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:56:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:42][DEBUG] jax_fem: PETSc linear solve res = 5.122454893929629e-06
# [05-23 01:56:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0233 seconds
# [05-23 01:56:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:42][DEBUG] jax_fem: Before, res l_2 = 0.00731532976651254
# [05-23 01:56:42][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:42][DEBUG] jax_fem: PETSc linear solve res = 1.3257896258046832e-08
# [05-23 01:56:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0230 seconds
# [05-23 01:56:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:42][DEBUG] jax_fem: res l_2 = 4.5277740236916895e-05
# [05-23 01:56:42][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:42][DEBUG] jax_fem: PETSc linear solve res = 5.2602211343289675e-11
# [05-23 01:56:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0229 seconds
# [05-23 01:56:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:42][DEBUG] jax_fem: res l_2 = 3.2671087112045273e-09
# [05-23 01:56:42][INFO] jax_fem: Solve took 0.8064320087432861 [s]
# [05-23 01:56:42][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [05-23 01:56:42][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:56:42][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:56:42][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:56:42][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:56:42][DEBUG] jax_fem: Done pre-computations, took 0.5487439632415771 [s]
# [05-23 01:56:42][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:56:45][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:56:45][DEBUG] jax_fem: Start timing
# [05-23 01:56:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.5996 seconds
# [05-23 01:56:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:45][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:56:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:45][DEBUG] jax_fem: PETSc linear solve res = 7.683682340576242e-06
# [05-23 01:56:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0228 seconds
# [05-23 01:56:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:45][DEBUG] jax_fem: Before, res l_2 = 0.012742527962084678
# [05-23 01:56:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:45][DEBUG] jax_fem: PETSc linear solve res = 7.750628236399032e-09
# [05-23 01:56:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0228 seconds
# [05-23 01:56:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:45][DEBUG] jax_fem: res l_2 = 0.0001283114803667229
# [05-23 01:56:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:45][DEBUG] jax_fem: PETSc linear solve res = 2.548807424746013e-10
# [05-23 01:56:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0247 seconds
# [05-23 01:56:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:46][DEBUG] jax_fem: res l_2 = 2.5714241006700436e-08
# [05-23 01:56:46][INFO] jax_fem: Solve took 0.8043322563171387 [s]
# [05-23 01:56:46][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [05-23 01:56:46][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:56:46][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:56:46][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:56:46][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:56:46][DEBUG] jax_fem: Done pre-computations, took 0.4957399368286133 [s]
# [05-23 01:56:46][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:56:48][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:56:48][DEBUG] jax_fem: Start timing
# [05-23 01:56:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.6049 seconds
# [05-23 01:56:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:49][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:56:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:49][DEBUG] jax_fem: PETSc linear solve res = 1.0244909787894486e-05
# [05-23 01:56:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0236 seconds
# [05-23 01:56:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:49][DEBUG] jax_fem: Before, res l_2 = 0.0175277092219987
# [05-23 01:56:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:49][DEBUG] jax_fem: PETSc linear solve res = 1.3033021711670174e-08
# [05-23 01:56:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [05-23 01:56:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:49][DEBUG] jax_fem: res l_2 = 0.00022652070360709356
# [05-23 01:56:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:56:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:56:49][DEBUG] jax_fem: PETSc linear solve res = 4.71922937133958e-10
# [05-23 01:56:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:56:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0232 seconds
# [05-23 01:56:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:56:49][DEBUG] jax_fem: res l_2 = 7.213317567700192e-08
# [05-23 01:56:49][INFO] jax_fem: Solve took 0.8120241165161133 [s]
# [05-23 01:56:49][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [05-23 01:56:49][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 40 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])#*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 1.911311e-04
# it 2000, train loss = 6.334370e-05
# it 3000, train loss = 3.352036e-05
# it 4000, train loss = 2.112816e-05
# it 5000, train loss = 1.512795e-05
# it 6000, train loss = 1.213499e-05
# it 7000, train loss = 1.029178e-05
# it 8000, train loss = 9.366820e-06
# it 9000, train loss = 8.945271e-06
# it 10000, train loss = 7.555657e-06
# it 11000, train loss = 7.698173e-06
# it 12000, train loss = 7.664809e-06
# it 13000, train loss = 7.212871e-06
# it 14000, train loss = 6.676285e-06
# it 15000, train loss = 6.739597e-06
# it 16000, train loss = 6.043844e-06
# it 17000, train loss = 6.406874e-06
# it 18000, train loss = 7.102755e-06
# it 19000, train loss = 7.126688e-06
# it 20000, train loss = 5.665134e-06
# it 21000, train loss = 6.083632e-06
# it 22000, train loss = 5.488258e-06
# it 23000, train loss = 5.643988e-06
# it 24000, train loss = 5.298707e-06
# it 25000, train loss = 5.023956e-06
# it 26000, train loss = 5.639236e-06
# it 27000, train loss = 4.683192e-06
# it 28000, train loss = 5.628144e-06
# it 29000, train loss = 5.516535e-06
# it 30000, train loss = 5.093548e-06
# it 31000, train loss = 5.685607e-06
# it 32000, train loss = 4.858577e-06
# it 33000, train loss = 5.217058e-06
# it 34000, train loss = 5.328365e-06
# it 35000, train loss = 5.140202e-06
# it 36000, train loss = 4.725835e-06
# it 37000, train loss = 4.702447e-06
# it 38000, train loss = 4.637000e-06
# it 39000, train loss = 4.440303e-06
# it 40000, train loss = 4.679855e-06
# it 41000, train loss = 4.832390e-06
# it 42000, train loss = 5.277004e-06
# it 43000, train loss = 5.172033e-06
# it 44000, train loss = 4.731497e-06
# it 45000, train loss = 4.853637e-06
# it 46000, train loss = 4.778261e-06
# it 47000, train loss = 4.497212e-06
# it 48000, train loss = 4.993120e-06
# it 49000, train loss = 4.177761e-06
# it 50000, train loss = 4.588438e-06
# it 51000, train loss = 3.975191e-06
# it 52000, train loss = 4.412753e-06
# it 53000, train loss = 4.749662e-06
# it 54000, train loss = 4.711289e-06
# it 55000, train loss = 4.160880e-06
# it 56000, train loss = 3.577811e-06
# it 57000, train loss = 4.082497e-06
# it 58000, train loss = 3.553486e-06
# it 59000, train loss = 3.864619e-06
# it 60000, train loss = 3.292719e-06
# it 61000, train loss = 4.929288e-06
# it 62000, train loss = 3.837513e-06
# it 63000, train loss = 4.120103e-06
# it 64000, train loss = 3.667816e-06
# it 65000, train loss = 3.775156e-06
# it 66000, train loss = 3.403996e-06
# it 67000, train loss = 3.884446e-06
# it 68000, train loss = 2.942392e-06
# it 69000, train loss = 3.080138e-06
# it 70000, train loss = 3.394441e-06
# it 71000, train loss = 3.911410e-06
# it 72000, train loss = 3.647300e-06
# it 73000, train loss = 3.293705e-06
# it 74000, train loss = 3.366273e-06
# it 75000, train loss = 3.387503e-06
# it 76000, train loss = 3.182390e-06
# it 77000, train loss = 2.442212e-06
# it 78000, train loss = 2.957694e-06
# it 79000, train loss = 2.805497e-06
# it 80000, train loss = 2.595615e-06
# it 81000, train loss = 3.061943e-06
# it 82000, train loss = 3.395145e-06
# it 83000, train loss = 2.838294e-06
# it 84000, train loss = 3.081097e-06
# it 85000, train loss = 2.510103e-06
# it 86000, train loss = 2.952214e-06
# it 87000, train loss = 3.163436e-06
# it 88000, train loss = 2.690843e-06
# it 89000, train loss = 2.454089e-06
# it 90000, train loss = 2.504818e-06
# it 91000, train loss = 2.576931e-06
# it 92000, train loss = 2.614690e-06
# it 93000, train loss = 2.352638e-06
# it 94000, train loss = 2.579319e-06
# it 95000, train loss = 2.439865e-06
# it 96000, train loss = 2.719315e-06
# it 97000, train loss = 2.494018e-06
# it 98000, train loss = 2.201719e-06
# it 99000, train loss = 2.554502e-06
# it 100000, train loss = 2.264871e-06

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 9.918790e-02
# it 2000, train loss = 5.954728e-02
# it 3000, train loss = 3.491997e-02
# it 4000, train loss = 2.365389e-02
# it 5000, train loss = 2.642999e-03
# it 6000, train loss = 3.972683e-05
# it 7000, train loss = 3.591507e-05
# it 8000, train loss = 2.792894e-05
# it 9000, train loss = 1.469153e-05
# it 10000, train loss = 7.814744e-06
# it 11000, train loss = 6.361208e-06
# it 12000, train loss = 6.287755e-06
# it 13000, train loss = 6.266718e-06
# it 14000, train loss = 6.240660e-06
# it 15000, train loss = 6.208286e-06
# it 16000, train loss = 6.254813e-06
# it 17000, train loss = 6.123093e-06
# it 18000, train loss = 6.072194e-06
# it 19000, train loss = 6.019173e-06
# it 20000, train loss = 5.968059e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.3652  0.66258 0.91265 1.12992] [0.35262 0.63445 0.86564 1.06023]
# pr P_xx & P_yy:  [0.36383 0.66501 0.91073 1.13048] [0.35138 0.63687 0.86358 1.06086]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.572815e-04
# it 2000, train loss = 4.199491e-05
# it 3000, train loss = 1.713263e-05
# it 4000, train loss = 8.296303e-06
# it 5000, train loss = 4.408509e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/+_sharp_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/+_sharp_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 40000, print_freq=1000, batch_size=1000)

with open('params/+_sharp_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-05-23 02:05:04.503620: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-05-23 02:05:41.292796: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m36.794555s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 4.962068e+00
# it 1001, val loss = 4.547845e+00
# it 2001, val loss = 3.100579e+00
# it 3001, val loss = 5.206156e+00
# it 4001, val loss = 8.196306e+00
# it 5001, val loss = 3.201991e+00
# it 6001, val loss = 2.508226e+00
# it 7001, val loss = 4.930336e-01
# it 8001, val loss = 5.372991e-01
# it 9001, val loss = 1.299516e+00
# it 10001, val loss = 4.139591e-01
# it 11001, val loss = 2.071059e+00
# it 12001, val loss = 1.526432e+00
# it 13001, val loss = 2.123823e+00
# it 14001, val loss = 3.831570e-01
# it 15001, val loss = 1.543908e+00
# it 16001, val loss = 3.258006e+00
# it 17001, val loss = 3.061828e-01
# it 18001, val loss = 9.826336e-01
# it 19001, val loss = 3.705632e+00
# it 20001, val loss = 1.382295e+00
# it 21001, val loss = 1.478938e+00
# it 22001, val loss = 1.409054e+00
# it 23001, val loss = 6.314469e-01
# it 24001, val loss = 4.478031e-01
# it 25001, val loss = 5.630069e-01
# it 26001, val loss = 7.601784e-01
# it 27001, val loss = 6.833485e-01
# it 28001, val loss = 1.301005e+00
# it 29001, val loss = 1.077955e+00
# it 30001, val loss = 8.444878e-01
# it 31001, val loss = 5.717338e-01
# it 32001, val loss = 2.579669e-01
# it 33001, val loss = 1.363178e+00
# it 34001, val loss = 8.760492e-01
# it 35001, val loss = 9.200086e-01
# it 36001, val loss = 3.954204e-01
# it 37001, val loss = 1.144851e+00
# it 38001, val loss = 5.259725e-01
# it 39001, val loss = 4.640540e-01

# %% [markdown]
# ## 3. Test

# %%
with open('params/+_sharp_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
elem_X = mesh.points[mesh.cells].mean(1)


params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [05-23 08:59:50][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 08:59:50][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 08:59:50][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 08:59:51][DEBUG] jax_fem: Done pre-computations, took 0.3985018730163574 [s]
# [05-23 08:59:51][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 08:59:51][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 08:59:51][DEBUG] jax_fem: Start timing
# [05-23 08:59:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:54][DEBUG] jax_fem: Function split_and_compute_cell took 2.7246 seconds
# [05-23 08:59:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:54][DEBUG] jax_fem: Linear guess solve...
# [05-23 08:59:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:54][DEBUG] jax_fem: PETSc linear solve res = 0.0006671793099291086
# [05-23 08:59:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0317 seconds
# [05-23 08:59:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:54][DEBUG] jax_fem: Before, res l_2 = 0.062264995769888254
# [05-23 08:59:54][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:54][DEBUG] jax_fem: PETSc linear solve res = 2.359331332720782e-07
# [05-23 08:59:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0302 seconds
# [05-23 08:59:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:54][DEBUG] jax_fem: res l_2 = 0.011078328399337848
# [05-23 08:59:54][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:54][DEBUG] jax_fem: PETSc linear solve res = 3.758035038879125e-09
# [05-23 08:59:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0285 seconds
# [05-23 08:59:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:54][DEBUG] jax_fem: res l_2 = 0.001411036521806152
# [05-23 08:59:54][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:54][DEBUG] jax_fem: PETSc linear solve res = 6.62619009926535e-10
# [05-23 08:59:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0306 seconds
# [05-23 08:59:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:55][DEBUG] jax_fem: res l_2 = 6.260443085929345e-05
# [05-23 08:59:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:55][DEBUG] jax_fem: PETSc linear solve res = 8.757541654871666e-13
# [05-23 08:59:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0297 seconds
# [05-23 08:59:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:55][DEBUG] jax_fem: res l_2 = 1.517137329602759e-07
# [05-23 08:59:55][INFO] jax_fem: Solve took 3.6987099647521973 [s]
# [05-23 08:59:55][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [05-23 08:59:55][DEBUG] jax_fem: min of sol = 0.0
# [05-23 08:59:55][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 08:59:55][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 08:59:55][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 08:59:55][DEBUG] jax_fem: Done pre-computations, took 0.04832100868225098 [s]
# [05-23 08:59:55][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 08:59:55][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 08:59:55][DEBUG] jax_fem: Start timing
# [05-23 08:59:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 2.4035 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: Linear guess solve...
# [05-23 08:59:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:58][DEBUG] jax_fem: PETSc linear solve res = 0.0013343586198582172
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0302 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: Before, res l_2 = 0.1574763893190295
# [05-23 08:59:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:58][DEBUG] jax_fem: PETSc linear solve res = 5.896381024166109e-08
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: res l_2 = 0.03399860091198871
# [05-23 08:59:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:58][DEBUG] jax_fem: PETSc linear solve res = 2.3258240910308955e-08
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0290 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: res l_2 = 0.002501947287968634
# [05-23 08:59:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:58][DEBUG] jax_fem: PETSc linear solve res = 4.001244329007125e-09
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0294 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: res l_2 = 1.548989710401254e-05
# [05-23 08:59:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 08:59:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 08:59:58][DEBUG] jax_fem: PETSc linear solve res = 3.2618907061815166e-12
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 08:59:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0295 seconds
# [05-23 08:59:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 08:59:58][DEBUG] jax_fem: res l_2 = 9.414080785624115e-10
# [05-23 08:59:58][INFO] jax_fem: Solve took 2.784487009048462 [s]
# [05-23 08:59:58][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [05-23 08:59:58][DEBUG] jax_fem: min of sol = 0.0
# [05-23 08:59:58][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 08:59:58][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 08:59:58][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 08:59:58][DEBUG] jax_fem: Done pre-computations, took 0.04641890525817871 [s]
# [05-23 08:59:58][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 08:59:58][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 08:59:58][DEBUG] jax_fem: Start timing
# [05-23 08:59:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 2.4124 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:01][DEBUG] jax_fem: PETSc linear solve res = 0.002748067527620822
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0338 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: Before, res l_2 = 0.2970727795951071
# [05-23 09:00:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:01][DEBUG] jax_fem: PETSc linear solve res = 1.5471087611221e-07
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: res l_2 = 0.09333914700218246
# [05-23 09:00:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:01][DEBUG] jax_fem: PETSc linear solve res = 2.3268976164132439e-07
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0279 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: res l_2 = 0.009693886216943825
# [05-23 09:00:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:01][DEBUG] jax_fem: PETSc linear solve res = 6.690553248864807e-09
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0285 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: res l_2 = 9.647838963304852e-05
# [05-23 09:00:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:01][DEBUG] jax_fem: PETSc linear solve res = 4.7281201847747676e-11
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [05-23 09:00:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:01][DEBUG] jax_fem: res l_2 = 8.360388055629888e-09
# [05-23 09:00:01][INFO] jax_fem: Solve took 2.812376022338867 [s]
# [05-23 09:00:01][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [05-23 09:00:01][DEBUG] jax_fem: min of sol = 0.0
# [05-23 09:00:01][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:00:01][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:00:01][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:00:01][DEBUG] jax_fem: Done pre-computations, took 0.044467926025390625 [s]
# [05-23 09:00:01][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:00:01][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:00:01][DEBUG] jax_fem: Start timing
# [05-23 09:00:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 2.5488 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 0.0027850880170527327
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: Before, res l_2 = 1.0354264712597292
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 1.6071723304952926e-06
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0285 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 0.43768727173868516
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 1.7248144375902867e-07
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 0.22303231825310652
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 7.200036754066108e-08
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0297 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 0.06007199549434968
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 4.0329085691527254e-08
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0292 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 0.0032286338083125006
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 1.5847180148649862e-10
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 7.100149571019158e-06
# [05-23 09:00:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:04][DEBUG] jax_fem: PETSc linear solve res = 7.899711876494854e-13
# [05-23 09:00:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0294 seconds
# [05-23 09:00:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:04][DEBUG] jax_fem: res l_2 = 4.338336251850014e-11
# [05-23 09:00:04][INFO] jax_fem: Solve took 3.024967908859253 [s]
# [05-23 09:00:04][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [05-23 09:00:04][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
