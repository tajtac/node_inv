# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/-.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [05-23 01:57:57][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:57:57][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:57:57][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:57:58][DEBUG] jax_fem: Done pre-computations, took 1.0598278045654297 [s]
# [05-23 01:57:58][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:58:00][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:58:00][DEBUG] jax_fem: Start timing
# [05-23 01:58:00][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.9522 seconds
# [05-23 01:58:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:02][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:58:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:02][DEBUG] jax_fem: PETSc linear solve res = 1.3778294502489666e-06
# [05-23 01:58:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0242 seconds
# [05-23 01:58:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:02][DEBUG] jax_fem: Before, res l_2 = 0.001653965924100335
# [05-23 01:58:02][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:02][DEBUG] jax_fem: PETSc linear solve res = 1.7036769154899697e-09
# [05-23 01:58:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0239 seconds
# [05-23 01:58:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:02][DEBUG] jax_fem: res l_2 = 3.902815989748736e-06
# [05-23 01:58:02][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:02][DEBUG] jax_fem: PETSc linear solve res = 3.3431552053165896e-12
# [05-23 01:58:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0241 seconds
# [05-23 01:58:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:02][DEBUG] jax_fem: res l_2 = 3.0217215461595353e-11
# [05-23 01:58:02][INFO] jax_fem: Solve took 1.9023497104644775 [s]
# [05-23 01:58:02][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [05-23 01:58:02][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:58:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:58:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:58:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:58:04][DEBUG] jax_fem: Done pre-computations, took 0.639376163482666 [s]
# [05-23 01:58:04][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:58:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:58:06][DEBUG] jax_fem: Start timing
# [05-23 01:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.6983 seconds
# [05-23 01:58:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:07][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:58:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:07][DEBUG] jax_fem: PETSc linear solve res = 2.755658900497933e-06
# [05-23 01:58:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0242 seconds
# [05-23 01:58:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:07][DEBUG] jax_fem: Before, res l_2 = 0.005137807424237656
# [05-23 01:58:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:07][DEBUG] jax_fem: PETSc linear solve res = 1.3699700512889988e-08
# [05-23 01:58:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0263 seconds
# [05-23 01:58:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:07][DEBUG] jax_fem: res l_2 = 3.585366939261593e-05
# [05-23 01:58:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:07][DEBUG] jax_fem: PETSc linear solve res = 7.502054583732571e-11
# [05-23 01:58:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0244 seconds
# [05-23 01:58:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:07][DEBUG] jax_fem: res l_2 = 2.474026234454011e-09
# [05-23 01:58:07][INFO] jax_fem: Solve took 0.9149861335754395 [s]
# [05-23 01:58:07][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [05-23 01:58:07][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:58:07][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:58:07][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:58:07][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:58:08][DEBUG] jax_fem: Done pre-computations, took 0.5287618637084961 [s]
# [05-23 01:58:08][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:58:10][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:58:10][DEBUG] jax_fem: Start timing
# [05-23 01:58:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.6009 seconds
# [05-23 01:58:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:10][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:58:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:10][DEBUG] jax_fem: PETSc linear solve res = 4.133488349862558e-06
# [05-23 01:58:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0236 seconds
# [05-23 01:58:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:10][DEBUG] jax_fem: Before, res l_2 = 0.009059790522858293
# [05-23 01:58:10][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:10][DEBUG] jax_fem: PETSc linear solve res = 2.2208011119561122e-08
# [05-23 01:58:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0233 seconds
# [05-23 01:58:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:11][DEBUG] jax_fem: res l_2 = 0.00010011290442827215
# [05-23 01:58:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:11][DEBUG] jax_fem: PETSc linear solve res = 2.2852446359954948e-10
# [05-23 01:58:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0240 seconds
# [05-23 01:58:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:11][DEBUG] jax_fem: res l_2 = 1.7877703964744276e-08
# [05-23 01:58:11][INFO] jax_fem: Solve took 0.8089768886566162 [s]
# [05-23 01:58:11][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [05-23 01:58:11][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:58:11][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:58:11][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:58:11][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:58:11][DEBUG] jax_fem: Done pre-computations, took 0.4837031364440918 [s]
# [05-23 01:58:11][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:58:13][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:58:13][DEBUG] jax_fem: Start timing
# [05-23 01:58:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.6207 seconds
# [05-23 01:58:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:14][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:58:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:14][DEBUG] jax_fem: PETSc linear solve res = 5.511317802694127e-06
# [05-23 01:58:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0246 seconds
# [05-23 01:58:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:14][DEBUG] jax_fem: Before, res l_2 = 0.012751030240295813
# [05-23 01:58:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:14][DEBUG] jax_fem: PETSc linear solve res = 2.627601871662156e-08
# [05-23 01:58:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [05-23 01:58:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:14][DEBUG] jax_fem: res l_2 = 0.00016910602505778975
# [05-23 01:58:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:58:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:58:14][DEBUG] jax_fem: PETSc linear solve res = 3.579224496582864e-10
# [05-23 01:58:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:58:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0253 seconds
# [05-23 01:58:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:58:14][DEBUG] jax_fem: res l_2 = 4.533860812638516e-08
# [05-23 01:58:14][INFO] jax_fem: Solve took 0.8344800472259521 [s]
# [05-23 01:58:14][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [05-23 01:58:14][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 40 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])#*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 1.614143e-04
# it 2000, train loss = 5.275246e-05
# it 3000, train loss = 2.592432e-05
# it 4000, train loss = 1.684239e-05
# it 5000, train loss = 1.040682e-05
# it 6000, train loss = 6.990466e-06
# it 7000, train loss = 5.312056e-06
# it 8000, train loss = 5.440879e-06
# it 9000, train loss = 4.322075e-06
# it 10000, train loss = 4.580362e-06
# it 11000, train loss = 3.505985e-06
# it 12000, train loss = 3.257157e-06
# it 13000, train loss = 3.333337e-06
# it 14000, train loss = 4.727578e-06
# it 15000, train loss = 2.549317e-06
# it 16000, train loss = 2.849566e-06
# it 17000, train loss = 3.295147e-06
# it 18000, train loss = 3.156604e-06
# it 19000, train loss = 3.238921e-06
# it 20000, train loss = 2.406257e-06
# it 21000, train loss = 2.773331e-06
# it 22000, train loss = 2.516126e-06
# it 23000, train loss = 2.582241e-06
# it 24000, train loss = 2.355781e-06
# it 25000, train loss = 2.591982e-06
# it 26000, train loss = 2.477335e-06
# it 27000, train loss = 2.378858e-06
# it 28000, train loss = 2.702004e-06
# it 29000, train loss = 2.457142e-06
# it 30000, train loss = 1.814851e-06
# it 31000, train loss = 2.995272e-06
# it 32000, train loss = 1.858715e-06
# it 33000, train loss = 1.846614e-06
# it 34000, train loss = 1.688246e-06
# it 35000, train loss = 1.808009e-06
# it 36000, train loss = 1.781381e-06
# it 37000, train loss = 1.494910e-06
# it 38000, train loss = 1.655350e-06
# it 39000, train loss = 2.061711e-06
# it 40000, train loss = 1.861672e-06
# it 41000, train loss = 1.669415e-06
# it 42000, train loss = 1.615010e-06
# it 43000, train loss = 1.672195e-06
# it 44000, train loss = 1.722268e-06
# it 45000, train loss = 1.454837e-06
# it 46000, train loss = 1.892854e-06
# it 47000, train loss = 2.435416e-06
# it 48000, train loss = 2.177008e-06
# it 49000, train loss = 1.638090e-06
# it 50000, train loss = 2.735443e-06
# it 51000, train loss = 1.211830e-06
# it 52000, train loss = 1.384430e-06
# it 53000, train loss = 1.013775e-06
# it 54000, train loss = 1.005766e-06
# it 55000, train loss = 1.001931e-06
# it 56000, train loss = 1.080415e-06
# it 57000, train loss = 1.107859e-06
# it 58000, train loss = 1.135504e-06
# it 59000, train loss = 9.287548e-07
# it 60000, train loss = 1.051103e-06
# it 61000, train loss = 9.399867e-07
# it 62000, train loss = 1.179961e-06
# it 63000, train loss = 8.111913e-07
# it 64000, train loss = 1.053620e-06
# it 65000, train loss = 1.180343e-06
# it 66000, train loss = 1.540471e-06
# it 67000, train loss = 9.968081e-07
# it 68000, train loss = 8.119478e-07
# it 69000, train loss = 7.278579e-07
# it 70000, train loss = 8.289311e-07
# it 71000, train loss = 9.600235e-07
# it 72000, train loss = 8.388148e-07
# it 73000, train loss = 6.596170e-07
# it 74000, train loss = 5.984385e-07
# it 75000, train loss = 6.533447e-07
# it 76000, train loss = 7.189883e-07
# it 77000, train loss = 7.343735e-07
# it 78000, train loss = 6.672770e-07
# it 79000, train loss = 6.021269e-07
# it 80000, train loss = 5.570145e-07
# it 81000, train loss = 8.145468e-07
# it 82000, train loss = 1.038056e-06
# it 83000, train loss = 6.891086e-07
# it 84000, train loss = 8.243732e-07
# it 85000, train loss = 5.244649e-07
# it 86000, train loss = 5.914222e-07
# it 87000, train loss = 5.604906e-07
# it 88000, train loss = 7.596143e-07
# it 89000, train loss = 7.955579e-07
# it 90000, train loss = 4.852575e-07
# it 91000, train loss = 6.089115e-07
# it 92000, train loss = 5.420418e-07
# it 93000, train loss = 7.029729e-07
# it 94000, train loss = 4.146124e-07
# it 95000, train loss = 5.655451e-07
# it 96000, train loss = 5.582699e-07
# it 97000, train loss = 5.324542e-07
# it 98000, train loss = 4.369021e-07
# it 99000, train loss = 6.613462e-07
# it 100000, train loss = 4.575747e-07

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.045574e-01
# it 2000, train loss = 6.170149e-02
# it 3000, train loss = 3.546561e-02
# it 4000, train loss = 2.199780e-02
# it 5000, train loss = 2.839627e-04
# it 6000, train loss = 4.031858e-05
# it 7000, train loss = 3.558991e-05
# it 8000, train loss = 2.464386e-05
# it 9000, train loss = 1.301226e-05
# it 10000, train loss = 7.804432e-06
# it 11000, train loss = 6.855783e-06
# it 12000, train loss = 6.761139e-06
# it 13000, train loss = 6.667496e-06
# it 14000, train loss = 6.616477e-06
# it 15000, train loss = 6.570091e-06
# it 16000, train loss = 6.525637e-06
# it 17000, train loss = 6.476481e-06
# it 18000, train loss = 6.421805e-06
# it 19000, train loss = 6.363845e-06
# it 20000, train loss = 6.306627e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.37752 0.68507 0.94349 1.16751] [0.36358 0.65421 0.89253 1.09291]
# pr P_xx & P_yy:  [0.37615 0.68757 0.94147 1.16812] [0.36225 0.6567  0.89046 1.09354]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.187125e-04
# it 2000, train loss = 3.284428e-05
# it 3000, train loss = 1.364397e-05
# it 4000, train loss = 6.669974e-06
# it 5000, train loss = 3.531304e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/-_sharp_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/-_sharp_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 40000, print_freq=1000, batch_size=1000)

with open('params/-_sharp_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-05-23 02:06:38.248177: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-05-23 02:07:56.805536: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 3m18.560287s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 1.403807e+00
# it 1001, val loss = 1.250628e+00
# it 2001, val loss = 1.825806e+00
# it 3001, val loss = 3.378656e+00
# it 4001, val loss = 2.097547e+00
# it 5001, val loss = 1.667099e+00
# it 6001, val loss = 1.567137e+00
# it 7001, val loss = 7.342366e-01
# it 8001, val loss = 2.103531e+00
# it 9001, val loss = 9.098860e-01
# it 10001, val loss = 7.346439e-01
# it 11001, val loss = 2.570983e+00
# it 12001, val loss = 1.074821e+00
# it 13001, val loss = 1.247401e+00
# it 14001, val loss = 1.309833e+00
# it 15001, val loss = 1.496590e+00
# it 16001, val loss = 1.464431e+00
# it 17001, val loss = 1.096421e+00
# it 18001, val loss = 1.314766e+00
# it 19001, val loss = 3.362733e+00
# it 20001, val loss = 1.297844e+00
# it 21001, val loss = 2.556943e+00
# it 22001, val loss = 1.648977e+00
# it 23001, val loss = 5.695816e-01
# it 24001, val loss = 1.587192e+00
# it 25001, val loss = 1.512064e+00
# it 26001, val loss = 5.102397e-01
# it 27001, val loss = 1.102840e+00
# it 28001, val loss = 4.313925e-01
# it 29001, val loss = 5.500206e-01
# it 30001, val loss = 6.720131e-01
# it 31001, val loss = 1.679915e+00
# it 32001, val loss = 9.460259e-01
# it 33001, val loss = 2.000988e+00
# it 34001, val loss = 2.507559e+00
# it 35001, val loss = 9.981807e-01
# it 36001, val loss = 6.545641e-01
# it 37001, val loss = 1.175352e+00
# it 38001, val loss = 1.424459e+00
# it 39001, val loss = 3.172837e-01

# %% [markdown]
# ## 3. Test

# %%
with open('params/-_sharp_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
elem_X = mesh.points[mesh.cells].mean(1)


params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [05-23 09:00:19][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:00:19][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:00:19][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:00:19][DEBUG] jax_fem: Done pre-computations, took 0.047975778579711914 [s]
# [05-23 09:00:19][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:00:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:00:19][DEBUG] jax_fem: Start timing
# [05-23 09:00:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 2.3703 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:21][DEBUG] jax_fem: PETSc linear solve res = 0.0003104704709746952
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0272 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: Before, res l_2 = 0.01732117858370157
# [05-23 09:00:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:21][DEBUG] jax_fem: PETSc linear solve res = 2.2707218076778557e-10
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0267 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: res l_2 = 0.0030948917776348586
# [05-23 09:00:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:21][DEBUG] jax_fem: PETSc linear solve res = 1.3889749265130084e-09
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0261 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: res l_2 = 0.00022211025627338
# [05-23 09:00:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:21][DEBUG] jax_fem: PETSc linear solve res = 4.167498693464704e-10
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0271 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: res l_2 = 1.7380513953548315e-06
# [05-23 09:00:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:21][DEBUG] jax_fem: PETSc linear solve res = 1.8090182723011364e-12
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0290 seconds
# [05-23 09:00:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:21][DEBUG] jax_fem: res l_2 = 1.337330975332729e-10
# [05-23 09:00:21][INFO] jax_fem: Solve took 2.6802568435668945 [s]
# [05-23 09:00:21][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [05-23 09:00:21][DEBUG] jax_fem: min of sol = 0.0
# [05-23 09:00:21][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:00:21][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:00:21][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:00:21][DEBUG] jax_fem: Done pre-computations, took 0.04452824592590332 [s]
# [05-23 09:00:21][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:00:21][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:00:21][DEBUG] jax_fem: Start timing
# [05-23 09:00:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:24][DEBUG] jax_fem: Function split_and_compute_cell took 2.3551 seconds
# [05-23 09:00:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:24][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:24][DEBUG] jax_fem: PETSc linear solve res = 0.0006209409419493904
# [05-23 09:00:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [05-23 09:00:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:24][DEBUG] jax_fem: Before, res l_2 = 0.0537652807785866
# [05-23 09:00:24][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:24][DEBUG] jax_fem: PETSc linear solve res = 2.221428896703745e-08
# [05-23 09:00:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0265 seconds
# [05-23 09:00:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:24][DEBUG] jax_fem: res l_2 = 0.009764635429611899
# [05-23 09:00:24][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:24][DEBUG] jax_fem: PETSc linear solve res = 8.196348813734619e-09
# [05-23 09:00:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0276 seconds
# [05-23 09:00:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:24][DEBUG] jax_fem: res l_2 = 0.000263451881568849
# [05-23 09:00:24][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:24][DEBUG] jax_fem: PETSc linear solve res = 6.389843283951552e-11
# [05-23 09:00:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0253 seconds
# [05-23 09:00:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:24][DEBUG] jax_fem: res l_2 = 1.551596813897432e-07
# [05-23 09:00:24][INFO] jax_fem: Solve took 2.61729097366333 [s]
# [05-23 09:00:24][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [05-23 09:00:24][DEBUG] jax_fem: min of sol = 0.0
# [05-23 09:00:24][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:00:24][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:00:24][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:00:24][DEBUG] jax_fem: Done pre-computations, took 0.04265904426574707 [s]
# [05-23 09:00:24][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:00:24][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:00:24][DEBUG] jax_fem: Start timing
# [05-23 09:00:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:26][DEBUG] jax_fem: Function split_and_compute_cell took 2.3449 seconds
# [05-23 09:00:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:26][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:27][DEBUG] jax_fem: PETSc linear solve res = 0.0010283017404118869
# [05-23 09:00:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [05-23 09:00:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:27][DEBUG] jax_fem: Before, res l_2 = 0.09675812802092117
# [05-23 09:00:27][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:27][DEBUG] jax_fem: PETSc linear solve res = 3.5581635960208824e-08
# [05-23 09:00:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [05-23 09:00:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:27][DEBUG] jax_fem: res l_2 = 0.014392637107866478
# [05-23 09:00:27][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:27][DEBUG] jax_fem: PETSc linear solve res = 2.1669798504868684e-08
# [05-23 09:00:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0312 seconds
# [05-23 09:00:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:27][DEBUG] jax_fem: res l_2 = 0.0003299419366071063
# [05-23 09:00:27][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:27][DEBUG] jax_fem: PETSc linear solve res = 1.2197770751234957e-10
# [05-23 09:00:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0331 seconds
# [05-23 09:00:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:27][DEBUG] jax_fem: res l_2 = 1.561363360812168e-07
# [05-23 09:00:27][INFO] jax_fem: Solve took 2.6405129432678223 [s]
# [05-23 09:00:27][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [05-23 09:00:27][DEBUG] jax_fem: min of sol = 0.0
# [05-23 09:00:27][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:00:27][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:00:27][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:00:27][DEBUG] jax_fem: Done pre-computations, took 0.06614804267883301 [s]
# [05-23 09:00:27][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:00:27][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:00:27][DEBUG] jax_fem: Start timing
# [05-23 09:00:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:29][DEBUG] jax_fem: Function split_and_compute_cell took 2.3747 seconds
# [05-23 09:00:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:29][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:00:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:29][DEBUG] jax_fem: PETSc linear solve res = 0.0011038114292232202
# [05-23 09:00:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [05-23 09:00:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:29][DEBUG] jax_fem: Before, res l_2 = 0.13873732554898935
# [05-23 09:00:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:29][DEBUG] jax_fem: PETSc linear solve res = 1.775198745133336e-07
# [05-23 09:00:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0265 seconds
# [05-23 09:00:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:29][DEBUG] jax_fem: res l_2 = 0.026877790597592904
# [05-23 09:00:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:29][DEBUG] jax_fem: PETSc linear solve res = 2.366476823144015e-10
# [05-23 09:00:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0266 seconds
# [05-23 09:00:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:29][DEBUG] jax_fem: res l_2 = 0.0013203986799736507
# [05-23 09:00:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:29][DEBUG] jax_fem: PETSc linear solve res = 5.2255908971874935e-11
# [05-23 09:00:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [05-23 09:00:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:30][DEBUG] jax_fem: res l_2 = 4.942489034344567e-06
# [05-23 09:00:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:00:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:00:30][DEBUG] jax_fem: PETSc linear solve res = 1.1137733391532432e-12
# [05-23 09:00:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:00:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0280 seconds
# [05-23 09:00:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:00:30][DEBUG] jax_fem: res l_2 = 9.48091465354392e-11
# [05-23 09:00:30][INFO] jax_fem: Solve took 2.6887378692626953 [s]
# [05-23 09:00:30][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [05-23 09:00:30][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
