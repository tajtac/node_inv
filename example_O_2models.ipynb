# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd
from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('/home/amir/inverse_prob/O_bold.png')
image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.0,0.20,0.1,0.0]) + c*jnp.stack([0.2,5.0,0.04,0.0,0.0])

# %%
mat1_params = coords_2_params_gt([0.00,0.0])
mat2_params = coords_2_params_gt([0.25,0.5])
lmb_hist2 = [1.0, 1.05, 1.10, 1.15, 1.20]
mat1_P = []
mat2_Px = []
mat2_Py = []
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])
    mat2_Px.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_Py.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[1,1])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P, label='$P_{xx}$')
# ax.plot(lmb_hist, mat2_P, label='mat 2')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P$', title='mat 1')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat2_Px, label='$P_{xx}$')
ax.plot(lmb_hist2, mat2_Py, label='$P_{yy}$')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P$', title='mat 2')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [04-08 20:31:35][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [04-08 20:31:35][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [04-08 20:31:35][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [04-08 20:31:35][DEBUG] jax_fem: Done pre-computations, took 0.5904688835144043 [s]
# [04-08 20:31:35][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [04-08 20:31:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [04-08 20:31:37][DEBUG] jax_fem: Start timing
# [04-08 20:31:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:41][DEBUG] jax_fem: Function split_and_compute_cell took 3.8125 seconds
# [04-08 20:31:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:42][DEBUG] jax_fem: Linear guess solve...
# [04-08 20:31:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:42][DEBUG] jax_fem: PETSc linear solve res = 5.803202499167005e-07
# [04-08 20:31:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0148 seconds
# [04-08 20:31:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:42][DEBUG] jax_fem: Before, res l_2 = 0.03452107425300776
# [04-08 20:31:42][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:42][DEBUG] jax_fem: PETSc linear solve res = 2.3760608129917735e-10
# [04-08 20:31:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0117 seconds
# [04-08 20:31:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:42][DEBUG] jax_fem: res l_2 = 0.0003370927317596319
# [04-08 20:31:42][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:42][DEBUG] jax_fem: PETSc linear solve res = 3.9057944143585547e-11
# [04-08 20:31:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:42][DEBUG] jax_fem: Function split_and_compute_cell took 0.0118 seconds
# [04-08 20:31:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:42][DEBUG] jax_fem: res l_2 = 6.753446630182924e-08
# [04-08 20:31:42][INFO] jax_fem: Solve took 5.415189266204834 [s]
# [04-08 20:31:42][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [04-08 20:31:42][DEBUG] jax_fem: min of sol = 0.0
# [04-08 20:31:44][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [04-08 20:31:44][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [04-08 20:31:44][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [04-08 20:31:44][DEBUG] jax_fem: Done pre-computations, took 0.03231549263000488 [s]
# [04-08 20:31:44][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [04-08 20:31:44][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [04-08 20:31:44][DEBUG] jax_fem: Start timing
# [04-08 20:31:44][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:47][DEBUG] jax_fem: Function split_and_compute_cell took 2.7795 seconds
# [04-08 20:31:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:47][DEBUG] jax_fem: Linear guess solve...
# [04-08 20:31:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:47][DEBUG] jax_fem: PETSc linear solve res = 1.160640499833401e-06
# [04-08 20:31:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:47][DEBUG] jax_fem: Function split_and_compute_cell took 0.0394 seconds
# [04-08 20:31:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:47][DEBUG] jax_fem: Before, res l_2 = 0.08809317345334124
# [04-08 20:31:47][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:47][DEBUG] jax_fem: PETSc linear solve res = 2.3418284527676267e-08
# [04-08 20:31:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:47][DEBUG] jax_fem: Function split_and_compute_cell took 0.0119 seconds
# [04-08 20:31:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:47][DEBUG] jax_fem: res l_2 = 0.0020377490691084726
# [04-08 20:31:47][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:48][DEBUG] jax_fem: PETSc linear solve res = 1.1980341831691272e-11
# [04-08 20:31:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.0115 seconds
# [04-08 20:31:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:48][DEBUG] jax_fem: res l_2 = 1.9884279486795576e-06
# [04-08 20:31:48][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:48][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:48][DEBUG] jax_fem: PETSc linear solve res = 6.489761807253369e-13
# [04-08 20:31:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.0112 seconds
# [04-08 20:31:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:48][DEBUG] jax_fem: res l_2 = 2.972300265242493e-12
# [04-08 20:31:48][INFO] jax_fem: Solve took 3.1149444580078125 [s]
# [04-08 20:31:48][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [04-08 20:31:48][DEBUG] jax_fem: min of sol = 0.0
# [04-08 20:31:48][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [04-08 20:31:48][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [04-08 20:31:48][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [04-08 20:31:48][DEBUG] jax_fem: Done pre-computations, took 0.03604578971862793 [s]
# [04-08 20:31:48][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [04-08 20:31:49][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [04-08 20:31:49][DEBUG] jax_fem: Start timing
# [04-08 20:31:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:51][DEBUG] jax_fem: Function split_and_compute_cell took 2.7799 seconds
# [04-08 20:31:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:51][DEBUG] jax_fem: Linear guess solve...
# [04-08 20:31:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:51][DEBUG] jax_fem: PETSc linear solve res = 1.7409607501380232e-06
# [04-08 20:31:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.0144 seconds
# [04-08 20:31:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:51][DEBUG] jax_fem: Before, res l_2 = 0.15718930238386608
# [04-08 20:31:51][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:51][DEBUG] jax_fem: PETSc linear solve res = 4.891991099316075e-08
# [04-08 20:31:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.0118 seconds
# [04-08 20:31:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:51][DEBUG] jax_fem: res l_2 = 0.005995627482506642
# [04-08 20:31:51][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:52][DEBUG] jax_fem: PETSc linear solve res = 4.76393204699688e-11
# [04-08 20:31:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0129 seconds
# [04-08 20:31:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:52][DEBUG] jax_fem: res l_2 = 1.363600328650205e-05
# [04-08 20:31:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:52][DEBUG] jax_fem: PETSc linear solve res = 1.7803212537843514e-12
# [04-08 20:31:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0112 seconds
# [04-08 20:31:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:52][DEBUG] jax_fem: res l_2 = 1.204525920303866e-10
# [04-08 20:31:52][INFO] jax_fem: Solve took 3.0572028160095215 [s]
# [04-08 20:31:52][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [04-08 20:31:52][DEBUG] jax_fem: min of sol = 0.0
# [04-08 20:31:52][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [04-08 20:31:52][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [04-08 20:31:52][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [04-08 20:31:52][DEBUG] jax_fem: Done pre-computations, took 0.031481027603149414 [s]
# [04-08 20:31:52][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [04-08 20:31:53][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [04-08 20:31:53][DEBUG] jax_fem: Start timing
# [04-08 20:31:53][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:55][DEBUG] jax_fem: Function split_and_compute_cell took 2.5663 seconds
# [04-08 20:31:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:55][DEBUG] jax_fem: Linear guess solve...
# [04-08 20:31:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:55][DEBUG] jax_fem: PETSc linear solve res = 2.3212809998086775e-06
# [04-08 20:31:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0123 seconds
# [04-08 20:31:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:55][DEBUG] jax_fem: Before, res l_2 = 0.2399718283000801
# [04-08 20:31:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:55][DEBUG] jax_fem: PETSc linear solve res = 8.632006732253139e-08
# [04-08 20:31:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0119 seconds
# [04-08 20:31:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:55][DEBUG] jax_fem: res l_2 = 0.013063931040286525
# [04-08 20:31:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:55][DEBUG] jax_fem: PETSc linear solve res = 5.0712629278302814e-11
# [04-08 20:31:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0103 seconds
# [04-08 20:31:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:55][DEBUG] jax_fem: res l_2 = 5.508745942543232e-05
# [04-08 20:31:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-08 20:31:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-08 20:31:55][DEBUG] jax_fem: PETSc linear solve res = 9.30967989600509e-12
# [04-08 20:31:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-08 20:31:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0106 seconds
# [04-08 20:31:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-08 20:31:55][DEBUG] jax_fem: res l_2 = 1.4243462984596596e-09
# [04-08 20:31:55][INFO] jax_fem: Solve took 2.8088841438293457 [s]
# [04-08 20:31:55][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [04-08 20:31:55][DEBUG] jax_fem: min of sol = 0.0

# %%
plotmesh(mesh.cells, mesh.points, params[:,0,1], title='k1');

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,20,20,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 50000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 3.916631e-04
# it 2000, train loss = 1.972470e-04
# it 3000, train loss = 1.465295e-04
# it 4000, train loss = 1.227504e-04
# it 5000, train loss = 9.096244e-05
# it 6000, train loss = 7.085043e-05
# it 7000, train loss = 5.885659e-05
# it 8000, train loss = 4.216467e-05
# it 9000, train loss = 3.413441e-05
# it 10000, train loss = 2.928954e-05
# it 11000, train loss = 2.358789e-05
# it 12000, train loss = 1.991038e-05
# it 13000, train loss = 1.909250e-05
# it 14000, train loss = 1.553778e-05
# it 15000, train loss = 1.380039e-05
# it 16000, train loss = 1.247985e-05
# it 17000, train loss = 1.197346e-05
# it 18000, train loss = 1.027517e-05
# it 19000, train loss = 1.073926e-05
# it 20000, train loss = 9.741709e-06
# it 21000, train loss = 9.680943e-06
# it 22000, train loss = 8.268797e-06
# it 23000, train loss = 7.453033e-06
# it 24000, train loss = 7.981863e-06
# it 25000, train loss = 6.939590e-06
# it 26000, train loss = 7.143751e-06
# it 27000, train loss = 6.504957e-06
# it 28000, train loss = 6.514936e-06
# it 29000, train loss = 6.132959e-06
# it 30000, train loss = 6.095223e-06
# it 31000, train loss = 6.205855e-06
# it 32000, train loss = 5.452808e-06
# it 33000, train loss = 4.928667e-06
# it 34000, train loss = 4.904729e-06
# it 35000, train loss = 5.445419e-06
# it 36000, train loss = 4.913593e-06
# it 37000, train loss = 5.188186e-06
# it 38000, train loss = 4.734650e-06
# it 39000, train loss = 5.105049e-06
# it 40000, train loss = 4.366162e-06
# it 41000, train loss = 4.448970e-06
# it 42000, train loss = 4.277968e-06
# it 43000, train loss = 4.228684e-06
# it 44000, train loss = 4.145254e-06
# it 45000, train loss = 4.081044e-06
# it 46000, train loss = 4.072692e-06
# it 47000, train loss = 4.013537e-06
# it 48000, train loss = 3.985170e-06
# it 49000, train loss = 3.888624e-06
# it 50000, train loss = 4.024512e-06

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)

# %%
print(Force_y)
len(rgt_bd_elems)
# Out:
# [ 5.94665 10.81237 14.90079 18.43671]
# 19

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.47179 0.90666 1.32315 1.73781] [0.31298 0.56907 0.78425 0.97035]
# pr P_xx & P_yy:  [0.4702  0.90903 1.32154 1.73822] [0.31205 0.57133 0.78211 0.97105]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 3.272433e-04
# it 2000, train loss = 8.992741e-05
# it 3000, train loss = 3.807935e-05
# it 4000, train loss = 1.902093e-05
# it 5000, train loss = 1.020286e-05

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/O_2models_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/O_2models_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)

# %%
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):

    P_pred = get_P_vmap(XYt_colloc[:,0],XYt_colloc[:,1], XYt_colloc[:,2], Lambda_params, coord_2_strain_params, NODE_w_unravel)
    P_xx = P_xx_mean[jnp.array(XYt_colloc[:,2], int)]
    P_yy = P_yy_mean[jnp.array(XYt_colloc[:,2], int)]

    loss_P = jnp.mean((P_pred[0] - P_xx)**2 + (P_pred[3] - P_yy)**2)
    # loss_F = 0.0
    
    return loss_P

lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 50000, print_freq=100, batch_size=1000)

# with open('params/O_post.npy', 'wb') as f:
#     pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# it 1, val loss = 6.251444e-01
# it 101, val loss = 6.221102e-02
# it 201, val loss = 1.641122e-02
# it 301, val loss = 8.283661e-03
# it 401, val loss = 6.246506e-03
# it 501, val loss = 5.039714e-03
# it 601, val loss = 4.604109e-03
# it 701, val loss = 4.404591e-03
# it 801, val loss = 3.907143e-03
# it 901, val loss = 5.116643e-03
# it 1001, val loss = 3.318587e-03
# it 1101, val loss = 3.449196e-03
# it 1201, val loss = 3.236529e-03
# it 1301, val loss = 3.044605e-03
# it 1401, val loss = 2.687183e-03
# it 1501, val loss = 2.771543e-03
# it 1601, val loss = 2.063895e-03
# it 1701, val loss = 2.217546e-03
# it 1801, val loss = 2.596529e-03
# it 1901, val loss = 1.749618e-03
# it 2001, val loss = 1.873330e-03
# it 2101, val loss = 1.733177e-03
# it 2201, val loss = 2.119652e-03
# it 2301, val loss = 2.294183e-03
# it 2401, val loss = 1.477190e-03
# it 2501, val loss = 1.421132e-03
# it 2601, val loss = 2.407816e-03
# it 2701, val loss = 1.487587e-03
# it 2801, val loss = 1.167654e-03
# it 2901, val loss = 1.132927e-03
# it 3001, val loss = 1.295568e-03
# it 3101, val loss = 1.080509e-03
# it 3201, val loss = 1.232711e-03
# it 3301, val loss = 1.118007e-03
# it 3401, val loss = 1.297047e-03
# it 3501, val loss = 1.377989e-03
# it 3601, val loss = 9.670427e-04
# it 3701, val loss = 1.035718e-03
# it 3801, val loss = 1.372059e-03
# it 3901, val loss = 1.159787e-03
# it 4001, val loss = 1.065036e-03
# it 4101, val loss = 1.115299e-03
# it 4201, val loss = 8.873976e-04
# it 4301, val loss = 1.109240e-03
# it 4401, val loss = 9.040505e-04
# it 4501, val loss = 9.487980e-04
# it 4601, val loss = 9.218103e-04
# it 4701, val loss = 9.765423e-04
# it 4801, val loss = 8.718366e-04
# it 4901, val loss = 8.648628e-04
# it 5001, val loss = 1.496299e-03
# it 5101, val loss = 7.667534e-04
# it 5201, val loss = 8.412137e-04
# it 5301, val loss = 8.453155e-04
# it 5401, val loss = 8.142773e-04
# it 5501, val loss = 8.522591e-04
# it 5601, val loss = 1.246962e-03
# it 5701, val loss = 8.062052e-04
# it 5801, val loss = 8.383922e-04
# it 5901, val loss = 8.036305e-04
# it 6001, val loss = 8.112134e-04
# it 6101, val loss = 9.976421e-04
# it 6201, val loss = 7.045849e-04
# it 6301, val loss = 7.520939e-04
# it 6401, val loss = 6.541529e-04
# it 6501, val loss = 7.164663e-04
# it 6601, val loss = 1.395255e-03
# it 6701, val loss = 6.940976e-04
# it 6801, val loss = 7.079787e-04
# it 6901, val loss = 6.904210e-04
# it 7001, val loss = 1.002145e-03
# it 7101, val loss = 7.672302e-04
# it 7201, val loss = 7.885894e-04
# it 7301, val loss = 7.572376e-04
# it 7401, val loss = 7.165150e-04
# it 7501, val loss = 8.124200e-04
# it 7601, val loss = 6.913599e-04
# it 7701, val loss = 6.955616e-04
# it 7801, val loss = 6.396513e-04
# it 7901, val loss = 6.626194e-04
# it 8001, val loss = 7.090252e-04
# it 8101, val loss = 5.572982e-04
# it 8201, val loss = 6.193240e-04
# it 8301, val loss = 6.533811e-04
# it 8401, val loss = 5.198497e-04
# it 8501, val loss = 5.559125e-04
# it 8601, val loss = 5.996444e-04
# it 8701, val loss = 6.721750e-04
# it 8801, val loss = 5.111624e-04
# it 8901, val loss = 7.743993e-04
# it 9001, val loss = 5.189728e-04
# it 9101, val loss = 6.378312e-04
# it 9201, val loss = 6.023015e-04
# it 9301, val loss = 5.011909e-04
# it 9401, val loss = 5.841124e-04
# it 9501, val loss = 5.245500e-04
# it 9601, val loss = 4.624827e-04
# it 9701, val loss = 5.614766e-04
# it 9801, val loss = 4.312944e-04
# it 9901, val loss = 5.001651e-04
# it 10001, val loss = 4.896201e-04
# it 10101, val loss = 4.830137e-04
# it 10201, val loss = 6.567096e-04
# it 10301, val loss = 4.970498e-04
# it 10401, val loss = 6.056575e-04
# it 10501, val loss = 5.520225e-04
# it 10601, val loss = 4.914447e-04
# it 10701, val loss = 5.021605e-04
# it 10801, val loss = 4.194037e-04
# it 10901, val loss = 4.732850e-04
# it 11001, val loss = 4.361572e-04
# it 11101, val loss = 4.957652e-04
# it 11201, val loss = 6.925986e-04
# it 11301, val loss = 4.965975e-04
# it 11401, val loss = 4.712477e-04
# it 11501, val loss = 4.161429e-04
# it 11601, val loss = 4.913407e-04
# it 11701, val loss = 4.975701e-04
# it 11801, val loss = 4.819656e-04
# it 11901, val loss = 4.153597e-04
# it 12001, val loss = 4.028780e-04
# it 12101, val loss = 5.161242e-04
# it 12201, val loss = 4.835302e-04
# it 12301, val loss = 4.357695e-04
# it 12401, val loss = 4.027553e-04
# it 12501, val loss = 4.452334e-04
# it 12601, val loss = 4.166733e-04
# it 12701, val loss = 4.483601e-04
# it 12801, val loss = 5.889156e-04
# it 12901, val loss = 3.567080e-04
# it 13001, val loss = 3.772501e-04
# it 13101, val loss = 3.619805e-04
# it 13201, val loss = 3.346438e-04
# it 13301, val loss = 4.481876e-04
# it 13401, val loss = 4.086055e-04
# it 13501, val loss = 6.661427e-04
# it 13601, val loss = 3.674908e-04
# it 13701, val loss = 3.516288e-04
# it 13801, val loss = 4.468504e-04
# it 13901, val loss = 3.787741e-04
# it 14001, val loss = 3.455083e-04
# it 14101, val loss = 4.614060e-04
# it 14201, val loss = 3.947484e-04
# it 14301, val loss = 3.231065e-04
# it 14401, val loss = 3.317140e-04
# it 14501, val loss = 3.936620e-04
# it 14601, val loss = 3.531496e-04
# it 14701, val loss = 3.827169e-04
# it 14801, val loss = 3.655780e-04
# it 14901, val loss = 3.049071e-04
# it 15001, val loss = 3.416421e-04
# it 15101, val loss = 3.497728e-04
# it 15201, val loss = 3.354242e-04
# it 15301, val loss = 3.635685e-04
# it 15401, val loss = 3.192544e-04
# it 15501, val loss = 2.565199e-04
# it 15601, val loss = 3.149604e-04
# it 15701, val loss = 2.995197e-04
# it 15801, val loss = 3.147280e-04
# it 15901, val loss = 2.925686e-04
# it 16001, val loss = 3.397042e-04
# it 16101, val loss = 3.955987e-04
# it 16201, val loss = 3.023311e-04
# it 16301, val loss = 3.471587e-04
# it 16401, val loss = 2.836434e-04
# it 16501, val loss = 2.798918e-04
# it 16601, val loss = 3.071055e-04
# it 16701, val loss = 2.597212e-04
# it 16801, val loss = 2.796313e-04
# it 16901, val loss = 4.275792e-04
# it 17001, val loss = 2.810591e-04
# it 17101, val loss = 2.463159e-04
# it 17201, val loss = 3.793988e-04
# it 17301, val loss = 3.971648e-04
# it 17401, val loss = 2.701594e-04
# it 17501, val loss = 2.690922e-04
# it 17601, val loss = 3.431225e-04
# it 17701, val loss = 2.713793e-04
# it 17801, val loss = 2.806393e-04
# it 17901, val loss = 3.605193e-04
# it 18001, val loss = 2.633063e-04
# it 18101, val loss = 2.642083e-04
# it 18201, val loss = 2.922682e-04
# it 18301, val loss = 3.915354e-04
# it 18401, val loss = 2.694732e-04
# it 18501, val loss = 2.536013e-04
# it 18601, val loss = 2.955820e-04
# it 18701, val loss = 2.552800e-04
# it 18801, val loss = 3.273171e-04
# it 18901, val loss = 2.812286e-04
# it 19001, val loss = 2.775054e-04
# it 19101, val loss = 2.687893e-04
# it 19201, val loss = 2.891843e-04
# it 19301, val loss = 2.945158e-04
# it 19401, val loss = 2.315354e-04
# it 19501, val loss = 3.823657e-04
# it 19601, val loss = 2.276118e-04
# it 19701, val loss = 3.459906e-04
# it 19801, val loss = 2.260092e-04
# it 19901, val loss = 2.223845e-04
# it 20001, val loss = 2.613658e-04
# it 20101, val loss = 2.177859e-04
# it 20201, val loss = 2.416497e-04
# it 20301, val loss = 2.469858e-04
# it 20401, val loss = 2.287530e-04
# it 20501, val loss = 3.306372e-04
# it 20601, val loss = 2.388047e-04
# it 20701, val loss = 2.205698e-04
# it 20801, val loss = 2.281702e-04
# it 20901, val loss = 2.649385e-04
# it 21001, val loss = 3.221343e-04
# it 21101, val loss = 2.336289e-04
# it 21201, val loss = 2.389581e-04
# it 21301, val loss = 2.552487e-04
# it 21401, val loss = 3.288995e-04
# it 21501, val loss = 2.777736e-04
# it 21601, val loss = 2.209003e-04
# it 21701, val loss = 3.646153e-04
# it 21801, val loss = 3.649758e-04
# it 21901, val loss = 3.502004e-04
# it 22001, val loss = 2.065672e-04
# it 22101, val loss = 2.786162e-04
# it 22201, val loss = 2.263974e-04
# it 22301, val loss = 2.347941e-04
# it 22401, val loss = 2.591536e-04
# it 22501, val loss = 2.379526e-04
# it 22601, val loss = 2.000107e-04
# it 22701, val loss = 2.379133e-04
# it 22801, val loss = 2.044351e-04
# it 22901, val loss = 1.946473e-04
# it 23001, val loss = 2.243597e-04
# it 23101, val loss = 2.477335e-04
# it 23201, val loss = 3.008611e-04
# it 23301, val loss = 2.200310e-04
# it 23401, val loss = 2.798695e-04
# it 23501, val loss = 2.528787e-04
# it 23601, val loss = 2.033534e-04
# it 23701, val loss = 2.113446e-04
# it 23801, val loss = 2.141575e-04
# it 23901, val loss = 1.978080e-04
# it 24001, val loss = 2.250492e-04
# it 24101, val loss = 2.265721e-04
# it 24201, val loss = 1.849617e-04
# it 24301, val loss = 2.666106e-04
# it 24401, val loss = 2.253907e-04
# it 24501, val loss = 2.131033e-04
# it 24601, val loss = 2.746435e-04
# it 24701, val loss = 1.850216e-04
# it 24801, val loss = 1.800130e-04
# it 24901, val loss = 2.566481e-04
# it 25001, val loss = 2.237347e-04
# it 25101, val loss = 2.448857e-04
# it 25201, val loss = 3.496090e-04
# it 25301, val loss = 2.528923e-04
# it 25401, val loss = 2.160815e-04
# it 25501, val loss = 2.494642e-04
# it 25601, val loss = 1.868077e-04
# it 25701, val loss = 2.375379e-04
# it 25801, val loss = 1.653581e-04
# it 25901, val loss = 1.673276e-04
# it 26001, val loss = 1.799161e-04
# it 26101, val loss = 1.980563e-04
# it 26201, val loss = 1.635459e-04
# it 26301, val loss = 1.546618e-04
# it 26401, val loss = 2.527616e-04
# it 26501, val loss = 1.688754e-04
# it 26601, val loss = 2.010808e-04
# it 26701, val loss = 2.581998e-04
# it 26801, val loss = 1.842331e-04
# it 26901, val loss = 2.629875e-04
# it 27001, val loss = 1.831852e-04
# it 27101, val loss = 1.827771e-04
# it 27201, val loss = 1.540156e-04
# it 27301, val loss = 1.925379e-04
# it 27401, val loss = 1.919402e-04
# it 27501, val loss = 1.698397e-04
# it 27601, val loss = 2.522358e-04
# it 27701, val loss = 2.112999e-04
# it 27801, val loss = 2.230907e-04
# it 27901, val loss = 1.921691e-04
# it 28001, val loss = 1.897719e-04
# it 28101, val loss = 1.731531e-04
# it 28201, val loss = 1.653634e-04
# it 28301, val loss = 2.308695e-04
# it 28401, val loss = 2.016834e-04
# it 28501, val loss = 1.944797e-04
# it 28601, val loss = 1.649055e-04
# it 28701, val loss = 1.698478e-04
# it 28801, val loss = 1.859771e-04
# it 28901, val loss = 2.250662e-04
# it 29001, val loss = 1.787079e-04
# it 29101, val loss = 2.701424e-04
# it 29201, val loss = 1.914574e-04
# it 29301, val loss = 2.187617e-04
# it 29401, val loss = 2.038890e-04
# it 29501, val loss = 3.095534e-04
# it 29601, val loss = 2.294053e-04
# it 29701, val loss = 1.735158e-04
# it 29801, val loss = 1.863193e-04
# it 29901, val loss = 1.919192e-04
# it 30001, val loss = 1.476222e-04
# it 30101, val loss = 2.205394e-04
# it 30201, val loss = 1.552326e-04
# it 30301, val loss = 1.916216e-04
# it 30401, val loss = 1.620278e-04
# it 30501, val loss = 1.949328e-04
# it 30601, val loss = 1.938980e-04
# it 30701, val loss = 2.892749e-04
# it 30801, val loss = 1.879415e-04
# it 30901, val loss = 1.660884e-04
# it 31001, val loss = 1.406722e-04
# it 31101, val loss = 1.862330e-04
# it 31201, val loss = 1.817465e-04
# it 31301, val loss = 1.786716e-04
# it 31401, val loss = 1.627802e-04
# it 31501, val loss = 1.421447e-04
# it 31601, val loss = 1.854295e-04
# it 31701, val loss = 1.670469e-04
# it 31801, val loss = 1.662188e-04
# it 31901, val loss = 1.728328e-04
# it 32001, val loss = 2.409696e-04
# it 32101, val loss = 1.785128e-04
# it 32201, val loss = 2.044406e-04
# it 32301, val loss = 2.455320e-04
# it 32401, val loss = 2.221071e-04
# it 32501, val loss = 1.453068e-04
# it 32601, val loss = 1.593843e-04
# it 32701, val loss = 1.430287e-04
# it 32801, val loss = 1.516721e-04
# it 32901, val loss = 3.560200e-04
# it 33001, val loss = 1.556048e-04
# it 33101, val loss = 1.622542e-04
# it 33201, val loss = 1.426139e-04
# it 33301, val loss = 1.483164e-04
# it 33401, val loss = 1.297792e-04
# it 33501, val loss = 1.408157e-04
# it 33601, val loss = 2.417458e-04
# it 33701, val loss = 1.576099e-04
# it 33801, val loss = 2.541322e-04
# it 33901, val loss = 1.653449e-04
# it 34001, val loss = 1.497595e-04
# it 34101, val loss = 1.775918e-04
# it 34201, val loss = 1.529641e-04
# it 34301, val loss = 1.463503e-04
# it 34401, val loss = 1.445704e-04
# it 34501, val loss = 1.338236e-04
# it 34601, val loss = 1.475851e-04
# it 34701, val loss = 1.638517e-04
# it 34801, val loss = 1.660507e-04
# it 34901, val loss = 1.373964e-04
# it 35001, val loss = 1.803362e-04
# it 35101, val loss = 1.421641e-04
# it 35201, val loss = 1.268381e-04
# it 35301, val loss = 1.860471e-04
# it 35401, val loss = 1.515536e-04
# it 35501, val loss = 2.018151e-04
# it 35601, val loss = 1.349176e-04
# it 35701, val loss = 1.687816e-04
# it 35801, val loss = 1.307698e-04
# it 35901, val loss = 1.395917e-04
# it 36001, val loss = 1.890455e-04
# it 36101, val loss = 1.368624e-04
# it 36201, val loss = 2.729501e-04
# it 36301, val loss = 1.384256e-04
# it 36401, val loss = 1.542831e-04
# it 36501, val loss = 1.999397e-04
# it 36601, val loss = 1.187884e-04
# it 36701, val loss = 1.356758e-04
# it 36801, val loss = 2.244228e-04
# it 36901, val loss = 1.402099e-04
# it 37001, val loss = 1.583630e-04
# it 37101, val loss = 1.576222e-04
# it 37201, val loss = 2.624319e-04
# it 37301, val loss = 1.223168e-04
# it 37401, val loss = 1.425175e-04
# it 37501, val loss = 1.695260e-04
# it 37601, val loss = 1.222301e-04
# it 37701, val loss = 1.576508e-04
# it 37801, val loss = 1.314463e-04
# it 37901, val loss = 1.733394e-04
# it 38001, val loss = 1.317876e-04
# it 38101, val loss = 1.483663e-04
# it 38201, val loss = 1.429813e-04
# it 38301, val loss = 1.337684e-04
# it 38401, val loss = 1.579977e-04
# it 38501, val loss = 1.813863e-04
# it 38601, val loss = 1.418012e-04
# it 38701, val loss = 1.894212e-04
# it 38801, val loss = 1.307010e-04
# it 38901, val loss = 1.292073e-04
# it 39001, val loss = 2.516623e-04
# it 39101, val loss = 1.331813e-04
# it 39201, val loss = 1.846536e-04
# it 39301, val loss = 1.426433e-04
# it 39401, val loss = 1.309912e-04
# it 39501, val loss = 1.266600e-04
# it 39601, val loss = 1.708105e-04
# it 39701, val loss = 1.201773e-04
# it 39801, val loss = 4.001920e-04
# it 39901, val loss = 1.274228e-04
# it 40001, val loss = 1.160534e-04
# it 40101, val loss = 1.667684e-04
# it 40201, val loss = 1.778506e-04
# it 40301, val loss = 1.976329e-04
# it 40401, val loss = 1.354303e-04
# it 40501, val loss = 1.145059e-04
# it 40601, val loss = 1.227128e-04
# it 40701, val loss = 1.389573e-04
# it 40801, val loss = 2.754885e-04
# it 40901, val loss = 2.027941e-04
# it 41001, val loss = 1.711113e-04
# it 41101, val loss = 1.528380e-04
# it 41201, val loss = 1.119568e-04
# it 41301, val loss = 1.522576e-04
# it 41401, val loss = 1.624929e-04
# it 41501, val loss = 1.673584e-04
# it 41601, val loss = 1.353309e-04
# it 41701, val loss = 1.732858e-04
# it 41801, val loss = 1.328408e-04
# it 41901, val loss = 1.427900e-04
# it 42001, val loss = 1.412669e-04
# it 42101, val loss = 1.360259e-04
# it 42201, val loss = 1.379960e-04
# it 42301, val loss = 1.248681e-04
# it 42401, val loss = 1.233764e-04
# it 42501, val loss = 1.232616e-04
# it 42601, val loss = 1.289994e-04
# it 42701, val loss = 1.294681e-04
# it 42801, val loss = 1.636349e-04
# it 42901, val loss = 1.462994e-04
# it 43001, val loss = 1.421781e-04
# it 43101, val loss = 1.921422e-04
# it 43201, val loss = 1.534878e-04
# it 43301, val loss = 1.643289e-04
# it 43401, val loss = 1.164576e-04
# it 43501, val loss = 1.435144e-04
# it 43601, val loss = 1.015761e-04
# it 43701, val loss = 1.563336e-04
# it 43801, val loss = 1.472075e-04
# it 43901, val loss = 1.283288e-04
# it 44001, val loss = 1.604861e-04
# it 44101, val loss = 1.235832e-04
# it 44201, val loss = 1.673924e-04
# it 44301, val loss = 1.128195e-04
# it 44401, val loss = 1.268080e-04
# it 44501, val loss = 1.505455e-04
# it 44601, val loss = 1.287837e-04
# it 44701, val loss = 1.124994e-04
# it 44801, val loss = 1.315612e-04
# it 44901, val loss = 2.375911e-04
# it 45001, val loss = 1.545217e-04
# it 45101, val loss = 1.290639e-04
# it 45201, val loss = 1.167385e-04
# it 45301, val loss = 1.805302e-04
# it 45401, val loss = 1.261433e-04
# it 45501, val loss = 1.062695e-04
# it 45601, val loss = 1.737120e-04
# it 45701, val loss = 1.292745e-04
# it 45801, val loss = 1.486551e-04
# it 45901, val loss = 1.512874e-04
# it 46001, val loss = 1.116044e-04
# it 46101, val loss = 1.758623e-04
# it 46201, val loss = 1.404652e-04
# it 46301, val loss = 1.319154e-04
# it 46401, val loss = 1.426853e-04
# it 46501, val loss = 1.018538e-04
# it 46601, val loss = 1.047048e-04
# it 46701, val loss = 1.006780e-04
# it 46801, val loss = 1.297636e-04
# it 46901, val loss = 1.321046e-04
# it 47001, val loss = 1.262040e-04
# it 47101, val loss = 1.279952e-04
# it 47201, val loss = 1.385072e-04
# it 47301, val loss = 1.501410e-04
# it 47401, val loss = 1.126823e-04
# it 47501, val loss = 1.357812e-04
# it 47601, val loss = 1.413079e-04
# it 47701, val loss = 9.441769e-05
# it 47801, val loss = 1.193242e-04
# it 47901, val loss = 1.437804e-04
# it 48001, val loss = 1.119692e-04
# it 48101, val loss = 1.548631e-04
# it 48201, val loss = 9.965736e-05
# it 48301, val loss = 1.268659e-04
# it 48401, val loss = 1.728853e-04
# it 48501, val loss = 1.531091e-04
# it 48601, val loss = 1.458970e-04
# it 48701, val loss = 1.054572e-04
# it 48801, val loss = 1.498864e-04
# it 48901, val loss = 1.886715e-04
# it 49001, val loss = 1.048959e-04
# it 49101, val loss = 1.593910e-04
# it 49201, val loss = 1.084009e-04
# it 49301, val loss = 1.738351e-04
# it 49401, val loss = 1.153003e-04
# it 49501, val loss = 9.863256e-05
# it 49601, val loss = 1.269217e-04
# it 49701, val loss = 1.429226e-04
# it 49801, val loss = 1.087822e-04
# it 49901, val loss = 1.286366e-04

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 50000, print_freq=1000, batch_size=1000)

with open('params/O_2models_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-09-19 03:19:19.560042: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-09-19 03:21:33.538084: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 4m13.978170218s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 2.051508e+01
# it 1001, val loss = 1.916506e-01
# it 2001, val loss = 1.205500e+00
# it 3001, val loss = 7.287185e+00
# it 4001, val loss = 9.781114e+00
# it 5001, val loss = 5.105591e-01
# it 6001, val loss = 4.419661e-01
# it 7001, val loss = 3.559840e-01
# it 8001, val loss = 8.180373e+00
# it 9001, val loss = 8.723793e-01
# it 10001, val loss = 3.617481e+00
# it 11001, val loss = 1.744301e+00
# it 12001, val loss = 1.167535e+00
# it 13001, val loss = 2.241941e+00
# it 14001, val loss = 6.883305e+00
# it 15001, val loss = 1.857371e+00
# it 16001, val loss = 5.288395e+00
# it 17001, val loss = 6.392816e-01
# it 18001, val loss = 8.079550e-01
# it 19001, val loss = 4.328719e-01
# it 20001, val loss = 4.569945e-01
# it 21001, val loss = 1.213020e+00
# it 22001, val loss = 2.089259e+00
# it 23001, val loss = 1.456083e+01
# it 24001, val loss = 3.752305e+00
# it 25001, val loss = 8.070363e-01
# it 26001, val loss = 4.121592e+00
# it 27001, val loss = 1.422849e+00
# it 28001, val loss = 2.016115e+00
# it 29001, val loss = 2.025036e+00
# it 30001, val loss = 1.286251e-01
# it 31001, val loss = 2.382989e-01
# it 32001, val loss = 2.608127e+00
# it 33001, val loss = 3.982508e-01
# it 34001, val loss = 1.534596e+01
# it 35001, val loss = 3.282447e+00
# it 36001, val loss = 2.239120e+00
# it 37001, val loss = 1.592578e+00
# it 38001, val loss = 1.618289e+00
# it 39001, val loss = 1.798759e+00
# it 40001, val loss = 1.370152e+00
# it 41001, val loss = 1.832573e+00
# it 42001, val loss = 2.431517e+00
# it 43001, val loss = 9.236594e-01
# it 44001, val loss = 4.146058e-01
# it 45001, val loss = 1.039780e+00
# it 46001, val loss = 5.341159e-01
# it 47001, val loss = 6.439584e-01
# it 48001, val loss = 6.144092e-01
# it 49001, val loss = 3.121080e+00

# %% [markdown]
# ## 3. Test

# %%
with open('params/O_2models_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
fig, ax = plt.subplots()
ax.plot(val_loss)
ax.set(xlabel='Iteration', ylabel='Validation loss')
# Out:
# [Text(0.5, 0, 'Iteration'), Text(0, 0.5, 'Validation loss')]

# %%
p1 = [0.0,0.0]
p2 = [0.75,0.5]
mat1_params = coords_2_params_gt(p1)
mat2_params = coords_2_params_gt(p2)
mat1_P_gt = []
mat2_Px_gt = []
mat2_Py_gt = []
mat1_P_pr = []
mat2_Px_pr = []
mat2_Py_pr = []
# lmb_hist2 = [1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.35)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])
    mat2_Px_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_Py_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[1,1])

    mat1_params_pr = ff_nn(np.array(p1), Lambda_params)
    mat2_params_pr = ff_nn(np.array(p2), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])
    mat2_Px_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_Py_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[1,1])


fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='gt')
ax.plot(lmb_hist2, mat1_P_pr, '--', label='pr')
ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat2_Px_gt, label='$P_{xx}$ (gt)')
ax.plot(lmb_hist2, mat2_Py_gt, label='$P_{yy}$ (gt)')
fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat2_Px_pr, '--', label='$P_{xx}$ (pr)')
ax.plot(lmb_hist2, mat2_Py_pr, '--', label='$P_{yy}$ (pr)')
ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
mat1_params = coords_2_params_gt([0.0,0.0])
mat2_params = coords_2_params_gt([0.25,0.5])
mat1_P_gt = []
mat2_Px_gt = []
mat2_Py_gt = []
mat1_P_pr = []
mat2_Px_pr = []
mat2_Py_pr = []
# lmb_hist2 = [1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.35)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_Px_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])
    mat2_Py_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[1,1])

    mat1_params_pr = ff_nn(np.array([0.0, 0.0]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_Px_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])
    mat2_Py_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[1,1])


fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='gt')
ax.plot(lmb_hist2, mat1_P_pr, '--', label='pr')
ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat2_Px_gt, label='$P_{xx}$ (gt)')
ax.plot(lmb_hist2, mat2_Py_gt, label='$P_{yy}$ (gt)')
fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat2_Px_pr, '--', label='$P_{xx}$ (pr)')
ax.plot(lmb_hist2, mat2_Py_pr, '--', label='$P_{yy}$ (pr)')
ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 26
#      24 elif extent[1] < np.max(c_elem_pr):
#      25     extend='max'
# ---> 26 plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);
#
# NameError: name 'extend' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [04-20 12:58:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [04-20 12:58:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [04-20 12:58:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [04-20 12:58:03][DEBUG] jax_fem: Done pre-computations, took 0.06334996223449707 [s]
# [04-20 12:58:03][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [04-20 12:58:03][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [04-20 12:58:03][DEBUG] jax_fem: Start timing
# [04-20 12:58:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 2.5023 seconds
# [04-20 12:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:05][DEBUG] jax_fem: Linear guess solve...
# [04-20 12:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:05][DEBUG] jax_fem: PETSc linear solve res = 0.03084850156763897
# [04-20 12:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0281 seconds
# [04-20 12:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:05][DEBUG] jax_fem: Before, res l_2 = 8.769052366338553
# [04-20 12:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:05][DEBUG] jax_fem: PETSc linear solve res = 2.804210206436035e-07
# [04-20 12:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0299 seconds
# [04-20 12:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:05][DEBUG] jax_fem: res l_2 = 3.1649419666511696
# [04-20 12:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:05][DEBUG] jax_fem: PETSc linear solve res = 1.040569838850839e-06
# [04-20 12:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [04-20 12:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:05][DEBUG] jax_fem: res l_2 = 1.107141462324974
# [04-20 12:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:05][DEBUG] jax_fem: PETSc linear solve res = 1.795992895527011e-07
# [04-20 12:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0295 seconds
# [04-20 12:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:05][DEBUG] jax_fem: res l_2 = 0.4295583930859545
# [04-20 12:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:05][DEBUG] jax_fem: PETSc linear solve res = 1.4755916895993707e-07
# [04-20 12:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0294 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 0.15801059952744498
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 2.7007066007746555e-07
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0271 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 7818464.594038938
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 783.8127628487254
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0283 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 8674996965.156046
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 95.51911747647473
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0281 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 111983366859.46004
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 7526.768050018927
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0277 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 2.5464867985011953e+18
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 1.840700434312162e+20
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0280 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = 2.120792833369013e+91
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = 8.934613158839704e+94
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0277 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = inf
# [04-20 12:58:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [04-20 12:58:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [04-20 12:58:06][DEBUG] jax_fem: PETSc linear solve res = inf
# [04-20 12:58:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [04-20 12:58:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0265 seconds
# [04-20 12:58:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [04-20 12:58:06][DEBUG] jax_fem: res l_2 = nan
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 56
#      51 elem_X = problem.get_physical_quad_points().mean(1)
#      53 problem.set_params(params_vec)
# ---> 56 node_x = solver(problem, use_petsc=True)
#      57 u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
#      58 F = u_grad + np.eye(2)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:849, in solver(problem, linear, precond, initial_guess, use_petsc)
#     846 # TODO: print platform jax.lib.xla_bridge.get_backend().platform
#     847 # and suggest PETSc or jax solver
#     848 if problem.periodic_bc_info is None:
# --> 849     return solver_row_elimination(problem, linear, precond, initial_guess,
#     850                                   use_petsc)
#     851 else:
#     852     return solver_lagrange_multiplier(problem, linear, use_petsc)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:393, in solver_row_elimination(problem, linear, precond, initial_guess, use_petsc)
#     390         res_val = np.linalg.norm(res_vec)
#     391         logger.debug(f"res l_2 = {res_val}")
# --> 393 assert np.all(
#     394     np.isfinite(res_val)), f"res_val contains NaN, stop the program!"
#     396 assert np.all(np.isfinite(dofs)), f"dofs contains NaN, stop the program!"
#     398 sol = dofs.reshape(sol_shape)
#
# AssertionError: res_val contains NaN, stop the program!

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
