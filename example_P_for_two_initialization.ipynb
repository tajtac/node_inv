# %%
import os
import inspect
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

def ty(a):
    b = type(a)  # Get the type of `a`
    print(b)  # Print the type
    
    if isinstance(a, np.ndarray): 
        return b, a.shape
    else:
        return b, len(a)
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
##########################################################################this is I am using to understand the above code##### skip it when you run the code
print(inspect.getsource(Mesh))
# Out:
# class Mesh():
#     """
#     A custom mesh manager might be better using a third-party library like
#     meshio.
#     """
#     def __init__(self, points, cells, ele_type='TET4'):
#         # TODO: Assert that cells must have correct orders
#         # TODO: first cells, then points?
#         self.points = points
#         self.cells = cells
#         self.ele_type = ele_type
#
#     def count_selected_faces(self, location_fn):
#         """Given location functions, compute the count of faces that satisfy
#         the location function. Useful for setting up distributed load
#         conditions.
#
#         Parameters
#         ----------
#         location_fns : List[Callable]
#             Callable: a function that inputs a point and returns a boolean
#             value describing whether the boundary condition should be applied.
#
#         Returns
#         -------
#         face_count : int
#         """
#
#         _, _, _, _, face_inds = get_face_shape_vals_and_grads(self.ele_type)
#         cell_points = onp.take(self.points, self.cells, axis=0)
#         cell_face_points = onp.take(cell_points, face_inds, axis=1)
#
#         vmap_location_fn = jax.vmap(location_fn)
#
#         def on_boundary(cell_points):
#             boundary_flag = vmap_location_fn(cell_points)
#             return onp.all(boundary_flag)
#
#         vvmap_on_boundary = jax.vmap(jax.vmap(on_boundary))
#         boundary_flags = vvmap_on_boundary(cell_face_points)
#         boundary_inds = onp.argwhere(boundary_flags)
#         return boundary_inds.shape[0]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('/home/amir/inverse_prob/PP.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
#image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    ##### image size is 1500 by 1500 but the range of values are x,y, pts_x and pts_y are between [0,1]
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
print(mesh)

# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,00,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [11-23 22:25:18][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [11-23 22:25:18][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [11-23 22:25:18][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# <jax_fem.generate_mesh.Mesh object at 0x74bae52e5f40>
# [11-23 22:25:18][DEBUG] jax_fem: Done pre-computations, took 0.6509699821472168 [s]
# [11-23 22:25:18][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [11-23 22:25:21][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [11-23 22:25:21][DEBUG] jax_fem: Start timing
# [11-23 22:25:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:23][DEBUG] jax_fem: Function split_and_compute_cell took 1.7677 seconds
# [11-23 22:25:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:24][DEBUG] jax_fem: Linear guess solve...
# [11-23 22:25:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:25][DEBUG] jax_fem: PETSc linear solve res = 3.135234039341322e-06
# [11-23 22:25:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0383 seconds
# [11-23 22:25:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:25][DEBUG] jax_fem: Before, res l_2 = 0.002170409417611664
# [11-23 22:25:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:25][DEBUG] jax_fem: PETSc linear solve res = 5.433884068282526e-09
# [11-23 22:25:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0355 seconds
# [11-23 22:25:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:25][DEBUG] jax_fem: res l_2 = 4.375476176009191e-06
# [11-23 22:25:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:25][DEBUG] jax_fem: PETSc linear solve res = 8.908907349303261e-12
# [11-23 22:25:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0375 seconds
# [11-23 22:25:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:25][DEBUG] jax_fem: res l_2 = 3.325760538688995e-11
# [11-23 22:25:25][INFO] jax_fem: Solve took 3.49497127532959 [s]
# [11-23 22:25:25][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [11-23 22:25:25][DEBUG] jax_fem: min of sol = 0.0
# [11-23 22:25:27][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [11-23 22:25:27][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [11-23 22:25:27][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [11-23 22:25:27][DEBUG] jax_fem: Done pre-computations, took 0.0567479133605957 [s]
# [11-23 22:25:27][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [11-23 22:25:30][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [11-23 22:25:30][DEBUG] jax_fem: Start timing
# [11-23 22:25:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:31][DEBUG] jax_fem: Function split_and_compute_cell took 1.0859 seconds
# [11-23 22:25:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:31][DEBUG] jax_fem: Linear guess solve...
# [11-23 22:25:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:31][DEBUG] jax_fem: PETSc linear solve res = 6.270468078682644e-06
# [11-23 22:25:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0411 seconds
# [11-23 22:25:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:31][DEBUG] jax_fem: Before, res l_2 = 0.0067522917264845805
# [11-23 22:25:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:31][DEBUG] jax_fem: PETSc linear solve res = 1.507136221641515e-08
# [11-23 22:25:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0359 seconds
# [11-23 22:25:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:31][DEBUG] jax_fem: res l_2 = 3.98335812031492e-05
# [11-23 22:25:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:31][DEBUG] jax_fem: PETSc linear solve res = 7.440081503624547e-11
# [11-23 22:25:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0405 seconds
# [11-23 22:25:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:32][DEBUG] jax_fem: res l_2 = 2.560840029647189e-09
# [11-23 22:25:32][INFO] jax_fem: Solve took 1.5037100315093994 [s]
# [11-23 22:25:32][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [11-23 22:25:32][DEBUG] jax_fem: min of sol = 0.0
# [11-23 22:25:32][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [11-23 22:25:32][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [11-23 22:25:32][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [11-23 22:25:32][DEBUG] jax_fem: Done pre-computations, took 0.044827938079833984 [s]
# [11-23 22:25:32][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [11-23 22:25:34][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [11-23 22:25:34][DEBUG] jax_fem: Start timing
# [11-23 22:25:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:36][DEBUG] jax_fem: Function split_and_compute_cell took 1.0634 seconds
# [11-23 22:25:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:36][DEBUG] jax_fem: Linear guess solve...
# [11-23 22:25:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:36][DEBUG] jax_fem: PETSc linear solve res = 9.405702119730791e-06
# [11-23 22:25:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0359 seconds
# [11-23 22:25:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:36][DEBUG] jax_fem: Before, res l_2 = 0.011913961885930188
# [11-23 22:25:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:36][DEBUG] jax_fem: PETSc linear solve res = 2.278885400974698e-08
# [11-23 22:25:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0361 seconds
# [11-23 22:25:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:36][DEBUG] jax_fem: res l_2 = 0.0001110336200693722
# [11-23 22:25:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:36][DEBUG] jax_fem: PETSc linear solve res = 1.5719142844274106e-10
# [11-23 22:25:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0374 seconds
# [11-23 22:25:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:36][DEBUG] jax_fem: res l_2 = 1.8261562994860258e-08
# [11-23 22:25:36][INFO] jax_fem: Solve took 1.5081377029418945 [s]
# [11-23 22:25:36][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [11-23 22:25:36][DEBUG] jax_fem: min of sol = 0.0
# [11-23 22:25:36][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [11-23 22:25:36][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [11-23 22:25:36][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [11-23 22:25:36][DEBUG] jax_fem: Done pre-computations, took 0.050919294357299805 [s]
# [11-23 22:25:36][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [11-23 22:25:39][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [11-23 22:25:39][DEBUG] jax_fem: Start timing
# [11-23 22:25:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:40][DEBUG] jax_fem: Function split_and_compute_cell took 1.0846 seconds
# [11-23 22:25:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:40][DEBUG] jax_fem: Linear guess solve...
# [11-23 22:25:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:40][DEBUG] jax_fem: PETSc linear solve res = 1.2540936157143945e-05
# [11-23 22:25:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0466 seconds
# [11-23 22:25:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:40][DEBUG] jax_fem: Before, res l_2 = 0.016764183863678193
# [11-23 22:25:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:40][DEBUG] jax_fem: PETSc linear solve res = 4.272005565257535e-08
# [11-23 22:25:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0367 seconds
# [11-23 22:25:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:40][DEBUG] jax_fem: res l_2 = 0.00018864894577434914
# [11-23 22:25:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [11-23 22:25:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [11-23 22:25:40][DEBUG] jax_fem: PETSc linear solve res = 3.4934321842268106e-10
# [11-23 22:25:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [11-23 22:25:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0381 seconds
# [11-23 22:25:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [11-23 22:25:40][DEBUG] jax_fem: res l_2 = 4.602732288772797e-08
# [11-23 22:25:40][INFO] jax_fem: Solve took 1.558833122253418 [s]
# [11-23 22:25:40][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [11-23 22:25:40][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    print(evals.shape)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)
# Out:
# (2500, 2)
# (2500, 2)
# (2500, 2)
# (2500, 2)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 100 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)
X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 5.225758e-05
# it 2000, train loss = 2.348248e-05
# it 3000, train loss = 1.498859e-05
# it 4000, train loss = 1.391915e-05
# it 5000, train loss = 1.317236e-05
# it 6000, train loss = 1.305363e-05
# it 7000, train loss = 1.126688e-05
# it 8000, train loss = 1.243469e-05
# it 9000, train loss = 2.161094e-05
# it 10000, train loss = 9.174466e-06
# it 11000, train loss = 9.075923e-06
# it 12000, train loss = 1.008614e-05
# it 13000, train loss = 9.336045e-06
# it 14000, train loss = 1.045683e-05
# it 15000, train loss = 1.213460e-05
# it 16000, train loss = 7.878613e-06
# it 17000, train loss = 8.386030e-06
# it 18000, train loss = 9.214542e-06
# it 19000, train loss = 8.948587e-06
# it 20000, train loss = 9.174015e-06
# it 21000, train loss = 9.546822e-06
# it 22000, train loss = 9.997674e-06
# it 23000, train loss = 7.253281e-06
# it 24000, train loss = 7.982010e-06
# it 25000, train loss = 1.032069e-05
# it 26000, train loss = 8.585436e-06
# it 27000, train loss = 6.834711e-06
# it 28000, train loss = 6.471655e-06
# it 29000, train loss = 6.935262e-06
# it 30000, train loss = 7.973865e-06
# it 31000, train loss = 6.469288e-06
# it 32000, train loss = 5.867006e-06
# it 33000, train loss = 7.617927e-06
# it 34000, train loss = 7.230826e-06
# it 35000, train loss = 6.065489e-06
# it 36000, train loss = 5.977359e-06
# it 37000, train loss = 8.105920e-06
# it 38000, train loss = 6.655018e-06
# it 39000, train loss = 6.263515e-06
# it 40000, train loss = 6.855697e-06
# it 41000, train loss = 4.876099e-06
# it 42000, train loss = 6.326338e-06
# it 43000, train loss = 6.073802e-06
# it 44000, train loss = 5.602231e-06
# it 45000, train loss = 6.619708e-06
# it 46000, train loss = 6.439070e-06
# it 47000, train loss = 5.661025e-06
# it 48000, train loss = 5.562376e-06
# it 49000, train loss = 5.600829e-06
# it 50000, train loss = 6.964252e-06
# it 51000, train loss = 5.630735e-06
# it 52000, train loss = 5.203740e-06
# it 53000, train loss = 5.170635e-06
# it 54000, train loss = 5.068605e-06
# it 55000, train loss = 4.049271e-06
# it 56000, train loss = 4.046495e-06
# it 57000, train loss = 5.689844e-06
# it 58000, train loss = 5.172245e-06
# it 59000, train loss = 4.920506e-06
# it 60000, train loss = 5.373988e-06
# it 61000, train loss = 5.158468e-06
# it 62000, train loss = 5.066261e-06
# it 63000, train loss = 4.749724e-06
# it 64000, train loss = 5.009753e-06
# it 65000, train loss = 4.659255e-06
# it 66000, train loss = 4.550674e-06
# it 67000, train loss = 3.538778e-06
# it 68000, train loss = 4.732777e-06
# it 69000, train loss = 4.578763e-06
# it 70000, train loss = 5.049945e-06
# it 71000, train loss = 4.760480e-06
# it 72000, train loss = 4.344594e-06
# it 73000, train loss = 4.485089e-06
# it 74000, train loss = 4.052514e-06
# it 75000, train loss = 4.003107e-06
# it 76000, train loss = 5.890194e-06
# it 77000, train loss = 3.701310e-06
# it 78000, train loss = 3.676156e-06
# it 79000, train loss = 3.376115e-06
# it 80000, train loss = 3.500463e-06
# it 81000, train loss = 4.709402e-06
# it 82000, train loss = 4.607622e-06
# it 83000, train loss = 5.345730e-06
# it 84000, train loss = 4.084022e-06
# it 85000, train loss = 4.558192e-06
# it 86000, train loss = 3.398930e-06
# it 87000, train loss = 4.319392e-06
# it 88000, train loss = 3.432253e-06
# it 89000, train loss = 3.576269e-06
# it 90000, train loss = 3.711209e-06
# it 91000, train loss = 3.940205e-06
# it 92000, train loss = 3.977657e-06
# it 93000, train loss = 3.924624e-06
# it 94000, train loss = 3.672176e-06
# it 95000, train loss = 3.494548e-06
# it 96000, train loss = 4.599347e-06
# it 97000, train loss = 5.160370e-06
# it 98000, train loss = 3.937997e-06
# it 99000, train loss = 3.836958e-06
# it 100000, train loss = 5.599915e-06

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
with open('params_purdue_pre_paper.npy' ,'wb') as f:
    pickle.dump([coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist,len(rgt_bd_elems),len(top_bd_elems )], f)
with open('params_purdue_pre_paper.npy', 'rb') as f:
    coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y,strains, bd_X, \
                 lmb_hist, P_hist_goh, F_hist_goh, t_hist,len_rgt_bd_elems,len_top_bd_elems  = pickle.load(f)

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.007893e-01
# it 2000, train loss = 6.019956e-02
# it 3000, train loss = 3.512392e-02
# it 4000, train loss = 2.341390e-02
# it 5000, train loss = 1.478241e-03
# it 6000, train loss = 4.155416e-05
# it 7000, train loss = 3.906001e-05
# it 8000, train loss = 3.680261e-05
# it 9000, train loss = 2.807834e-05
# it 10000, train loss = 1.031260e-05
# it 11000, train loss = 6.603896e-06
# it 12000, train loss = 6.422157e-06
# it 13000, train loss = 6.395178e-06
# it 14000, train loss = 6.478992e-06
# it 15000, train loss = 6.328562e-06
# it 16000, train loss = 6.287921e-06
# it 17000, train loss = 6.241677e-06
# it 18000, train loss = 6.190166e-06
# it 19000, train loss = 6.143892e-06
# it 20000, train loss = 6.088578e-06

# %%
ty(node_params[0][0])
# Out:
# <class 'tuple'>
# (tuple, 2)

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.36949 0.67047 0.92346 1.14297] [0.35553 0.63957 0.87244 1.06829]
# pr P_xx & P_yy:  [0.36818 0.67297 0.92153 1.14363] [0.35426 0.64206 0.87045 1.06896]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_sΛ train_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
ff_nn_ff = lambda x, params: ff_nn(x, params)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 10000, print_freq=1000)
# Out:
# it 1000, train loss = 1.496339e-04
# it 2000, train loss = 4.295416e-05
# it 3000, train loss = 1.740043e-05
# it 4000, train loss = 8.339356e-06
# it 5000, train loss = 4.404910e-06
# it 6000, train loss = 2.508360e-06
# it 7000, train loss = 1.362525e-06
# it 8000, train loss = 1.024966e-06
# it 9000, train loss = 2.059689e-06
# it 10000, train loss = 2.886569e-07

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)

# %%
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y
#%%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):

    P_pred = get_P_vmap(XYt_colloc[:,0],XYt_colloc[:,1], XYt_colloc[:,2], Lambda_params, coord_2_strain_params, NODE_w_unravel)
    P_xx = P_xx_mean[jnp.array(XYt_colloc[:,2], int)]
    P_yy = P_yy_mean[jnp.array(XYt_colloc[:,2], int)]

    loss_P = jnp.mean((P_pred[0] - P_xx)**2 + (P_pred[3] - P_yy)**2)
    # loss_F = 0.0
    
    return loss_P

lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 30000, print_freq=1000, batch_size=1000)
# Out:
# it 1, val loss = 2.121439e-01
# it 1001, val loss = 1.731605e-04
# it 2001, val loss = 9.498534e-05
# it 3001, val loss = 1.438518e-04
# it 4001, val loss = 7.478258e-05
# it 5001, val loss = 5.282934e-05
# it 6001, val loss = 4.733942e-05
# it 7001, val loss = 1.159619e-04
# it 8001, val loss = 3.126732e-04
# it 9001, val loss = 5.632037e-05
# it 10001, val loss = 1.025291e-04
# it 11001, val loss = 8.049030e-05
# it 12001, val loss = 2.900162e-05
# it 13001, val loss = 2.243541e-05
# it 14001, val loss = 3.975590e-05
# it 15001, val loss = 2.745076e-05
# it 16001, val loss = 2.272600e-05
# it 17001, val loss = 2.925479e-05
# it 18001, val loss = 2.990827e-05
# it 19001, val loss = 2.292615e-05
# it 20001, val loss = 2.015085e-05
# it 21001, val loss = 3.191988e-05
# it 22001, val loss = 2.601550e-05
# it 23001, val loss = 2.403067e-05
# it 24001, val loss = 5.121493e-05
# it 25001, val loss = 2.187923e-05
# it 26001, val loss = 2.209921e-05
# it 27001, val loss = 9.353150e-05
# it 28001, val loss = 4.325111e-05
# it 29001, val loss = 1.842069e-05

# %%
def get_P_pretraining_plot(F, X,Y,Lambda_params, model):
    F_xx=F[0,0]
    F_xy=F[0,1]
    F_yx=F[1,0]
    F_yy=F[1,1]
    #F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_pretraining_plot_vmap = vmap(get_P_pretraining_plot, in_axes=(0,0,0,None,None), out_axes=(0,0,0,0))
lmb_hist_plot = [1.05, 1.10, 1.15, 1.20]
t_hist = len(lmb_hist_plot )
n_plots = len(lmb_hist_plot)  
n_cols = 4
n_rows = (n_plots + n_cols - 1) // n_cols 
t_hist =np.arange(0, t_hist)
# c_range=np.ones((n_cols,2))
# c_range[:,[0]]=100000*c_range[:,[0]]
# c_range[:,[1]]=-100000*c_range[:,[1]]
ff_nn_ff = lambda x, params: ff_nn(x, params)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_y = axes_y.flatten()
for lam in lmb_hist_plot:
    ax_x = axes_x[id_for_range]
    ax_y = axes_y[id_for_range]
    uniform_F= lam *np.eye(2).reshape(1, 2, 2)
    uniform_F_batch= np.repeat(uniform_F, elem_X.shape[0], axis=0)
    P_xx, P_xy,P_yx,P_yy=get_P_pretraining_plot_vmap(uniform_F_batch, elem_X[:,0],elem_X[:,1],Lambda_params,NODE_w_unravel)
    title=fr'$P_{{xx}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_xx,title=title, ax=ax_x)
    title=fr'$P_{{yy}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_yy,title=title, ax=ax_y)
    id_for_range+=1

# %%
with open('purdue_prob_paper_second_pretraining.pickle', 'wb') as f:
    pickle.dump([Lambda_params,val_loss, metrics], f)

# %% [markdown]
# ## 2. Retrain

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 20000, print_freq=1000, batch_size=1000)

with open('purde_prob_paper_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-11-23 23:42:43.716703: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-11-23 23:46:29.916134: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 5m46.20222822s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 7.079658e-01
# it 1001, val loss = 3.320977e-01
# it 2001, val loss = 4.951148e-01
# it 3001, val loss = 7.133898e-02
# it 4001, val loss = 1.298570e-01
# it 5001, val loss = 4.113757e-01
# it 6001, val loss = 1.891917e-01
# it 7001, val loss = 2.452543e-01
# it 8001, val loss = 5.597057e-01
# it 9001, val loss = 1.304070e-01
# it 10001, val loss = 2.323600e-01
# it 11001, val loss = 7.628143e-02
# it 12001, val loss = 2.136410e-01
# it 13001, val loss = 1.743743e-01
# it 14001, val loss = 8.134059e-02
# it 15001, val loss = 1.836332e-01
# it 16001, val loss = 5.186345e-02
# it 17001, val loss = 2.138335e-01
# it 18001, val loss = 3.558399e-01
# it 19001, val loss = 2.656189e-01

# %% [markdown]
# ## 3. Test

# %%
with open('purde_prob_paper_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
mat1_params = coords_2_params_gt([0.0,0.0])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.35)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.0, 0.0]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
elem_X = mesh.points[mesh.cells].mean(1)


params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)



# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [05-23 09:02:01][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:02:01][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:02:01][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:02:01][DEBUG] jax_fem: Done pre-computations, took 0.31884193420410156 [s]
# [05-23 09:02:01][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:02:01][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:02:01][DEBUG] jax_fem: Start timing
# [05-23 09:02:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:04][DEBUG] jax_fem: Function split_and_compute_cell took 2.5223 seconds
# [05-23 09:02:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:04][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:02:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:04][DEBUG] jax_fem: PETSc linear solve res = 0.053708384166010245
# [05-23 09:02:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [05-23 09:02:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:04][DEBUG] jax_fem: Before, res l_2 = 305166.08786536794
# [05-23 09:02:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:04][DEBUG] jax_fem: PETSc linear solve res = 0.01988853412445046
# [05-23 09:02:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0281 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 122370.34987259388
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:05][DEBUG] jax_fem: PETSc linear solve res = 0.01948392987300144
# [05-23 09:02:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0317 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 115234.2940386903
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:05][DEBUG] jax_fem: PETSc linear solve res = 0.031702177026270324
# [05-23 09:02:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0273 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 563431767.2780468
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:05][DEBUG] jax_fem: PETSc linear solve res = 114.67364715301107
# [05-23 09:02:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 50252683557111.62
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:05][DEBUG] jax_fem: PETSc linear solve res = 4229997.379760535
# [05-23 09:02:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 274869144564414.38
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:05][DEBUG] jax_fem: PETSc linear solve res = 54638612.650197394
# [05-23 09:02:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0262 seconds
# [05-23 09:02:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:05][DEBUG] jax_fem: res l_2 = 1.7247280850147936e+16
# [05-23 09:02:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:06][DEBUG] jax_fem: PETSc linear solve res = 1.6422876409007976e+16
# [05-23 09:02:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0261 seconds
# [05-23 09:02:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:06][DEBUG] jax_fem: res l_2 = 6.705329193116174e+50
# [05-23 09:02:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:06][DEBUG] jax_fem: PETSc linear solve res = 6.632978349770882e+45
# [05-23 09:02:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0256 seconds
# [05-23 09:02:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:06][DEBUG] jax_fem: res l_2 = 4.84891837854027e+79
# [05-23 09:02:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:06][DEBUG] jax_fem: PETSc linear solve res = 9.621176093391754e+73
# [05-23 09:02:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0268 seconds
# [05-23 09:02:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:06][DEBUG] jax_fem: res l_2 = 1.608753816586358e+117
# [05-23 09:02:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:06][DEBUG] jax_fem: PETSc linear solve res = 5.238194459152152e+112
# [05-23 09:02:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0265 seconds
# [05-23 09:02:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:06][DEBUG] jax_fem: res l_2 = inf
# [05-23 09:02:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:02:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:02:06][DEBUG] jax_fem: PETSc linear solve res = inf
# [05-23 09:02:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:02:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0259 seconds
# [05-23 09:02:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:02:06][DEBUG] jax_fem: res l_2 = nan
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 66
#      57 problem = HyperElasticity(mesh,
#      58                         vec=2,
#      59                         dim=2,
#      60                         ele_type=ele_type,
#      61                         dirichlet_bc_info=dirichlet_bc_info)
#      63 problem.set_params(params_vec)
# ---> 66 node_x = solver(problem, use_petsc=True)
#      67 u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
#      68 F = u_grad + np.eye(2)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:849, in solver(problem, linear, precond, initial_guess, use_petsc)
#     846 # TODO: print platform jax.lib.xla_bridge.get_backend().platform
#     847 # and suggest PETSc or jax solver
#     848 if problem.periodic_bc_info is None:
# --> 849     return solver_row_elimination(problem, linear, precond, initial_guess,
#     850                                   use_petsc)
#     851 else:
#     852     return solver_lagrange_multiplier(problem, linear, use_petsc)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:393, in solver_row_elimination(problem, linear, precond, initial_guess, use_petsc)
#     390         res_val = np.linalg.norm(res_vec)
#     391         logger.debug(f"res l_2 = {res_val}")
# --> 393 assert np.all(
#     394     np.isfinite(res_val)), f"res_val contains NaN, stop the program!"
#     396 assert np.all(np.isfinite(dofs)), f"dofs contains NaN, stop the program!"
#     398 sol = dofs.reshape(sol_shape)
#
# AssertionError: res_val contains NaN, stop the program!

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
