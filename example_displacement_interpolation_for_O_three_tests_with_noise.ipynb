# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd
from utils import coords_2_strain_nn_vmap
from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, plotmesh_updated, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('/home/amir/inverse_prob/O.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
u_hist_goh=[]
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    # dirichlet_bc_info = [
    #     [bottom,            top],
    #     [1,                 1 ],
    #     [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max)]
    # ]
    # dirichlet_bc_info = [
    #     [left, right],
    #     [0, 0],
    #     [zero_dirichlet,lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    middle_displacements = []
    for element in mesh.cells:
       element_displacements = u[element,:]
       middle_displacements.append(np.mean(element_displacements, axis=0))
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    u_hist_goh.append(np.array(middle_displacements))
    # u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    # F = u_grad + np.eye(2)

    # P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    # F_hist_goh.append(F)
    # P_hist_goh.append(P)
# F_hist_goh = np.array(F_hist_goh)
# P_hist_goh = np.array(P_hist_goh)
# Out:
# [10-10 11:45:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:45:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:45:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:45:38][DEBUG] jax_fem: Done pre-computations, took 0.5163211822509766 [s]
# [10-10 11:45:38][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:45:42][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:45:42][DEBUG] jax_fem: Start timing
# [10-10 11:45:42][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:44][DEBUG] jax_fem: Function split_and_compute_cell took 1.8826 seconds
# [10-10 11:45:44][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:45][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:45:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:45][DEBUG] jax_fem: PETSc linear solve res = 2.804120597507043e-06
# [10-10 11:45:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0399 seconds
# [10-10 11:45:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:45][DEBUG] jax_fem: Before, res l_2 = 0.003115044331343982
# [10-10 11:45:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:45][DEBUG] jax_fem: PETSc linear solve res = 4.265197761724921e-09
# [10-10 11:45:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0399 seconds
# [10-10 11:45:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:45][DEBUG] jax_fem: res l_2 = 6.918703760640068e-06
# [10-10 11:45:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:45][DEBUG] jax_fem: PETSc linear solve res = 3.862768592805902e-12
# [10-10 11:45:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0363 seconds
# [10-10 11:45:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:45][DEBUG] jax_fem: res l_2 = 5.509094357290201e-11
# [10-10 11:45:45][INFO] jax_fem: Solve took 3.653977394104004 [s]
# [10-10 11:45:45][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [10-10 11:45:45][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:45:45][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:45:45][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:45:45][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:45:45][DEBUG] jax_fem: Done pre-computations, took 0.04723167419433594 [s]
# [10-10 11:45:45][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:45:48][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:45:48][DEBUG] jax_fem: Start timing
# [10-10 11:45:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:50][DEBUG] jax_fem: Function split_and_compute_cell took 1.2690 seconds
# [10-10 11:45:50][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:50][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:45:50][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:50][DEBUG] jax_fem: PETSc linear solve res = 3.942662351429631e-06
# [10-10 11:45:50][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:50][DEBUG] jax_fem: Function split_and_compute_cell took 0.0438 seconds
# [10-10 11:45:50][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:50][DEBUG] jax_fem: Before, res l_2 = 0.005518449789912624
# [10-10 11:45:50][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:50][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:50][DEBUG] jax_fem: PETSc linear solve res = 4.692608116915166e-09
# [10-10 11:45:50][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:50][DEBUG] jax_fem: Function split_and_compute_cell took 0.0359 seconds
# [10-10 11:45:50][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:50][DEBUG] jax_fem: res l_2 = 2.0974664721776265e-05
# [10-10 11:45:50][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:50][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:50][DEBUG] jax_fem: PETSc linear solve res = 4.775761539170237e-11
# [10-10 11:45:50][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:50][DEBUG] jax_fem: Function split_and_compute_cell took 0.0349 seconds
# [10-10 11:45:50][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:50][DEBUG] jax_fem: res l_2 = 5.067926830932601e-10
# [10-10 11:45:50][INFO] jax_fem: Solve took 1.6558032035827637 [s]
# [10-10 11:45:50][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [10-10 11:45:50][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:45:50][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:45:50][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:45:50][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:45:50][DEBUG] jax_fem: Done pre-computations, took 0.045705318450927734 [s]
# [10-10 11:45:50][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:45:53][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:45:53][DEBUG] jax_fem: Start timing
# [10-10 11:45:53][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:54][DEBUG] jax_fem: Function split_and_compute_cell took 1.1295 seconds
# [10-10 11:45:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:54][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:45:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:54][DEBUG] jax_fem: PETSc linear solve res = 5.090814179065092e-06
# [10-10 11:45:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0478 seconds
# [10-10 11:45:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:54][DEBUG] jax_fem: Before, res l_2 = 0.008202950402131178
# [10-10 11:45:54][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:54][DEBUG] jax_fem: PETSc linear solve res = 1.550277060477305e-08
# [10-10 11:45:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0363 seconds
# [10-10 11:45:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:54][DEBUG] jax_fem: res l_2 = 4.457430027707671e-05
# [10-10 11:45:54][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:54][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:54][DEBUG] jax_fem: PETSc linear solve res = 8.099491363860986e-11
# [10-10 11:45:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:54][DEBUG] jax_fem: Function split_and_compute_cell took 0.0457 seconds
# [10-10 11:45:54][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:54][DEBUG] jax_fem: res l_2 = 2.2877461326189266e-09
# [10-10 11:45:54][INFO] jax_fem: Solve took 1.5532996654510498 [s]
# [10-10 11:45:54][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [10-10 11:45:54][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:45:54][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:45:54][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:45:54][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:45:54][DEBUG] jax_fem: Done pre-computations, took 0.04389619827270508 [s]
# [10-10 11:45:54][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:45:57][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:45:57][DEBUG] jax_fem: Start timing
# [10-10 11:45:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:58][DEBUG] jax_fem: Function split_and_compute_cell took 1.0585 seconds
# [10-10 11:45:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:58][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:45:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:58][DEBUG] jax_fem: PETSc linear solve res = 6.2344138722354365e-06
# [10-10 11:45:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0474 seconds
# [10-10 11:45:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:58][DEBUG] jax_fem: Before, res l_2 = 0.010959471936286215
# [10-10 11:45:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:58][DEBUG] jax_fem: PETSc linear solve res = 2.026852891997358e-08
# [10-10 11:45:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0368 seconds
# [10-10 11:45:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:59][DEBUG] jax_fem: res l_2 = 7.60415997024158e-05
# [10-10 11:45:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:45:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:45:59][DEBUG] jax_fem: PETSc linear solve res = 1.0224248752867713e-10
# [10-10 11:45:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:45:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0361 seconds
# [10-10 11:45:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:45:59][DEBUG] jax_fem: res l_2 = 6.657818058646402e-09
# [10-10 11:45:59][INFO] jax_fem: Solve took 1.4656102657318115 [s]
# [10-10 11:45:59][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [10-10 11:45:59][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:45:59][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:45:59][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:45:59][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:45:59][DEBUG] jax_fem: Done pre-computations, took 0.04223990440368652 [s]
# [10-10 11:45:59][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:02][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:02][DEBUG] jax_fem: Start timing
# [10-10 11:46:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:03][DEBUG] jax_fem: Function split_and_compute_cell took 1.0159 seconds
# [10-10 11:46:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:03][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:03][DEBUG] jax_fem: PETSc linear solve res = 7.378013555759292e-06
# [10-10 11:46:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0381 seconds
# [10-10 11:46:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:03][DEBUG] jax_fem: Before, res l_2 = 0.01366815541833411
# [10-10 11:46:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:03][DEBUG] jax_fem: PETSc linear solve res = 1.931552664662326e-08
# [10-10 11:46:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0399 seconds
# [10-10 11:46:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:03][DEBUG] jax_fem: res l_2 = 0.00011234635260997274
# [10-10 11:46:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:03][DEBUG] jax_fem: PETSc linear solve res = 1.2353560627895803e-10
# [10-10 11:46:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0356 seconds
# [10-10 11:46:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:03][DEBUG] jax_fem: res l_2 = 1.445928100571643e-08
# [10-10 11:46:03][INFO] jax_fem: Solve took 1.4683549404144287 [s]
# [10-10 11:46:03][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [10-10 11:46:03][DEBUG] jax_fem: min of sol = 0.0

# %%
# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
for lmb_max in lmb_hist:
    # dirichlet_bc_info = [
    #     [bottom,            top],
    #     [1,                 1 ],
    #     [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max)]
    # ]
    # dirichlet_bc_info = [
    #     [left, right],
    #     [0, 0],
    #     [zero_dirichlet,lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    dirichlet_bc_info = [
        [bottom,         top,                                     ],
        [1,              1,                                       ],
        [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    middle_displacements = []
    for element in mesh.cells:
       element_displacements = u[element,:]
       middle_displacements.append(np.mean(element_displacements, axis=0))
    u_hist_goh.append(np.array(middle_displacements))
    # u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    # F = u_grad + np.eye(2)

    # P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    # F_hist_goh.append(F)
    # P_hist_goh.append(P)
# Out:
# [10-10 11:46:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:03][DEBUG] jax_fem: Done pre-computations, took 0.04103446006774902 [s]
# [10-10 11:46:03][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:06][DEBUG] jax_fem: Start timing
# [10-10 11:46:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:07][DEBUG] jax_fem: Function split_and_compute_cell took 1.0354 seconds
# [10-10 11:46:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:07][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:07][DEBUG] jax_fem: PETSc linear solve res = 9.492041927642487e-07
# [10-10 11:46:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0450 seconds
# [10-10 11:46:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:07][DEBUG] jax_fem: Before, res l_2 = 0.0009216769784098309
# [10-10 11:46:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:07][DEBUG] jax_fem: PETSc linear solve res = 3.0609988802076327e-09
# [10-10 11:46:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0344 seconds
# [10-10 11:46:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:07][DEBUG] jax_fem: res l_2 = 1.1977821378827656e-06
# [10-10 11:46:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:07][DEBUG] jax_fem: PETSc linear solve res = 2.4473007653491214e-12
# [10-10 11:46:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0359 seconds
# [10-10 11:46:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:07][DEBUG] jax_fem: res l_2 = 3.64165772031814e-12
# [10-10 11:46:07][INFO] jax_fem: Solve took 1.4432744979858398 [s]
# [10-10 11:46:07][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [10-10 11:46:07][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:46:07][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:07][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:07][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:07][DEBUG] jax_fem: Done pre-computations, took 0.03398585319519043 [s]
# [10-10 11:46:07][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:10][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:10][DEBUG] jax_fem: Start timing
# [10-10 11:46:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:11][DEBUG] jax_fem: Function split_and_compute_cell took 1.0182 seconds
# [10-10 11:46:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:11][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:11][DEBUG] jax_fem: PETSc linear solve res = 1.334604376417072e-06
# [10-10 11:46:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0378 seconds
# [10-10 11:46:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:11][DEBUG] jax_fem: Before, res l_2 = 0.001996919662279909
# [10-10 11:46:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:11][DEBUG] jax_fem: PETSc linear solve res = 1.1629928071943836e-08
# [10-10 11:46:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0341 seconds
# [10-10 11:46:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:11][DEBUG] jax_fem: res l_2 = 5.622804459416235e-06
# [10-10 11:46:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:11][DEBUG] jax_fem: PETSc linear solve res = 1.3107085823933744e-11
# [10-10 11:46:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0338 seconds
# [10-10 11:46:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:12][DEBUG] jax_fem: res l_2 = 5.982647941544437e-11
# [10-10 11:46:12][INFO] jax_fem: Solve took 1.4296236038208008 [s]
# [10-10 11:46:12][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [10-10 11:46:12][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:46:12][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:12][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:12][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:12][DEBUG] jax_fem: Done pre-computations, took 0.03400301933288574 [s]
# [10-10 11:46:12][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:15][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:15][DEBUG] jax_fem: Start timing
# [10-10 11:46:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:16][DEBUG] jax_fem: Function split_and_compute_cell took 1.0681 seconds
# [10-10 11:46:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:16][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:16][DEBUG] jax_fem: PETSc linear solve res = 1.723257603449373e-06
# [10-10 11:46:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0523 seconds
# [10-10 11:46:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:16][DEBUG] jax_fem: Before, res l_2 = 0.00346712873658895
# [10-10 11:46:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:16][DEBUG] jax_fem: PETSc linear solve res = 8.342633354745415e-09
# [10-10 11:46:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0348 seconds
# [10-10 11:46:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:16][DEBUG] jax_fem: res l_2 = 1.6871273653778703e-05
# [10-10 11:46:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:16][DEBUG] jax_fem: PETSc linear solve res = 3.1049678992372207e-11
# [10-10 11:46:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0372 seconds
# [10-10 11:46:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:16][DEBUG] jax_fem: res l_2 = 5.168836434706702e-10
# [10-10 11:46:16][INFO] jax_fem: Solve took 1.4530079364776611 [s]
# [10-10 11:46:16][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [10-10 11:46:16][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:46:16][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:16][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:16][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:16][DEBUG] jax_fem: Done pre-computations, took 0.036284446716308594 [s]
# [10-10 11:46:16][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:19][DEBUG] jax_fem: Start timing
# [10-10 11:46:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:20][DEBUG] jax_fem: Function split_and_compute_cell took 1.1135 seconds
# [10-10 11:46:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:20][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:20][DEBUG] jax_fem: PETSc linear solve res = 2.11036992355908e-06
# [10-10 11:46:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0626 seconds
# [10-10 11:46:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:20][DEBUG] jax_fem: Before, res l_2 = 0.005291705281408901
# [10-10 11:46:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:20][DEBUG] jax_fem: PETSc linear solve res = 1.612297014057509e-08
# [10-10 11:46:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0401 seconds
# [10-10 11:46:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:20][DEBUG] jax_fem: res l_2 = 3.91708689928427e-05
# [10-10 11:46:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:20][DEBUG] jax_fem: PETSc linear solve res = 2.064796171563913e-10
# [10-10 11:46:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0358 seconds
# [10-10 11:46:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:20][DEBUG] jax_fem: res l_2 = 2.759507841042043e-09
# [10-10 11:46:20][INFO] jax_fem: Solve took 1.5303261280059814 [s]
# [10-10 11:46:20][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [10-10 11:46:20][DEBUG] jax_fem: min of sol = 0.0
# [10-10 11:46:21][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:21][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:21][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:21][DEBUG] jax_fem: Done pre-computations, took 0.037024736404418945 [s]
# [10-10 11:46:21][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:23][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:23][DEBUG] jax_fem: Start timing
# [10-10 11:46:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:24][DEBUG] jax_fem: Function split_and_compute_cell took 1.0920 seconds
# [10-10 11:46:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:25][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:25][DEBUG] jax_fem: PETSc linear solve res = 2.497482242340437e-06
# [10-10 11:46:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0595 seconds
# [10-10 11:46:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:25][DEBUG] jax_fem: Before, res l_2 = 0.0074570566014241875
# [10-10 11:46:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:25][DEBUG] jax_fem: PETSc linear solve res = 2.7053147331571813e-08
# [10-10 11:46:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0345 seconds
# [10-10 11:46:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:25][DEBUG] jax_fem: res l_2 = 7.758624358300668e-05
# [10-10 11:46:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:25][DEBUG] jax_fem: PETSc linear solve res = 2.195255080946353e-10
# [10-10 11:46:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0396 seconds
# [10-10 11:46:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:25][DEBUG] jax_fem: res l_2 = 1.070252793384724e-08
# [10-10 11:46:25][INFO] jax_fem: Solve took 1.488048791885376 [s]
# [10-10 11:46:25][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [10-10 11:46:25][DEBUG] jax_fem: min of sol = 0.0

# %%
# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
for lmb_max in lmb_hist:
    # dirichlet_bc_info = [
    #     [bottom,            top],
    #     [1,                 1 ],
    #     [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max)]
    # ]
    # dirichlet_bc_info = [
    #     [left, right],
    #     [0, 0],
    #     [zero_dirichlet,lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    dirichlet_bc_info = [
        [left,           right,                                  ],
        [0,              0,                                      ],
        [zero_dirichlet, lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    middle_displacements = []
    for element in mesh.cells:
       element_displacements = u[element,:]
       middle_displacements.append(np.mean(element_displacements, axis=0))
    u_hist_goh.append(np.array(middle_displacements))
    # u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    # F = u_grad + np.eye(2)

    # P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    # F_hist_goh.append(F)
    # P_hist_goh.append(P)
# F_hist_goh = np.array(F_hist_goh)
# P_hist_goh = np.array(P_hist_goh)
u_hist_goh = np.array(u_hist_goh)
# Out:
# [10-10 11:46:25][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:25][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:25][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:25][DEBUG] jax_fem: Done pre-computations, took 0.042594194412231445 [s]
# [10-10 11:46:25][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:28][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:28][DEBUG] jax_fem: Start timing
# [10-10 11:46:28][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:29][DEBUG] jax_fem: Function split_and_compute_cell took 1.1099 seconds
# [10-10 11:46:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:29][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:29][DEBUG] jax_fem: PETSc linear solve res = 1.3085752311788642e-06
# [10-10 11:46:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0425 seconds
# [10-10 11:46:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:29][DEBUG] jax_fem: Before, res l_2 = 0.00136238361199908
# [10-10 11:46:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:29][DEBUG] jax_fem: PETSc linear solve res = 3.215774641997186e-09
# [10-10 11:46:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0385 seconds
# [10-10 11:46:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:29][DEBUG] jax_fem: res l_2 = 2.550777243519862e-06
# [10-10 11:46:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:29][DEBUG] jax_fem: PETSc linear solve res = 5.193194206028334e-12
# [10-10 11:46:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0438 seconds
# [10-10 11:46:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:29][DEBUG] jax_fem: res l_2 = 1.196938142876001e-11
# [10-10 11:46:29][INFO] jax_fem: Solve took 1.5772387981414795 [s]
# [10-10 11:46:29][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [10-10 11:46:29][DEBUG] jax_fem: min of sol = -0.006231385807744282
# [10-10 11:46:29][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:29][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:29][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:30][DEBUG] jax_fem: Done pre-computations, took 0.0340120792388916 [s]
# [10-10 11:46:30][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:32][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:32][DEBUG] jax_fem: Start timing
# [10-10 11:46:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:33][DEBUG] jax_fem: Function split_and_compute_cell took 1.0363 seconds
# [10-10 11:46:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:33][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:33][DEBUG] jax_fem: PETSc linear solve res = 1.8398888756495452e-06
# [10-10 11:46:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0479 seconds
# [10-10 11:46:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:34][DEBUG] jax_fem: Before, res l_2 = 0.002642787334664008
# [10-10 11:46:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:34][DEBUG] jax_fem: PETSc linear solve res = 1.1684395780310012e-08
# [10-10 11:46:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0355 seconds
# [10-10 11:46:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:34][DEBUG] jax_fem: res l_2 = 9.614823962409939e-06
# [10-10 11:46:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:34][DEBUG] jax_fem: PETSc linear solve res = 1.567249568712909e-11
# [10-10 11:46:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0343 seconds
# [10-10 11:46:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:34][DEBUG] jax_fem: res l_2 = 1.5550158488328087e-10
# [10-10 11:46:34][INFO] jax_fem: Solve took 1.4218471050262451 [s]
# [10-10 11:46:34][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [10-10 11:46:34][DEBUG] jax_fem: min of sol = -0.00845622743421551
# [10-10 11:46:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:34][DEBUG] jax_fem: Done pre-computations, took 0.03406095504760742 [s]
# [10-10 11:46:34][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:37][DEBUG] jax_fem: Start timing
# [10-10 11:46:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:38][DEBUG] jax_fem: Function split_and_compute_cell took 1.3589 seconds
# [10-10 11:46:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:38][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:38][DEBUG] jax_fem: PETSc linear solve res = 2.375687174715139e-06
# [10-10 11:46:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0374 seconds
# [10-10 11:46:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:38][DEBUG] jax_fem: Before, res l_2 = 0.004315876475377175
# [10-10 11:46:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:38][DEBUG] jax_fem: PETSc linear solve res = 1.08734312294906e-08
# [10-10 11:46:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0353 seconds
# [10-10 11:46:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:38][DEBUG] jax_fem: res l_2 = 2.569861621917532e-05
# [10-10 11:46:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:38][DEBUG] jax_fem: PETSc linear solve res = 4.903376461297645e-11
# [10-10 11:46:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0366 seconds
# [10-10 11:46:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:38][DEBUG] jax_fem: res l_2 = 1.1134308352916129e-09
# [10-10 11:46:38][INFO] jax_fem: Solve took 1.7185680866241455 [s]
# [10-10 11:46:38][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [10-10 11:46:38][DEBUG] jax_fem: min of sol = -0.01053517149661138
# [10-10 11:46:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:38][DEBUG] jax_fem: Done pre-computations, took 0.03699541091918945 [s]
# [10-10 11:46:38][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:41][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:41][DEBUG] jax_fem: Start timing
# [10-10 11:46:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:42][DEBUG] jax_fem: Function split_and_compute_cell took 1.0800 seconds
# [10-10 11:46:42][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:42][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:42][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:43][DEBUG] jax_fem: PETSc linear solve res = 2.9093611640563736e-06
# [10-10 11:46:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0394 seconds
# [10-10 11:46:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:43][DEBUG] jax_fem: Before, res l_2 = 0.006342321208145418
# [10-10 11:46:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:43][DEBUG] jax_fem: PETSc linear solve res = 2.3776704947687414e-08
# [10-10 11:46:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0362 seconds
# [10-10 11:46:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:43][DEBUG] jax_fem: res l_2 = 5.5632292354953376e-05
# [10-10 11:46:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:43][DEBUG] jax_fem: PETSc linear solve res = 1.9629618332345632e-10
# [10-10 11:46:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0340 seconds
# [10-10 11:46:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:43][DEBUG] jax_fem: res l_2 = 5.257068060266507e-09
# [10-10 11:46:43][INFO] jax_fem: Solve took 1.5064234733581543 [s]
# [10-10 11:46:43][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [10-10 11:46:43][DEBUG] jax_fem: min of sol = -0.01244989882005586
# [10-10 11:46:43][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-10 11:46:43][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-10 11:46:43][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-10 11:46:43][DEBUG] jax_fem: Done pre-computations, took 0.03439927101135254 [s]
# [10-10 11:46:43][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-10 11:46:46][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-10 11:46:46][DEBUG] jax_fem: Start timing
# [10-10 11:46:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:47][DEBUG] jax_fem: Function split_and_compute_cell took 1.0440 seconds
# [10-10 11:46:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:47][DEBUG] jax_fem: Linear guess solve...
# [10-10 11:46:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:47][DEBUG] jax_fem: PETSc linear solve res = 3.44303515088016e-06
# [10-10 11:46:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:47][DEBUG] jax_fem: Function split_and_compute_cell took 0.0555 seconds
# [10-10 11:46:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:47][DEBUG] jax_fem: Before, res l_2 = 0.008711779038391172
# [10-10 11:46:47][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:47][DEBUG] jax_fem: PETSc linear solve res = 1.8328453976253636e-08
# [10-10 11:46:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:47][DEBUG] jax_fem: Function split_and_compute_cell took 0.0347 seconds
# [10-10 11:46:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:47][DEBUG] jax_fem: res l_2 = 0.00010522987302031811
# [10-10 11:46:47][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-10 11:46:47][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-10 11:46:47][DEBUG] jax_fem: PETSc linear solve res = 3.836290220839504e-10
# [10-10 11:46:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-10 11:46:47][DEBUG] jax_fem: Function split_and_compute_cell took 0.0376 seconds
# [10-10 11:46:47][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-10 11:46:47][DEBUG] jax_fem: res l_2 = 1.8956251120989817e-08
# [10-10 11:46:47][INFO] jax_fem: Solve took 1.4378507137298584 [s]
# [10-10 11:46:47][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [10-10 11:46:47][DEBUG] jax_fem: min of sol = -0.014216786122116335

# %%
displacements = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587, 
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587, 
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587]

n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 

fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

axes_x = axes_x.flatten()
axes_y = axes_y.flatten()

for idx, (lmb_i, t, u) in enumerate(zip(lmb_hist_plot, t_hist, u_hist_goh)):
    key = random.PRNGKey(t)
    noise = jax.random.normal(key, shape=u.shape)
    mu=0
    sigma=.005
    scale_noise=mu + sigma * noise
    noise_scale = 1
    u_noisy = u + noise_scale * noise
    u_noisy_x = u_noisy[:, [0]].flatten()
    u_noisy_y = u_noisy[:, [1]].flatten()

    ax_x = axes_x[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_x, title=f'displacement_x [-]', ax=ax_x)

    ax_y = axes_y[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_y, title=f'displacement_y [-]', ax=ax_y)

    displacements.append(np.array([t * np.ones(len(u)), u_noisy[:, 0], u_noisy[:, 1]]))

for i in range(n_plots, len(axes_x)):
    fig_x.delaxes(axes_x[i])
for i in range(n_plots, len(axes_y)):
    fig_y.delaxes(axes_y[i])

fig_x.tight_layout()
fig_y.tight_layout()

plt.show()

displacements = np.hstack(displacements)

# %%
def loss_coords_2_disp(nn_params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] # X consists of 5 columns: X, Y, lmb (time), ux, uy. The first 3 are inputs of the NN and the last 2 the outputs.
    out_pr = coords_2_strain_nn(inp, [ff_params, nn_params])
    return jnp.mean((out_pr-out_gt)**2)
n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5

nn_layers = [2*n_ff+1,40,40,2] # +1 because t is not fed into the fourier features part
nn_params = init_params_nn(nn_layers, key)

# lr = optimizers.exponential_decay(8e-4, 10000, 0.9)
lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
# lr = 5e-4
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init(nn_params)

X = np.vstack([elem_X]*len(u_hist_goh))
inp = np.hstack([X, displacements.T])
nn_params, train_loss, _ = train(loss_coords_2_disp, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000)
coord_2_strain_params = [ff_params, nn_params]
# Out:
# it 1000, train loss = 2.837146e+01
# it 2000, train loss = 2.363254e+01
# it 3000, train loss = 2.194267e+01
# it 4000, train loss = 2.172896e+01
# it 5000, train loss = 3.597504e+01
# it 6000, train loss = 1.245120e+01
# it 7000, train loss = 9.698178e+00
# it 8000, train loss = 1.171947e+01
# it 9000, train loss = 7.711599e+00
# it 10000, train loss = 6.781146e+00
# it 11000, train loss = 5.914297e+00
# it 12000, train loss = 4.958687e+00
# it 13000, train loss = 4.015728e+00
# it 14000, train loss = 3.262494e+00
# it 15000, train loss = 2.716350e+00
# it 16000, train loss = 2.099106e+00
# it 17000, train loss = 2.340903e+00
# it 18000, train loss = 1.557926e+00
# it 19000, train loss = 1.447086e+00
# it 20000, train loss = 1.356752e+00
# it 21000, train loss = 1.161624e+00
# it 22000, train loss = 1.327541e+00
# it 23000, train loss = 9.692195e-01
# it 24000, train loss = 9.218363e-01
# it 25000, train loss = 9.993381e-01
# it 26000, train loss = 8.492709e-01
# it 27000, train loss = 9.151343e-01
# it 28000, train loss = 8.071810e-01
# it 29000, train loss = 7.545622e-01
# it 30000, train loss = 7.217337e-01
# it 31000, train loss = 7.498852e-01
# it 32000, train loss = 6.845085e-01
# it 33000, train loss = 6.537117e-01
# it 34000, train loss = 6.789996e-01
# it 35000, train loss = 5.834673e-01
# it 36000, train loss = 7.098722e-01
# it 37000, train loss = 5.427472e-01
# it 38000, train loss = 6.052974e-01
# it 39000, train loss = 9.606181e-01
# it 40000, train loss = 4.593035e-01
# it 41000, train loss = 4.238146e-01
# it 42000, train loss = 5.218918e-01
# it 43000, train loss = 4.987360e-01
# it 44000, train loss = 3.607649e-01
# it 45000, train loss = 3.321847e-01
# it 46000, train loss = 4.670355e-01
# it 47000, train loss = 3.055235e-01
# it 48000, train loss = 3.527876e-01
# it 49000, train loss = 2.855124e-01
# it 50000, train loss = 2.805081e-01
# it 51000, train loss = 2.705873e-01
# it 52000, train loss = 5.586227e-01
# it 53000, train loss = 7.433258e-01
# it 54000, train loss = 2.675027e-01
# it 55000, train loss = 3.139026e-01
# it 56000, train loss = 2.989171e-01
# it 57000, train loss = 2.441289e-01
# it 58000, train loss = 2.425568e-01
# it 59000, train loss = 3.305050e-01
# it 60000, train loss = 3.254771e-01
# it 61000, train loss = 2.524538e-01
# it 62000, train loss = 2.308745e-01
# it 63000, train loss = 2.324873e-01
# it 64000, train loss = 2.263341e-01
# it 65000, train loss = 2.382890e-01
# it 66000, train loss = 2.254682e-01
# it 67000, train loss = 2.403879e-01
# it 68000, train loss = 2.899779e-01
# it 69000, train loss = 2.360356e-01
# it 70000, train loss = 3.892600e-01
# it 71000, train loss = 2.277042e-01
# it 72000, train loss = 6.210369e-01
# it 73000, train loss = 2.127432e-01
# it 74000, train loss = 2.123736e-01
# it 75000, train loss = 2.593341e-01
# it 76000, train loss = 2.110720e-01
# it 77000, train loss = 2.097947e-01
# it 78000, train loss = 4.267593e-01
# it 79000, train loss = 2.065680e-01
# it 80000, train loss = 2.068468e-01
# it 81000, train loss = 3.705401e-01
# it 82000, train loss = 2.236191e-01
# it 83000, train loss = 2.086356e-01
# it 84000, train loss = 2.094532e-01
# it 85000, train loss = 2.094390e-01
# it 86000, train loss = 2.017122e-01
# it 87000, train loss = 2.074266e-01
# it 88000, train loss = 2.154104e-01
# it 89000, train loss = 2.056573e-01
# it 90000, train loss = 2.112639e-01
# it 91000, train loss = 2.124664e-01
# it 92000, train loss = 1.997705e-01
# it 93000, train loss = 1.998979e-01
# it 94000, train loss = 2.109441e-01
# it 95000, train loss = 1.988924e-01
# it 96000, train loss = 1.982672e-01
# it 97000, train loss = 2.947820e-01
# it 98000, train loss = 2.405835e-01
# it 99000, train loss = 1.955918e-01
# it 100000, train loss = 2.014380e-01

# %%
coord_2_displacement_params=coord_2_strain_params

# %%
def displacement_intpo(x1,x2,x3,ff_params,nn_params):
  inp=jnp.hstack((x1,x2,x3))
  return coords_2_strain_nn_vmap(inp,[ff_params, nn_params])
X, Y = elem_X[:,[0]],elem_X[:,[1]]
du1_dx1 =grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[0], argnums=0)
du1_dx2=grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[0], argnums=1)

du2_dx1 =grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[1], argnums=0)
du2_dx2=grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[1], argnums=1)
vmap_du1_dx1 = vmap(du1_dx1, in_axes=(0, 0, 0))
vmap_du1_dx2 = vmap(du1_dx2, in_axes=(0, 0, 0))
vmap_du2_dx1 = vmap(du2_dx1 , in_axes=(0, 0, 0))
vmap_du2_dx2 = vmap(du2_dx2, in_axes=(0, 0, 0))
F_hist_goh=[]
P_hist_goh=[]
for t in t_hist:
  #print((t*t_sam).shape)
  us_grad=jnp.hstack((vmap_du1_dx1(X,Y,t*jnp.ones_like(X)),vmap_du1_dx2(X,Y,t*jnp.ones_like(X)),vmap_du2_dx1(X,Y,t*jnp.ones_like(X)),vmap_du2_dx2(X,Y,t*jnp.ones_like(X))))
  F_hist_goh.append(us_grad.reshape((n_elem,2,2))+np.eye(2))
  P = GOH_P_vmap(us_grad.reshape((n_elem,2,2)), params_vec[:,0,:], 2)
  P_hist_goh.append(P)

F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)

# %%
strains = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587, 
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587, 
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
c_range=np.ones((n_cols,2))
c_range[:,[0]]=100000*c_range[:,[0]]
c_range[:,[1]]=-100000*c_range[:,[1]]
id_for_range=0
for i in range(n_rows):
    for j in range(n_cols):
        F=F_hist_goh[id_for_range,:,:,:]
        E = E_fun(F)
        evals, efuns = jnp.linalg.eigh(E)
        E_11, E_22 = evals.T
        ax_x = axes_x[idx]
        mps = np.maximum(E_11, E_22)
        c_range[j,0]=min(c_range[j,0],np.min(mps))
        c_range[j,1]=max(c_range[j,1],np.max(mps))
        id_for_range+=1
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
for idx, (t, F, P) in enumerate(zip(t_hist, F_hist_goh, P_hist_goh)):
    if id_for_range==n_cols:
        id_for_range=0
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    ax_x = axes_x[idx]
    mps = np.maximum(E_11, E_22)
    plotmesh_updated(mesh.cells, mesh.points, mps, c_range[id_for_range,0], c_range[id_for_range,1],title='Max. Princip. Strain [-]', ax=ax_x)
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
strains_gt = np.hstack(strains)
print(c_range)
# Out:
# [[0.01824 0.1296 ]
#  [0.04047 0.17575]
#  [0.05445 0.17231]
#  [0.0622  0.41202]
#  [0.04619 0.26056]]

# %% [markdown]
# ### Coordinates to strains

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 40 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X,elem_X, elem_X, elem_X, elem_X,elem_X, elem_X,\
               elem_X, elem_X, elem_X,elem_X, elem_X])
inp = np.hstack([X, strains_gt.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 4.896959e-05
# it 2000, train loss = 2.888496e-05
# it 3000, train loss = 2.021270e-05
# it 4000, train loss = 1.709679e-05
# it 5000, train loss = 1.558434e-05
# it 6000, train loss = 1.402546e-05
# it 7000, train loss = 1.190269e-05
# it 8000, train loss = 1.065045e-05
# it 9000, train loss = 1.006638e-05
# it 10000, train loss = 8.866477e-06
# it 11000, train loss = 9.480709e-06
# it 12000, train loss = 7.189018e-06
# it 13000, train loss = 6.204673e-06
# it 14000, train loss = 5.057833e-06
# it 15000, train loss = 4.737396e-06
# it 16000, train loss = 4.933586e-06
# it 17000, train loss = 5.025673e-06
# it 18000, train loss = 3.672587e-06
# it 19000, train loss = 3.630684e-06
# it 20000, train loss = 2.951403e-06
# it 21000, train loss = 2.521027e-06
# it 22000, train loss = 2.439249e-06
# it 23000, train loss = 2.056427e-06
# it 24000, train loss = 1.815139e-06
# it 25000, train loss = 2.710267e-06
# it 26000, train loss = 1.549369e-06
# it 27000, train loss = 1.888546e-06
# it 28000, train loss = 1.693691e-06
# it 29000, train loss = 1.713464e-06
# it 30000, train loss = 1.573445e-06
# it 31000, train loss = 1.831970e-06
# it 32000, train loss = 1.505350e-06
# it 33000, train loss = 1.457388e-06
# it 34000, train loss = 1.341997e-06
# it 35000, train loss = 1.316449e-06
# it 36000, train loss = 1.817092e-06
# it 37000, train loss = 1.270657e-06
# it 38000, train loss = 2.393318e-06
# it 39000, train loss = 1.293233e-06
# it 40000, train loss = 1.108622e-06
# it 41000, train loss = 1.098637e-06
# it 42000, train loss = 1.179276e-06
# it 43000, train loss = 1.211209e-06
# it 44000, train loss = 1.270589e-06
# it 45000, train loss = 1.414948e-06
# it 46000, train loss = 1.243394e-06
# it 47000, train loss = 2.443499e-06
# it 48000, train loss = 1.087826e-06
# it 49000, train loss = 1.054030e-06
# it 50000, train loss = 1.277861e-06
# it 51000, train loss = 1.403449e-06
# it 52000, train loss = 1.051428e-06
# it 53000, train loss = 1.208943e-06
# it 54000, train loss = 1.359429e-06
# it 55000, train loss = 1.180631e-06
# it 56000, train loss = 1.317103e-06
# it 57000, train loss = 9.406545e-07
# it 58000, train loss = 9.705597e-07
# it 59000, train loss = 8.829516e-07
# it 60000, train loss = 8.382967e-07
# it 61000, train loss = 9.243429e-07
# it 62000, train loss = 9.007147e-07
# it 63000, train loss = 1.072104e-06
# it 64000, train loss = 2.820146e-06
# it 65000, train loss = 9.323577e-07
# it 66000, train loss = 8.335430e-07
# it 67000, train loss = 8.736962e-07
# it 68000, train loss = 8.079575e-07
# it 69000, train loss = 8.359356e-07
# it 70000, train loss = 8.033393e-07
# it 71000, train loss = 1.623539e-06
# it 72000, train loss = 1.214002e-06
# it 73000, train loss = 1.088268e-06
# it 74000, train loss = 1.059423e-06
# it 75000, train loss = 8.895309e-07
# it 76000, train loss = 6.655899e-07
# it 77000, train loss = 8.185836e-07
# it 78000, train loss = 1.033907e-06
# it 79000, train loss = 7.838535e-07
# it 80000, train loss = 8.919598e-07
# it 81000, train loss = 9.618651e-07
# it 82000, train loss = 9.874139e-07
# it 83000, train loss = 9.212411e-07
# it 84000, train loss = 7.949136e-07
# it 85000, train loss = 8.284190e-07
# it 86000, train loss = 7.342390e-07
# it 87000, train loss = 1.057649e-06
# it 88000, train loss = 6.826955e-07
# it 89000, train loss = 7.226700e-07
# it 90000, train loss = 1.219999e-06
# it 91000, train loss = 7.248134e-07
# it 92000, train loss = 8.080879e-07
# it 93000, train loss = 1.059393e-06
# it 94000, train loss = 6.691595e-07
# it 95000, train loss = 7.041569e-07
# it 96000, train loss = 6.111468e-07
# it 97000, train loss = 9.432284e-07
# it 98000, train loss = 6.874420e-07
# it 99000, train loss = 7.743151e-07
# it 100000, train loss = 6.278502e-07

# %%
strains = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587, 
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587,
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
c_range_for_strain=np.ones((n_cols,2))
c_range_for_strain[:,[0]]=100000*c_range_for_strain[:,[0]]
c_range_for_strain[:,[1]]=-100000*c_range_for_strain[:,[1]]
id_for_range=0
for i in range(n_rows):
    for j in range(n_cols):
        t=t_hist[id_for_range]
        aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
        F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
        F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
        E = E_fun(F)
        evals, efuns = jnp.linalg.eigh(E)
        E_11, E_22 = evals.T
        ax_x = axes_x[idx]
        mps = np.maximum(E_11, E_22)
        c_range_for_strain[j,0]=min(c_range_for_strain[j,0],np.min(mps))
        c_range_for_strain[j,1]=max(c_range_for_strain[j,1],np.max(mps))
        id_for_range+=1
print(c_range_for_strain)
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
for idx, (t) in enumerate(t_hist):
    if id_for_range==n_cols:
        id_for_range=0
    t=t_hist[idx]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    ax_x = axes_x[idx]
    mps = np.maximum(E_11, E_22)
    plotmesh_updated(mesh.cells, mesh.points, mps, c_range_for_strain[id_for_range,0], c_range_for_strain[id_for_range,1],title='Max. Princip. Strain [-]', ax=ax_x)
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
strains = np.hstack(strains)
print(c_range)
# fig, axes = plt.subplots(1,4,figsize=(20,4))
# for t in t_hist:
#     ax = axes[t]
#     aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
#     F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
#     F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
#     E = E_fun(F)
#     evals, efuns = jnp.linalg.eigh(E)
#     E_11, E_22 = evals.T
#     mps = np.maximum(E_11, E_22)

#     plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);
# Out:
# [[0.01166 0.09814]
#  [0.04206 0.12817]
#  [0.06395 0.17659]
#  [0.08147 0.3034 ]
#  [0.03694 0.20971]]
# [[0.01824 0.1296 ]
#  [0.04047 0.17575]
#  [0.05445 0.17231]
#  [0.0622  0.41202]
#  [0.04619 0.26056]]

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
with open('params_for_cluster_ring_biaxial_noisy_3_tests_prob_displacement.npy' ,'wb') as f:
    pickle.dump([coord_2_displacement_params,coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains_gt,strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist,len(rgt_bd_elems),len(top_bd_elems )], f)

# %%
with open('params_for_cluster_ring_biaxial_noisy_3_tests_prob_displacement.npy', 'rb') as f:
    coord_2_displacement_params,coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains_gt,strains, bd_X, \
                 lmb_hist, P_hist_goh, F_hist_goh, t_hist,len_rgt_bd_elems,len_top_bd_elems  = pickle.load(f)

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 9.556606e-02
# it 2000, train loss = 5.802860e-02
# it 3000, train loss = 3.446219e-02
# it 4000, train loss = 2.391356e-02
# it 5000, train loss = 7.030474e-03
# it 6000, train loss = 3.981246e-05
# it 7000, train loss = 3.610921e-05
# it 8000, train loss = 3.052233e-05
# it 9000, train loss = 1.676647e-05
# it 10000, train loss = 8.451532e-06
# it 11000, train loss = 6.305932e-06
# it 12000, train loss = 6.126113e-06
# it 13000, train loss = 6.061621e-06
# it 14000, train loss = 6.056907e-06
# it 15000, train loss = 5.984966e-06
# it 16000, train loss = 5.947917e-06
# it 17000, train loss = 5.904485e-06
# it 18000, train loss = 5.856178e-06
# it 19000, train loss = 5.806323e-06
# it 20000, train loss = 5.758832e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.35711 0.64781 0.89229 1.10484] [0.34491 0.62049 0.84657 1.03693]
# pr P_xx & P_yy:  [0.35575 0.6502  0.89041 1.10539] [0.3437  0.62288 0.84454 1.03756]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.513763e-04
# it 2000, train loss = 3.935676e-05
# it 3000, train loss = 1.593164e-05
# it 4000, train loss = 7.698439e-06
# it 5000, train loss = 4.063821e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/O_sharp_pre_biaxial_one_noise.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/O_sharp_pre_biaxial_one_noise.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 20000, print_freq=1000, batch_size=1000)

with open('params/O_sharp_post_biaxial_one_noise.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)

# %%
plt.plot(val_loss)

# %% [markdown]
# ## 3. Test

# %% [markdown]
# ### pretraining plots

# %%
with open('ring_biaxial_noisy_3_tests_prob_displacement_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh_points,elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
with open('ring_biaxial_noisy_3_tests_displacement_second_pretraining.pickle', 'rb') as f:
    [Lambda_params,val_loss, metrics]=pickle.load(f)
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587,
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587,
                 1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_plots = len(P_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols

# %%
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
axes_y = axes_y.flatten()
for idx, (t) in enumerate(t_hist):
    if id_for_range==n_cols:
        id_for_range=0
    t=t_hist[idx]
    aux = jnp.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    Pxx,Pxy,Pyx,Pyy=get_P_vmap(aux[:,0],aux[:,1], aux[:,2], Lambda_params, coord_2_strain_params,NODE_w_unravel)
    ax_x = axes_x[idx]
    ax_y = axes_y[idx]
    plotmesh(mesh.cells, mesh.points, Pxx,title='Pxx [-]', ax=ax_x)
    plotmesh(mesh.cells, mesh.points, Pyy,title='Pyy[-]', ax=ax_y)

# %%
with open('ring_biaxial_noisy_3_tests_prob_displacement_post.npy', 'rb') as f:
    elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])

# %%
fig, ax = plt.subplots()
ax.plot(val_loss)
ax.set(xlabel='Iteration', ylabel='Validation loss')
# Out:
# [Text(0.5, 0, 'Iteration'), Text(0, 0.5, 'Validation loss')]

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,5,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
mat1_params = coords_2_params_gt([0.5,0.9])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.35)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.5, 0.9]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [01-29 12:02:18][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:18][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:18][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:19][DEBUG] jax_fem: Done pre-computations, took 0.3462047576904297 [s]
# [01-29 12:02:19][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:19][DEBUG] jax_fem: Start timing
# [01-29 12:02:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 2.7130 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 0.0036905625916567415
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: Before, res l_2 = 0.011526985072150886
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 4.767070052561915e-10
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0320 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 0.0011043176920788333
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 3.6825363631446657e-10
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0313 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 1.938881294341329e-06
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 2.061865543736903e-12
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 3.627697207926912e-11
# [01-29 12:02:22][INFO] jax_fem: Solve took 3.5776472091674805 [s]
# [01-29 12:02:22][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [01-29 12:02:22][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:23][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:23][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:23][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:23][DEBUG] jax_fem: Done pre-computations, took 0.042654991149902344 [s]
# [01-29 12:02:23][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:23][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:23][DEBUG] jax_fem: Start timing
# [01-29 12:02:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 2.4059 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 0.007381125183313483
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: Before, res l_2 = 0.03192482705227
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.3654810209482553e-08
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 0.0031246068844033386
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.8600026095675939e-10
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0282 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 1.5502257045814567e-05
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.4221083074155572e-12
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0261 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 8.095624959509216e-10
# [01-29 12:02:26][INFO] jax_fem: Solve took 2.668717622756958 [s]
# [01-29 12:02:26][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [01-29 12:02:26][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:26][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:26][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:26][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:26][DEBUG] jax_fem: Done pre-computations, took 0.04655599594116211 [s]
# [01-29 12:02:26][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:26][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:26][DEBUG] jax_fem: Start timing
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:28][DEBUG] jax_fem: Function split_and_compute_cell took 2.4271 seconds
# [01-29 12:02:28][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 0.001533462192273752
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0276 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: Before, res l_2 = 0.009427350514540385
# [01-29 12:02:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 1.040619907742982e-08
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: res l_2 = 0.00020509918341214526
# [01-29 12:02:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 3.151016361403172e-11
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: res l_2 = 2.5841599304971627e-08
# [01-29 12:02:29][INFO] jax_fem: Solve took 2.6418890953063965 [s]
# [01-29 12:02:29][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [01-29 12:02:29][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:29][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:29][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:29][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:29][DEBUG] jax_fem: Done pre-computations, took 0.04050707817077637 [s]
# [01-29 12:02:29][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:29][DEBUG] jax_fem: Start timing
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 2.4993 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 0.02384338861974766
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0303 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: Before, res l_2 = 0.1572552453489813
# [01-29 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 2.274793598014596e-08
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0284 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: res l_2 = 0.024244543168059376
# [01-29 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 3.7007471141555687e-09
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [01-29 12:02:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:32][DEBUG] jax_fem: res l_2 = 0.0007288910129005116
# [01-29 12:02:32][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:32][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:32][DEBUG] jax_fem: PETSc linear solve res = 6.014778830742415e-10
# [01-29 12:02:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0282 seconds
# [01-29 12:02:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:32][DEBUG] jax_fem: res l_2 = 7.072063636359669e-07
# [01-29 12:02:32][INFO] jax_fem: Solve took 2.7749388217926025 [s]
# [01-29 12:02:32][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [01-29 12:02:32][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
