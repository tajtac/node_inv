# %%
import os
import inspect
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
# from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax,plotmesh_updated

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

def ty(a):
    b = type(a)  # Get the type of `a`
    print(b)  # Print the type
    
    if isinstance(a, np.ndarray): 
        return b, a.shape
    else:
        return b, len(a)
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
from matplotlib.colors import LinearSegmentedColormap
from PIL import Image

# Define your custom colormap (light to dark orange)
orange_cmap = LinearSegmentedColormap.from_list(
    "dark_to_light_orange", ["#754732" ,"#f7eae7", ], N=256
)
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('×.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image,cmap=orange_cmap)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    ##### image size is 1500 by 1500 but the range of values are x,y, pts_x and pts_y are between [0,1]
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
lmb_hist = [1.05, 1.10, 1.15, 1.20, 1.30, 1.40, 1.50]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
print(mesh)

# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0

n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,00,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [01-23 09:57:32][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:57:32][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:57:32][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:57:32][DEBUG] jax_fem: Done pre-computations, took 0.03970789909362793 [s]
# [01-23 09:57:32][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# <jax_fem.generate_mesh.Mesh object at 0x35edbfca0>
# [01-23 09:57:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:57:38][DEBUG] jax_fem: Start timing
# [01-23 09:57:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.1906 seconds
# [01-23 09:57:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:38][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:57:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:38][DEBUG] jax_fem: PETSc linear solve res = 2.354434185033286e-06
# [01-23 09:57:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0397 seconds
# [01-23 09:57:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:38][DEBUG] jax_fem: Before, res l_2 = 0.0014798102044304348
# [01-23 09:57:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:38][DEBUG] jax_fem: PETSc linear solve res = 5.034525379001077e-09
# [01-23 09:57:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0387 seconds
# [01-23 09:57:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:38][DEBUG] jax_fem: res l_2 = 3.3904292367771095e-06
# [01-23 09:57:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:38][DEBUG] jax_fem: PETSc linear solve res = 9.324580379282259e-12
# [01-23 09:57:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0395 seconds
# [01-23 09:57:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:38][DEBUG] jax_fem: res l_2 = 2.2950988963232295e-11
# [01-23 09:57:38][INFO] jax_fem: Solve took 0.5527381896972656 [s]
# [01-23 09:57:38][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [01-23 09:57:38][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:57:39][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:57:39][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:57:39][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:57:39][DEBUG] jax_fem: Done pre-computations, took 0.023627042770385742 [s]
# [01-23 09:57:39][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:57:45][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:57:45][DEBUG] jax_fem: Start timing
# [01-23 09:57:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.1956 seconds
# [01-23 09:57:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:45][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:57:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:45][DEBUG] jax_fem: PETSc linear solve res = 4.708868370066572e-06
# [01-23 09:57:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0445 seconds
# [01-23 09:57:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:45][DEBUG] jax_fem: Before, res l_2 = 0.004558473077280518
# [01-23 09:57:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:45][DEBUG] jax_fem: PETSc linear solve res = 1.9732960846423788e-08
# [01-23 09:57:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0436 seconds
# [01-23 09:57:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:45][DEBUG] jax_fem: res l_2 = 2.989528717582371e-05
# [01-23 09:57:45][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:45][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:45][DEBUG] jax_fem: PETSc linear solve res = 4.8573121281049036e-11
# [01-23 09:57:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:45][DEBUG] jax_fem: Function split_and_compute_cell took 0.0420 seconds
# [01-23 09:57:45][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:45][DEBUG] jax_fem: res l_2 = 1.6460973535772043e-09
# [01-23 09:57:45][INFO] jax_fem: Solve took 0.6440126895904541 [s]
# [01-23 09:57:45][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [01-23 09:57:45][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:57:45][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:57:45][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:57:45][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:57:45][DEBUG] jax_fem: Done pre-computations, took 0.024991989135742188 [s]
# [01-23 09:57:45][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:57:51][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:57:51][DEBUG] jax_fem: Start timing
# [01-23 09:57:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.2199 seconds
# [01-23 09:57:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:51][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:57:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:52][DEBUG] jax_fem: PETSc linear solve res = 7.0633025566666295e-06
# [01-23 09:57:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0434 seconds
# [01-23 09:57:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:52][DEBUG] jax_fem: Before, res l_2 = 0.007909497860839354
# [01-23 09:57:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:52][DEBUG] jax_fem: PETSc linear solve res = 2.224288527066934e-08
# [01-23 09:57:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0425 seconds
# [01-23 09:57:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:52][DEBUG] jax_fem: res l_2 = 7.832870576386196e-05
# [01-23 09:57:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:52][DEBUG] jax_fem: PETSc linear solve res = 5.3897352243124524e-11
# [01-23 09:57:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0411 seconds
# [01-23 09:57:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:52][DEBUG] jax_fem: res l_2 = 1.1477205021373975e-08
# [01-23 09:57:52][INFO] jax_fem: Solve took 0.6134350299835205 [s]
# [01-23 09:57:52][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [01-23 09:57:52][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:57:52][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:57:52][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:57:52][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:57:52][DEBUG] jax_fem: Done pre-computations, took 0.02811288833618164 [s]
# [01-23 09:57:52][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:57:58][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:57:58][DEBUG] jax_fem: Start timing
# [01-23 09:57:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.2217 seconds
# [01-23 09:57:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:58][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:57:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:58][DEBUG] jax_fem: PETSc linear solve res = 9.41773673976174e-06
# [01-23 09:57:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0465 seconds
# [01-23 09:57:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:58][DEBUG] jax_fem: Before, res l_2 = 0.01087337459529939
# [01-23 09:57:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:58][DEBUG] jax_fem: PETSc linear solve res = 2.8920362811240054e-08
# [01-23 09:57:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0453 seconds
# [01-23 09:57:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:58][DEBUG] jax_fem: res l_2 = 0.00012207919583004772
# [01-23 09:57:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:57:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:57:58][DEBUG] jax_fem: PETSc linear solve res = 1.7531295832323372e-10
# [01-23 09:57:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:57:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0419 seconds
# [01-23 09:57:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:57:59][DEBUG] jax_fem: res l_2 = 2.843074593843462e-08
# [01-23 09:57:59][INFO] jax_fem: Solve took 0.6275372505187988 [s]
# [01-23 09:57:59][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [01-23 09:57:59][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:57:59][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:57:59][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:57:59][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:57:59][DEBUG] jax_fem: Done pre-computations, took 0.023992061614990234 [s]
# [01-23 09:57:59][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:58:05][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:58:05][DEBUG] jax_fem: Start timing
# [01-23 09:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.2007 seconds
# [01-23 09:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:05][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:05][DEBUG] jax_fem: PETSc linear solve res = 1.4126605110037679e-05
# [01-23 09:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0419 seconds
# [01-23 09:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:05][DEBUG] jax_fem: Before, res l_2 = 0.014508140839840993
# [01-23 09:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:05][DEBUG] jax_fem: PETSc linear solve res = 3.896516976081607e-08
# [01-23 09:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0426 seconds
# [01-23 09:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:05][DEBUG] jax_fem: res l_2 = 0.00013967051745953962
# [01-23 09:58:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:05][DEBUG] jax_fem: PETSc linear solve res = 3.290038579142922e-10
# [01-23 09:58:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0435 seconds
# [01-23 09:58:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:05][DEBUG] jax_fem: res l_2 = 3.678845097608847e-08
# [01-23 09:58:05][INFO] jax_fem: Solve took 0.6014409065246582 [s]
# [01-23 09:58:05][DEBUG] jax_fem: max of sol = 0.30000000000000004
# [01-23 09:58:05][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:58:05][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:58:05][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:58:05][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:58:05][DEBUG] jax_fem: Done pre-computations, took 0.024134159088134766 [s]
# [01-23 09:58:05][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:58:11][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:58:11][DEBUG] jax_fem: Start timing
# [01-23 09:58:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.2209 seconds
# [01-23 09:58:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:12][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:58:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:12][DEBUG] jax_fem: PETSc linear solve res = 1.883547347952348e-05
# [01-23 09:58:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0467 seconds
# [01-23 09:58:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:12][DEBUG] jax_fem: Before, res l_2 = 0.014684161216910794
# [01-23 09:58:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:12][DEBUG] jax_fem: PETSc linear solve res = 7.985820343178913e-08
# [01-23 09:58:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0440 seconds
# [01-23 09:58:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:12][DEBUG] jax_fem: res l_2 = 0.00012660068812315632
# [01-23 09:58:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:12][DEBUG] jax_fem: PETSc linear solve res = 1.83470351427836e-10
# [01-23 09:58:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0409 seconds
# [01-23 09:58:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:12][DEBUG] jax_fem: res l_2 = 2.088006466016549e-08
# [01-23 09:58:12][INFO] jax_fem: Solve took 0.6291661262512207 [s]
# [01-23 09:58:12][DEBUG] jax_fem: max of sol = 0.3999999999999999
# [01-23 09:58:12][DEBUG] jax_fem: min of sol = 0.0
# [01-23 09:58:12][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-23 09:58:12][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-23 09:58:12][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-23 09:58:12][DEBUG] jax_fem: Done pre-computations, took 0.024344921112060547 [s]
# [01-23 09:58:12][INFO] jax_fem: Solving a problem with 10000 cells, 10201x2 = 20402 dofs.
# [01-23 09:58:18][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-23 09:58:18][DEBUG] jax_fem: Start timing
# [01-23 09:58:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.2034 seconds
# [01-23 09:58:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:18][DEBUG] jax_fem: Linear guess solve...
# [01-23 09:58:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:18][DEBUG] jax_fem: PETSc linear solve res = 2.3544341841477278e-05
# [01-23 09:58:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0431 seconds
# [01-23 09:58:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:18][DEBUG] jax_fem: Before, res l_2 = 0.01614938193806719
# [01-23 09:58:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:18][DEBUG] jax_fem: PETSc linear solve res = 1.1455716876508276e-07
# [01-23 09:58:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0482 seconds
# [01-23 09:58:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:18][DEBUG] jax_fem: res l_2 = 0.0007180214463320348
# [01-23 09:58:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:18][DEBUG] jax_fem: PETSc linear solve res = 3.705350277559351e-10
# [01-23 09:58:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0460 seconds
# [01-23 09:58:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:19][DEBUG] jax_fem: res l_2 = 4.0729523058373055e-06
# [01-23 09:58:19][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-23 09:58:19][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-23 09:58:19][DEBUG] jax_fem: PETSc linear solve res = 4.824083946416381e-13
# [01-23 09:58:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-23 09:58:19][DEBUG] jax_fem: Function split_and_compute_cell took 0.0431 seconds
# [01-23 09:58:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-23 09:58:19][DEBUG] jax_fem: res l_2 = 1.439116592595096e-10
# [01-23 09:58:19][INFO] jax_fem: Solve took 0.7436459064483643 [s]
# [01-23 09:58:19][DEBUG] jax_fem: max of sol = 0.5
# [01-23 09:58:19][DEBUG] jax_fem: min of sol = 0.0

# %% [markdown]
# ### we want to plot the following with the same range

# %%
max_min_range=np.zeros((2,))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P in zip(t_hist, F_hist_goh, P_hist_goh):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    print(evals.shape)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    if t==0:
        max_min_range[0]=np.min(mps)
        max_min_range[1]=np.max(mps)
    else:
        max_min_range[0]=np.min([np.min(mps),max_min_range[0]])
        max_min_range[1]=np.max([np.max(mps),max_min_range[1]])
# Out:
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)

# %%
natural_brown_cmap = LinearSegmentedColormap.from_list(
    "natural_brown",
    [ "#f7eae7", "#754732" ],  # dark brown → light brown → pale peach
    N=256)

fig, axes = plt.subplots(1,len(lmb_hist),figsize=(4*len(lmb_hist),5))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    print(evals.shape)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh_updated(mesh.cells, mesh.points, mps, max_min_range[0],max_min_range[1],title='Max. Princip. Strain [-]', ax=ax,ec='None',cmap=natural_brown_cmap)

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)
# Out:
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)
# (10000, 2)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 100 
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)
X = np.vstack([elem_X]*len(lmb_hist))
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 8.523544e-05
# it 2000, train loss = 4.879863e-05
# it 3000, train loss = 3.796663e-05
# it 4000, train loss = 3.038427e-05
# it 5000, train loss = 2.596077e-05
# it 6000, train loss = 2.636732e-05
# it 7000, train loss = 2.814920e-05
# it 8000, train loss = 2.244568e-05
# it 9000, train loss = 1.968460e-05
# it 10000, train loss = 2.462407e-05
# it 11000, train loss = 1.670259e-05
# it 12000, train loss = 1.411662e-05
# it 13000, train loss = 1.774456e-05
# it 14000, train loss = 1.537206e-05
# it 15000, train loss = 1.473183e-05
# it 16000, train loss = 1.248229e-05
# it 17000, train loss = 1.300160e-05
# it 18000, train loss = 1.159606e-05
# it 19000, train loss = 1.148261e-05
# it 20000, train loss = 1.008514e-05
# it 21000, train loss = 1.077459e-05
# it 22000, train loss = 1.171380e-05
# it 23000, train loss = 1.027065e-05
# it 24000, train loss = 8.708485e-06
# it 25000, train loss = 9.602902e-06
# it 26000, train loss = 1.155738e-05
# it 27000, train loss = 1.062235e-05
# it 28000, train loss = 1.012703e-05
# it 29000, train loss = 8.189074e-06
# it 30000, train loss = 1.092585e-05
# it 31000, train loss = 9.056504e-06
# it 32000, train loss = 7.579485e-06
# it 33000, train loss = 1.031342e-05
# it 34000, train loss = 1.040152e-05
# it 35000, train loss = 9.460999e-06
# it 36000, train loss = 9.422853e-06
# it 37000, train loss = 8.007100e-06
# it 38000, train loss = 8.730785e-06
# it 39000, train loss = 1.003779e-05
# it 40000, train loss = 7.975883e-06
# it 41000, train loss = 8.870806e-06
# it 42000, train loss = 7.944466e-06
# it 43000, train loss = 8.464845e-06
# it 44000, train loss = 7.607106e-06
# it 45000, train loss = 8.152607e-06
# it 46000, train loss = 8.002054e-06
# it 47000, train loss = 7.023286e-06
# it 48000, train loss = 7.579290e-06
# it 49000, train loss = 7.548688e-06
# it 50000, train loss = 6.994790e-06
# it 51000, train loss = 7.760657e-06
# it 52000, train loss = 6.866464e-06
# it 53000, train loss = 6.807929e-06
# it 54000, train loss = 6.536878e-06
# it 55000, train loss = 7.851562e-06
# it 56000, train loss = 6.518090e-06
# it 57000, train loss = 7.022126e-06
# it 58000, train loss = 5.952965e-06
# it 59000, train loss = 7.326878e-06
# it 60000, train loss = 8.226938e-06
# it 61000, train loss = 6.925673e-06
# it 62000, train loss = 6.313065e-06
# it 63000, train loss = 5.649822e-06
# it 64000, train loss = 6.152091e-06
# it 65000, train loss = 6.130056e-06
# it 66000, train loss = 6.663532e-06
# it 67000, train loss = 6.021224e-06
# it 68000, train loss = 5.546566e-06
# it 69000, train loss = 6.228365e-06
# it 70000, train loss = 6.013428e-06
# it 71000, train loss = 5.842764e-06
# it 72000, train loss = 4.874913e-06
# it 73000, train loss = 5.254937e-06
# it 74000, train loss = 5.457902e-06
# it 75000, train loss = 6.607807e-06
# it 76000, train loss = 6.332257e-06
# it 77000, train loss = 5.660084e-06
# it 78000, train loss = 5.850724e-06
# it 79000, train loss = 5.390928e-06
# it 80000, train loss = 5.892288e-06
# it 81000, train loss = 5.048169e-06
# it 82000, train loss = 5.405589e-06
# it 83000, train loss = 5.621216e-06
# it 84000, train loss = 4.921363e-06
# it 85000, train loss = 5.589179e-06
# it 86000, train loss = 5.445043e-06
# it 87000, train loss = 5.009650e-06
# it 88000, train loss = 6.385331e-06
# it 89000, train loss = 5.358838e-06
# it 90000, train loss = 4.466521e-06
# it 91000, train loss = 5.592795e-06
# it 92000, train loss = 5.109362e-06
# it 93000, train loss = 4.366792e-06
# it 94000, train loss = 4.679992e-06
# it 95000, train loss = 4.711338e-06
# it 96000, train loss = 4.974791e-06
# it 97000, train loss = 4.493593e-06
# it 98000, train loss = 5.741965e-06
# it 99000, train loss = 4.887085e-06
# it 100000, train loss = 4.272841e-06

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)

# %%
fig, axes = plt.subplots(1,len(lmb_hist),figsize=(4*len(lmb_hist),5))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax, ec=None);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
with open('params_purdue_pre_highstr_x.npy' ,'wb') as f:
    pickle.dump([coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist,len(rgt_bd_elems),len(top_bd_elems )], f)

# %%
with open('params_purdue_pre_highstr_x.npy', 'rb') as f:
    coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y,strains, bd_X, \
                 lmb_hist, P_hist_goh, F_hist_goh, t_hist,len_rgt_bd_elems,len_top_bd_elems  = pickle.load(f)

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
#Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 5.115215e+00
# it 2000, train loss = 1.067443e+00
# it 3000, train loss = 8.640149e-01
# it 4000, train loss = 7.487626e-01
# it 5000, train loss = 6.072043e-01
# it 6000, train loss = 4.607485e-01
# it 7000, train loss = 3.311962e-01
# it 8000, train loss = 1.619961e-01
# it 9000, train loss = 1.913200e-02
# it 10000, train loss = 1.113919e-02
# it 11000, train loss = 9.409637e-03
# it 12000, train loss = 7.631933e-03
# it 13000, train loss = 5.984285e-03
# it 14000, train loss = 4.627820e-03
# it 15000, train loss = 3.618285e-03
# it 16000, train loss = 2.942919e-03
# it 17000, train loss = 2.494652e-03
# it 18000, train loss = 2.175082e-03
# it 19000, train loss = 1.624047e-03
# it 20000, train loss = 9.179592e-04

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.36408 0.66049 0.90966 1.12604 1.49975 1.83953 2.18717] [0.35128 0.63199 0.86224 1.05604 1.37088 1.62635 1.84986]
# pr P_xx & P_yy:  [0.3705  0.68158 0.92872 1.13381 1.48494 1.81806 2.19322] [0.34463 0.6308  0.85492 1.03738 1.33901 1.61062 1.90544]

# %%
fig, ax=plt.subplots(1,2, figsize=(8, 4))
ax[0].plot(lmb_hist,P_xx_mean,label='gt',alpha=0.5,color='blue')
ax[0].plot(lmb_hist,P_xx_pr, label='pr',alpha=0.5,color='red')
ax[0].set_ylabel(r'$P_{XX}^{boundary}$')
ax[0].set_xlabel(r'$\lambda_{X}$')
ax[1].plot(lmb_hist,P_yy_mean,label='gt',alpha=0.5,color='blue')
ax[1].plot(lmb_hist,P_yy_pr, label='pr',alpha=0.5,color='red')
ax[1].set_ylabel(r'$P_{YY}^{boundary}$')
ax[1].set_xlabel(r'$\lambda_{Y}$')
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### plot in the boundary force distribution in the same plots

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.plot(lmb_hist, P_xx_mean, label=r'$P_{xX}^{gt}$', alpha=0.5, color='blue')
ax.plot(lmb_hist, P_xx_pr, label=r'$P_{xX}^{pr}$', alpha=0.5, color='red')

ax.plot(lmb_hist, P_yy_mean, label=r'$P_{yY}^{gt}$', alpha=0.5, color='green')
ax.plot(lmb_hist, P_yy_pr, label=r'$P_{yY}^{pr}$', alpha=0.5, color='orange')
ax.set_xlabel(r'$\lambda$',fontsize=15)
ax.set_ylabel(r'$P^{boundary}$',fontsize=15)
ax.tick_params(axis='both', labelsize=14)
ax.get_xlim()
ax.get_yaxis()
ax.legend()
plt.tight_layout()
plt.show()

# %%
light_brown = "#f1d3cc"
dark_brown = "#80310C"
light_green = "#8D9177" 
dark_green = "#3D5744"

fig, ax = plt.subplots(figsize=(5, 4))

# Ground truth curves
line1, = ax.plot(lmb_hist, P_xx_mean, label=r'$P_{xX}^{gt}$', color=light_brown, linewidth=5, linestyle='-', marker='o', markersize=14)
line2, = ax.plot(lmb_hist, P_yy_mean, label=r'$P_{yY}^{gt}$', color=dark_brown, linewidth=5, linestyle='-', marker='o', markersize=14)

# Predicted curves
line3, = ax.plot(lmb_hist, P_xx_pr, label=r'$P_{xX}^{pr}$', color=light_green, linewidth=5, linestyle='--', marker='*', markersize=14)
line4, = ax.plot(lmb_hist, P_yy_pr, label=r'$P_{yY}^{pr}$', color=dark_green, linewidth=5, linestyle='--', marker='*', markersize=14)

# Add legends separately
legend1 = ax.legend(handles=[line1, line2], fontsize=16, loc='upper left', bbox_to_anchor=(-0.02, 1.2))
ax.add_artist(legend1)
legend2 = ax.legend(handles=[line3, line4], fontsize=16, loc='lower right', bbox_to_anchor=(1.02, 0))

# Axes and labels
ax.set_xlabel(r'$\lambda$', fontsize=25)
ax.set_ylabel(r'$P^{\text{boundary}}$', fontsize=25)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(axis='both', labelsize=25)

plt.tight_layout()
plt.show()

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_sΛ train_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
ff_nn_ff = lambda x, params: ff_nn(x, params)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 10000, print_freq=1000)
# Out:
# it 1000, train loss = 1.658454e-04
# it 2000, train loss = 4.393768e-05
# it 3000, train loss = 1.798049e-05
# it 4000, train loss = 8.686796e-06
# it 5000, train loss = 4.579505e-06
# it 6000, train loss = 2.534770e-06
# it 7000, train loss = 1.383472e-06
# it 8000, train loss = 7.955827e-07
# it 9000, train loss = 1.103331e-06
# it 10000, train loss = 2.749243e-07

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)

# %%
from jax.sharding import NamedSharding
from jax.sharding import Mesh as shardingmesh

from jax.sharding import PartitionSpec

# Arrange devices as (n_cores, 1) 2D grid
devices = jax.devices()[:n_cores]
device_mesh = [[d] for d in devices]

shrdmesh = shardingmesh(device_mesh, axis_names=('x', 'y'))

# %%
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y
#%%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):

    P_pred = get_P_vmap(XYt_colloc[:,0],XYt_colloc[:,1], XYt_colloc[:,2], Lambda_params, coord_2_strain_params, NODE_w_unravel)
    P_xx = P_xx_mean[jnp.array(XYt_colloc[:,2], int)]
    P_yy = P_yy_mean[jnp.array(XYt_colloc[:,2], int)]

    loss_P = jnp.mean((P_pred[0] - P_xx)**2 + (P_pred[3] - P_yy)**2)
    # loss_F = 0.0
    
    return loss_P

lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
# sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
sharding = NamedSharding(shrdmesh, PartitionSpec('x', None))
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 30000, print_freq=1000, batch_size=1000)
# Out:
# it 1, val loss = 6.138060e-01
# it 1001, val loss = 3.768771e-03
# it 2001, val loss = 1.773505e-03
# it 3001, val loss = 1.273291e-03
# it 4001, val loss = 3.549135e-03
# it 5001, val loss = 1.052027e-03
# it 6001, val loss = 1.799894e-03
# it 7001, val loss = 9.026539e-04
# it 8001, val loss = 1.219590e-01
# it 9001, val loss = 1.991804e-02
# it 10001, val loss = 1.624418e-02
# it 11001, val loss = 1.239946e-02
# it 12001, val loss = 4.252418e-03
# it 13001, val loss = 3.569354e-03
# it 14001, val loss = 2.989161e-03
# it 15001, val loss = 4.212022e-03
# it 16001, val loss = 2.698399e-03
# it 17001, val loss = 3.277432e-03
# it 18001, val loss = 1.383853e-03
# it 19001, val loss = 1.249027e-03
# it 20001, val loss = 1.227712e-03
# it 21001, val loss = 1.281315e-03
# it 22001, val loss = 1.607160e-03
# it 23001, val loss = 6.785571e-03
# it 24001, val loss = 3.654762e-03
# it 25001, val loss = 1.944190e-03
# it 26001, val loss = 3.635347e-03
# it 27001, val loss = 1.281193e-03
# it 28001, val loss = 8.922570e-04
# it 29001, val loss = 7.637415e-04

# %%
def get_P_pretraining_plot(F, X,Y,Lambda_params, model):
    F_xx=F[0,0]
    F_xy=F[0,1]
    F_yx=F[1,0]
    F_yy=F[1,1]
    #F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_pretraining_plot_vmap = vmap(get_P_pretraining_plot, in_axes=(0,0,0,None,None), out_axes=(0,0,0,0))
lmb_hist_plot = [1.05, 1.10, 1.15, 1.20]
t_hist = len(lmb_hist_plot )
n_plots = len(lmb_hist_plot)  
n_cols = 4
n_rows = (n_plots + n_cols - 1) // n_cols 
t_hist =np.arange(0, t_hist)
# c_range=np.ones((n_cols,2))
# c_range[:,[0]]=100000*c_range[:,[0]]
# c_range[:,[1]]=-100000*c_range[:,[1]]
ff_nn_ff = lambda x, params: ff_nn(x, params)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
axes_x = axes_x.flatten()
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
axes_y = axes_y.flatten()
for lam in lmb_hist_plot:
    ax_x = axes_x[id_for_range]
    ax_y = axes_y[id_for_range]
    uniform_F= lam *np.eye(2).reshape(1, 2, 2)
    uniform_F_batch= np.repeat(uniform_F, elem_X.shape[0], axis=0)
    P_xx, P_xy,P_yx,P_yy=get_P_pretraining_plot_vmap(uniform_F_batch, elem_X[:,0],elem_X[:,1],Lambda_params,NODE_w_unravel)
    title=fr'$P_{{xx}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_xx,title=title, ax=ax_x, ec='None')
    title=fr'$P_{{yy}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_yy,title=title, ax=ax_y, ec='None')
    id_for_range+=1

# %%
with open('purdue_prob_highstr_x_second_pretraining.pickle', 'wb') as f:
    pickle.dump([Lambda_params,val_loss, metrics], f)

# %%
with open('purdue_prob_highstr_x_second_pretraining.pickle', 'rb') as f:
    Lambda_params,val_loss, metrics = pickle.load(f)

# %% [markdown]
# ## 2. Retrain

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
# sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
sharding = NamedSharding(shrdmesh, PartitionSpec('x', None))
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 60000, print_freq=1000, batch_size=1000)

with open('purde_prob_highstr_x_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# it 1, val loss = 4.347227e+00
# it 1001, val loss = 1.288519e+00
# it 2001, val loss = 1.837954e+00
# it 3001, val loss = 7.695553e-01
# it 4001, val loss = 4.044525e-01
# it 5001, val loss = 4.849594e-01
# it 6001, val loss = 8.043806e-01
# it 7001, val loss = 1.881962e-01
# it 8001, val loss = 3.361356e-01
# it 9001, val loss = 4.051614e-01
# it 10001, val loss = 8.019807e-01
# it 11001, val loss = 5.619045e-01
# it 12001, val loss = 3.850586e-01
# it 13001, val loss = 3.179130e-01
# it 14001, val loss = 3.412725e-01
# it 15001, val loss = 8.986287e-02
# it 16001, val loss = 5.928731e-01
# it 17001, val loss = 1.608582e-01
# it 18001, val loss = 4.362915e-01
# it 19001, val loss = 1.915662e-01
# it 20001, val loss = 1.155375e-01
# it 21001, val loss = 3.140076e-01
# it 22001, val loss = 2.149279e-01
# it 23001, val loss = 4.749282e-01
# it 24001, val loss = 2.449198e-01
# it 25001, val loss = 5.532090e-01
# it 26001, val loss = 6.150869e-01
# it 27001, val loss = 5.427599e-01
# it 28001, val loss = 4.240322e-01
# it 29001, val loss = 3.196887e-01
# it 30001, val loss = 4.322384e-01
# it 31001, val loss = 2.048057e-01
# it 32001, val loss = 9.635444e-02
# it 33001, val loss = 2.724112e-01
# it 34001, val loss = 2.920901e-01
# it 35001, val loss = 2.039147e-01
# it 36001, val loss = 1.250243e-01
# it 37001, val loss = 6.664540e-01
# it 38001, val loss = 1.625018e-01
# it 39001, val loss = 1.406313e-01
# it 40001, val loss = 2.274004e-01
# it 41001, val loss = 3.280615e-01
# it 42001, val loss = 1.677752e-01
# it 43001, val loss = 2.321723e-01
# it 44001, val loss = 1.243995e-01
# it 45001, val loss = 1.714194e-01
# it 46001, val loss = 1.394662e-01
# it 47001, val loss = 2.041323e-01
# it 48001, val loss = 1.542512e-01
# it 49001, val loss = 2.811045e-01
# it 50001, val loss = 1.313558e-01
# it 51001, val loss = 1.530867e-01
# it 52001, val loss = 2.969011e-01
# it 53001, val loss = 3.410916e-01
# it 54001, val loss = 3.943819e-01
# it 55001, val loss = 1.822116e-01
# it 56001, val loss = 1.246407e-01
# it 57001, val loss = 6.594399e-01
# it 58001, val loss = 2.157590e-01
# it 59001, val loss = 8.941410e-02

# %% [markdown]
# ## 3. Test

# %%
with open('purde_prob_highstr_x_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.36408 0.66049 0.90966 1.12604 1.49975 1.83953 2.18717] [0.35128 0.63199 0.86224 1.05604 1.37088 1.62635 1.84986]
# pr P_xx & P_yy:  [0.3705  0.68158 0.92872 1.13381 1.48494 1.81806 2.19322] [0.34463 0.6308  0.85492 1.03738 1.33901 1.61062 1.90544]

# %%
light_brown = "#f1d3cc"
dark_brown = "#80310C"
light_green = "#8D9177" 
dark_green = "#3D5744"

fig, ax = plt.subplots(figsize=(5, 4))

# Ground truth curves
line1, = ax.plot(lmb_hist, P_xx_mean, label=r'$P_{xX}^{gt}$', color=light_brown, linewidth=5, linestyle='-', marker='o', markersize=14)
line2, = ax.plot(lmb_hist, P_yy_mean, label=r'$P_{yY}^{gt}$', color=dark_brown, linewidth=5, linestyle='-', marker='o', markersize=14)

# Predicted curves
line3, = ax.plot(lmb_hist, P_xx_pr, label=r'$P_{xX}^{pr}$', color=light_green, linewidth=5, linestyle='--', marker='*', markersize=14)
line4, = ax.plot(lmb_hist, P_yy_pr, label=r'$P_{yY}^{pr}$', color=dark_green, linewidth=5, linestyle='--', marker='*', markersize=14)

# Add legends separately
legend1 = ax.legend(handles=[line1, line2], fontsize=16, loc='upper left', bbox_to_anchor=(-0.02, 1.2))
ax.add_artist(legend1)
legend2 = ax.legend(handles=[line3, line4], fontsize=16, loc='lower right', bbox_to_anchor=(1.02, 0))

# Axes and labels
ax.set_xlabel(r'$\lambda$', fontsize=30)
ax.set_ylabel(r'$P^{\text{boundary}}$', fontsize=25)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(axis='both', labelsize=25)

plt.tight_layout()
plt.show()

# %%
light_brown = "#f1d3cc"
dark_brown = "#724835"
light_green = "#8D9177" 
dark_green = "#3D5744"
mat1_params = coords_2_params_gt([0.0,0.0])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.5)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.0, 0.0]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt,'-', label='mat 1 (gt)',color=light_brown, linewidth=5)
ax.plot(lmb_hist2, mat2_P_gt,'-', label='mat 2 (gt)',color=dark_brown, linewidth=5)

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)',color=light_green , linewidth=5)
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)',color=dark_green, linewidth=5)
ax.set_xlabel(r'$\lambda$',fontsize=25)
ax.set_ylabel(r'$P_{xX}$',fontsize=25)
ax.legend(fontsize=16, loc='upper left', bbox_to_anchor=(0, 1.20))
ax.set(xlabel='$\lambda$', ylabel='$P_{xX}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(axis='both', labelsize=20)

# %%
mat1_P_gt=np.array(mat1_P_gt)
mat2_P_gt=np.array(mat2_P_gt)
mat1_P_pr=np.array(mat1_P_pr)
mat2_P_pr=np.array(mat2_P_pr)
print(np.linalg.norm(mat1_P_gt-mat1_P_pr)/np.linalg.norm(mat1_P_gt))
print(np.linalg.norm(mat2_P_gt-mat2_P_pr)/np.linalg.norm(mat2_P_gt))
# Out:
# 0.02979157776990184
# 0.09273462766182265

# %%
from sklearn.metrics import r2_score
r2 = r2_score(mat1_P_gt, mat1_P_pr)
print("R² Score for mat1:", r2)
r2 = r2_score(mat2_P_gt, mat2_P_pr)
print("R² Score for mat1:", r2)
# Out:
# R² Score for mat1: 0.9953599764518043
# R² Score for mat1: 0.9554876705564165

# %%
range_minmax_gt=np.zeros((2,))
range_minmax_pr=np.zeros((2,))
# Stiffness across the domain
for lmb, ax in zip(lmb_hist,axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0]+\
                         ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[1,1])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0]+\
                         ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[1,1])
    if lmb==1.05:
        range_minmax_gt[0]=np.min(c_elem_gt)
        range_minmax_gt[1]=np.max(c_elem_gt)
        range_minmax_pr[0]=np.min(c_elem_pr)
        range_minmax_pr[1]=np.max(c_elem_pr)
    else:
        range_minmax_gt[0]=np.min([np.min(c_elem_gt),range_minmax_gt[0]])
        range_minmax_gt[1]=np.max([np.max(c_elem_gt),range_minmax_gt[1]])
        range_minmax_pr[0]=np.min([np.min(c_elem_pr),range_minmax_pr[0]])
        range_minmax_pr[1]=np.max([np.max(c_elem_pr),range_minmax_pr[1]])

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,len(lmb_hist),figsize=(5*len(lmb_hist),8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0]+\
                         ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[1,1])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0]+\
                         ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[1,1])
    
    #plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0],cmap=orange_cmap ,ec='none'); 
    plotmesh_updated(mesh.cells, mesh.points, c_elem_gt, range_minmax_gt[0],range_minmax_gt[1],title=f'gt stress at {lmb}', ax=ax[0],ec='none',cmap=orange_cmap)
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh_updated(mesh.cells, mesh.points, c_elem_pr, range_minmax_gt[0],range_minmax_gt[1],title=f'pr stress at {lmb}', ax=ax[1],ec='none')

# %% [markdown]
# ### plots of P's wrt F(X,t)

# %% [markdown]
# ### calculation for range of plots

# %%
##### this is for calculation of the range of predicted stress in material that is why I am deleting the extra calculaitons 
range_minmax=np.zeros((2,))
id_f=0
for lmb, ax in zip(lmb_hist, axes.T):
    F=F_hist_goh[id_f]

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)
    # E = E_fun(F)
    # evals, efuns = jnp.linalg.eigh(E)
    # print(evals.shape)
    E_11, E_22 = evals.T
    c_elem_gt = []
    c_elem_pr = []
    id_elem=0
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        ugrad=jnp.squeeze(F[id_elem,:,:])-jnp.eye(2)
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
        id_elem+=1
    if lmb==1.05:
        range_minmax[0]=np.min(c_elem_pr)
        range_minmax[1]=np.max(c_elem_pr)
    else:
        range_minmax[0]=np.min([np.min(c_elem_pr),range_minmax[0]])
        range_minmax[1]=np.max([np.max(c_elem_pr),range_minmax[1]])

    id_f+=1

# %%
fig, axes = plt.subplots(2,len(lmb_hist),figsize=(5*len(lmb_hist),8))
id_f=0
for lmb, ax in zip(lmb_hist, axes.T):
    F=F_hist_goh[id_f]

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)
    # E = E_fun(F)
    # evals, efuns = jnp.linalg.eigh(E)
    # print(evals.shape)
    E_11, E_22 = evals.T
    c_elem_gt = []
    c_elem_pr = []
    id_elem=0
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        ugrad=jnp.squeeze(F[id_elem,:,:])-jnp.eye(2)
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
        id_elem+=1
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0],ec='None'); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh_updated(mesh.cells, mesh.points, c_elem_pr, range_minmax[0],range_minmax[1],title=f'pr stress at {lmb}', ax=ax[1],ec='None')
    #plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend,ec='None');
    id_f+=1
