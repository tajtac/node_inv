# %% [markdown]
# ### The idea behind this notebook:
# Fit the analytical model to the data from Manu and use those models to generate the synthetic FEM.

# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from scipy.optimize import minimize
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity, neohook_model
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ### 0. Analyze the homogeneous material data

# %%
with open('data/manu/soft_homo.npy', 'rb') as f:
    x,y,F_hist_mtrx,force_mtrx = pickle.load(f)
F_hist_mtrx = F_hist_mtrx.mean(axis=1)

with open('data/manu/stiff2_homo.npy', 'rb') as f:
    x,y,F_hist_incl,force_incl = pickle.load(f)
F_hist_incl = F_hist_incl.mean(axis=1)

fig, ax = plt.subplots()
ax.plot(F_hist_mtrx[:,1,1], force_mtrx, label='Matrix')
ax.plot(F_hist_incl[:,1,1], force_incl, label='Inclusion')
ax.set(xlabel='$F_{xx}$ [-]', ylabel='Force [N]')
ax.legend();

# %%
# Train neo Hookean material model with these two datasets
ugrad_incl = F_hist_incl - np.eye(2)
ugrad_mtrx = F_hist_mtrx - np.eye(2)

get_neohook_stress = lambda ugrad, params : ThreeDElasticity(neohook_model).ugrad_2_P(ugrad, params, 2)[1,1]
get_neohook_vmap = vmap(get_neohook_stress, in_axes=(0, None))
def loss(params, ugrad_vec, P_gt):
    P_pr = get_neohook_vmap(ugrad_vec, params)
    return jnp.mean((P_pr-P_gt)**2)

mu_0 = jnp.array([0.0])
loss_incl = lambda params: loss(params, ugrad_incl, force_incl)
loss_mtrx = lambda params: loss(params, ugrad_mtrx, force_mtrx)
params_incl = minimize(loss_incl, mu_0, jac = grad(loss_incl), method='Newton-CG').x
params_mtrx = minimize(loss_mtrx, mu_0, jac = grad(loss_mtrx), method='Newton-CG').x

# %%
# Test
P_pr_incl = get_neohook_vmap(ugrad_incl, params_incl)
P_pr_mtrx = get_neohook_vmap(ugrad_mtrx, params_mtrx)

fig, ax = plt.subplots()
ax.plot(F_hist_mtrx[:,1,1], force_mtrx, label='Matrix (gt)', color='tab:blue')
ax.plot(F_hist_incl[:,1,1], force_incl, label='Inclusion (gt)', color='tab:orange')

ax.plot(F_hist_mtrx[:,1,1], P_pr_mtrx, label='Matrix (pr)', color='tab:blue', linestyle='--')
ax.plot(F_hist_incl[:,1,1], P_pr_incl, label='Inclusion (pr)', color='tab:orange', linestyle='--')
ax.set(xlabel='$F_{xx}$ [-]', ylabel='Force [N]')
ax.legend();

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/mnist_S.png')
image = image.filter(ImageFilter.GaussianBlur(radius=10))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return params_mtrx + c*(params_incl-params_mtrx)

# %%
neohook_P_vmap = vmap(ThreeDElasticity(neohook_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(neohook_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [left,           right,                                  ],
        [0,              0,                                      ],
        [zero_dirichlet, lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = neohook_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [05-27 23:23:00][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-27 23:23:00][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-27 23:23:00][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-27 23:23:01][DEBUG] jax_fem: Done pre-computations, took 0.8066699504852295 [s]
# [05-27 23:23:01][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-27 23:23:02][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-27 23:23:02][DEBUG] jax_fem: Start timing
# [05-27 23:23:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.7250 seconds
# [05-27 23:23:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:03][DEBUG] jax_fem: Linear guess solve...
# [05-27 23:23:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:03][DEBUG] jax_fem: PETSc linear solve res = 7.364851340295541e-06
# [05-27 23:23:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0218 seconds
# [05-27 23:23:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:04][DEBUG] jax_fem: Before, res l_2 = 0.012720281202073353
# [05-27 23:23:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:04][DEBUG] jax_fem: PETSc linear solve res = 5.754110163025797e-08
# [05-27 23:23:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0218 seconds
# [05-27 23:23:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:04][DEBUG] jax_fem: res l_2 = 2.387653532155483e-05
# [05-27 23:23:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:04][DEBUG] jax_fem: PETSc linear solve res = 1.116468872674332e-10
# [05-27 23:23:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [05-27 23:23:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:04][DEBUG] jax_fem: res l_2 = 1.4739909945303876e-10
# [05-27 23:23:04][INFO] jax_fem: Solve took 1.5968818664550781 [s]
# [05-27 23:23:04][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [05-27 23:23:04][DEBUG] jax_fem: min of sol = -0.007576929760893825
# [05-27 23:23:04][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-27 23:23:04][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-27 23:23:04][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-27 23:23:05][DEBUG] jax_fem: Done pre-computations, took 0.2844829559326172 [s]
# [05-27 23:23:05][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-27 23:23:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-27 23:23:06][DEBUG] jax_fem: Start timing
# [05-27 23:23:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.5155 seconds
# [05-27 23:23:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:06][DEBUG] jax_fem: Linear guess solve...
# [05-27 23:23:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:06][DEBUG] jax_fem: PETSc linear solve res = 1.0355161654986367e-05
# [05-27 23:23:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0230 seconds
# [05-27 23:23:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:06][DEBUG] jax_fem: Before, res l_2 = 0.024615257281152242
# [05-27 23:23:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:06][DEBUG] jax_fem: PETSc linear solve res = 8.907622634404045e-08
# [05-27 23:23:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0222 seconds
# [05-27 23:23:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:06][DEBUG] jax_fem: res l_2 = 9.013838252023761e-05
# [05-27 23:23:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:06][DEBUG] jax_fem: PETSc linear solve res = 4.248263022014072e-10
# [05-27 23:23:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0218 seconds
# [05-27 23:23:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:06][DEBUG] jax_fem: res l_2 = 1.4887648540357472e-09
# [05-27 23:23:06][INFO] jax_fem: Solve took 0.7089259624481201 [s]
# [05-27 23:23:06][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [05-27 23:23:06][DEBUG] jax_fem: min of sol = -0.010270986259971287
# [05-27 23:23:06][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-27 23:23:06][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-27 23:23:06][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-27 23:23:07][DEBUG] jax_fem: Done pre-computations, took 0.298508882522583 [s]
# [05-27 23:23:07][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-27 23:23:07][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-27 23:23:07][DEBUG] jax_fem: Start timing
# [05-27 23:23:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.5150 seconds
# [05-27 23:23:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:08][DEBUG] jax_fem: Linear guess solve...
# [05-27 23:23:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:08][DEBUG] jax_fem: PETSc linear solve res = 1.3370712151935954e-05
# [05-27 23:23:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0232 seconds
# [05-27 23:23:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:08][DEBUG] jax_fem: Before, res l_2 = 0.04021851681726377
# [05-27 23:23:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:08][DEBUG] jax_fem: PETSc linear solve res = 1.8510864775215494e-07
# [05-27 23:23:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [05-27 23:23:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:08][DEBUG] jax_fem: res l_2 = 0.00024235686105481422
# [05-27 23:23:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:08][DEBUG] jax_fem: PETSc linear solve res = 8.570773046377996e-10
# [05-27 23:23:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0218 seconds
# [05-27 23:23:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:08][DEBUG] jax_fem: res l_2 = 1.0446552764544995e-08
# [05-27 23:23:08][INFO] jax_fem: Solve took 0.7106471061706543 [s]
# [05-27 23:23:08][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [05-27 23:23:08][DEBUG] jax_fem: min of sol = -0.012784547525803902
# [05-27 23:23:08][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-27 23:23:08][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-27 23:23:08][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-27 23:23:08][DEBUG] jax_fem: Done pre-computations, took 0.3394923210144043 [s]
# [05-27 23:23:08][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-27 23:23:09][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-27 23:23:09][DEBUG] jax_fem: Start timing
# [05-27 23:23:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.5136 seconds
# [05-27 23:23:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:10][DEBUG] jax_fem: Linear guess solve...
# [05-27 23:23:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:10][DEBUG] jax_fem: PETSc linear solve res = 1.6374306762187276e-05
# [05-27 23:23:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0256 seconds
# [05-27 23:23:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:10][DEBUG] jax_fem: Before, res l_2 = 0.05919119828319547
# [05-27 23:23:10][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:10][DEBUG] jax_fem: PETSc linear solve res = 2.4551252909126483e-07
# [05-27 23:23:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [05-27 23:23:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:10][DEBUG] jax_fem: res l_2 = 0.0005281429810883569
# [05-27 23:23:10][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:10][DEBUG] jax_fem: PETSc linear solve res = 2.01211574825514e-09
# [05-27 23:23:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0216 seconds
# [05-27 23:23:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:10][DEBUG] jax_fem: res l_2 = 5.016976785136219e-08
# [05-27 23:23:10][INFO] jax_fem: Solve took 0.7129168510437012 [s]
# [05-27 23:23:10][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [05-27 23:23:10][DEBUG] jax_fem: min of sol = -0.015097317414804768
# [05-27 23:23:10][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-27 23:23:10][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-27 23:23:10][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-27 23:23:10][DEBUG] jax_fem: Done pre-computations, took 0.26898980140686035 [s]
# [05-27 23:23:10][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-27 23:23:11][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-27 23:23:11][DEBUG] jax_fem: Start timing
# [05-27 23:23:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.5205 seconds
# [05-27 23:23:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:12][DEBUG] jax_fem: Linear guess solve...
# [05-27 23:23:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:12][DEBUG] jax_fem: PETSc linear solve res = 1.9377901537992908e-05
# [05-27 23:23:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0221 seconds
# [05-27 23:23:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:12][DEBUG] jax_fem: Before, res l_2 = 0.08144909423897247
# [05-27 23:23:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:12][DEBUG] jax_fem: PETSc linear solve res = 2.3121079994838846e-07
# [05-27 23:23:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0222 seconds
# [05-27 23:23:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:12][DEBUG] jax_fem: res l_2 = 0.0010050355003466574
# [05-27 23:23:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-27 23:23:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-27 23:23:12][DEBUG] jax_fem: PETSc linear solve res = 3.2221997036904707e-09
# [05-27 23:23:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-27 23:23:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0205 seconds
# [05-27 23:23:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-27 23:23:12][DEBUG] jax_fem: res l_2 = 1.840885448420768e-07
# [05-27 23:23:12][INFO] jax_fem: Solve took 0.7151072025299072 [s]
# [05-27 23:23:12][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [05-27 23:23:12][DEBUG] jax_fem: min of sol = -0.017230643082707442

# %%
fig, axes = plt.subplots(1,5,figsize=(25,5))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax, ec='none'); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 40 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 4.134372e-05
# it 2000, train loss = 1.608073e-05
# it 3000, train loss = 8.034736e-06
# it 4000, train loss = 5.759295e-06
# it 5000, train loss = 4.622987e-06
# it 6000, train loss = 4.656405e-06
# it 7000, train loss = 4.366912e-06
# it 8000, train loss = 3.322038e-06
# it 9000, train loss = 3.122486e-06
# it 10000, train loss = 3.115622e-06
# it 11000, train loss = 2.809685e-06
# it 12000, train loss = 4.341270e-06
# it 13000, train loss = 3.628236e-06
# it 14000, train loss = 2.869324e-06
# it 15000, train loss = 2.590120e-06
# it 16000, train loss = 2.226852e-06
# it 17000, train loss = 2.430369e-06
# it 18000, train loss = 2.184145e-06
# it 19000, train loss = 2.605007e-06
# it 20000, train loss = 2.049659e-06
# it 21000, train loss = 2.108854e-06
# it 22000, train loss = 2.506217e-06
# it 23000, train loss = 2.747243e-06
# it 24000, train loss = 4.348905e-06
# it 25000, train loss = 1.440327e-06
# it 26000, train loss = 1.590639e-06
# it 27000, train loss = 2.827782e-06
# it 28000, train loss = 1.332966e-06
# it 29000, train loss = 1.307351e-06
# it 30000, train loss = 1.605553e-06
# it 31000, train loss = 1.534996e-06
# it 32000, train loss = 1.273398e-06
# it 33000, train loss = 1.518512e-06
# it 34000, train loss = 1.198059e-06
# it 35000, train loss = 1.291915e-06
# it 36000, train loss = 1.397709e-06
# it 37000, train loss = 1.602027e-06
# it 38000, train loss = 2.364973e-06
# it 39000, train loss = 1.039207e-06
# it 40000, train loss = 1.035694e-06
# it 41000, train loss = 9.851049e-07
# it 42000, train loss = 9.063795e-07
# it 43000, train loss = 1.107954e-06
# it 44000, train loss = 1.178701e-06
# it 45000, train loss = 9.552953e-07
# it 46000, train loss = 8.204521e-07
# it 47000, train loss = 1.377215e-06
# it 48000, train loss = 2.319536e-06
# it 49000, train loss = 8.221824e-07
# it 50000, train loss = 1.376838e-06
# it 51000, train loss = 1.109019e-06
# it 52000, train loss = 9.443022e-07
# it 53000, train loss = 1.102650e-06
# it 54000, train loss = 7.991378e-07
# it 55000, train loss = 9.319744e-07
# it 56000, train loss = 1.138093e-06
# it 57000, train loss = 8.921976e-07
# it 58000, train loss = 7.493864e-07
# it 59000, train loss = 8.954038e-07
# it 60000, train loss = 7.132985e-07
# it 61000, train loss = 8.451085e-07
# it 62000, train loss = 8.510346e-07
# it 63000, train loss = 7.672984e-07
# it 64000, train loss = 8.781417e-07
# it 65000, train loss = 8.380549e-07
# it 66000, train loss = 6.690650e-07
# it 67000, train loss = 6.446831e-07
# it 68000, train loss = 6.744552e-07
# it 69000, train loss = 9.994403e-07
# it 70000, train loss = 8.996131e-07
# it 71000, train loss = 6.626344e-07
# it 72000, train loss = 9.092852e-07
# it 73000, train loss = 6.616062e-07
# it 74000, train loss = 7.081687e-07
# it 75000, train loss = 6.155061e-07
# it 76000, train loss = 7.019910e-07
# it 77000, train loss = 7.387510e-07
# it 78000, train loss = 7.278225e-07
# it 79000, train loss = 2.072991e-06
# it 80000, train loss = 1.485032e-06
# it 81000, train loss = 1.192580e-06
# it 82000, train loss = 7.802874e-07
# it 83000, train loss = 5.946449e-07
# it 84000, train loss = 8.824681e-07
# it 85000, train loss = 5.422630e-07
# it 86000, train loss = 1.435767e-06
# it 87000, train loss = 6.790901e-07
# it 88000, train loss = 6.496801e-07
# it 89000, train loss = 7.526973e-07
# it 90000, train loss = 1.092237e-06
# it 91000, train loss = 5.610442e-07
# it 92000, train loss = 5.680569e-07
# it 93000, train loss = 8.457590e-07
# it 94000, train loss = 7.009785e-07
# it 95000, train loss = 6.302974e-07
# it 96000, train loss = 5.776483e-07
# it 97000, train loss = 5.645564e-07
# it 98000, train loss = 5.025551e-07
# it 99000, train loss = 5.156659e-07
# it 100000, train loss = 5.521713e-07

# %%
fig, axes = plt.subplots(1,5,figsize=(25,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax, ec='none');

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 8.888263e-02
# it 2000, train loss = 2.264418e-02
# it 3000, train loss = 1.034231e-02
# it 4000, train loss = 5.980356e-03
# it 5000, train loss = 3.565567e-03
# it 6000, train loss = 1.997549e-03
# it 7000, train loss = 1.044642e-03
# it 8000, train loss = 5.301710e-04
# it 9000, train loss = 2.699594e-04
# it 10000, train loss = 1.385622e-04
# it 11000, train loss = 7.168842e-05
# it 12000, train loss = 3.820294e-05
# it 13000, train loss = 2.223345e-05
# it 14000, train loss = 1.502250e-05
# it 15000, train loss = 1.165868e-05
# it 16000, train loss = 9.978249e-06
# it 17000, train loss = 9.063719e-06
# it 18000, train loss = 8.526707e-06
# it 19000, train loss = 8.193451e-06
# it 20000, train loss = 7.976998e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [2.22199 3.06182 3.87666 4.65878 5.4138 ] [0. 0. 0. 0. 0.]
# pr P_xx & P_yy:  [2.21946 3.06587 3.87684 4.65533 5.41537] [0.00024 0.00039 0.00059 0.00084 0.00116]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.359478e-04
# it 2000, train loss = 3.566401e-05
# it 3000, train loss = 1.441095e-05
# it 4000, train loss = 6.936746e-06
# it 5000, train loss = 3.641141e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/mnist_S_data_uni_x_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/mnist_S_data_uni_x_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 40000, print_freq=1000, batch_size=1000)

with open('params/mnist_S_data_uni_x_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# it 1, val loss = 2.946396e+02
# it 1001, val loss = 1.273230e+02
# it 2001, val loss = 6.289171e+01
# it 3001, val loss = 7.290636e+01
# it 4001, val loss = 3.447952e+01
# it 5001, val loss = 3.975247e+01
# it 6001, val loss = 1.611734e+01
# it 7001, val loss = 2.440243e+01
# it 8001, val loss = 4.893558e+01
# it 9001, val loss = 2.581612e+01
# it 10001, val loss = 3.005438e+01
# it 11001, val loss = 1.630341e+01
# it 12001, val loss = 2.555913e+01
# it 13001, val loss = 3.381748e+01
# it 14001, val loss = 2.939495e+01
# it 15001, val loss = 2.936493e+01
# it 16001, val loss = 2.277525e+01
# it 17001, val loss = 2.182781e+01
# it 18001, val loss = 1.505728e+01
# it 19001, val loss = 3.515205e+00
# it 20001, val loss = 3.450316e+01
# it 21001, val loss = 1.633141e+01
# it 22001, val loss = 2.380440e+01
# it 23001, val loss = 2.985819e+01
# it 24001, val loss = 2.226151e+01
# it 25001, val loss = 2.048761e+01
# it 26001, val loss = 1.951276e+01
# it 27001, val loss = 6.224839e+00
# it 28001, val loss = 5.016052e+00
# it 29001, val loss = 1.642247e+01
# it 30001, val loss = 3.754177e+00
# it 31001, val loss = 2.328473e+01
# it 32001, val loss = 4.056986e+00
# it 33001, val loss = 1.007954e+01
# it 34001, val loss = 6.220441e+00
# it 35001, val loss = 2.816683e+01
# it 36001, val loss = 1.908583e+01
# it 37001, val loss = 1.086373e+01
# it 38001, val loss = 2.431332e+00
# it 39001, val loss = 1.489416e+01

# %% [markdown]
# ## 3. Test

# %%
with open('params/mnist_S_data_uni_x_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,5,figsize=(25,8))
for lmb, ax in zip(lmb_hist, axes.T):
    lmby = 1.0/lmb
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmby-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(neohook_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [01-29 12:02:18][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:18][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:18][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:19][DEBUG] jax_fem: Done pre-computations, took 0.3462047576904297 [s]
# [01-29 12:02:19][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:19][DEBUG] jax_fem: Start timing
# [01-29 12:02:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 2.7130 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 0.0036905625916567415
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: Before, res l_2 = 0.011526985072150886
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 4.767070052561915e-10
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0320 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 0.0011043176920788333
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 3.6825363631446657e-10
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0313 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 1.938881294341329e-06
# [01-29 12:02:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:22][DEBUG] jax_fem: PETSc linear solve res = 2.061865543736903e-12
# [01-29 12:02:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0293 seconds
# [01-29 12:02:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:22][DEBUG] jax_fem: res l_2 = 3.627697207926912e-11
# [01-29 12:02:22][INFO] jax_fem: Solve took 3.5776472091674805 [s]
# [01-29 12:02:22][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [01-29 12:02:22][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:23][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:23][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:23][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:23][DEBUG] jax_fem: Done pre-computations, took 0.042654991149902344 [s]
# [01-29 12:02:23][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:23][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:23][DEBUG] jax_fem: Start timing
# [01-29 12:02:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 2.4059 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 0.007381125183313483
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: Before, res l_2 = 0.03192482705227
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.3654810209482553e-08
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0275 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 0.0031246068844033386
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.8600026095675939e-10
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0282 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 1.5502257045814567e-05
# [01-29 12:02:26][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:26][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:26][DEBUG] jax_fem: PETSc linear solve res = 1.4221083074155572e-12
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.0261 seconds
# [01-29 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:26][DEBUG] jax_fem: res l_2 = 8.095624959509216e-10
# [01-29 12:02:26][INFO] jax_fem: Solve took 2.668717622756958 [s]
# [01-29 12:02:26][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [01-29 12:02:26][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:26][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:26][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:26][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:26][DEBUG] jax_fem: Done pre-computations, took 0.04655599594116211 [s]
# [01-29 12:02:26][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:26][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:26][DEBUG] jax_fem: Start timing
# [01-29 12:02:26][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:28][DEBUG] jax_fem: Function split_and_compute_cell took 2.4271 seconds
# [01-29 12:02:28][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 0.001533462192273752
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0276 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: Before, res l_2 = 0.009427350514540385
# [01-29 12:02:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 1.040619907742982e-08
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: res l_2 = 0.00020509918341214526
# [01-29 12:02:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:29][DEBUG] jax_fem: PETSc linear solve res = 3.151016361403172e-11
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0274 seconds
# [01-29 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:29][DEBUG] jax_fem: res l_2 = 2.5841599304971627e-08
# [01-29 12:02:29][INFO] jax_fem: Solve took 2.6418890953063965 [s]
# [01-29 12:02:29][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [01-29 12:02:29][DEBUG] jax_fem: min of sol = 0.0
# [01-29 12:02:29][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [01-29 12:02:29][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [01-29 12:02:29][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [01-29 12:02:29][DEBUG] jax_fem: Done pre-computations, took 0.04050707817077637 [s]
# [01-29 12:02:29][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [01-29 12:02:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [01-29 12:02:29][DEBUG] jax_fem: Start timing
# [01-29 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 2.4993 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: Linear guess solve...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 0.02384338861974766
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0303 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: Before, res l_2 = 0.1572552453489813
# [01-29 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 2.274793598014596e-08
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0284 seconds
# [01-29 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:31][DEBUG] jax_fem: res l_2 = 0.024244543168059376
# [01-29 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 3.7007471141555687e-09
# [01-29 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [01-29 12:02:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:32][DEBUG] jax_fem: res l_2 = 0.0007288910129005116
# [01-29 12:02:32][DEBUG] jax_fem: Solving linear system with lift solver...
# [01-29 12:02:32][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [01-29 12:02:32][DEBUG] jax_fem: PETSc linear solve res = 6.014778830742415e-10
# [01-29 12:02:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [01-29 12:02:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0282 seconds
# [01-29 12:02:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [01-29 12:02:32][DEBUG] jax_fem: res l_2 = 7.072063636359669e-07
# [01-29 12:02:32][INFO] jax_fem: Solve took 2.7749388217926025 [s]
# [01-29 12:02:32][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [01-29 12:02:32][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
