# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/÷.png')
image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [02-03 11:29:33][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [02-03 11:29:33][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [02-03 11:29:33][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [02-03 11:29:34][DEBUG] jax_fem: Done pre-computations, took 0.3501250743865967 [s]
# [02-03 11:29:34][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [02-03 11:29:34][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [02-03 11:29:34][DEBUG] jax_fem: Start timing
# [02-03 11:29:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:35][DEBUG] jax_fem: Function split_and_compute_cell took 1.2914 seconds
# [02-03 11:29:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:36][DEBUG] jax_fem: Linear guess solve...
# [02-03 11:29:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:36][DEBUG] jax_fem: PETSc linear solve res = 1.025815161465713e-06
# [02-03 11:29:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0053 seconds
# [02-03 11:29:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:36][DEBUG] jax_fem: Before, res l_2 = 0.0018930874075507812
# [02-03 11:29:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:36][DEBUG] jax_fem: PETSc linear solve res = 1.819848696203463e-09
# [02-03 11:29:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0047 seconds
# [02-03 11:29:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:36][DEBUG] jax_fem: res l_2 = 3.3325729847715508e-06
# [02-03 11:29:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:36][DEBUG] jax_fem: PETSc linear solve res = 7.609770169753923e-13
# [02-03 11:29:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0048 seconds
# [02-03 11:29:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:36][DEBUG] jax_fem: res l_2 = 1.2691099637882772e-11
# [02-03 11:29:36][INFO] jax_fem: Solve took 1.9470701217651367 [s]
# [02-03 11:29:36][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [02-03 11:29:36][DEBUG] jax_fem: min of sol = 0.0
# [02-03 11:29:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [02-03 11:29:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [02-03 11:29:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [02-03 11:29:37][DEBUG] jax_fem: Done pre-computations, took 0.04042792320251465 [s]
# [02-03 11:29:37][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [02-03 11:29:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [02-03 11:29:37][DEBUG] jax_fem: Start timing
# [02-03 11:29:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:38][DEBUG] jax_fem: Function split_and_compute_cell took 1.0800 seconds
# [02-03 11:29:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:38][DEBUG] jax_fem: Linear guess solve...
# [02-03 11:29:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:38][DEBUG] jax_fem: PETSc linear solve res = 2.051630322931426e-06
# [02-03 11:29:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0055 seconds
# [02-03 11:29:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:38][DEBUG] jax_fem: Before, res l_2 = 0.005937008544438248
# [02-03 11:29:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:38][DEBUG] jax_fem: PETSc linear solve res = 2.1347875423272657e-09
# [02-03 11:29:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0050 seconds
# [02-03 11:29:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:38][DEBUG] jax_fem: res l_2 = 3.263253960084778e-05
# [02-03 11:29:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:38][DEBUG] jax_fem: PETSc linear solve res = 5.704067973553729e-12
# [02-03 11:29:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0052 seconds
# [02-03 11:29:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:38][DEBUG] jax_fem: res l_2 = 1.229244803013875e-09
# [02-03 11:29:38][INFO] jax_fem: Solve took 1.1515161991119385 [s]
# [02-03 11:29:38][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [02-03 11:29:38][DEBUG] jax_fem: min of sol = 0.0
# [02-03 11:29:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [02-03 11:29:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [02-03 11:29:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [02-03 11:29:38][DEBUG] jax_fem: Done pre-computations, took 0.039283037185668945 [s]
# [02-03 11:29:38][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [02-03 11:29:39][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [02-03 11:29:39][DEBUG] jax_fem: Start timing
# [02-03 11:29:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:40][DEBUG] jax_fem: Function split_and_compute_cell took 1.0191 seconds
# [02-03 11:29:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:40][DEBUG] jax_fem: Linear guess solve...
# [02-03 11:29:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:40][DEBUG] jax_fem: PETSc linear solve res = 3.0774454845059457e-06
# [02-03 11:29:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0053 seconds
# [02-03 11:29:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:40][DEBUG] jax_fem: Before, res l_2 = 0.010523027101879643
# [02-03 11:29:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:40][DEBUG] jax_fem: PETSc linear solve res = 3.5552134106984765e-09
# [02-03 11:29:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0054 seconds
# [02-03 11:29:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:40][DEBUG] jax_fem: res l_2 = 9.783548977135318e-05
# [02-03 11:29:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:40][DEBUG] jax_fem: PETSc linear solve res = 1.8783752764319044e-11
# [02-03 11:29:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0047 seconds
# [02-03 11:29:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:40][DEBUG] jax_fem: res l_2 = 1.068416142475483e-08
# [02-03 11:29:40][INFO] jax_fem: Solve took 1.0930707454681396 [s]
# [02-03 11:29:40][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [02-03 11:29:40][DEBUG] jax_fem: min of sol = 0.0
# [02-03 11:29:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [02-03 11:29:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [02-03 11:29:40][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [02-03 11:29:40][DEBUG] jax_fem: Done pre-computations, took 0.04171895980834961 [s]
# [02-03 11:29:40][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [02-03 11:29:40][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [02-03 11:29:40][DEBUG] jax_fem: Start timing
# [02-03 11:29:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:41][DEBUG] jax_fem: Function split_and_compute_cell took 1.0840 seconds
# [02-03 11:29:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:41][DEBUG] jax_fem: Linear guess solve...
# [02-03 11:29:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:41][DEBUG] jax_fem: PETSc linear solve res = 4.103260646108619e-06
# [02-03 11:29:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0059 seconds
# [02-03 11:29:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:41][DEBUG] jax_fem: Before, res l_2 = 0.014842340322666316
# [02-03 11:29:41][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:41][DEBUG] jax_fem: PETSc linear solve res = 5.880042133768705e-09
# [02-03 11:29:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0053 seconds
# [02-03 11:29:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:41][DEBUG] jax_fem: res l_2 = 0.00017929302113751274
# [02-03 11:29:41][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 11:29:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 11:29:41][DEBUG] jax_fem: PETSc linear solve res = 4.5778392912883224e-11
# [02-03 11:29:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 11:29:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0051 seconds
# [02-03 11:29:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 11:29:41][DEBUG] jax_fem: res l_2 = 3.287127155050627e-08
# [02-03 11:29:41][INFO] jax_fem: Solve took 1.1570508480072021 [s]
# [02-03 11:29:41][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [02-03 11:29:41][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 20 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])#*0.5
nn_layers = [2*n_ff+1,20,20,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 50000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 3.795036e-04
# it 2000, train loss = 1.359558e-04
# it 3000, train loss = 5.958156e-05
# it 4000, train loss = 3.213115e-05
# it 5000, train loss = 1.887252e-05
# it 6000, train loss = 1.138818e-05
# it 7000, train loss = 8.188733e-06
# it 8000, train loss = 5.766474e-06
# it 9000, train loss = 4.469847e-06
# it 10000, train loss = 3.923258e-06
# it 11000, train loss = 3.136571e-06
# it 12000, train loss = 3.042920e-06
# it 13000, train loss = 2.529073e-06
# it 14000, train loss = 2.376888e-06
# it 15000, train loss = 2.112820e-06
# it 16000, train loss = 2.075594e-06
# it 17000, train loss = 1.807952e-06
# it 18000, train loss = 1.770121e-06
# it 19000, train loss = 1.795752e-06
# it 20000, train loss = 1.700505e-06
# it 21000, train loss = 1.542758e-06
# it 22000, train loss = 1.456107e-06
# it 23000, train loss = 1.447528e-06
# it 24000, train loss = 1.266274e-06
# it 25000, train loss = 1.301813e-06
# it 26000, train loss = 1.221126e-06
# it 27000, train loss = 1.202808e-06
# it 28000, train loss = 1.231318e-06
# it 29000, train loss = 1.148466e-06
# it 30000, train loss = 1.146562e-06
# it 31000, train loss = 1.116426e-06
# it 32000, train loss = 2.011485e-06
# it 33000, train loss = 1.299421e-06
# it 34000, train loss = 1.078353e-06
# it 35000, train loss = 1.049506e-06
# it 36000, train loss = 1.160273e-06
# it 37000, train loss = 9.317016e-07
# it 38000, train loss = 1.090893e-06
# it 39000, train loss = 1.243765e-06
# it 40000, train loss = 7.931853e-07
# it 41000, train loss = 8.717380e-07
# it 42000, train loss = 1.024716e-06
# it 43000, train loss = 8.291579e-07
# it 44000, train loss = 8.275811e-07
# it 45000, train loss = 7.848427e-07
# it 46000, train loss = 8.134980e-07
# it 47000, train loss = 6.663786e-07
# it 48000, train loss = 7.054089e-07
# it 49000, train loss = 7.188726e-07
# it 50000, train loss = 7.864484e-07

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.015454e-01
# it 2000, train loss = 6.051386e-02
# it 3000, train loss = 3.518334e-02
# it 4000, train loss = 2.318065e-02
# it 5000, train loss = 1.077804e-03
# it 6000, train loss = 3.871795e-05
# it 7000, train loss = 3.473065e-05
# it 8000, train loss = 2.583419e-05
# it 9000, train loss = 1.364142e-05
# it 10000, train loss = 7.744187e-06
# it 11000, train loss = 6.586721e-06
# it 12000, train loss = 6.515919e-06
# it 13000, train loss = 6.484389e-06
# it 14000, train loss = 6.450478e-06
# it 15000, train loss = 6.423218e-06
# it 16000, train loss = 6.372343e-06
# it 17000, train loss = 6.325580e-06
# it 18000, train loss = 6.273865e-06
# it 19000, train loss = 6.219719e-06
# it 20000, train loss = 6.166980e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.3705  0.67239 0.92609 1.14604] [0.35734 0.64316 0.87765 1.07481]
# pr P_xx & P_yy:  [0.36913 0.67486 0.92411 1.14663] [0.35604 0.64563 0.87559 1.07544]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 3.091822e-04
# it 2000, train loss = 8.934684e-05
# it 3000, train loss = 3.809869e-05
# it 4000, train loss = 1.883078e-05
# it 5000, train loss = 9.934426e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/÷_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/÷_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 20000, print_freq=1000, batch_size=1000)

with open('params/÷_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# it 1000, val loss = 1.311438e+00
# it 2000, val loss = 1.172718e+00
# it 3000, val loss = 2.152735e+00
# it 4000, val loss = 4.338133e+00
# it 5000, val loss = 2.725260e+00
# it 6000, val loss = 5.578511e+00
# it 7000, val loss = 5.883582e+00
# it 8000, val loss = 2.699766e+00
# it 9000, val loss = 5.214611e+00
# it 10000, val loss = 8.063097e+00
# it 11000, val loss = 2.607344e+00
# it 12000, val loss = 6.929492e+00
# it 13000, val loss = 4.190518e+00
# it 14000, val loss = 6.567544e+00
# it 15000, val loss = 4.188366e+00
# it 16000, val loss = 5.316306e+00
# it 17000, val loss = 5.922172e+00
# it 18000, val loss = 1.116210e+00
# it 19000, val loss = 2.441103e+00
# it 20000, val loss = 3.109886e+00

# %% [markdown]
# ## 3. Test

# %%
with open('params/÷_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [02-03 12:01:36][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [02-03 12:01:36][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [02-03 12:01:36][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [02-03 12:01:36][DEBUG] jax_fem: Done pre-computations, took 0.051458120346069336 [s]
# [02-03 12:01:36][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [02-03 12:01:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [02-03 12:01:36][DEBUG] jax_fem: Start timing
# [02-03 12:01:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:38][DEBUG] jax_fem: Function split_and_compute_cell took 2.4153 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: Linear guess solve...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 0.029381751688043984
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0307 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: Before, res l_2 = 880.2308975568826
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 0.0004838218460716511
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0294 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 349.34318018995606
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 0.00011872129207731065
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0302 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 137.1906325793187
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 5.3503202686968215e-05
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0299 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 14736025289.5323
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 58984.230833685164
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0355 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 571684263435.3096
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 997753221790881.4
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0303 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 3.0265556090688705e+73
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 1.758058493560884e+71
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0273 seconds
# [02-03 12:01:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:39][DEBUG] jax_fem: res l_2 = 9.983497224698278e+116
# [02-03 12:01:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:39][DEBUG] jax_fem: PETSc linear solve res = 1.7676711530019154e+118
# [02-03 12:01:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0302 seconds
# [02-03 12:01:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:40][DEBUG] jax_fem: res l_2 = inf
# [02-03 12:01:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [02-03 12:01:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [02-03 12:01:40][DEBUG] jax_fem: PETSc linear solve res = inf
# [02-03 12:01:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [02-03 12:01:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [02-03 12:01:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [02-03 12:01:40][DEBUG] jax_fem: res l_2 = nan
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[20], line 56
#      51 elem_X = problem.get_physical_quad_points().mean(1)
#      53 problem.set_params(params_vec)
# ---> 56 node_x = solver(problem, use_petsc=True)
#      57 u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
#      58 F = u_grad + np.eye(2)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:849, in solver(problem, linear, precond, initial_guess, use_petsc)
#     846 # TODO: print platform jax.lib.xla_bridge.get_backend().platform
#     847 # and suggest PETSc or jax solver
#     848 if problem.periodic_bc_info is None:
# --> 849     return solver_row_elimination(problem, linear, precond, initial_guess,
#     850                                   use_petsc)
#     851 else:
#     852     return solver_lagrange_multiplier(problem, linear, use_petsc)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:393, in solver_row_elimination(problem, linear, precond, initial_guess, use_petsc)
#     390         res_val = np.linalg.norm(res_vec)
#     391         logger.debug(f"res l_2 = {res_val}")
# --> 393 assert np.all(
#     394     np.isfinite(res_val)), f"res_val contains NaN, stop the program!"
#     396 assert np.all(np.isfinite(dofs)), f"dofs contains NaN, stop the program!"
#     398 sol = dofs.reshape(sol_shape)
#
# AssertionError: res_val contains NaN, stop the program!

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
