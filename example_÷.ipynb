# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/÷.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
F_hist_goh = []
P_hist_goh = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)
# Out:
# [05-23 01:55:04][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:55:04][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:55:04][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:55:04][DEBUG] jax_fem: Done pre-computations, took 0.6689531803131104 [s]
# [05-23 01:55:04][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:55:07][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:55:07][DEBUG] jax_fem: Start timing
# [05-23 01:55:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.8406 seconds
# [05-23 01:55:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:08][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:55:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:08][DEBUG] jax_fem: PETSc linear solve res = 2.179528195011478e-06
# [05-23 01:55:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0228 seconds
# [05-23 01:55:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:08][DEBUG] jax_fem: Before, res l_2 = 0.002330874131223984
# [05-23 01:55:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:08][DEBUG] jax_fem: PETSc linear solve res = 2.6316426044816826e-09
# [05-23 01:55:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0224 seconds
# [05-23 01:55:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:08][DEBUG] jax_fem: res l_2 = 4.998129990893993e-06
# [05-23 01:55:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:08][DEBUG] jax_fem: PETSc linear solve res = 1.3447723751126887e-11
# [05-23 01:55:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0217 seconds
# [05-23 01:55:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:08][DEBUG] jax_fem: res l_2 = 4.2744937468388843e-11
# [05-23 01:55:08][INFO] jax_fem: Solve took 1.6998860836029053 [s]
# [05-23 01:55:09][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [05-23 01:55:09][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:55:10][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:55:10][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:55:10][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:55:10][DEBUG] jax_fem: Done pre-computations, took 0.3247799873352051 [s]
# [05-23 01:55:10][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:55:12][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:55:12][DEBUG] jax_fem: Start timing
# [05-23 01:55:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.5979 seconds
# [05-23 01:55:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:13][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:55:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:13][DEBUG] jax_fem: PETSc linear solve res = 4.359056390022956e-06
# [05-23 01:55:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0233 seconds
# [05-23 01:55:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:13][DEBUG] jax_fem: Before, res l_2 = 0.007261158496486886
# [05-23 01:55:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:13][DEBUG] jax_fem: PETSc linear solve res = 8.519986637243165e-09
# [05-23 01:55:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0219 seconds
# [05-23 01:55:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:13][DEBUG] jax_fem: res l_2 = 4.6842640200149895e-05
# [05-23 01:55:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:13][DEBUG] jax_fem: PETSc linear solve res = 7.367467486942217e-11
# [05-23 01:55:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0220 seconds
# [05-23 01:55:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:13][DEBUG] jax_fem: res l_2 = 3.520520043936312e-09
# [05-23 01:55:13][INFO] jax_fem: Solve took 0.7928190231323242 [s]
# [05-23 01:55:13][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [05-23 01:55:13][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:55:13][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:55:13][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:55:13][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:55:13][DEBUG] jax_fem: Done pre-computations, took 0.3193998336791992 [s]
# [05-23 01:55:13][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:55:16][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:55:16][DEBUG] jax_fem: Start timing
# [05-23 01:55:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.5789 seconds
# [05-23 01:55:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:16][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:55:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:16][DEBUG] jax_fem: PETSc linear solve res = 6.538584584444999e-06
# [05-23 01:55:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0236 seconds
# [05-23 01:55:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:16][DEBUG] jax_fem: Before, res l_2 = 0.01279454004599694
# [05-23 01:55:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:16][DEBUG] jax_fem: PETSc linear solve res = 1.143610998413014e-08
# [05-23 01:55:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0227 seconds
# [05-23 01:55:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:16][DEBUG] jax_fem: res l_2 = 0.00013455559188653665
# [05-23 01:55:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:16][DEBUG] jax_fem: PETSc linear solve res = 1.9258342054534863e-10
# [05-23 01:55:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0217 seconds
# [05-23 01:55:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:16][DEBUG] jax_fem: res l_2 = 2.7350465895377968e-08
# [05-23 01:55:16][INFO] jax_fem: Solve took 0.7787189483642578 [s]
# [05-23 01:55:16][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [05-23 01:55:16][DEBUG] jax_fem: min of sol = 0.0
# [05-23 01:55:16][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 01:55:16][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 01:55:16][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 01:55:17][DEBUG] jax_fem: Done pre-computations, took 0.3128948211669922 [s]
# [05-23 01:55:17][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [05-23 01:55:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 01:55:19][DEBUG] jax_fem: Start timing
# [05-23 01:55:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.5837 seconds
# [05-23 01:55:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:20][DEBUG] jax_fem: Linear guess solve...
# [05-23 01:55:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:20][DEBUG] jax_fem: PETSc linear solve res = 8.718112776720036e-06
# [05-23 01:55:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0211 seconds
# [05-23 01:55:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:20][DEBUG] jax_fem: Before, res l_2 = 0.01795549648198705
# [05-23 01:55:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:20][DEBUG] jax_fem: PETSc linear solve res = 2.7542656193331108e-08
# [05-23 01:55:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [05-23 01:55:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:20][DEBUG] jax_fem: res l_2 = 0.00023624412862247076
# [05-23 01:55:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 01:55:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 01:55:20][DEBUG] jax_fem: PETSc linear solve res = 2.752201611544518e-10
# [05-23 01:55:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 01:55:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0221 seconds
# [05-23 01:55:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 01:55:20][DEBUG] jax_fem: res l_2 = 7.476876978353168e-08
# [05-23 01:55:20][INFO] jax_fem: Solve took 0.7746801376342773 [s]
# [05-23 01:55:20][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [05-23 01:55:20][DEBUG] jax_fem: min of sol = 0.0

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax); 

    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### Coords_2_strain NN

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 40 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])#*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = [ff_params, nn_params]

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 1.591474e-04
# it 2000, train loss = 5.638404e-05
# it 3000, train loss = 3.012818e-05
# it 4000, train loss = 2.100761e-05
# it 5000, train loss = 1.621063e-05
# it 6000, train loss = 1.251072e-05
# it 7000, train loss = 1.093287e-05
# it 8000, train loss = 1.067903e-05
# it 9000, train loss = 9.738248e-06
# it 10000, train loss = 9.104052e-06
# it 11000, train loss = 8.222809e-06
# it 12000, train loss = 8.173726e-06
# it 13000, train loss = 8.209095e-06
# it 14000, train loss = 6.969521e-06
# it 15000, train loss = 6.942709e-06
# it 16000, train loss = 6.248946e-06
# it 17000, train loss = 7.399237e-06
# it 18000, train loss = 7.099425e-06
# it 19000, train loss = 6.916373e-06
# it 20000, train loss = 5.577736e-06
# it 21000, train loss = 6.405231e-06
# it 22000, train loss = 5.809256e-06
# it 23000, train loss = 5.703833e-06
# it 24000, train loss = 5.059856e-06
# it 25000, train loss = 5.356288e-06
# it 26000, train loss = 5.616799e-06
# it 27000, train loss = 5.066111e-06
# it 28000, train loss = 6.124648e-06
# it 29000, train loss = 5.248092e-06
# it 30000, train loss = 5.290815e-06
# it 31000, train loss = 5.650315e-06
# it 32000, train loss = 5.329184e-06
# it 33000, train loss = 5.074810e-06
# it 34000, train loss = 5.078584e-06
# it 35000, train loss = 4.929234e-06
# it 36000, train loss = 5.258898e-06
# it 37000, train loss = 4.604542e-06
# it 38000, train loss = 5.012493e-06
# it 39000, train loss = 5.155225e-06
# it 40000, train loss = 4.730397e-06
# it 41000, train loss = 5.152651e-06
# it 42000, train loss = 5.289448e-06
# it 43000, train loss = 5.486721e-06
# it 44000, train loss = 4.620407e-06
# it 45000, train loss = 5.249492e-06
# it 46000, train loss = 5.679766e-06
# it 47000, train loss = 4.680623e-06
# it 48000, train loss = 5.045284e-06
# it 49000, train loss = 4.526239e-06
# it 50000, train loss = 5.131914e-06
# it 51000, train loss = 3.852701e-06
# it 52000, train loss = 4.707882e-06
# it 53000, train loss = 4.674218e-06
# it 54000, train loss = 4.192186e-06
# it 55000, train loss = 4.309438e-06
# it 56000, train loss = 3.805124e-06
# it 57000, train loss = 4.921879e-06
# it 58000, train loss = 4.121854e-06
# it 59000, train loss = 4.430559e-06
# it 60000, train loss = 3.810073e-06
# it 61000, train loss = 4.319839e-06
# it 62000, train loss = 4.284066e-06
# it 63000, train loss = 5.101929e-06
# it 64000, train loss = 4.072379e-06
# it 65000, train loss = 4.004960e-06
# it 66000, train loss = 3.963060e-06
# it 67000, train loss = 4.293751e-06
# it 68000, train loss = 3.603582e-06
# it 69000, train loss = 3.274962e-06
# it 70000, train loss = 3.830985e-06
# it 71000, train loss = 3.642340e-06
# it 72000, train loss = 4.886184e-06
# it 73000, train loss = 3.329789e-06
# it 74000, train loss = 3.633731e-06
# it 75000, train loss = 3.853093e-06
# it 76000, train loss = 3.491742e-06
# it 77000, train loss = 3.329577e-06
# it 78000, train loss = 3.486697e-06
# it 79000, train loss = 3.180009e-06
# it 80000, train loss = 2.773792e-06
# it 81000, train loss = 3.201273e-06
# it 82000, train loss = 3.755547e-06
# it 83000, train loss = 3.032909e-06
# it 84000, train loss = 3.242457e-06
# it 85000, train loss = 3.095228e-06
# it 86000, train loss = 3.323022e-06
# it 87000, train loss = 3.047479e-06
# it 88000, train loss = 2.769107e-06
# it 89000, train loss = 3.242731e-06
# it 90000, train loss = 2.790241e-06
# it 91000, train loss = 2.688262e-06
# it 92000, train loss = 3.572533e-06
# it 93000, train loss = 2.724461e-06
# it 94000, train loss = 2.827156e-06
# it 95000, train loss = 2.612664e-06
# it 96000, train loss = 2.730436e-06
# it 97000, train loss = 2.760092e-06
# it 98000, train loss = 2.314892e-06
# it 99000, train loss = 3.048709e-06
# it 100000, train loss = 2.739293e-06

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax);

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 1.009345e-01
# it 2000, train loss = 6.027790e-02
# it 3000, train loss = 3.514097e-02
# it 4000, train loss = 2.336795e-02
# it 5000, train loss = 1.401952e-03
# it 6000, train loss = 4.123274e-05
# it 7000, train loss = 3.680071e-05
# it 8000, train loss = 2.740718e-05
# it 9000, train loss = 1.425321e-05
# it 10000, train loss = 7.764995e-06
# it 11000, train loss = 6.493980e-06
# it 12000, train loss = 6.428483e-06
# it 13000, train loss = 6.451323e-06
# it 14000, train loss = 6.372769e-06
# it 15000, train loss = 6.337684e-06
# it 16000, train loss = 6.297026e-06
# it 17000, train loss = 6.250683e-06
# it 18000, train loss = 6.199170e-06
# it 19000, train loss = 6.145254e-06
# it 20000, train loss = 6.092986e-06

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.3696  0.67068 0.92377 1.14339] [0.35577 0.64    0.87303 1.06901]
# pr P_xx & P_yy:  [0.36826 0.67314 0.92179 1.14398] [0.35447 0.64246 0.87099 1.06963]

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.155757e-04
# it 2000, train loss = 3.299987e-05
# it 3000, train loss = 1.387438e-05
# it 4000, train loss = 6.791032e-06
# it 5000, train loss = 3.620059e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %%
with open('params/÷_sharp_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('params/÷_sharp_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, Force_x, Force_y, strains, \
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Train
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 40000, print_freq=1000, batch_size=1000)

with open('params/÷_sharp_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-05-23 02:03:17.826668: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2024-05-23 02:03:41.341281: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m23.515153s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 5.664862e+00
# it 1001, val loss = 4.819177e+00
# it 2001, val loss = 2.080578e+00
# it 3001, val loss = 1.252960e+00
# it 4001, val loss = 1.465617e+00
# it 5001, val loss = 5.697585e+00
# it 6001, val loss = 1.345299e+00
# it 7001, val loss = 1.437650e+00
# it 8001, val loss = 3.957435e-01
# it 9001, val loss = 8.860802e-01
# it 10001, val loss = 1.587022e+00
# it 11001, val loss = 1.279565e+00
# it 12001, val loss = 4.061831e-01
# it 13001, val loss = 5.334854e-01
# it 14001, val loss = 3.948456e-01
# it 15001, val loss = 5.040460e-01
# it 16001, val loss = 5.601886e-01
# it 17001, val loss = 1.059609e+00
# it 18001, val loss = 1.983994e+00
# it 19001, val loss = 1.644524e+00
# it 20001, val loss = 7.036515e-01
# it 21001, val loss = 5.170765e-01
# it 22001, val loss = 3.670669e-01
# it 23001, val loss = 3.433022e+00
# it 24001, val loss = 6.200805e-01
# it 25001, val loss = 7.041515e-01
# it 26001, val loss = 3.389824e-01
# it 27001, val loss = 3.848988e-01
# it 28001, val loss = 8.972802e-01
# it 29001, val loss = 6.105807e-01
# it 30001, val loss = 1.856834e-01
# it 31001, val loss = 2.534355e-01
# it 32001, val loss = 8.180102e-01
# it 33001, val loss = 4.087343e-01
# it 34001, val loss = 4.656694e-01
# it 35001, val loss = 2.728156e-01
# it 36001, val loss = 6.520787e-01
# it 37001, val loss = 7.735699e-01
# it 38001, val loss = 2.533365e-01
# it 39001, val loss = 1.004687e+00

# %% [markdown]
# ## 3. Test

# %%
with open('params/÷_sharp_post.npy', 'rb') as f:
    mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,4,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
P_vmap = vmap(ThreeDElasticity(NODE_w_unravel).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(NODE_w_unravel).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 19, 19
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
elem_X = mesh.points[mesh.cells].mean(1)


params_vec = []
for x, y in elem_X:
    Lambda_inp = np.array([x,y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    params_vec.append(phi)
params_vec = jnp.array(params_vec).reshape([len(params_vec),1,-1])
params_vec = jnp.repeat(params_vec, axis=1, repeats=4)


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny
C10 = jnp.zeros(n_elem)
k1  = jnp.zeros(n_elem)
k2  = jnp.zeros(n_elem)
F_hist = []
node_x_hist = []
P_hist = []
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist.append(F)
    node_x_hist.append(node_x)
    P_hist.append(P)
node_x_hist = np.array(node_x_hist)
F_hist = np.array(F_hist)
P_hist = np.array(P_hist)
# Out:
# [05-23 09:01:08][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [05-23 09:01:08][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [05-23 09:01:08][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [05-23 09:01:08][DEBUG] jax_fem: Done pre-computations, took 0.043164730072021484 [s]
# [05-23 09:01:08][INFO] jax_fem: Solving a problem with 361 cells, 400x2 = 800 dofs.
# [05-23 09:01:08][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [05-23 09:01:08][DEBUG] jax_fem: Start timing
# [05-23 09:01:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:11][DEBUG] jax_fem: Function split_and_compute_cell took 2.7970 seconds
# [05-23 09:01:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:11][DEBUG] jax_fem: Linear guess solve...
# [05-23 09:01:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 0.01008420705112451
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0308 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: Before, res l_2 = 0.34818854244420827
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 1.1666825562782422e-07
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.14223983636388376
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 6.655140769579531e-07
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.480486996291139
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 3.536151457124779e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.18405193709444936
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 9.549643514132665e-09
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0273 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.10687875399401321
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 5.259383456992658e-10
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0294 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.06711553215263819
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 3.803024965012958e-09
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0310 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.1492602872348697
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 1.0419755996644294e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0291 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.20755699278216824
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 2.2500003522604453e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0287 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.10545979213597209
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 6.370520929398812e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0298 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.1128969145692486
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 3.0008368444260414e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.16017338181703195
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 3.998827828601687e-09
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0315 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.16258297105218375
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 3.0102093175684295e-08
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0306 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.13707251863360195
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 6.256965730781933e-09
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0300 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 0.1985662594697289
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 6.8382747450489564e-09
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 120.34351226687971
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 9.07744406283801e-06
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0321 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:12][DEBUG] jax_fem: res l_2 = 44.055303896426835
# [05-23 09:01:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:12][DEBUG] jax_fem: PETSc linear solve res = 1.052582746551016e-05
# [05-23 09:01:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0364 seconds
# [05-23 09:01:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 4331848.43165795
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 1.9787814559578571
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0316 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 26963544.742572784
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 773.5242012497922
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0315 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 769110836177.5353
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 702668.7364875629
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0300 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 3315309866994612.5
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 2.578738586857878e+20
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0278 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 3.185419175717998e+79
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 1.2353416562544413e+75
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0295 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = 2.583236251301483e+112
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 5.5590350499027314e+100
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0288 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = inf
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = 3.9998592009268986e+150
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0283 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = inf
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = inf
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0296 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = inf
# [05-23 09:01:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [05-23 09:01:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [05-23 09:01:13][DEBUG] jax_fem: PETSc linear solve res = inf
# [05-23 09:01:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [05-23 09:01:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0289 seconds
# [05-23 09:01:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [05-23 09:01:13][DEBUG] jax_fem: res l_2 = nan
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 66
#      61 elem_X = problem.get_physical_quad_points().mean(1)
#      63 problem.set_params(params_vec)
# ---> 66 node_x = solver(problem, use_petsc=True)
#      67 u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
#      68 F = u_grad + np.eye(2)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:849, in solver(problem, linear, precond, initial_guess, use_petsc)
#     846 # TODO: print platform jax.lib.xla_bridge.get_backend().platform
#     847 # and suggest PETSc or jax solver
#     848 if problem.periodic_bc_info is None:
# --> 849     return solver_row_elimination(problem, linear, precond, initial_guess,
#     850                                   use_petsc)
#     851 else:
#     852     return solver_lagrange_multiplier(problem, linear, use_petsc)
#
# File ~/Library/CloudStorage/OneDrive-purdue.edu/Research/node_inv/jax_fem/solver.py:393, in solver_row_elimination(problem, linear, precond, initial_guess, use_petsc)
#     390         res_val = np.linalg.norm(res_vec)
#     391         logger.debug(f"res l_2 = {res_val}")
# --> 393 assert np.all(
#     394     np.isfinite(res_val)), f"res_val contains NaN, stop the program!"
#     396 assert np.all(np.isfinite(dofs)), f"dofs contains NaN, stop the program!"
#     398 sol = dofs.reshape(sol_shape)
#
# AssertionError: res_val contains NaN, stop the program!

# %%
fig, axes = plt.subplots(1,4,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
for t, node_x, F, ax in zip(t_hist, node_x_hist, F_hist, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
