# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
from functools import partial
import jax.random as random
key = random.PRNGKey(2022)
from jax.flatten_util import ravel_pytree
import jax.example_libraries.optimizers as optimizers

import matplotlib.pyplot as plt

from fem import plotmesh
from utils import ff_nn, init_params_nn, train

# from jax.scipy.optimize import minimize
from scipy.optimize import minimize

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

from utils_hyperelasticity import ThreeDElasticity, GOH_model


E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

def VF1(x,y,h,w,p):
    U_x = x**p/w**p
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF2(x,y,h,w,p):
    U_x = 0.0
    U_y = y**p/h**p
    return jnp.stack([U_x,U_y]).T

def VF3(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    U_y = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    return jnp.stack([U_x,U_y]).T

def VF4(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    U_y = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    return jnp.stack([U_x,U_y]).T

def VF5(x,y,h,w,p):
    U_x = 1.0-(x/w-1)**(2*p)
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF6(x,y,h,w,p):
    U_x = 0.0
    U_y = 1.0-(y/h-1)**(2*p)
    return jnp.stack([U_x,U_y]).T

def VF_and_grad(VF, x, y, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x,y,h,w,p), VF_grad(x,y,h,w,p)

def VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x_node,y_node,h,w,p), VF_grad(x_elem,y_elem,h,w,p)
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %%
GOH_P = ThreeDElasticity(GOH_model).ugrad_2_P
GOH_P_vmap = vmap(GOH_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/V.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))

lmb_hist = [1.025, 1.050, 1.075, 1.100, 1.125, 1.150, 1.175, 1.200, 1.225, 1.250]
n_elem = Nx*Ny

# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0
F_hist_goh = []
P_hist_goh = []

# %%
# Equibiaxial
for lmb_max in lmb_hist:    
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-16 22:12:27][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:27][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:27][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:27][DEBUG] jax_fem: Done pre-computations, took 0.5546319484710693 [s]
# [07-16 22:12:27][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:29][DEBUG] jax_fem: Start timing
# [07-16 22:12:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.7357 seconds
# [07-16 22:12:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:30][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:30][DEBUG] jax_fem: PETSc linear solve res = 1.0391403373890118e-06
# [07-16 22:12:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-16 22:12:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:30][DEBUG] jax_fem: Before, res l_2 = 0.0005703085371009989
# [07-16 22:12:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:31][DEBUG] jax_fem: PETSc linear solve res = 8.625703149704198e-10
# [07-16 22:12:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0202 seconds
# [07-16 22:12:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:31][DEBUG] jax_fem: res l_2 = 2.50586385740124e-07
# [07-16 22:12:31][INFO] jax_fem: Solve took 1.4265649318695068 [s]
# [07-16 22:12:31][DEBUG] jax_fem: max of sol = 0.02499999999999991
# [07-16 22:12:31][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:31][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:31][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:31][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:32][DEBUG] jax_fem: Done pre-computations, took 0.21602606773376465 [s]
# [07-16 22:12:32][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:34][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:34][DEBUG] jax_fem: Start timing
# [07-16 22:12:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.5263 seconds
# [07-16 22:12:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:34][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:34][DEBUG] jax_fem: PETSc linear solve res = 2.0782806743816303e-06
# [07-16 22:12:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-16 22:12:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:34][DEBUG] jax_fem: Before, res l_2 = 0.0021554806801099805
# [07-16 22:12:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:34][DEBUG] jax_fem: PETSc linear solve res = 1.814029612486154e-09
# [07-16 22:12:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0189 seconds
# [07-16 22:12:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:34][DEBUG] jax_fem: res l_2 = 3.379850982602685e-06
# [07-16 22:12:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:34][DEBUG] jax_fem: PETSc linear solve res = 2.5045930760795407e-12
# [07-16 22:12:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0210 seconds
# [07-16 22:12:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:34][DEBUG] jax_fem: res l_2 = 1.2594854566127157e-11
# [07-16 22:12:34][INFO] jax_fem: Solve took 0.7085011005401611 [s]
# [07-16 22:12:34][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-16 22:12:34][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:35][DEBUG] jax_fem: Done pre-computations, took 0.22180509567260742 [s]
# [07-16 22:12:35][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:37][DEBUG] jax_fem: Start timing
# [07-16 22:12:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.5454 seconds
# [07-16 22:12:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:37][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:37][DEBUG] jax_fem: PETSc linear solve res = 3.117421011954008e-06
# [07-16 22:12:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-16 22:12:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:37][DEBUG] jax_fem: Before, res l_2 = 0.004319792514574995
# [07-16 22:12:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:37][DEBUG] jax_fem: PETSc linear solve res = 5.453625334814467e-09
# [07-16 22:12:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0214 seconds
# [07-16 22:12:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:37][DEBUG] jax_fem: res l_2 = 1.2681549390038777e-05
# [07-16 22:12:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:37][DEBUG] jax_fem: PETSc linear solve res = 1.683982664051274e-11
# [07-16 22:12:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0242 seconds
# [07-16 22:12:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:37][DEBUG] jax_fem: res l_2 = 1.679850486824087e-10
# [07-16 22:12:37][INFO] jax_fem: Solve took 0.7380342483520508 [s]
# [07-16 22:12:37][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-16 22:12:37][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:38][DEBUG] jax_fem: Done pre-computations, took 0.23499703407287598 [s]
# [07-16 22:12:38][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:40][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:40][DEBUG] jax_fem: Start timing
# [07-16 22:12:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.5771 seconds
# [07-16 22:12:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:40][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:40][DEBUG] jax_fem: PETSc linear solve res = 4.156561348763261e-06
# [07-16 22:12:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0222 seconds
# [07-16 22:12:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:40][DEBUG] jax_fem: Before, res l_2 = 0.006746274640744302
# [07-16 22:12:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:40][DEBUG] jax_fem: PETSc linear solve res = 1.2567339402772954e-08
# [07-16 22:12:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-16 22:12:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:40][DEBUG] jax_fem: res l_2 = 2.8235843298833853e-05
# [07-16 22:12:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:40][DEBUG] jax_fem: PETSc linear solve res = 3.0642948263143226e-11
# [07-16 22:12:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0216 seconds
# [07-16 22:12:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:40][DEBUG] jax_fem: res l_2 = 8.036324348639305e-10
# [07-16 22:12:40][INFO] jax_fem: Solve took 0.7678642272949219 [s]
# [07-16 22:12:40][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-16 22:12:40][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:40][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:41][DEBUG] jax_fem: Done pre-computations, took 0.2372417449951172 [s]
# [07-16 22:12:41][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:43][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:43][DEBUG] jax_fem: Start timing
# [07-16 22:12:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.5597 seconds
# [07-16 22:12:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:43][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:43][DEBUG] jax_fem: PETSc linear solve res = 5.1957016867294805e-06
# [07-16 22:12:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:12:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:43][DEBUG] jax_fem: Before, res l_2 = 0.009207926191588852
# [07-16 22:12:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:43][DEBUG] jax_fem: PETSc linear solve res = 8.915776910926201e-09
# [07-16 22:12:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:12:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:43][DEBUG] jax_fem: res l_2 = 4.6809323767097224e-05
# [07-16 22:12:43][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:43][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:43][DEBUG] jax_fem: PETSc linear solve res = 8.531061211411067e-11
# [07-16 22:12:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:43][DEBUG] jax_fem: Function split_and_compute_cell took 0.0202 seconds
# [07-16 22:12:43][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:43][DEBUG] jax_fem: res l_2 = 2.1718938750626482e-09
# [07-16 22:12:43][INFO] jax_fem: Solve took 0.7336969375610352 [s]
# [07-16 22:12:43][DEBUG] jax_fem: max of sol = 0.125
# [07-16 22:12:43][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:43][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:43][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:43][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:44][DEBUG] jax_fem: Done pre-computations, took 0.22527408599853516 [s]
# [07-16 22:12:44][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:45][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:45][DEBUG] jax_fem: Start timing
# [07-16 22:12:45][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.5581 seconds
# [07-16 22:12:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:46][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:46][DEBUG] jax_fem: PETSc linear solve res = 6.234842023908016e-06
# [07-16 22:12:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:12:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:46][DEBUG] jax_fem: Before, res l_2 = 0.011541217155256042
# [07-16 22:12:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:46][DEBUG] jax_fem: PETSc linear solve res = 8.09881776592538e-09
# [07-16 22:12:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:12:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:46][DEBUG] jax_fem: res l_2 = 6.379852719182438e-05
# [07-16 22:12:46][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:46][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:46][DEBUG] jax_fem: PETSc linear solve res = 3.694752062451973e-11
# [07-16 22:12:46][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:46][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-16 22:12:46][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:46][DEBUG] jax_fem: res l_2 = 4.101445051399148e-09
# [07-16 22:12:46][INFO] jax_fem: Solve took 0.7278187274932861 [s]
# [07-16 22:12:46][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-16 22:12:46][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:46][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:46][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:46][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:47][DEBUG] jax_fem: Done pre-computations, took 0.39937806129455566 [s]
# [07-16 22:12:47][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:49][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:49][DEBUG] jax_fem: Start timing
# [07-16 22:12:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.5146 seconds
# [07-16 22:12:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:49][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:49][DEBUG] jax_fem: PETSc linear solve res = 7.273982362048594e-06
# [07-16 22:12:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-16 22:12:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:49][DEBUG] jax_fem: Before, res l_2 = 0.013627484300644355
# [07-16 22:12:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:49][DEBUG] jax_fem: PETSc linear solve res = 1.5266647345139645e-08
# [07-16 22:12:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:12:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:49][DEBUG] jax_fem: res l_2 = 7.564093598003229e-05
# [07-16 22:12:49][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:49][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:49][DEBUG] jax_fem: PETSc linear solve res = 8.753078625844091e-11
# [07-16 22:12:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:49][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-16 22:12:49][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:49][DEBUG] jax_fem: res l_2 = 6.129670776540599e-09
# [07-16 22:12:49][INFO] jax_fem: Solve took 0.684124231338501 [s]
# [07-16 22:12:49][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-16 22:12:49][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:49][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:49][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:49][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:50][DEBUG] jax_fem: Done pre-computations, took 0.26601600646972656 [s]
# [07-16 22:12:50][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:52][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:52][DEBUG] jax_fem: Start timing
# [07-16 22:12:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.5280 seconds
# [07-16 22:12:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:52][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:52][DEBUG] jax_fem: PETSc linear solve res = 8.313122698119007e-06
# [07-16 22:12:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-16 22:12:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:52][DEBUG] jax_fem: Before, res l_2 = 0.01538004299811732
# [07-16 22:12:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:52][DEBUG] jax_fem: PETSc linear solve res = 2.0301160104744004e-08
# [07-16 22:12:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-16 22:12:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:52][DEBUG] jax_fem: res l_2 = 8.186298233304654e-05
# [07-16 22:12:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:52][DEBUG] jax_fem: PETSc linear solve res = 5.319222077374723e-11
# [07-16 22:12:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0207 seconds
# [07-16 22:12:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:52][DEBUG] jax_fem: res l_2 = 7.78905133422771e-09
# [07-16 22:12:52][INFO] jax_fem: Solve took 0.7046680450439453 [s]
# [07-16 22:12:52][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-16 22:12:52][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:52][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:52][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:52][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:53][DEBUG] jax_fem: Done pre-computations, took 0.24013590812683105 [s]
# [07-16 22:12:53][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:55][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:55][DEBUG] jax_fem: Start timing
# [07-16 22:12:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.5188 seconds
# [07-16 22:12:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:55][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:55][DEBUG] jax_fem: PETSc linear solve res = 9.352263034973178e-06
# [07-16 22:12:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:12:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:55][DEBUG] jax_fem: Before, res l_2 = 0.016735907701344328
# [07-16 22:12:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:55][DEBUG] jax_fem: PETSc linear solve res = 4.3214086638324515e-09
# [07-16 22:12:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0239 seconds
# [07-16 22:12:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:55][DEBUG] jax_fem: res l_2 = 8.597155846374376e-05
# [07-16 22:12:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:55][DEBUG] jax_fem: PETSc linear solve res = 3.779200661517286e-11
# [07-16 22:12:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-16 22:12:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:55][DEBUG] jax_fem: res l_2 = 8.814591031669076e-09
# [07-16 22:12:55][INFO] jax_fem: Solve took 0.6952610015869141 [s]
# [07-16 22:12:55][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-16 22:12:55][DEBUG] jax_fem: min of sol = 0.0
# [07-16 22:12:55][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:55][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:55][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:55][DEBUG] jax_fem: Done pre-computations, took 0.2131328582763672 [s]
# [07-16 22:12:55][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:57][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:57][DEBUG] jax_fem: Start timing
# [07-16 22:12:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.6367 seconds
# [07-16 22:12:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:58][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:58][DEBUG] jax_fem: PETSc linear solve res = 1.0391403373458961e-05
# [07-16 22:12:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0226 seconds
# [07-16 22:12:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:58][DEBUG] jax_fem: Before, res l_2 = 0.017651959968551182
# [07-16 22:12:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:58][DEBUG] jax_fem: PETSc linear solve res = 3.0160427939962837e-09
# [07-16 22:12:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [07-16 22:12:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:58][DEBUG] jax_fem: res l_2 = 9.331178665404639e-05
# [07-16 22:12:58][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:58][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:58][DEBUG] jax_fem: PETSc linear solve res = 1.1505722151774597e-10
# [07-16 22:12:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:58][DEBUG] jax_fem: Function split_and_compute_cell took 0.0211 seconds
# [07-16 22:12:58][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:58][DEBUG] jax_fem: res l_2 = 9.468239870651575e-09
# [07-16 22:12:58][INFO] jax_fem: Solve took 0.8321001529693604 [s]
# [07-16 22:12:58][DEBUG] jax_fem: max of sol = 0.25
# [07-16 22:12:58][DEBUG] jax_fem: min of sol = 0.0

# %%
# Uniaxial in x
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           right,                                  ],
        [1,                 0,              0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-16 22:12:58][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:58][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:58][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:12:59][DEBUG] jax_fem: Done pre-computations, took 0.26238274574279785 [s]
# [07-16 22:12:59][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:12:59][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:12:59][DEBUG] jax_fem: Start timing
# [07-16 22:12:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.5659 seconds
# [07-16 22:12:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:59][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:12:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:59][DEBUG] jax_fem: PETSc linear solve res = 7.063724131943154e-07
# [07-16 22:12:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-16 22:12:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:59][DEBUG] jax_fem: Before, res l_2 = 0.00020931033376022677
# [07-16 22:12:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:12:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:12:59][DEBUG] jax_fem: PETSc linear solve res = 1.6504806344163647e-10
# [07-16 22:12:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:12:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0199 seconds
# [07-16 22:12:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:12:59][DEBUG] jax_fem: res l_2 = 8.265824701329191e-08
# [07-16 22:12:59][INFO] jax_fem: Solve took 0.691218376159668 [s]
# [07-16 22:12:59][DEBUG] jax_fem: max of sol = 0.02499999999999991
# [07-16 22:12:59][DEBUG] jax_fem: min of sol = -0.012428174206426088
# [07-16 22:12:59][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:12:59][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:12:59][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:00][DEBUG] jax_fem: Done pre-computations, took 0.23404788970947266 [s]
# [07-16 22:13:00][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:00][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:00][DEBUG] jax_fem: Start timing
# [07-16 22:13:00][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:00][DEBUG] jax_fem: Function split_and_compute_cell took 0.5787 seconds
# [07-16 22:13:00][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:00][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:00][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:00][DEBUG] jax_fem: PETSc linear solve res = 1.4127449793583354e-06
# [07-16 22:13:00][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:00][DEBUG] jax_fem: Function split_and_compute_cell took 0.0286 seconds
# [07-16 22:13:00][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:00][DEBUG] jax_fem: Before, res l_2 = 0.0008485407092288233
# [07-16 22:13:00][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:00][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:00][DEBUG] jax_fem: PETSc linear solve res = 5.028182098761698e-10
# [07-16 22:13:00][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:00][DEBUG] jax_fem: Function split_and_compute_cell took 0.0238 seconds
# [07-16 22:13:00][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:00][DEBUG] jax_fem: res l_2 = 1.361282869641239e-06
# [07-16 22:13:00][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:00][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:00][DEBUG] jax_fem: PETSc linear solve res = 3.49796635788692e-13
# [07-16 22:13:00][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:00][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:13:00][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:00][DEBUG] jax_fem: res l_2 = 4.129314719597906e-12
# [07-16 22:13:00][INFO] jax_fem: Solve took 0.8001890182495117 [s]
# [07-16 22:13:00][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-16 22:13:00][DEBUG] jax_fem: min of sol = -0.024397211880011996
# [07-16 22:13:00][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:00][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:00][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:01][DEBUG] jax_fem: Done pre-computations, took 0.32886576652526855 [s]
# [07-16 22:13:01][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:01][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:01][DEBUG] jax_fem: Start timing
# [07-16 22:13:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.5422 seconds
# [07-16 22:13:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:01][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:01][DEBUG] jax_fem: PETSc linear solve res = 2.119117222957331e-06
# [07-16 22:13:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0202 seconds
# [07-16 22:13:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:01][DEBUG] jax_fem: Before, res l_2 = 0.001867886970156072
# [07-16 22:13:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:01][DEBUG] jax_fem: PETSc linear solve res = 1.623251240698388e-09
# [07-16 22:13:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-16 22:13:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:01][DEBUG] jax_fem: res l_2 = 6.583770254763133e-06
# [07-16 22:13:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:01][DEBUG] jax_fem: PETSc linear solve res = 2.0435039711876047e-12
# [07-16 22:13:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0201 seconds
# [07-16 22:13:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:01][DEBUG] jax_fem: res l_2 = 9.654626915570004e-11
# [07-16 22:13:01][INFO] jax_fem: Solve took 0.7175459861755371 [s]
# [07-16 22:13:01][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-16 22:13:01][DEBUG] jax_fem: min of sol = -0.0359344584772323
# [07-16 22:13:01][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:01][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:02][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:02][DEBUG] jax_fem: Done pre-computations, took 0.2042250633239746 [s]
# [07-16 22:13:02][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:02][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:02][DEBUG] jax_fem: Start timing
# [07-16 22:13:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.5477 seconds
# [07-16 22:13:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:02][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:02][DEBUG] jax_fem: PETSc linear solve res = 2.825489958716671e-06
# [07-16 22:13:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-16 22:13:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:02][DEBUG] jax_fem: Before, res l_2 = 0.0032247997933617786
# [07-16 22:13:02][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:02][DEBUG] jax_fem: PETSc linear solve res = 6.722964778563208e-09
# [07-16 22:13:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-16 22:13:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:02][DEBUG] jax_fem: res l_2 = 1.9592436870350993e-05
# [07-16 22:13:02][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:02][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:02][DEBUG] jax_fem: PETSc linear solve res = 1.0136671483468932e-11
# [07-16 22:13:02][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:02][DEBUG] jax_fem: Function split_and_compute_cell took 0.0176 seconds
# [07-16 22:13:02][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:02][DEBUG] jax_fem: res l_2 = 8.605714473579739e-10
# [07-16 22:13:02][INFO] jax_fem: Solve took 0.71238112449646 [s]
# [07-16 22:13:02][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-16 22:13:02][DEBUG] jax_fem: min of sol = -0.04706474760587131
# [07-16 22:13:02][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:02][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:02][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:03][DEBUG] jax_fem: Done pre-computations, took 0.21541523933410645 [s]
# [07-16 22:13:03][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:03][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:03][DEBUG] jax_fem: Start timing
# [07-16 22:13:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.5047 seconds
# [07-16 22:13:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:03][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:03][DEBUG] jax_fem: PETSc linear solve res = 3.531862562204311e-06
# [07-16 22:13:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-16 22:13:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:03][DEBUG] jax_fem: Before, res l_2 = 0.004887749738198296
# [07-16 22:13:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:03][DEBUG] jax_fem: PETSc linear solve res = 1.0849282205122447e-08
# [07-16 22:13:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0177 seconds
# [07-16 22:13:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:03][DEBUG] jax_fem: res l_2 = 4.4966996526381877e-05
# [07-16 22:13:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:03][DEBUG] jax_fem: PETSc linear solve res = 9.173231560474945e-11
# [07-16 22:13:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-16 22:13:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:03][DEBUG] jax_fem: res l_2 = 4.5735232648574694e-09
# [07-16 22:13:03][INFO] jax_fem: Solve took 0.6713788509368896 [s]
# [07-16 22:13:03][DEBUG] jax_fem: max of sol = 0.125
# [07-16 22:13:03][DEBUG] jax_fem: min of sol = -0.057811034829067236
# [07-16 22:13:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:04][DEBUG] jax_fem: Done pre-computations, took 0.21196794509887695 [s]
# [07-16 22:13:04][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:04][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:04][DEBUG] jax_fem: Start timing
# [07-16 22:13:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.5066 seconds
# [07-16 22:13:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:04][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:04][DEBUG] jax_fem: PETSc linear solve res = 4.238234445914662e-06
# [07-16 22:13:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0185 seconds
# [07-16 22:13:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:04][DEBUG] jax_fem: Before, res l_2 = 0.006833878243922865
# [07-16 22:13:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:04][DEBUG] jax_fem: PETSc linear solve res = 1.9692513583872963e-08
# [07-16 22:13:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-16 22:13:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:04][DEBUG] jax_fem: res l_2 = 8.789029752794246e-05
# [07-16 22:13:04][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:04][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:04][DEBUG] jax_fem: PETSc linear solve res = 1.8968290559465312e-11
# [07-16 22:13:04][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:04][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-16 22:13:04][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:04][DEBUG] jax_fem: res l_2 = 1.7634211809090747e-08
# [07-16 22:13:04][INFO] jax_fem: Solve took 0.6722590923309326 [s]
# [07-16 22:13:04][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-16 22:13:04][DEBUG] jax_fem: min of sol = -0.06819452872084522
# [07-16 22:13:04][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:04][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:04][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:05][DEBUG] jax_fem: Done pre-computations, took 0.2811610698699951 [s]
# [07-16 22:13:05][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:05][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:05][DEBUG] jax_fem: Start timing
# [07-16 22:13:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.5509 seconds
# [07-16 22:13:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:05][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:05][DEBUG] jax_fem: PETSc linear solve res = 4.944607142983426e-06
# [07-16 22:13:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:13:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:05][DEBUG] jax_fem: Before, res l_2 = 0.009047340843985362
# [07-16 22:13:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:05][DEBUG] jax_fem: PETSc linear solve res = 1.581797612593683e-08
# [07-16 22:13:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-16 22:13:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:05][DEBUG] jax_fem: res l_2 = 0.0001541391599310377
# [07-16 22:13:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:05][DEBUG] jax_fem: PETSc linear solve res = 1.8480403374667746e-11
# [07-16 22:13:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:13:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:05][DEBUG] jax_fem: res l_2 = 5.482679215129344e-08
# [07-16 22:13:05][INFO] jax_fem: Solve took 0.7148239612579346 [s]
# [07-16 22:13:05][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-16 22:13:05][DEBUG] jax_fem: min of sol = -0.07823487722963464
# [07-16 22:13:05][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:05][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:05][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:06][DEBUG] jax_fem: Done pre-computations, took 0.2089710235595703 [s]
# [07-16 22:13:06][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:06][DEBUG] jax_fem: Start timing
# [07-16 22:13:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.5094 seconds
# [07-16 22:13:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:06][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:06][DEBUG] jax_fem: PETSc linear solve res = 5.650978871613743e-06
# [07-16 22:13:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:13:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:06][DEBUG] jax_fem: Before, res l_2 = 0.01151812053891537
# [07-16 22:13:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:06][DEBUG] jax_fem: PETSc linear solve res = 9.396029669027336e-08
# [07-16 22:13:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0175 seconds
# [07-16 22:13:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:06][DEBUG] jax_fem: res l_2 = 0.00025013270492342147
# [07-16 22:13:06][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:06][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:06][DEBUG] jax_fem: PETSc linear solve res = 4.6435537413982637e-10
# [07-16 22:13:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:06][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-16 22:13:06][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:06][DEBUG] jax_fem: res l_2 = 1.4607947568015178e-07
# [07-16 22:13:06][INFO] jax_fem: Solve took 0.6698620319366455 [s]
# [07-16 22:13:06][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-16 22:13:06][DEBUG] jax_fem: min of sol = -0.08795032832020848
# [07-16 22:13:06][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:06][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:06][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:06][DEBUG] jax_fem: Done pre-computations, took 0.21053075790405273 [s]
# [07-16 22:13:06][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:06][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:06][DEBUG] jax_fem: Start timing
# [07-16 22:13:06][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.5184 seconds
# [07-16 22:13:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:07][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:07][DEBUG] jax_fem: PETSc linear solve res = 6.357351558334596e-06
# [07-16 22:13:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0186 seconds
# [07-16 22:13:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:07][DEBUG] jax_fem: Before, res l_2 = 0.014241216301305941
# [07-16 22:13:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:07][DEBUG] jax_fem: PETSc linear solve res = 9.289363476924934e-08
# [07-16 22:13:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-16 22:13:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:07][DEBUG] jax_fem: res l_2 = 0.0003829848162946057
# [07-16 22:13:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:07][DEBUG] jax_fem: PETSc linear solve res = 1.9015352473196856e-09
# [07-16 22:13:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0201 seconds
# [07-16 22:13:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:07][DEBUG] jax_fem: res l_2 = 3.467152234730505e-07
# [07-16 22:13:07][INFO] jax_fem: Solve took 0.6861269474029541 [s]
# [07-16 22:13:07][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-16 22:13:07][DEBUG] jax_fem: min of sol = -0.09735787448601971
# [07-16 22:13:07][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:07][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:07][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:07][DEBUG] jax_fem: Done pre-computations, took 0.24152803421020508 [s]
# [07-16 22:13:07][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:07][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:07][DEBUG] jax_fem: Start timing
# [07-16 22:13:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.5361 seconds
# [07-16 22:13:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:08][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:08][DEBUG] jax_fem: PETSc linear solve res = 7.063725124408622e-06
# [07-16 22:13:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-16 22:13:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:08][DEBUG] jax_fem: Before, res l_2 = 0.017216147617303324
# [07-16 22:13:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:08][DEBUG] jax_fem: PETSc linear solve res = 4.375572627893076e-08
# [07-16 22:13:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:13:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:08][DEBUG] jax_fem: res l_2 = 0.0005605515787814704
# [07-16 22:13:08][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:08][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:08][DEBUG] jax_fem: PETSc linear solve res = 1.373760933562024e-09
# [07-16 22:13:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:08][DEBUG] jax_fem: Function split_and_compute_cell took 0.0192 seconds
# [07-16 22:13:08][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:08][DEBUG] jax_fem: res l_2 = 7.516692202374414e-07
# [07-16 22:13:08][INFO] jax_fem: Solve took 0.7059581279754639 [s]
# [07-16 22:13:08][DEBUG] jax_fem: max of sol = 0.25
# [07-16 22:13:08][DEBUG] jax_fem: min of sol = -0.10647337674439991

# %%
# Uniaxial in y
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                     ],
        [1,                 0,              1,                                       ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-16 22:13:08][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:08][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:08][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:08][DEBUG] jax_fem: Done pre-computations, took 0.30048370361328125 [s]
# [07-16 22:13:08][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:08][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:08][DEBUG] jax_fem: Start timing
# [07-16 22:13:08][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.5178 seconds
# [07-16 22:13:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:09][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:09][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:09][DEBUG] jax_fem: PETSc linear solve res = 4.496828730888435e-08
# [07-16 22:13:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.0201 seconds
# [07-16 22:13:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:09][DEBUG] jax_fem: Before, res l_2 = 9.163554076676684e-05
# [07-16 22:13:09][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:09][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:09][DEBUG] jax_fem: PETSc linear solve res = 1.9746673775125514e-10
# [07-16 22:13:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-16 22:13:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:09][DEBUG] jax_fem: res l_2 = 8.099283951095507e-09
# [07-16 22:13:09][INFO] jax_fem: Solve took 0.639915943145752 [s]
# [07-16 22:13:09][DEBUG] jax_fem: max of sol = 0.02499999999999991
# [07-16 22:13:09][DEBUG] jax_fem: min of sol = -0.012385648673623663
# [07-16 22:13:09][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:09][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:09][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:09][DEBUG] jax_fem: Done pre-computations, took 0.23735499382019043 [s]
# [07-16 22:13:09][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:09][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:09][DEBUG] jax_fem: Start timing
# [07-16 22:13:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.5514 seconds
# [07-16 22:13:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:10][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:10][DEBUG] jax_fem: PETSc linear solve res = 8.993657420841228e-08
# [07-16 22:13:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [07-16 22:13:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:10][DEBUG] jax_fem: Before, res l_2 = 0.00046496283852815666
# [07-16 22:13:10][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:10][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:10][DEBUG] jax_fem: PETSc linear solve res = 2.7381689951161337e-09
# [07-16 22:13:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:10][DEBUG] jax_fem: Function split_and_compute_cell took 0.0202 seconds
# [07-16 22:13:10][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:10][DEBUG] jax_fem: res l_2 = 3.110894080490703e-07
# [07-16 22:13:10][INFO] jax_fem: Solve took 0.6814219951629639 [s]
# [07-16 22:13:10][DEBUG] jax_fem: max of sol = 0.05000000000000005
# [07-16 22:13:10][DEBUG] jax_fem: min of sol = -0.024321415517177227
# [07-16 22:13:10][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:10][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:10][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:10][DEBUG] jax_fem: Done pre-computations, took 0.2192850112915039 [s]
# [07-16 22:13:10][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:10][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:10][DEBUG] jax_fem: Start timing
# [07-16 22:13:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.5104 seconds
# [07-16 22:13:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:11][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:11][DEBUG] jax_fem: PETSc linear solve res = 1.3490486187548674e-07
# [07-16 22:13:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0202 seconds
# [07-16 22:13:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:11][DEBUG] jax_fem: Before, res l_2 = 0.001225961238787774
# [07-16 22:13:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:11][DEBUG] jax_fem: PETSc linear solve res = 4.1848622585674483e-10
# [07-16 22:13:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-16 22:13:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:11][DEBUG] jax_fem: res l_2 = 2.497958590925987e-06
# [07-16 22:13:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:11][DEBUG] jax_fem: PETSc linear solve res = 7.987101120122904e-12
# [07-16 22:13:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-16 22:13:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:11][DEBUG] jax_fem: res l_2 = 1.7831604326411506e-11
# [07-16 22:13:11][INFO] jax_fem: Solve took 0.6778221130371094 [s]
# [07-16 22:13:11][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-16 22:13:11][DEBUG] jax_fem: min of sol = -0.03583352203769766
# [07-16 22:13:11][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:11][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:11][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:11][DEBUG] jax_fem: Done pre-computations, took 0.22905182838439941 [s]
# [07-16 22:13:11][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:11][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:11][DEBUG] jax_fem: Start timing
# [07-16 22:13:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.5661 seconds
# [07-16 22:13:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:12][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:12][DEBUG] jax_fem: PETSc linear solve res = 1.7987314841682456e-07
# [07-16 22:13:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0206 seconds
# [07-16 22:13:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:12][DEBUG] jax_fem: Before, res l_2 = 0.0023255338029872607
# [07-16 22:13:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:12][DEBUG] jax_fem: PETSc linear solve res = 1.2284494705794976e-08
# [07-16 22:13:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0221 seconds
# [07-16 22:13:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:12][DEBUG] jax_fem: res l_2 = 9.453273881650461e-06
# [07-16 22:13:12][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:12][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:12][DEBUG] jax_fem: PETSc linear solve res = 1.2220379140658375e-11
# [07-16 22:13:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:12][DEBUG] jax_fem: Function split_and_compute_cell took 0.0223 seconds
# [07-16 22:13:12][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:12][DEBUG] jax_fem: res l_2 = 2.3467624078518906e-10
# [07-16 22:13:12][INFO] jax_fem: Solve took 0.7578833103179932 [s]
# [07-16 22:13:12][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-16 22:13:12][DEBUG] jax_fem: min of sol = -0.04694735288868309
# [07-16 22:13:12][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:12][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:12][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:12][DEBUG] jax_fem: Done pre-computations, took 0.2418670654296875 [s]
# [07-16 22:13:12][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:12][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:12][DEBUG] jax_fem: Start timing
# [07-16 22:13:12][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.6315 seconds
# [07-16 22:13:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:13][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:13][DEBUG] jax_fem: PETSc linear solve res = 2.2484143707036776e-07
# [07-16 22:13:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0207 seconds
# [07-16 22:13:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:13][DEBUG] jax_fem: Before, res l_2 = 0.0037416984637825682
# [07-16 22:13:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:13][DEBUG] jax_fem: PETSc linear solve res = 8.70795206654378e-09
# [07-16 22:13:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-16 22:13:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:13][DEBUG] jax_fem: res l_2 = 2.515695608997003e-05
# [07-16 22:13:13][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:13][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:13][DEBUG] jax_fem: PETSc linear solve res = 3.100689371082877e-11
# [07-16 22:13:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:13][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-16 22:13:13][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:13][DEBUG] jax_fem: res l_2 = 1.6928663947451826e-09
# [07-16 22:13:13][INFO] jax_fem: Solve took 0.805208683013916 [s]
# [07-16 22:13:13][DEBUG] jax_fem: max of sol = 0.125
# [07-16 22:13:13][DEBUG] jax_fem: min of sol = -0.057685125348711445
# [07-16 22:13:13][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:13][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:13][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:13][DEBUG] jax_fem: Done pre-computations, took 0.22390985488891602 [s]
# [07-16 22:13:13][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:13][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:13][DEBUG] jax_fem: Start timing
# [07-16 22:13:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.5276 seconds
# [07-16 22:13:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:14][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:14][DEBUG] jax_fem: PETSc linear solve res = 2.698097237509735e-07
# [07-16 22:13:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0219 seconds
# [07-16 22:13:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:14][DEBUG] jax_fem: Before, res l_2 = 0.005458490966408593
# [07-16 22:13:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:14][DEBUG] jax_fem: PETSc linear solve res = 4.761720855499743e-09
# [07-16 22:13:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0233 seconds
# [07-16 22:13:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:14][DEBUG] jax_fem: res l_2 = 5.45225983667614e-05
# [07-16 22:13:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:14][DEBUG] jax_fem: PETSc linear solve res = 4.2058752130674065e-10
# [07-16 22:13:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0226 seconds
# [07-16 22:13:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:14][DEBUG] jax_fem: res l_2 = 8.091694667657072e-09
# [07-16 22:13:14][INFO] jax_fem: Solve took 0.7337989807128906 [s]
# [07-16 22:13:14][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-16 22:13:14][DEBUG] jax_fem: min of sol = -0.06806763037275322
# [07-16 22:13:14][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:14][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:14][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:14][DEBUG] jax_fem: Done pre-computations, took 0.22995519638061523 [s]
# [07-16 22:13:14][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:14][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:14][DEBUG] jax_fem: Start timing
# [07-16 22:13:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.6159 seconds
# [07-16 22:13:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:15][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:15][DEBUG] jax_fem: PETSc linear solve res = 3.147780108515235e-07
# [07-16 22:13:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0195 seconds
# [07-16 22:13:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:15][DEBUG] jax_fem: Before, res l_2 = 0.007463642910708642
# [07-16 22:13:15][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:15][DEBUG] jax_fem: PETSc linear solve res = 3.692920380225478e-09
# [07-16 22:13:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-16 22:13:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:15][DEBUG] jax_fem: res l_2 = 0.00010327921996435738
# [07-16 22:13:15][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:15][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:15][DEBUG] jax_fem: PETSc linear solve res = 5.581565711345381e-10
# [07-16 22:13:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:15][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-16 22:13:15][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:15][DEBUG] jax_fem: res l_2 = 2.9412823582262313e-08
# [07-16 22:13:15][INFO] jax_fem: Solve took 0.7821910381317139 [s]
# [07-16 22:13:15][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-16 22:13:15][DEBUG] jax_fem: min of sol = -0.07811407332268239
# [07-16 22:13:15][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:15][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:15][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:15][DEBUG] jax_fem: Done pre-computations, took 0.21922612190246582 [s]
# [07-16 22:13:15][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:15][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:15][DEBUG] jax_fem: Start timing
# [07-16 22:13:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.5165 seconds
# [07-16 22:13:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:16][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:16][DEBUG] jax_fem: PETSc linear solve res = 3.597462978630499e-07
# [07-16 22:13:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-16 22:13:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:16][DEBUG] jax_fem: Before, res l_2 = 0.00974780822874026
# [07-16 22:13:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:16][DEBUG] jax_fem: PETSc linear solve res = 4.672307346699597e-09
# [07-16 22:13:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0185 seconds
# [07-16 22:13:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:16][DEBUG] jax_fem: res l_2 = 0.00017788222831156147
# [07-16 22:13:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:16][DEBUG] jax_fem: PETSc linear solve res = 2.8376754126341855e-10
# [07-16 22:13:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0177 seconds
# [07-16 22:13:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:16][DEBUG] jax_fem: res l_2 = 8.835036344273519e-08
# [07-16 22:13:16][INFO] jax_fem: Solve took 0.6795001029968262 [s]
# [07-16 22:13:16][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-16 22:13:16][DEBUG] jax_fem: min of sol = -0.08784223607958265
# [07-16 22:13:16][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:16][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:16][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:16][DEBUG] jax_fem: Done pre-computations, took 0.21631789207458496 [s]
# [07-16 22:13:16][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:16][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:16][DEBUG] jax_fem: Start timing
# [07-16 22:13:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.5946 seconds
# [07-16 22:13:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:17][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:17][DEBUG] jax_fem: PETSc linear solve res = 4.0471458569960235e-07
# [07-16 22:13:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0192 seconds
# [07-16 22:13:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:17][DEBUG] jax_fem: Before, res l_2 = 0.01230412320606619
# [07-16 22:13:17][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:17][DEBUG] jax_fem: PETSc linear solve res = 6.054000960794301e-09
# [07-16 22:13:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-16 22:13:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:17][DEBUG] jax_fem: res l_2 = 0.00028544524176277544
# [07-16 22:13:17][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:17][DEBUG] jax_fem: PETSc linear solve res = 1.5079602642755328e-10
# [07-16 22:13:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-16 22:13:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:17][DEBUG] jax_fem: res l_2 = 2.3020309695528605e-07
# [07-16 22:13:17][INFO] jax_fem: Solve took 0.7646007537841797 [s]
# [07-16 22:13:17][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-16 22:13:17][DEBUG] jax_fem: min of sol = -0.09726862305214495
# [07-16 22:13:17][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-16 22:13:17][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-16 22:13:17][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-16 22:13:17][DEBUG] jax_fem: Done pre-computations, took 0.27508091926574707 [s]
# [07-16 22:13:17][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-16 22:13:17][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-16 22:13:17][DEBUG] jax_fem: Start timing
# [07-16 22:13:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.5523 seconds
# [07-16 22:13:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:18][DEBUG] jax_fem: Linear guess solve...
# [07-16 22:13:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:18][DEBUG] jax_fem: PETSc linear solve res = 4.496828741407355e-07
# [07-16 22:13:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-16 22:13:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:18][DEBUG] jax_fem: Before, res l_2 = 0.015127908267335701
# [07-16 22:13:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:18][DEBUG] jax_fem: PETSc linear solve res = 5.205905234252258e-09
# [07-16 22:13:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-16 22:13:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:18][DEBUG] jax_fem: res l_2 = 0.00043368711269963
# [07-16 22:13:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-16 22:13:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-16 22:13:18][DEBUG] jax_fem: PETSc linear solve res = 5.695154083887059e-09
# [07-16 22:13:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-16 22:13:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0196 seconds
# [07-16 22:13:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-16 22:13:18][DEBUG] jax_fem: res l_2 = 5.372988361023694e-07
# [07-16 22:13:18][INFO] jax_fem: Solve took 0.7230362892150879 [s]
# [07-16 22:13:18][DEBUG] jax_fem: max of sol = 0.25
# [07-16 22:13:18][DEBUG] jax_fem: min of sol = -0.10640859174275821

# %%
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)

F_mean = F_hist_goh[-1].mean(axis=0)
params_gt = params_vec[:,0,:]

# %%
GOH_P_vmap2 = vmap(GOH_P, in_axes=(None,0,None))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_gt = GOH_P_vmap2(ugrad, params_gt,2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_gt, title='Ground Truth stress at $\lambda_x$=1.2', ax=ax); 
print(P_gt.min(), P_gt.max())



fig, axes = plt.subplots(1,12,figsize=(60,4))
t_hist = np.arange(len(lmb_hist)*3)
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
# Out:
# 0.6100125566303432 0.8540175792824803

# %%
h = 1.0
w = 1.0
# VF_list = [VF1, VF1, VF2, VF2, VF3, VF4, VF4, VF4, VF4, VF4, VF5, VF6]
# p_list =  [1.0, 2.0, 1.0, 2.0, 1.0, 2.0, 3.0, 4.0, 4.0, 5.0, 1.0, 1.0]
VF_list = [VF1, VF1, VF1, VF1, VF1, VF2, VF2, VF2, VF2, VF2, VF3, VF3, VF3, VF3, VF4, VF4, VF4, VF4, VF4, VF5, VF6]
p_list =  [1.0, 2.0, 3.0, 0.5, 0.3, 1.0, 2.0, 3.0, 0.5, 0.3, 1.0, 2.0, 3.0, 4.0, 2.0, 3.0, 4.0, 4.0, 5.0, 1.0, 1.0]

x_elem, y_elem = elem_X.T
x_node, y_node = mesh.points.T
U, gradU = [], []
fig, axes = plt.subplots(2,len(VF_list),figsize=(len(VF_list)*5,8))
for ax, VF, p in zip(axes.T, VF_list, p_list):
    Ui, gradUi = VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p)
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,0].mean(axis=1), title='Virtual Field i', ax=ax[0]); 
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,1].mean(axis=1), title=None, ax=ax[1]); 
    U.append(Ui)
    gradU.append(gradUi)
U, gradU = np.array(U), np.array(gradU)

# %%
dL = Lx/Nx
dA = dL*dL
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0]*dL, axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0]*dL, axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1]*dL, axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1]*dL, axis=1)
Fx = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Fy = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

rgt_bd_nodes = np.where(np.isclose(mesh.points[:,0], 1.0))[0]
top_bd_nodes = np.where(np.isclose(mesh.points[:,1], 1.0))[0]
lft_bd_nodes = np.where(np.isclose(mesh.points[:,0], 0.0))[0]
bot_bd_nodes = np.where(np.isclose(mesh.points[:,1], 0.0))[0]

# %%
def eval_W_int(P, gradU):
    return jnp.einsum('ijk,ijk', P, gradU)*dA
def eval_W_ext(U, Fx, Fy):
    W_rgt = jnp.sum(U[rgt_bd_nodes, 0]*Fx*dL)
    W_top = jnp.sum(U[top_bd_nodes, 1]*Fy*dL)
    W_lft = jnp.sum(U[lft_bd_nodes, 0]*Fx*dL)
    W_bot = jnp.sum(U[bot_bd_nodes, 1]*Fy*dL)
    return W_rgt + W_top# + W_lft + W_bot

def get_vworks(params):
    W_int_vec = []
    W_ext_vec = []
    for step in range(len(F_hist_goh)):
        F = F_hist_goh[step]
        u_grad = jnp.array(F - np.eye(2))
        P = GOH_P_vmap(u_grad, params, 2)
        W_int = []
        W_ext = []
        for i_vf in range(len(U)):
            W_int.append(eval_W_int(P, gradU[i_vf]))
            W_ext.append(eval_W_ext(U[i_vf], Fx[step], Fy[step]))
        W_int_vec.append(jnp.array(W_int))
        W_ext_vec.append(jnp.array(W_ext))
    W_int_vec = jnp.array(W_int_vec) # [n_steps, n_virtualfields]
    W_ext_vec = jnp.array(W_ext_vec)
    return W_int_vec, W_ext_vec

@jit
def obj_fn(params):
    params = jnp.exp(params)
    W_int_vec, W_ext_vec = get_vworks(params)
    return jnp.sum((W_int_vec-W_ext_vec)**2)
g = grad(obj_fn)

# %%
i_vf = 0
W_int_vec, W_ext_vec = get_vworks(params_gt)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));

# %%
def loss(Lambda_params, x, key):
    params = ff_nn(elem_X, Lambda_params)

    # tvr_loss = 0.0
    # for i in range(5):
    #     grads = vmap(grad(lambda inp: ff_nn(inp, Lambda_params)[i]))(elem_X) # Take derivative of the ith output wrt the input vector
    #     tvr_loss += jnp.mean(jnp.sqrt(jnp.sum(grads*grads, axis=1)))

    # w = 1.0e-2
    return obj_fn(params) #+ w*tvr_loss

n_ff = 20
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,20,10,5]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)


Lambda_params, train_loss, _ = train(loss, None, get_params, opt_update, opt_state, key, nIter=50000, print_freq=1000)
# Out:
# it 1000, train loss = 1.514491e+01
# it 2000, train loss = 4.571609e+00
# it 3000, train loss = 2.114365e+00
# it 4000, train loss = 1.282226e+00
# it 5000, train loss = 8.908403e-01
# it 6000, train loss = 6.437275e-01
# it 7000, train loss = 4.360171e-01
# it 8000, train loss = 2.904464e-01
# it 9000, train loss = 2.260014e-01
# it 10000, train loss = 1.849748e-01
# it 11000, train loss = 1.398378e-01
# it 12000, train loss = 8.357243e-02
# it 13000, train loss = 5.781107e-02
# it 14000, train loss = 4.901742e-02
# it 15000, train loss = 4.333925e-02
# it 16000, train loss = 3.955809e-02
# it 17000, train loss = 3.675391e-02
# it 18000, train loss = 3.459000e-02
# it 19000, train loss = 3.288571e-02
# it 20000, train loss = 3.152461e-02
# it 21000, train loss = 3.047924e-02
# it 22000, train loss = 2.969719e-02
# it 23000, train loss = 2.906738e-02
# it 24000, train loss = 2.851963e-02
# it 25000, train loss = 2.800757e-02
# it 26000, train loss = 2.752354e-02
# it 27000, train loss = 2.708438e-02
# it 28000, train loss = 2.684643e-02
# it 29000, train loss = 2.639881e-02
# it 30000, train loss = 2.597533e-02
# it 31000, train loss = 2.568974e-02
# it 32000, train loss = 2.543659e-02
# it 33000, train loss = 2.529709e-02
# it 34000, train loss = 2.544567e-02
# it 35000, train loss = 2.480121e-02
# it 36000, train loss = 2.460651e-02
# it 37000, train loss = 2.446004e-02
# it 38000, train loss = 2.756140e-02
# it 39000, train loss = 2.409182e-02
# it 40000, train loss = 2.399476e-02
# it 41000, train loss = 2.379701e-02
# it 42000, train loss = 2.390651e-02
# it 43000, train loss = 2.352693e-02
# it 44000, train loss = 2.337433e-02
# it 45000, train loss = 2.325028e-02
# it 46000, train loss = 2.318687e-02
# it 47000, train loss = 2.301408e-02
# it 48000, train loss = 2.290224e-02
# it 49000, train loss = 2.280528e-02
# it 50000, train loss = 2.284717e-02

# %%
params_vfm = jnp.exp(ff_nn(elem_X, Lambda_params))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_vfm = GOH_P_vmap2(ugrad, params_vfm, 2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_vfm, title='Predicted stress at $\lambda_x$=1.2', ax=ax, extent=[0.5,0.7], extend='both');

# %%
print(obj_fn(ff_nn(elem_X, Lambda_params)))
# Out:
# 1.7828972794744535e-07

# %%
i_vf = 0
W_int_vec, W_ext_vec = get_vworks(params_vfm)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));
