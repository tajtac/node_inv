# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
from functools import partial
import jax.random as random
key = random.PRNGKey(2022)
from jax.flatten_util import ravel_pytree
import jax.example_libraries.optimizers as optimizers

import matplotlib.pyplot as plt

from fem import plotmesh
from utils import ff_nn, init_params_nn, train

# from jax.scipy.optimize import minimize
from scipy.optimize import minimize

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

from utils_hyperelasticity import ThreeDElasticity, neohook_model


E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

def VF1(x,y,h,w,p):
    U_x = x**p/w**p
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF2(x,y,h,w,p):
    U_x = 0.0
    U_y = y**p/h**p
    return jnp.stack([U_x,U_y]).T

def VF3(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    U_y = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    return jnp.stack([U_x,U_y]).T

def VF4(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    U_y = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    return jnp.stack([U_x,U_y]).T

def VF5(x,y,h,w,p):
    U_x = 1.0-(x/w-1)**(2*p)
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF6(x,y,h,w,p):
    U_x = 0.0
    U_y = 1.0-(y/h-1)**(2*p)
    return jnp.stack([U_x,U_y]).T

def VF_and_grad(VF, x, y, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x,y,h,w,p), VF_grad(x,y,h,w,p)

def VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x_node,y_node,h,w,p), VF_grad(x_elem,y_elem,h,w,p)
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %%
GOH_P = ThreeDElasticity(neohook_model).ugrad_2_P
GOH_P_vmap = vmap(GOH_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(neohook_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/V.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5]) + c*jnp.stack([0.2])

# %%
# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))

lmb_hist = [1.025, 1.050, 1.075, 1.100, 1.125, 1.150, 1.175, 1.200, 1.225, 1.250]
n_elem = Nx*Ny

# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0
F_hist_goh = []
P_hist_goh = []

# %%
# Equibiaxial
for lmb_max in lmb_hist:    
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 11:39:49][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:39:49][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:39:49][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:39:49][DEBUG] jax_fem: Done pre-computations, took 0.653918981552124 [s]
# [07-18 11:39:49][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:39:51][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:39:51][DEBUG] jax_fem: Start timing
# [07-18 11:39:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.7175 seconds
# [07-18 11:39:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:52][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:39:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:52][DEBUG] jax_fem: PETSc linear solve res = 3.507863728072818e-06
# [07-18 11:39:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [07-18 11:39:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:52][DEBUG] jax_fem: Before, res l_2 = 0.0013260867808880267
# [07-18 11:39:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:52][DEBUG] jax_fem: PETSc linear solve res = 5.715538486942553e-10
# [07-18 11:39:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [07-18 11:39:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:52][DEBUG] jax_fem: res l_2 = 4.905249843896482e-07
# [07-18 11:39:52][INFO] jax_fem: Solve took 1.5712981224060059 [s]
# [07-18 11:39:52][DEBUG] jax_fem: max of sol = 0.024999999999999908
# [07-18 11:39:52][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:39:53][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:39:53][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:39:53][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:39:53][DEBUG] jax_fem: Done pre-computations, took 0.27651095390319824 [s]
# [07-18 11:39:53][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:39:54][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:39:54][DEBUG] jax_fem: Start timing
# [07-18 11:39:54][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.4971 seconds
# [07-18 11:39:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:55][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:39:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:55][DEBUG] jax_fem: PETSc linear solve res = 7.015727456842216e-06
# [07-18 11:39:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [07-18 11:39:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:55][DEBUG] jax_fem: Before, res l_2 = 0.004673571279364937
# [07-18 11:39:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:55][DEBUG] jax_fem: PETSc linear solve res = 9.765813641742748e-09
# [07-18 11:39:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0203 seconds
# [07-18 11:39:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:55][DEBUG] jax_fem: res l_2 = 6.22170579900853e-06
# [07-18 11:39:55][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:55][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:55][DEBUG] jax_fem: PETSc linear solve res = 3.091023192245249e-13
# [07-18 11:39:55][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:55][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:39:55][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:55][DEBUG] jax_fem: res l_2 = 1.4057924252230156e-11
# [07-18 11:39:55][INFO] jax_fem: Solve took 0.6841814517974854 [s]
# [07-18 11:39:55][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 11:39:55][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:39:55][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:39:55][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:39:55][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:39:55][DEBUG] jax_fem: Done pre-computations, took 0.27458691596984863 [s]
# [07-18 11:39:55][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:39:56][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:39:56][DEBUG] jax_fem: Start timing
# [07-18 11:39:56][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:57][DEBUG] jax_fem: Function split_and_compute_cell took 0.5137 seconds
# [07-18 11:39:57][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:57][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:39:57][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:57][DEBUG] jax_fem: PETSc linear solve res = 1.0523591185845318e-05
# [07-18 11:39:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:57][DEBUG] jax_fem: Function split_and_compute_cell took 0.0212 seconds
# [07-18 11:39:57][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:57][DEBUG] jax_fem: Before, res l_2 = 0.00929880795360072
# [07-18 11:39:57][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:57][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:57][DEBUG] jax_fem: PETSc linear solve res = 2.855423172322399e-09
# [07-18 11:39:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:57][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-18 11:39:57][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:57][DEBUG] jax_fem: res l_2 = 2.4843877062951985e-05
# [07-18 11:39:57][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:57][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:57][DEBUG] jax_fem: PETSc linear solve res = 6.7997774367428604e-12
# [07-18 11:39:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:57][DEBUG] jax_fem: Function split_and_compute_cell took 0.0206 seconds
# [07-18 11:39:57][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:57][DEBUG] jax_fem: res l_2 = 2.2607465615865872e-10
# [07-18 11:39:57][INFO] jax_fem: Solve took 0.7033398151397705 [s]
# [07-18 11:39:57][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-18 11:39:57][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:39:57][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:39:57][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:39:57][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:39:57][DEBUG] jax_fem: Done pre-computations, took 0.2902231216430664 [s]
# [07-18 11:39:57][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:39:58][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:39:58][DEBUG] jax_fem: Start timing
# [07-18 11:39:58][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.4992 seconds
# [07-18 11:39:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:59][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:39:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:59][DEBUG] jax_fem: PETSc linear solve res = 1.4031454913684432e-05
# [07-18 11:39:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0187 seconds
# [07-18 11:39:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:59][DEBUG] jax_fem: Before, res l_2 = 0.01466849306461021
# [07-18 11:39:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:59][DEBUG] jax_fem: PETSc linear solve res = 8.475439991523795e-09
# [07-18 11:39:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0208 seconds
# [07-18 11:39:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:59][DEBUG] jax_fem: res l_2 = 6.162093339324987e-05
# [07-18 11:39:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:39:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:39:59][DEBUG] jax_fem: PETSc linear solve res = 3.2514675588563844e-11
# [07-18 11:39:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:39:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0229 seconds
# [07-18 11:39:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:39:59][DEBUG] jax_fem: res l_2 = 1.3860395360939825e-09
# [07-18 11:39:59][INFO] jax_fem: Solve took 0.7088057994842529 [s]
# [07-18 11:39:59][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 11:39:59][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:39:59][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:39:59][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:39:59][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:39:59][DEBUG] jax_fem: Done pre-computations, took 0.2710599899291992 [s]
# [07-18 11:39:59][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:01][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:01][DEBUG] jax_fem: Start timing
# [07-18 11:40:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.4967 seconds
# [07-18 11:40:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:01][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:01][DEBUG] jax_fem: PETSc linear solve res = 1.7539318638277275e-05
# [07-18 11:40:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0190 seconds
# [07-18 11:40:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:01][DEBUG] jax_fem: Before, res l_2 = 0.02040250414317841
# [07-18 11:40:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:01][DEBUG] jax_fem: PETSc linear solve res = 3.083645301244008e-08
# [07-18 11:40:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-18 11:40:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:01][DEBUG] jax_fem: res l_2 = 0.00011749794696173102
# [07-18 11:40:01][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:01][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:01][DEBUG] jax_fem: PETSc linear solve res = 8.785185598762344e-11
# [07-18 11:40:01][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:01][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:40:01][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:01][DEBUG] jax_fem: res l_2 = 4.9678942920025445e-09
# [07-18 11:40:01][INFO] jax_fem: Solve took 0.6823229789733887 [s]
# [07-18 11:40:01][DEBUG] jax_fem: max of sol = 0.125
# [07-18 11:40:01][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:40:01][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:40:01][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:40:01][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:40:01][DEBUG] jax_fem: Done pre-computations, took 0.2712078094482422 [s]
# [07-18 11:40:01][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:03][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:03][DEBUG] jax_fem: Start timing
# [07-18 11:40:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.5081 seconds
# [07-18 11:40:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:03][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:03][DEBUG] jax_fem: PETSc linear solve res = 2.1047182371690635e-05
# [07-18 11:40:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [07-18 11:40:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:03][DEBUG] jax_fem: Before, res l_2 = 0.026232485848436276
# [07-18 11:40:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:03][DEBUG] jax_fem: PETSc linear solve res = 2.9276442717777134e-08
# [07-18 11:40:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 11:40:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:03][DEBUG] jax_fem: res l_2 = 0.00018944450356836722
# [07-18 11:40:03][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:03][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:03][DEBUG] jax_fem: PETSc linear solve res = 2.6813819719380447e-10
# [07-18 11:40:03][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:03][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-18 11:40:03][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:03][DEBUG] jax_fem: res l_2 = 1.2577329248184792e-08
# [07-18 11:40:03][INFO] jax_fem: Solve took 0.7025270462036133 [s]
# [07-18 11:40:03][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 11:40:03][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:40:03][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:40:03][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:40:03][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:40:04][DEBUG] jax_fem: Done pre-computations, took 0.28267598152160645 [s]
# [07-18 11:40:04][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:05][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:05][DEBUG] jax_fem: Start timing
# [07-18 11:40:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.4938 seconds
# [07-18 11:40:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:05][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:05][DEBUG] jax_fem: PETSc linear solve res = 2.45550460944068e-05
# [07-18 11:40:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-18 11:40:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:05][DEBUG] jax_fem: Before, res l_2 = 0.03197170685347258
# [07-18 11:40:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:05][DEBUG] jax_fem: PETSc linear solve res = 2.1697345196578205e-08
# [07-18 11:40:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0231 seconds
# [07-18 11:40:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:05][DEBUG] jax_fem: res l_2 = 0.0002718024338716387
# [07-18 11:40:05][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:05][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:05][DEBUG] jax_fem: PETSc linear solve res = 4.748251671584335e-10
# [07-18 11:40:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:05][DEBUG] jax_fem: Function split_and_compute_cell took 0.0220 seconds
# [07-18 11:40:05][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:05][DEBUG] jax_fem: res l_2 = 2.493855419287379e-08
# [07-18 11:40:05][INFO] jax_fem: Solve took 0.6953871250152588 [s]
# [07-18 11:40:05][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-18 11:40:05][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:40:05][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:40:05][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:40:05][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:40:06][DEBUG] jax_fem: Done pre-computations, took 0.26987504959106445 [s]
# [07-18 11:40:06][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:07][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:07][DEBUG] jax_fem: Start timing
# [07-18 11:40:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.4937 seconds
# [07-18 11:40:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:07][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:07][DEBUG] jax_fem: PETSc linear solve res = 2.8062909819009353e-05
# [07-18 11:40:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0214 seconds
# [07-18 11:40:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:07][DEBUG] jax_fem: Before, res l_2 = 0.03749303164465157
# [07-18 11:40:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:07][DEBUG] jax_fem: PETSc linear solve res = 8.568667691445666e-08
# [07-18 11:40:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-18 11:40:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:07][DEBUG] jax_fem: res l_2 = 0.0003578323530837447
# [07-18 11:40:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:07][DEBUG] jax_fem: PETSc linear solve res = 6.548382402349061e-10
# [07-18 11:40:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0221 seconds
# [07-18 11:40:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:07][DEBUG] jax_fem: res l_2 = 4.122828904508541e-08
# [07-18 11:40:07][INFO] jax_fem: Solve took 0.6869950294494629 [s]
# [07-18 11:40:07][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 11:40:07][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:40:07][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:40:07][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:40:07][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:40:08][DEBUG] jax_fem: Done pre-computations, took 0.2671668529510498 [s]
# [07-18 11:40:08][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:09][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:09][DEBUG] jax_fem: Start timing
# [07-18 11:40:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.4983 seconds
# [07-18 11:40:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:09][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:09][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:09][DEBUG] jax_fem: PETSc linear solve res = 3.1570773558107446e-05
# [07-18 11:40:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.0187 seconds
# [07-18 11:40:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:09][DEBUG] jax_fem: Before, res l_2 = 0.042712767671464466
# [07-18 11:40:09][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:09][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:09][DEBUG] jax_fem: PETSc linear solve res = 1.2462925233587812e-07
# [07-18 11:40:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-18 11:40:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:09][DEBUG] jax_fem: res l_2 = 0.00044101829486655527
# [07-18 11:40:09][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:09][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:09][DEBUG] jax_fem: PETSc linear solve res = 1.8487025884097027e-10
# [07-18 11:40:09][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:09][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 11:40:09][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:09][DEBUG] jax_fem: res l_2 = 5.91782597507266e-08
# [07-18 11:40:09][INFO] jax_fem: Solve took 0.6796970367431641 [s]
# [07-18 11:40:09][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-18 11:40:09][DEBUG] jax_fem: min of sol = 0.0
# [07-18 11:40:09][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:40:09][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:40:09][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:40:09][DEBUG] jax_fem: Done pre-computations, took 0.27642107009887695 [s]
# [07-18 11:40:09][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:40:10][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:40:10][DEBUG] jax_fem: Start timing
# [07-18 11:40:10][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.5146 seconds
# [07-18 11:40:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:11][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:40:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:11][DEBUG] jax_fem: PETSc linear solve res = 3.507863727655455e-05
# [07-18 11:40:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0196 seconds
# [07-18 11:40:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:11][DEBUG] jax_fem: Before, res l_2 = 0.04757878811808693
# [07-18 11:40:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:11][DEBUG] jax_fem: PETSc linear solve res = 6.619060183990192e-08
# [07-18 11:40:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-18 11:40:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:11][DEBUG] jax_fem: res l_2 = 0.0005159352534659892
# [07-18 11:40:11][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:40:11][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:40:11][DEBUG] jax_fem: PETSc linear solve res = 1.9373642908233574e-10
# [07-18 11:40:11][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:40:11][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-18 11:40:11][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:40:11][DEBUG] jax_fem: res l_2 = 7.594403770795306e-08
# [07-18 11:40:11][INFO] jax_fem: Solve took 0.6964120864868164 [s]
# [07-18 11:40:11][DEBUG] jax_fem: max of sol = 0.25
# [07-18 11:40:11][DEBUG] jax_fem: min of sol = 0.0

# %%
# Uniaxial in x
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           right,                                  ],
        [1,                 0,              0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 11:41:15][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:15][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:15][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:15][DEBUG] jax_fem: Done pre-computations, took 0.2832021713256836 [s]
# [07-18 11:41:15][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:15][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:15][DEBUG] jax_fem: Start timing
# [07-18 11:41:15][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.5081 seconds
# [07-18 11:41:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:16][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:16][DEBUG] jax_fem: PETSc linear solve res = 7.200746540609803e-07
# [07-18 11:41:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0229 seconds
# [07-18 11:41:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:16][DEBUG] jax_fem: Before, res l_2 = 0.0006099048558066327
# [07-18 11:41:16][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:16][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:16][DEBUG] jax_fem: PETSc linear solve res = 1.4878227217260666e-10
# [07-18 11:41:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:16][DEBUG] jax_fem: Function split_and_compute_cell took 0.0250 seconds
# [07-18 11:41:16][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:16][DEBUG] jax_fem: res l_2 = 2.426141106375345e-07
# [07-18 11:41:16][INFO] jax_fem: Solve took 0.6500380039215088 [s]
# [07-18 11:41:16][DEBUG] jax_fem: max of sol = 0.02499999999999991
# [07-18 11:41:16][DEBUG] jax_fem: min of sol = -0.012382490319401591
# [07-18 11:41:16][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:16][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:16][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:16][DEBUG] jax_fem: Done pre-computations, took 0.36066699028015137 [s]
# [07-18 11:41:16][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:16][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:16][DEBUG] jax_fem: Start timing
# [07-18 11:41:16][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.5177 seconds
# [07-18 11:41:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:17][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:17][DEBUG] jax_fem: PETSc linear solve res = 1.4401491828710106e-06
# [07-18 11:41:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-18 11:41:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:17][DEBUG] jax_fem: Before, res l_2 = 0.0023579286269412463
# [07-18 11:41:17][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:17][DEBUG] jax_fem: PETSc linear solve res = 2.55225786998435e-09
# [07-18 11:41:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:41:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:17][DEBUG] jax_fem: res l_2 = 3.6545710539855055e-06
# [07-18 11:41:17][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:17][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:17][DEBUG] jax_fem: PETSc linear solve res = 1.1971473470881805e-11
# [07-18 11:41:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:17][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-18 11:41:17][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:17][DEBUG] jax_fem: res l_2 = 1.535747037105808e-11
# [07-18 11:41:17][INFO] jax_fem: Solve took 0.7013781070709229 [s]
# [07-18 11:41:17][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 11:41:17][DEBUG] jax_fem: min of sol = -0.024316330445508776
# [07-18 11:41:17][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:17][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:17][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:17][DEBUG] jax_fem: Done pre-computations, took 0.3168790340423584 [s]
# [07-18 11:41:17][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:17][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:17][DEBUG] jax_fem: Start timing
# [07-18 11:41:17][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.5078 seconds
# [07-18 11:41:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:18][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:18][DEBUG] jax_fem: PETSc linear solve res = 2.16022408752987e-06
# [07-18 11:41:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0190 seconds
# [07-18 11:41:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:18][DEBUG] jax_fem: Before, res l_2 = 0.005141196883212764
# [07-18 11:41:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:18][DEBUG] jax_fem: PETSc linear solve res = 5.648823681584915e-09
# [07-18 11:41:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-18 11:41:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:18][DEBUG] jax_fem: res l_2 = 1.747634811068253e-05
# [07-18 11:41:18][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:18][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:18][DEBUG] jax_fem: PETSc linear solve res = 1.536399278058881e-11
# [07-18 11:41:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:18][DEBUG] jax_fem: Function split_and_compute_cell took 0.0204 seconds
# [07-18 11:41:18][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:18][DEBUG] jax_fem: res l_2 = 2.232584642584618e-10
# [07-18 11:41:18][INFO] jax_fem: Solve took 0.6971089839935303 [s]
# [07-18 11:41:18][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-18 11:41:18][DEBUG] jax_fem: min of sol = -0.03582815018627791
# [07-18 11:41:18][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:18][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:18][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:18][DEBUG] jax_fem: Done pre-computations, took 0.2762618064880371 [s]
# [07-18 11:41:18][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:18][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:18][DEBUG] jax_fem: Start timing
# [07-18 11:41:18][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:19][DEBUG] jax_fem: Function split_and_compute_cell took 0.5500 seconds
# [07-18 11:41:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:19][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:19][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:19][DEBUG] jax_fem: PETSc linear solve res = 2.8802983657420213e-06
# [07-18 11:41:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:19][DEBUG] jax_fem: Function split_and_compute_cell took 0.0197 seconds
# [07-18 11:41:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:19][DEBUG] jax_fem: Before, res l_2 = 0.008878882633452795
# [07-18 11:41:19][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:19][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:19][DEBUG] jax_fem: PETSc linear solve res = 1.863912146534867e-08
# [07-18 11:41:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:19][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-18 11:41:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:19][DEBUG] jax_fem: res l_2 = 5.236634507629092e-05
# [07-18 11:41:19][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:19][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:19][DEBUG] jax_fem: PETSc linear solve res = 6.070633591362223e-11
# [07-18 11:41:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:19][DEBUG] jax_fem: Function split_and_compute_cell took 0.0213 seconds
# [07-18 11:41:19][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:19][DEBUG] jax_fem: res l_2 = 2.014858632647127e-09
# [07-18 11:41:19][INFO] jax_fem: Solve took 0.7443089485168457 [s]
# [07-18 11:41:19][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 11:41:19][DEBUG] jax_fem: min of sol = -0.046942104148425534
# [07-18 11:41:19][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:19][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:19][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:19][DEBUG] jax_fem: Done pre-computations, took 0.26716113090515137 [s]
# [07-18 11:41:19][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:19][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:19][DEBUG] jax_fem: Start timing
# [07-18 11:41:19][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.5379 seconds
# [07-18 11:41:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:20][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:20][DEBUG] jax_fem: PETSc linear solve res = 3.6003725507166627e-06
# [07-18 11:41:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 11:41:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:20][DEBUG] jax_fem: Before, res l_2 = 0.013507838505432718
# [07-18 11:41:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:20][DEBUG] jax_fem: PETSc linear solve res = 5.1218187412648716e-08
# [07-18 11:41:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [07-18 11:41:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:20][DEBUG] jax_fem: res l_2 = 0.00012164452892857495
# [07-18 11:41:20][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:20][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:20][DEBUG] jax_fem: PETSc linear solve res = 2.8935826962858724e-10
# [07-18 11:41:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:20][DEBUG] jax_fem: Function split_and_compute_cell took 0.0239 seconds
# [07-18 11:41:20][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:20][DEBUG] jax_fem: res l_2 = 1.0936439160469094e-08
# [07-18 11:41:20][INFO] jax_fem: Solve took 0.7504148483276367 [s]
# [07-18 11:41:20][DEBUG] jax_fem: max of sol = 0.125
# [07-18 11:41:20][DEBUG] jax_fem: min of sol = -0.05768050452393814
# [07-18 11:41:20][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:20][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:20][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:20][DEBUG] jax_fem: Done pre-computations, took 0.3556230068206787 [s]
# [07-18 11:41:20][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:20][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:20][DEBUG] jax_fem: Start timing
# [07-18 11:41:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.5596 seconds
# [07-18 11:41:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:21][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:21][DEBUG] jax_fem: PETSc linear solve res = 4.32044817505974e-06
# [07-18 11:41:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0216 seconds
# [07-18 11:41:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:21][DEBUG] jax_fem: Before, res l_2 = 0.018979263259279323
# [07-18 11:41:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:21][DEBUG] jax_fem: PETSc linear solve res = 1.1615628368072945e-08
# [07-18 11:41:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0210 seconds
# [07-18 11:41:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:21][DEBUG] jax_fem: res l_2 = 0.0002408162066513738
# [07-18 11:41:21][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:21][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:21][DEBUG] jax_fem: PETSc linear solve res = 1.1941944447961212e-10
# [07-18 11:41:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:21][DEBUG] jax_fem: Function split_and_compute_cell took 0.0239 seconds
# [07-18 11:41:21][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:21][DEBUG] jax_fem: res l_2 = 4.311573376332812e-08
# [07-18 11:41:21][INFO] jax_fem: Solve took 0.7688288688659668 [s]
# [07-18 11:41:21][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 11:41:21][DEBUG] jax_fem: min of sol = -0.0680639398450818
# [07-18 11:41:21][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:21][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:21][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:21][DEBUG] jax_fem: Done pre-computations, took 0.32627081871032715 [s]
# [07-18 11:41:21][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:21][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:21][DEBUG] jax_fem: Start timing
# [07-18 11:41:21][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.5257 seconds
# [07-18 11:41:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:22][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:22][DEBUG] jax_fem: PETSc linear solve res = 5.040523918274109e-06
# [07-18 11:41:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0214 seconds
# [07-18 11:41:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:22][DEBUG] jax_fem: Before, res l_2 = 0.02525615688784638
# [07-18 11:41:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:22][DEBUG] jax_fem: PETSc linear solve res = 7.142711646531304e-08
# [07-18 11:41:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0214 seconds
# [07-18 11:41:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:22][DEBUG] jax_fem: res l_2 = 0.0004272806724952042
# [07-18 11:41:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:22][DEBUG] jax_fem: PETSc linear solve res = 2.6590359747768725e-10
# [07-18 11:41:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0213 seconds
# [07-18 11:41:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:22][DEBUG] jax_fem: res l_2 = 1.3659849739370104e-07
# [07-18 11:41:22][INFO] jax_fem: Solve took 0.7237718105316162 [s]
# [07-18 11:41:22][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-18 11:41:22][DEBUG] jax_fem: min of sol = -0.07811145446419732
# [07-18 11:41:22][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:22][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:22][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:22][DEBUG] jax_fem: Done pre-computations, took 0.299058198928833 [s]
# [07-18 11:41:22][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:22][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:22][DEBUG] jax_fem: Start timing
# [07-18 11:41:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:23][DEBUG] jax_fem: Function split_and_compute_cell took 0.5611 seconds
# [07-18 11:41:23][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:23][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:23][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:23][DEBUG] jax_fem: PETSc linear solve res = 5.760597435136153e-06
# [07-18 11:41:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:23][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [07-18 11:41:23][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:23][DEBUG] jax_fem: Before, res l_2 = 0.03231138017430017
# [07-18 11:41:23][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:23][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:23][DEBUG] jax_fem: PETSc linear solve res = 2.4822299094387172e-08
# [07-18 11:41:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:23][DEBUG] jax_fem: Function split_and_compute_cell took 0.0221 seconds
# [07-18 11:41:23][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:23][DEBUG] jax_fem: res l_2 = 0.000700158606916084
# [07-18 11:41:23][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:23][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:23][DEBUG] jax_fem: PETSc linear solve res = 1.308551611866667e-09
# [07-18 11:41:23][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:23][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [07-18 11:41:23][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:23][DEBUG] jax_fem: res l_2 = 3.6925361840821244e-07
# [07-18 11:41:23][INFO] jax_fem: Solve took 0.7703258991241455 [s]
# [07-18 11:41:23][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 11:41:23][DEBUG] jax_fem: min of sol = -0.08784070585563272
# [07-18 11:41:23][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:23][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:23][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:24][DEBUG] jax_fem: Done pre-computations, took 0.4814581871032715 [s]
# [07-18 11:41:24][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:24][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:24][DEBUG] jax_fem: Start timing
# [07-18 11:41:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.5201 seconds
# [07-18 11:41:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:24][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:24][DEBUG] jax_fem: PETSc linear solve res = 6.480675925259629e-06
# [07-18 11:41:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 11:41:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:24][DEBUG] jax_fem: Before, res l_2 = 0.04012618064563478
# [07-18 11:41:24][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:24][DEBUG] jax_fem: PETSc linear solve res = 5.2706184569288833e-08
# [07-18 11:41:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:41:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:24][DEBUG] jax_fem: res l_2 = 0.0010801761809278935
# [07-18 11:41:24][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:24][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:24][DEBUG] jax_fem: PETSc linear solve res = 2.803211736659595e-09
# [07-18 11:41:24][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:24][DEBUG] jax_fem: Function split_and_compute_cell took 0.0199 seconds
# [07-18 11:41:24][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:24][DEBUG] jax_fem: res l_2 = 8.849566749163927e-07
# [07-18 11:41:24][INFO] jax_fem: Solve took 0.7038838863372803 [s]
# [07-18 11:41:24][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-18 11:41:24][DEBUG] jax_fem: min of sol = -0.09726810756839636
# [07-18 11:41:24][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:24][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:24][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:25][DEBUG] jax_fem: Done pre-computations, took 0.2788207530975342 [s]
# [07-18 11:41:25][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:25][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:25][DEBUG] jax_fem: Start timing
# [07-18 11:41:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.5075 seconds
# [07-18 11:41:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:25][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:25][DEBUG] jax_fem: PETSc linear solve res = 7.2007451014333255e-06
# [07-18 11:41:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0192 seconds
# [07-18 11:41:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:25][DEBUG] jax_fem: Before, res l_2 = 0.048689081261889616
# [07-18 11:41:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:25][DEBUG] jax_fem: PETSc linear solve res = 1.4324897214877278e-07
# [07-18 11:41:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:41:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:25][DEBUG] jax_fem: res l_2 = 0.0015895969457920937
# [07-18 11:41:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:25][DEBUG] jax_fem: PETSc linear solve res = 1.2152808217313565e-08
# [07-18 11:41:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 11:41:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:25][DEBUG] jax_fem: res l_2 = 1.930170686426437e-06
# [07-18 11:41:25][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:25][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:25][DEBUG] jax_fem: PETSc linear solve res = 2.91282753785985e-12
# [07-18 11:41:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:25][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [07-18 11:41:25][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:26][DEBUG] jax_fem: res l_2 = 4.412986834801022e-12
# [07-18 11:41:26][INFO] jax_fem: Solve took 0.7500021457672119 [s]
# [07-18 11:41:26][DEBUG] jax_fem: max of sol = 0.25
# [07-18 11:41:26][DEBUG] jax_fem: min of sol = -0.10640823676199045

# %%
# Uniaxial in y
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                     ],
        [1,                 0,              1,                                       ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 11:41:28][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:28][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:28][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:29][DEBUG] jax_fem: Done pre-computations, took 0.28734421730041504 [s]
# [07-18 11:41:29][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:29][DEBUG] jax_fem: Start timing
# [07-18 11:41:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.4972 seconds
# [07-18 11:41:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:29][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:29][DEBUG] jax_fem: PETSc linear solve res = 8.74558462285668e-07
# [07-18 11:41:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0189 seconds
# [07-18 11:41:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:29][DEBUG] jax_fem: Before, res l_2 = 0.0005501864328978225
# [07-18 11:41:29][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:29][DEBUG] jax_fem: PETSc linear solve res = 4.988802001009034e-10
# [07-18 11:41:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.0175 seconds
# [07-18 11:41:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:29][DEBUG] jax_fem: res l_2 = 1.9726090266663756e-07
# [07-18 11:41:29][INFO] jax_fem: Solve took 0.6212649345397949 [s]
# [07-18 11:41:29][DEBUG] jax_fem: max of sol = 0.02499999999999991
# [07-18 11:41:29][DEBUG] jax_fem: min of sol = -0.012340086164813099
# [07-18 11:41:29][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:29][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:29][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:29][DEBUG] jax_fem: Done pre-computations, took 0.28879690170288086 [s]
# [07-18 11:41:29][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:29][DEBUG] jax_fem: Start timing
# [07-18 11:41:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.4998 seconds
# [07-18 11:41:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:30][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:30][DEBUG] jax_fem: PETSc linear solve res = 1.7491169252417e-06
# [07-18 11:41:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0206 seconds
# [07-18 11:41:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:30][DEBUG] jax_fem: Before, res l_2 = 0.0021508045108581597
# [07-18 11:41:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:30][DEBUG] jax_fem: PETSc linear solve res = 3.5721757814341006e-09
# [07-18 11:41:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0174 seconds
# [07-18 11:41:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:30][DEBUG] jax_fem: res l_2 = 3.0473542587900354e-06
# [07-18 11:41:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:30][DEBUG] jax_fem: PETSc linear solve res = 7.625715263390177e-12
# [07-18 11:41:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0177 seconds
# [07-18 11:41:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:30][DEBUG] jax_fem: res l_2 = 1.0409691879647658e-11
# [07-18 11:41:30][INFO] jax_fem: Solve took 0.676429033279419 [s]
# [07-18 11:41:30][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 11:41:30][DEBUG] jax_fem: min of sol = -0.024234357952173366
# [07-18 11:41:30][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:30][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:30][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:30][DEBUG] jax_fem: Done pre-computations, took 0.2561819553375244 [s]
# [07-18 11:41:30][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:30][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:30][DEBUG] jax_fem: Start timing
# [07-18 11:41:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.4987 seconds
# [07-18 11:41:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:31][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:31][DEBUG] jax_fem: PETSc linear solve res = 2.6236753882737734e-06
# [07-18 11:41:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-18 11:41:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:31][DEBUG] jax_fem: Before, res l_2 = 0.00473696209678069
# [07-18 11:41:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:31][DEBUG] jax_fem: PETSc linear solve res = 2.7725108346944536e-08
# [07-18 11:41:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-18 11:41:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:31][DEBUG] jax_fem: res l_2 = 1.4923085832362687e-05
# [07-18 11:41:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:31][DEBUG] jax_fem: PETSc linear solve res = 1.3039182724988043e-11
# [07-18 11:41:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0177 seconds
# [07-18 11:41:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:31][DEBUG] jax_fem: res l_2 = 1.7418614809428137e-10
# [07-18 11:41:31][INFO] jax_fem: Solve took 0.6703929901123047 [s]
# [07-18 11:41:31][DEBUG] jax_fem: max of sol = 0.07499999999999996
# [07-18 11:41:31][DEBUG] jax_fem: min of sol = -0.0357093496041776
# [07-18 11:41:31][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:31][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:31][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:31][DEBUG] jax_fem: Done pre-computations, took 0.26941490173339844 [s]
# [07-18 11:41:31][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:31][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:31][DEBUG] jax_fem: Start timing
# [07-18 11:41:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.4978 seconds
# [07-18 11:41:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:32][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:32][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:32][DEBUG] jax_fem: PETSc linear solve res = 3.4982338504834e-06
# [07-18 11:41:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:41:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:32][DEBUG] jax_fem: Before, res l_2 = 0.008255272143805911
# [07-18 11:41:32][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:32][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:32][DEBUG] jax_fem: PETSc linear solve res = 3.163373552725581e-08
# [07-18 11:41:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-18 11:41:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:32][DEBUG] jax_fem: res l_2 = 4.5693662115761454e-05
# [07-18 11:41:32][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:32][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:32][DEBUG] jax_fem: PETSc linear solve res = 2.6606829177504284e-11
# [07-18 11:41:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:32][DEBUG] jax_fem: Function split_and_compute_cell took 0.0184 seconds
# [07-18 11:41:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:32][DEBUG] jax_fem: res l_2 = 1.6475955589802224e-09
# [07-18 11:41:32][INFO] jax_fem: Solve took 0.6710789203643799 [s]
# [07-18 11:41:32][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 11:41:32][DEBUG] jax_fem: min of sol = -0.04678917724845612
# [07-18 11:41:32][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:32][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:32][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:32][DEBUG] jax_fem: Done pre-computations, took 0.2797400951385498 [s]
# [07-18 11:41:32][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:32][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:32][DEBUG] jax_fem: Start timing
# [07-18 11:41:32][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.5634 seconds
# [07-18 11:41:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:33][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:33][DEBUG] jax_fem: PETSc linear solve res = 4.372792311611104e-06
# [07-18 11:41:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0187 seconds
# [07-18 11:41:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:33][DEBUG] jax_fem: Before, res l_2 = 0.012662145244858437
# [07-18 11:41:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:33][DEBUG] jax_fem: PETSc linear solve res = 7.680566293532437e-09
# [07-18 11:41:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-18 11:41:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:33][DEBUG] jax_fem: res l_2 = 0.00010822843124209189
# [07-18 11:41:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:33][DEBUG] jax_fem: PETSc linear solve res = 3.568752178199331e-10
# [07-18 11:41:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0182 seconds
# [07-18 11:41:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:33][DEBUG] jax_fem: res l_2 = 9.349444312706686e-09
# [07-18 11:41:33][INFO] jax_fem: Solve took 0.7504069805145264 [s]
# [07-18 11:41:33][DEBUG] jax_fem: max of sol = 0.125
# [07-18 11:41:33][DEBUG] jax_fem: min of sol = -0.057495979519563735
# [07-18 11:41:33][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:33][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:33][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:33][DEBUG] jax_fem: Done pre-computations, took 0.3294789791107178 [s]
# [07-18 11:41:33][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:33][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:33][DEBUG] jax_fem: Start timing
# [07-18 11:41:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.5176 seconds
# [07-18 11:41:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:34][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:34][DEBUG] jax_fem: PETSc linear solve res = 5.247350776547547e-06
# [07-18 11:41:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0245 seconds
# [07-18 11:41:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:34][DEBUG] jax_fem: Before, res l_2 = 0.017922460771966648
# [07-18 11:41:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:34][DEBUG] jax_fem: PETSc linear solve res = 8.937294154099843e-08
# [07-18 11:41:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0203 seconds
# [07-18 11:41:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:34][DEBUG] jax_fem: res l_2 = 0.0002180045289884948
# [07-18 11:41:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:34][DEBUG] jax_fem: PETSc linear solve res = 9.257675031319494e-10
# [07-18 11:41:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 11:41:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:34][DEBUG] jax_fem: res l_2 = 3.830515982506421e-08
# [07-18 11:41:34][INFO] jax_fem: Solve took 0.7115020751953125 [s]
# [07-18 11:41:34][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 11:41:34][DEBUG] jax_fem: min of sol = -0.06785023658180024
# [07-18 11:41:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:35][DEBUG] jax_fem: Done pre-computations, took 0.2684192657470703 [s]
# [07-18 11:41:35][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:35][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:35][DEBUG] jax_fem: Start timing
# [07-18 11:41:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.5093 seconds
# [07-18 11:41:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:35][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:35][DEBUG] jax_fem: PETSc linear solve res = 6.121909235223349e-06
# [07-18 11:41:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0231 seconds
# [07-18 11:41:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:35][DEBUG] jax_fem: Before, res l_2 = 0.024008532566252457
# [07-18 11:41:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:35][DEBUG] jax_fem: PETSc linear solve res = 3.005588593125691e-08
# [07-18 11:41:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-18 11:41:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:35][DEBUG] jax_fem: res l_2 = 0.000392788085547862
# [07-18 11:41:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:35][DEBUG] jax_fem: PETSc linear solve res = 1.2579482373125413e-09
# [07-18 11:41:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0189 seconds
# [07-18 11:41:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:35][DEBUG] jax_fem: res l_2 = 1.2551796825606168e-07
# [07-18 11:41:35][INFO] jax_fem: Solve took 0.6977331638336182 [s]
# [07-18 11:41:35][DEBUG] jax_fem: max of sol = 0.17500000000000004
# [07-18 11:41:35][DEBUG] jax_fem: min of sol = -0.07787088828634409
# [07-18 11:41:35][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:35][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:35][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:36][DEBUG] jax_fem: Done pre-computations, took 0.2854130268096924 [s]
# [07-18 11:41:36][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:36][DEBUG] jax_fem: Start timing
# [07-18 11:41:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.5108 seconds
# [07-18 11:41:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:36][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:36][DEBUG] jax_fem: PETSc linear solve res = 6.996467694483831e-06
# [07-18 11:41:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-18 11:41:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:36][DEBUG] jax_fem: Before, res l_2 = 0.030899306416034892
# [07-18 11:41:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:36][DEBUG] jax_fem: PETSc linear solve res = 4.6175036379783514e-08
# [07-18 11:41:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-18 11:41:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:36][DEBUG] jax_fem: res l_2 = 0.0006523907006160565
# [07-18 11:41:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:36][DEBUG] jax_fem: PETSc linear solve res = 7.514548019634874e-10
# [07-18 11:41:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0176 seconds
# [07-18 11:41:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:36][DEBUG] jax_fem: res l_2 = 3.496723838992882e-07
# [07-18 11:41:36][INFO] jax_fem: Solve took 0.6849179267883301 [s]
# [07-18 11:41:36][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 11:41:36][DEBUG] jax_fem: min of sol = -0.08757549218960498
# [07-18 11:41:36][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:36][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:36][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:36][DEBUG] jax_fem: Done pre-computations, took 0.27196526527404785 [s]
# [07-18 11:41:36][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:36][DEBUG] jax_fem: Start timing
# [07-18 11:41:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.5053 seconds
# [07-18 11:41:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:37][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:37][DEBUG] jax_fem: PETSc linear solve res = 7.871026164604683e-06
# [07-18 11:41:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 11:41:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:37][DEBUG] jax_fem: Before, res l_2 = 0.0385797426647908
# [07-18 11:41:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:37][DEBUG] jax_fem: PETSc linear solve res = 4.3452148291570874e-08
# [07-18 11:41:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-18 11:41:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:37][DEBUG] jax_fem: res l_2 = 0.001018459810924624
# [07-18 11:41:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:37][DEBUG] jax_fem: PETSc linear solve res = 5.05048058474859e-10
# [07-18 11:41:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0175 seconds
# [07-18 11:41:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:37][DEBUG] jax_fem: res l_2 = 8.602763867993537e-07
# [07-18 11:41:37][INFO] jax_fem: Solve took 0.6785140037536621 [s]
# [07-18 11:41:37][DEBUG] jax_fem: max of sol = 0.2250000000000001
# [07-18 11:41:37][DEBUG] jax_fem: min of sol = -0.09698036309989744
# [07-18 11:41:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 11:41:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 11:41:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 11:41:38][DEBUG] jax_fem: Done pre-computations, took 0.328902006149292 [s]
# [07-18 11:41:38][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 11:41:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 11:41:38][DEBUG] jax_fem: Start timing
# [07-18 11:41:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.5197 seconds
# [07-18 11:41:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:38][DEBUG] jax_fem: Linear guess solve...
# [07-18 11:41:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:38][DEBUG] jax_fem: PETSc linear solve res = 8.745584623222208e-06
# [07-18 11:41:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0222 seconds
# [07-18 11:41:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:38][DEBUG] jax_fem: Before, res l_2 = 0.04704034921620754
# [07-18 11:41:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:38][DEBUG] jax_fem: PETSc linear solve res = 4.490902491868713e-08
# [07-18 11:41:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0186 seconds
# [07-18 11:41:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:38][DEBUG] jax_fem: res l_2 = 0.0015143225151007902
# [07-18 11:41:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:38][DEBUG] jax_fem: PETSc linear solve res = 1.097906914235305e-09
# [07-18 11:41:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0178 seconds
# [07-18 11:41:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:38][DEBUG] jax_fem: res l_2 = 1.9192030226811982e-06
# [07-18 11:41:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 11:41:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 11:41:38][DEBUG] jax_fem: PETSc linear solve res = 1.3583842065648148e-12
# [07-18 11:41:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 11:41:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 11:41:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 11:41:38][DEBUG] jax_fem: res l_2 = 4.4110602409729914e-12
# [07-18 11:41:38][INFO] jax_fem: Solve took 0.7553820610046387 [s]
# [07-18 11:41:38][DEBUG] jax_fem: max of sol = 0.25
# [07-18 11:41:38][DEBUG] jax_fem: min of sol = -0.1060999949063201

# %%
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)

F_mean = F_hist_goh[-1].mean(axis=0)
params_gt = params_vec[:,0,:]

# %%
GOH_P_vmap2 = vmap(GOH_P, in_axes=(None,0,None))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_gt = GOH_P_vmap2(ugrad, params_gt,2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_gt, title='Ground Truth stress at $\lambda_x$=1.2', ax=ax); 
print(P_gt.min(), P_gt.max())



fig, axes = plt.subplots(1,12,figsize=(60,4))
t_hist = np.arange(len(lmb_hist)*3)
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
# Out:
# 2.0114471931540416 2.4567871496118783

# %%
h = 1.0
w = 1.0
# VF_list = [VF1, VF1, VF2, VF2, VF3, VF4, VF4, VF4, VF4, VF4, VF5, VF6]
# p_list =  [1.0, 2.0, 1.0, 2.0, 1.0, 2.0, 3.0, 4.0, 4.0, 5.0, 1.0, 1.0]
VF_list = [VF1, VF1, VF1, VF1, VF1, VF2, VF2, VF2, VF2, VF2, VF3, VF3, VF3, VF3, VF4, VF4, VF4, VF4, VF4, VF5, VF6]
p_list =  [1.0, 2.0, 3.0, 0.5, 0.3, 1.0, 2.0, 3.0, 0.5, 0.3, 1.0, 2.0, 3.0, 4.0, 2.0, 3.0, 4.0, 4.0, 5.0, 1.0, 1.0]

x_elem, y_elem = elem_X.T
x_node, y_node = mesh.points.T
U, gradU = [], []
fig, axes = plt.subplots(2,len(VF_list),figsize=(len(VF_list)*5,8))
for ax, VF, p in zip(axes.T, VF_list, p_list):
    Ui, gradUi = VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p)
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,0].mean(axis=1), title='Virtual Field i', ax=ax[0]); 
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,1].mean(axis=1), title=None, ax=ax[1]); 
    U.append(Ui)
    gradU.append(gradUi)
U, gradU = np.array(U), np.array(gradU)

# %%
dL = Lx/Nx
dA = dL*dL
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0]*dL, axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0]*dL, axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1]*dL, axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1]*dL, axis=1)
Fx = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Fy = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

rgt_bd_nodes = np.where(np.isclose(mesh.points[:,0], 1.0))[0]
top_bd_nodes = np.where(np.isclose(mesh.points[:,1], 1.0))[0]
lft_bd_nodes = np.where(np.isclose(mesh.points[:,0], 0.0))[0]
bot_bd_nodes = np.where(np.isclose(mesh.points[:,1], 0.0))[0]

# %%
def eval_W_int(P, gradU):
    return jnp.einsum('ijk,ijk', P, gradU)*dA
def eval_W_ext(U, Fx, Fy):
    W_rgt = jnp.sum(U[rgt_bd_nodes, 0]*Fx*dL)
    W_top = jnp.sum(U[top_bd_nodes, 1]*Fy*dL)
    W_lft = jnp.sum(U[lft_bd_nodes, 0]*Fx*dL)
    W_bot = jnp.sum(U[bot_bd_nodes, 1]*Fy*dL)
    return W_rgt + W_top# + W_lft + W_bot

def get_vworks(params):
    W_int_vec = []
    W_ext_vec = []
    for step in range(len(F_hist_goh)):
        F = F_hist_goh[step]
        u_grad = jnp.array(F - np.eye(2))
        P = GOH_P_vmap(u_grad, params, 2)
        W_int = []
        W_ext = []
        for i_vf in range(len(U)):
            W_int.append(eval_W_int(P, gradU[i_vf]))
            W_ext.append(eval_W_ext(U[i_vf], Fx[step], Fy[step]))
        W_int_vec.append(jnp.array(W_int))
        W_ext_vec.append(jnp.array(W_ext))
    W_int_vec = jnp.array(W_int_vec) # [n_steps, n_virtualfields]
    W_ext_vec = jnp.array(W_ext_vec)
    return W_int_vec, W_ext_vec

@jit
def obj_fn(params):
    params = jnp.exp(params)
    W_int_vec, W_ext_vec = get_vworks(params)
    return jnp.sum((W_int_vec-W_ext_vec)**2)
g = grad(obj_fn)

# %%
i_vf = 0
W_int_vec, W_ext_vec = get_vworks(params_gt)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));

# %%
def loss(Lambda_params, x, key):
    params = ff_nn(elem_X, Lambda_params)

    # tvr_loss = 0.0
    # for i in range(5):
    #     grads = vmap(grad(lambda inp: ff_nn(inp, Lambda_params)[i]))(elem_X) # Take derivative of the ith output wrt the input vector
    #     tvr_loss += jnp.mean(jnp.sqrt(jnp.sum(grads*grads, axis=1)))

    # w = 1.0e-2
    return obj_fn(params) #+ w*tvr_loss

n_ff = 10
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,5,5,1]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)


Lambda_params, train_loss, _ = train(loss, None, get_params, opt_update, opt_state, key, nIter=20000, print_freq=1000)
# Out:
# it 1000, train loss = 5.944068e+00
# it 2000, train loss = 4.575726e+00
# it 3000, train loss = 3.436489e+00
# it 4000, train loss = 2.582760e+00
# it 5000, train loss = 2.099995e+00
# it 6000, train loss = 1.653063e+00
# it 7000, train loss = 1.133063e+00
# it 8000, train loss = 7.994953e-01
# it 9000, train loss = 6.719058e-01
# it 10000, train loss = 5.923974e-01
# it 11000, train loss = 5.203605e-01
# it 12000, train loss = 4.585786e-01
# it 13000, train loss = 4.089956e-01
# it 14000, train loss = 3.722897e-01
# it 15000, train loss = 3.463451e-01
# it 16000, train loss = 3.280904e-01
# it 17000, train loss = 3.142337e-01
# it 18000, train loss = 3.048622e-01
# it 19000, train loss = 2.973854e-01
# it 20000, train loss = 2.920116e-01

# %%
params_vfm = jnp.exp(ff_nn(elem_X, Lambda_params))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_vfm = GOH_P_vmap2(ugrad, params_vfm, 2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_vfm, title='Predicted stress at $\lambda_x$=1.2', ax=ax, extent=[2.0,2.46], extend='both');

# %%
print(obj_fn(ff_nn(elem_X, Lambda_params)))
# Out:
# 1.7828972794744535e-07

# %%
i_vf = 0
W_int_vec, W_ext_vec = get_vworks(params_vfm)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));
