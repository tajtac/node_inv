# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad
from functools import partial
import jax.random as random
key = random.PRNGKey(2022)
from jax.flatten_util import ravel_pytree
import jax.example_libraries.optimizers as optimizers

import matplotlib.pyplot as plt

from fem import plotmesh

# from jax.scipy.optimize import minimize
from scipy.optimize import minimize

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

from utils_hyperelasticity import ThreeDElasticity, neohook_model


E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

def VF1(x,y,h,w,p):
    U_x = x**p/w**p
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF2(x,y,h,w,p):
    U_x = 0.0
    U_y = y**p/h**p
    return jnp.stack([U_x,U_y]).T

def VF3(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    U_y = jnp.sin(p*x*jnp.pi)*jnp.sin(p*y*jnp.pi)
    return jnp.stack([U_x,U_y]).T

def VF4(x,y,h,w,p):
    U_x = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    U_y = jnp.sin(p*x*jnp.pi/w)**2*jnp.sin(p*y*jnp.pi/h)**2
    return jnp.stack([U_x,U_y]).T

def VF5(x,y,h,w,p):
    U_x = 1.0-(x/w-1)**(2*p)
    U_y = 0.0
    return jnp.stack([U_x,U_y]).T

def VF6(x,y,h,w,p):
    U_x = 0.0
    U_y = 1.0-(y/h-1)**(2*p)
    return jnp.stack([U_x,U_y]).T

def VF_and_grad(VF, x, y, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x,y,h,w,p), VF_grad(x,y,h,w,p)

def VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p):
    VF_dx = jax.jacfwd(VF, argnums=0)
    VF_dy = jax.jacfwd(VF, argnums=1)
    VF_grad = vmap(lambda x,y,h,w,p: jnp.stack([VF_dx(x,y,h,w,p), VF_dy(x,y,h,w,p)]).T, in_axes=(0,0,None,None,None))

    VF_vmap = vmap(VF, in_axes=(0,0,None,None,None))
    return VF_vmap(x_node,y_node,h,w,p), VF_grad(x_elem,y_elem,h,w,p)
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %%
GOH_P = ThreeDElasticity(neohook_model).ugrad_2_P
GOH_P_vmap = vmap(GOH_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(neohook_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('data/V.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5]) + c*jnp.stack([0.2])

# %%
# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))

lmb_hist = [1.05, 1.10, 1.15, 1.20]
n_elem = Nx*Ny

# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0
F_hist_goh = []
P_hist_goh = []

# %%
# Equibiaxial
for lmb_max in lmb_hist:    
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 12:02:24][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:24][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:24][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:24][DEBUG] jax_fem: Done pre-computations, took 0.5981640815734863 [s]
# [07-18 12:02:24][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:25][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:25][DEBUG] jax_fem: Start timing
# [07-18 12:02:25][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:26][DEBUG] jax_fem: Function split_and_compute_cell took 0.6901 seconds
# [07-18 12:02:26][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:27][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:27][DEBUG] jax_fem: PETSc linear solve res = 7.015727456842216e-06
# [07-18 12:02:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0209 seconds
# [07-18 12:02:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:27][DEBUG] jax_fem: Before, res l_2 = 0.004673571279364937
# [07-18 12:02:27][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:27][DEBUG] jax_fem: PETSc linear solve res = 9.765813641742748e-09
# [07-18 12:02:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0233 seconds
# [07-18 12:02:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:27][DEBUG] jax_fem: res l_2 = 6.22170579900853e-06
# [07-18 12:02:27][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:27][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:27][DEBUG] jax_fem: PETSc linear solve res = 3.091023192245249e-13
# [07-18 12:02:27][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:27][DEBUG] jax_fem: Function split_and_compute_cell took 0.0224 seconds
# [07-18 12:02:27][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:27][DEBUG] jax_fem: res l_2 = 1.4057924252230156e-11
# [07-18 12:02:27][INFO] jax_fem: Solve took 1.608421802520752 [s]
# [07-18 12:02:27][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 12:02:27][DEBUG] jax_fem: min of sol = 0.0
# [07-18 12:02:28][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:28][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:28][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:28][DEBUG] jax_fem: Done pre-computations, took 0.24898409843444824 [s]
# [07-18 12:02:28][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:29][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:29][DEBUG] jax_fem: Start timing
# [07-18 12:02:29][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:29][DEBUG] jax_fem: Function split_and_compute_cell took 0.5292 seconds
# [07-18 12:02:29][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:29][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:29][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:30][DEBUG] jax_fem: PETSc linear solve res = 1.4031454913684432e-05
# [07-18 12:02:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0201 seconds
# [07-18 12:02:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:30][DEBUG] jax_fem: Before, res l_2 = 0.01466849306461021
# [07-18 12:02:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:30][DEBUG] jax_fem: PETSc linear solve res = 8.475439991523795e-09
# [07-18 12:02:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0194 seconds
# [07-18 12:02:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:30][DEBUG] jax_fem: res l_2 = 6.162093339324987e-05
# [07-18 12:02:30][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:30][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:30][DEBUG] jax_fem: PETSc linear solve res = 3.2514675588563844e-11
# [07-18 12:02:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:30][DEBUG] jax_fem: Function split_and_compute_cell took 0.0207 seconds
# [07-18 12:02:30][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:30][DEBUG] jax_fem: res l_2 = 1.3860395360939825e-09
# [07-18 12:02:30][INFO] jax_fem: Solve took 0.7157998085021973 [s]
# [07-18 12:02:30][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 12:02:30][DEBUG] jax_fem: min of sol = 0.0
# [07-18 12:02:30][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:30][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:30][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:30][DEBUG] jax_fem: Done pre-computations, took 0.2510349750518799 [s]
# [07-18 12:02:30][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:31][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:31][DEBUG] jax_fem: Start timing
# [07-18 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.4954 seconds
# [07-18 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:31][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 2.1047182371690635e-05
# [07-18 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0192 seconds
# [07-18 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:31][DEBUG] jax_fem: Before, res l_2 = 0.026232485848436276
# [07-18 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 2.9276442717777134e-08
# [07-18 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0190 seconds
# [07-18 12:02:31][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:31][DEBUG] jax_fem: res l_2 = 0.00018944450356836722
# [07-18 12:02:31][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:31][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:31][DEBUG] jax_fem: PETSc linear solve res = 2.6813819719380447e-10
# [07-18 12:02:31][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:31][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-18 12:02:32][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:32][DEBUG] jax_fem: res l_2 = 1.2577329248184792e-08
# [07-18 12:02:32][INFO] jax_fem: Solve took 0.6719260215759277 [s]
# [07-18 12:02:32][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 12:02:32][DEBUG] jax_fem: min of sol = 0.0
# [07-18 12:02:32][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:32][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:32][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:32][DEBUG] jax_fem: Done pre-computations, took 0.30394792556762695 [s]
# [07-18 12:02:32][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:33][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:33][DEBUG] jax_fem: Start timing
# [07-18 12:02:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.5272 seconds
# [07-18 12:02:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:33][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:33][DEBUG] jax_fem: PETSc linear solve res = 2.8062909819009353e-05
# [07-18 12:02:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0214 seconds
# [07-18 12:02:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:33][DEBUG] jax_fem: Before, res l_2 = 0.03749303164465157
# [07-18 12:02:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:33][DEBUG] jax_fem: PETSc linear solve res = 8.568667691445666e-08
# [07-18 12:02:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0211 seconds
# [07-18 12:02:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:33][DEBUG] jax_fem: res l_2 = 0.0003578323530837447
# [07-18 12:02:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:33][DEBUG] jax_fem: PETSc linear solve res = 6.548382402349061e-10
# [07-18 12:02:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-18 12:02:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:33][DEBUG] jax_fem: res l_2 = 4.122828904508541e-08
# [07-18 12:02:33][INFO] jax_fem: Solve took 0.7138218879699707 [s]
# [07-18 12:02:33][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 12:02:33][DEBUG] jax_fem: min of sol = 0.0

# %%
# Uniaxial in x
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           right,                                  ],
        [1,                 0,              0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmbx_max_dirichlet(p, lmb_max)]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 12:02:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:34][DEBUG] jax_fem: Done pre-computations, took 0.2403099536895752 [s]
# [07-18 12:02:34][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:34][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:34][DEBUG] jax_fem: Start timing
# [07-18 12:02:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.5019 seconds
# [07-18 12:02:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:34][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:34][DEBUG] jax_fem: PETSc linear solve res = 1.4401491828710106e-06
# [07-18 12:02:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0210 seconds
# [07-18 12:02:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:34][DEBUG] jax_fem: Before, res l_2 = 0.0023579286269412463
# [07-18 12:02:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:34][DEBUG] jax_fem: PETSc linear solve res = 2.55225786998435e-09
# [07-18 12:02:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0190 seconds
# [07-18 12:02:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:34][DEBUG] jax_fem: res l_2 = 3.6545710539855055e-06
# [07-18 12:02:34][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:34][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:34][DEBUG] jax_fem: PETSc linear solve res = 1.1971473470881805e-11
# [07-18 12:02:34][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:34][DEBUG] jax_fem: Function split_and_compute_cell took 0.0198 seconds
# [07-18 12:02:34][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:34][DEBUG] jax_fem: res l_2 = 1.535747037105808e-11
# [07-18 12:02:34][INFO] jax_fem: Solve took 0.686331033706665 [s]
# [07-18 12:02:34][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 12:02:34][DEBUG] jax_fem: min of sol = -0.024316330445508776
# [07-18 12:02:34][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:34][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:34][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:35][DEBUG] jax_fem: Done pre-computations, took 0.2540252208709717 [s]
# [07-18 12:02:35][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:35][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:35][DEBUG] jax_fem: Start timing
# [07-18 12:02:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.5227 seconds
# [07-18 12:02:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:35][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:35][DEBUG] jax_fem: PETSc linear solve res = 2.8802983657420213e-06
# [07-18 12:02:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-18 12:02:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:35][DEBUG] jax_fem: Before, res l_2 = 0.008878882633452795
# [07-18 12:02:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:35][DEBUG] jax_fem: PETSc linear solve res = 1.863912146534867e-08
# [07-18 12:02:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 12:02:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:35][DEBUG] jax_fem: res l_2 = 5.236634507629092e-05
# [07-18 12:02:35][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:35][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:35][DEBUG] jax_fem: PETSc linear solve res = 6.070633591362223e-11
# [07-18 12:02:35][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:35][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-18 12:02:35][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:35][DEBUG] jax_fem: res l_2 = 2.014858632647127e-09
# [07-18 12:02:35][INFO] jax_fem: Solve took 0.7014570236206055 [s]
# [07-18 12:02:35][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 12:02:35][DEBUG] jax_fem: min of sol = -0.046942104148425534
# [07-18 12:02:35][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:35][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:35][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:36][DEBUG] jax_fem: Done pre-computations, took 0.22385478019714355 [s]
# [07-18 12:02:36][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:36][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:36][DEBUG] jax_fem: Start timing
# [07-18 12:02:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.5377 seconds
# [07-18 12:02:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:36][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:36][DEBUG] jax_fem: PETSc linear solve res = 4.32044817505974e-06
# [07-18 12:02:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0199 seconds
# [07-18 12:02:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:36][DEBUG] jax_fem: Before, res l_2 = 0.018979263259279323
# [07-18 12:02:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:36][DEBUG] jax_fem: PETSc linear solve res = 1.1615628368072945e-08
# [07-18 12:02:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 12:02:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:36][DEBUG] jax_fem: res l_2 = 0.0002408162066513738
# [07-18 12:02:36][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:36][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:36][DEBUG] jax_fem: PETSc linear solve res = 1.1941944447961212e-10
# [07-18 12:02:36][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:36][DEBUG] jax_fem: Function split_and_compute_cell took 0.0200 seconds
# [07-18 12:02:36][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:36][DEBUG] jax_fem: res l_2 = 4.311573376332812e-08
# [07-18 12:02:36][INFO] jax_fem: Solve took 0.7241489887237549 [s]
# [07-18 12:02:36][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 12:02:36][DEBUG] jax_fem: min of sol = -0.0680639398450818
# [07-18 12:02:36][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:36][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:36][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:37][DEBUG] jax_fem: Done pre-computations, took 0.24594998359680176 [s]
# [07-18 12:02:37][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:37][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:37][DEBUG] jax_fem: Start timing
# [07-18 12:02:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.5383 seconds
# [07-18 12:02:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:37][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:37][DEBUG] jax_fem: PETSc linear solve res = 5.760597435136153e-06
# [07-18 12:02:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0180 seconds
# [07-18 12:02:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:37][DEBUG] jax_fem: Before, res l_2 = 0.03231138017430017
# [07-18 12:02:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:37][DEBUG] jax_fem: PETSc linear solve res = 2.4822299094387172e-08
# [07-18 12:02:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0176 seconds
# [07-18 12:02:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:37][DEBUG] jax_fem: res l_2 = 0.000700158606916084
# [07-18 12:02:37][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:37][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:37][DEBUG] jax_fem: PETSc linear solve res = 1.308551611866667e-09
# [07-18 12:02:37][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:37][DEBUG] jax_fem: Function split_and_compute_cell took 0.0179 seconds
# [07-18 12:02:37][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:37][DEBUG] jax_fem: res l_2 = 3.6925361840821244e-07
# [07-18 12:02:37][INFO] jax_fem: Solve took 0.7153770923614502 [s]
# [07-18 12:02:37][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 12:02:37][DEBUG] jax_fem: min of sol = -0.08784070585563272

# %%
# Uniaxial in y
for lmb_max in lmb_hist:
    dirichlet_bc_info = [
        [bottom,            left,           top,                                     ],
        [1,                 0,              1,                                       ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),]
    ]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    problem.set_params(params_vec)


    node_x = solver(problem, use_petsc=True)
    u_grad = np.mean(problem.sol_to_grad(node_x), axis=1)
    F = u_grad + np.eye(2)
    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh.append(F)
    P_hist_goh.append(P)
# Out:
# [07-18 12:02:37][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:37][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:37][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:38][DEBUG] jax_fem: Done pre-computations, took 0.2248232364654541 [s]
# [07-18 12:02:38][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:38][DEBUG] jax_fem: Start timing
# [07-18 12:02:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.4832 seconds
# [07-18 12:02:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:38][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:38][DEBUG] jax_fem: PETSc linear solve res = 1.7491169252417e-06
# [07-18 12:02:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0201 seconds
# [07-18 12:02:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:38][DEBUG] jax_fem: Before, res l_2 = 0.0021508045108581597
# [07-18 12:02:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:38][DEBUG] jax_fem: PETSc linear solve res = 3.5721757814341006e-09
# [07-18 12:02:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0189 seconds
# [07-18 12:02:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:38][DEBUG] jax_fem: res l_2 = 3.0473542587900354e-06
# [07-18 12:02:38][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:38][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:38][DEBUG] jax_fem: PETSc linear solve res = 7.625715263390177e-12
# [07-18 12:02:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:38][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 12:02:38][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:38][DEBUG] jax_fem: res l_2 = 1.0409691879647658e-11
# [07-18 12:02:38][INFO] jax_fem: Solve took 0.6668131351470947 [s]
# [07-18 12:02:38][DEBUG] jax_fem: max of sol = 0.050000000000000044
# [07-18 12:02:38][DEBUG] jax_fem: min of sol = -0.024234357952173366
# [07-18 12:02:38][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:38][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:38][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:39][DEBUG] jax_fem: Done pre-computations, took 0.2560088634490967 [s]
# [07-18 12:02:39][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:39][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:39][DEBUG] jax_fem: Start timing
# [07-18 12:02:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.5036 seconds
# [07-18 12:02:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:39][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:39][DEBUG] jax_fem: PETSc linear solve res = 3.4982338504834e-06
# [07-18 12:02:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-18 12:02:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:39][DEBUG] jax_fem: Before, res l_2 = 0.008255272143805911
# [07-18 12:02:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:39][DEBUG] jax_fem: PETSc linear solve res = 3.163373552725581e-08
# [07-18 12:02:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0191 seconds
# [07-18 12:02:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:39][DEBUG] jax_fem: res l_2 = 4.5693662115761454e-05
# [07-18 12:02:39][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:39][DEBUG] jax_fem: PETSc linear solve res = 2.6606829177504284e-11
# [07-18 12:02:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0177 seconds
# [07-18 12:02:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:39][DEBUG] jax_fem: res l_2 = 1.6475955589802224e-09
# [07-18 12:02:39][INFO] jax_fem: Solve took 0.6798052787780762 [s]
# [07-18 12:02:39][DEBUG] jax_fem: max of sol = 0.10000000000000009
# [07-18 12:02:39][DEBUG] jax_fem: min of sol = -0.04678917724845612
# [07-18 12:02:39][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:39][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:39][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:40][DEBUG] jax_fem: Done pre-computations, took 0.23192977905273438 [s]
# [07-18 12:02:40][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:40][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:40][DEBUG] jax_fem: Start timing
# [07-18 12:02:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.5238 seconds
# [07-18 12:02:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:40][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:40][DEBUG] jax_fem: PETSc linear solve res = 5.247350776547547e-06
# [07-18 12:02:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0188 seconds
# [07-18 12:02:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:40][DEBUG] jax_fem: Before, res l_2 = 0.017922460771966648
# [07-18 12:02:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:40][DEBUG] jax_fem: PETSc linear solve res = 8.937294154099843e-08
# [07-18 12:02:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0183 seconds
# [07-18 12:02:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:40][DEBUG] jax_fem: res l_2 = 0.0002180045289884948
# [07-18 12:02:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:40][DEBUG] jax_fem: PETSc linear solve res = 9.257675031319494e-10
# [07-18 12:02:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0193 seconds
# [07-18 12:02:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:40][DEBUG] jax_fem: res l_2 = 3.830515982506421e-08
# [07-18 12:02:40][INFO] jax_fem: Solve took 0.707301139831543 [s]
# [07-18 12:02:40][DEBUG] jax_fem: max of sol = 0.1499999999999999
# [07-18 12:02:40][DEBUG] jax_fem: min of sol = -0.06785023658180024
# [07-18 12:02:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [07-18 12:02:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [07-18 12:02:40][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [07-18 12:02:41][DEBUG] jax_fem: Done pre-computations, took 0.25023913383483887 [s]
# [07-18 12:02:41][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [07-18 12:02:41][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [07-18 12:02:41][DEBUG] jax_fem: Start timing
# [07-18 12:02:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.5336 seconds
# [07-18 12:02:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:41][DEBUG] jax_fem: Linear guess solve...
# [07-18 12:02:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:41][DEBUG] jax_fem: PETSc linear solve res = 6.996467694483831e-06
# [07-18 12:02:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0181 seconds
# [07-18 12:02:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:41][DEBUG] jax_fem: Before, res l_2 = 0.030899306416034892
# [07-18 12:02:41][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:41][DEBUG] jax_fem: PETSc linear solve res = 4.6175036379783514e-08
# [07-18 12:02:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0244 seconds
# [07-18 12:02:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:41][DEBUG] jax_fem: res l_2 = 0.0006523907006160565
# [07-18 12:02:41][DEBUG] jax_fem: Solving linear system with lift solver...
# [07-18 12:02:41][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [07-18 12:02:41][DEBUG] jax_fem: PETSc linear solve res = 7.514548019634874e-10
# [07-18 12:02:41][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [07-18 12:02:41][DEBUG] jax_fem: Function split_and_compute_cell took 0.0234 seconds
# [07-18 12:02:41][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [07-18 12:02:41][DEBUG] jax_fem: res l_2 = 3.496723838992882e-07
# [07-18 12:02:41][INFO] jax_fem: Solve took 0.741703987121582 [s]
# [07-18 12:02:41][DEBUG] jax_fem: max of sol = 0.19999999999999996
# [07-18 12:02:41][DEBUG] jax_fem: min of sol = -0.08757549218960498

# %%
F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)

F_mean = F_hist_goh[-1].mean(axis=0)
params_gt = params_vec[:,0,:]

# %%
GOH_P_vmap2 = vmap(GOH_P, in_axes=(None,0,None))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_gt = GOH_P_vmap2(ugrad, params_gt,2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_gt, title='Ground Truth stress at $\lambda_x$=1.2', ax=ax); 
print(P_gt.min(), P_gt.max())



fig, axes = plt.subplots(1,12,figsize=(60,4))
t_hist = np.arange(len(lmb_hist)*3)
for t, F, P, ax in zip(t_hist, F_hist_goh, P_hist_goh, axes):
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='Max. Princip. Strain [-]', ax=ax);
# Out:
# 1.6670290124333391 2.0361138337191043

# %%
h = 1.0
w = 1.0
VF_list = [VF1, VF1, VF2, VF2, VF3, VF4, VF4, VF4, VF4, VF4, VF5, VF6]
p_list =  [1.0, 2.0, 1.0, 2.0, 1.0, 2.0, 3.0, 4.0, 4.0, 5.0, 1.0, 1.0]

x_elem, y_elem = elem_X.T
x_node, y_node = mesh.points.T
U, gradU = [], []
fig, axes = plt.subplots(2,len(VF_list),figsize=(len(VF_list)*5,8))
for ax, VF, p in zip(axes.T, VF_list, p_list):
    Ui, gradUi = VF_and_grad_2(VF, x_elem, y_elem, x_node, y_node, h, w, p)
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,0].mean(axis=1), title='Virtual Field i', ax=ax[0]); 
    plotmesh(mesh.cells, mesh.points, Ui[mesh.cells,1].mean(axis=1), title=None, ax=ax[1]); 
    U.append(Ui)
    gradU.append(gradUi)
U, gradU = np.array(U), np.array(gradU)

# %%
dL = Lx/Nx
dA = dL*dL
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0]*dL, axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0]*dL, axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1]*dL, axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1]*dL, axis=1)
Fx = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Fy = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

rgt_bd_nodes = np.where(np.isclose(mesh.points[:,0], 1.0))[0]
top_bd_nodes = np.where(np.isclose(mesh.points[:,1], 1.0))[0]
lft_bd_nodes = np.where(np.isclose(mesh.points[:,0], 0.0))[0]
bot_bd_nodes = np.where(np.isclose(mesh.points[:,1], 0.0))[0]

# %%
def eval_W_int(P, gradU):
    return jnp.einsum('ijk,ijk', P, gradU)*dA
def eval_W_ext(U, Fx, Fy):
    W_rgt = jnp.sum(U[rgt_bd_nodes, 0]*Fx*dL)
    W_top = jnp.sum(U[top_bd_nodes, 1]*Fy*dL)
    W_lft = jnp.sum(U[lft_bd_nodes, 0]*Fx*dL)
    W_bot = jnp.sum(U[bot_bd_nodes, 1]*Fy*dL)
    return W_rgt + W_top# + W_lft + W_bot

def get_vworks(params):
    W_int_vec = []
    W_ext_vec = []
    for step in range(len(F_hist_goh)):
        F = F_hist_goh[step]
        u_grad = jnp.array(F - np.eye(2))
        P = GOH_P_vmap(u_grad, params, 2)
        W_int = []
        W_ext = []
        for i_vf in range(len(U)):
            W_int.append(eval_W_int(P, gradU[i_vf]))
            W_ext.append(eval_W_ext(U[i_vf], Fx[step], Fy[step]))
        W_int_vec.append(jnp.array(W_int))
        W_ext_vec.append(jnp.array(W_ext))
    W_int_vec = jnp.array(W_int_vec) # [n_steps, n_virtualfields]
    W_ext_vec = jnp.array(W_ext_vec)
    return W_int_vec, W_ext_vec

@jit
def obj_fn(params):
    params = unravel(jnp.exp(params))
    W_int_vec, W_ext_vec = get_vworks(params)
    return jnp.sum((W_int_vec-W_ext_vec)**2)
g = grad(obj_fn)

# %%
i_vf = 3
W_int_vec, W_ext_vec = get_vworks(params_gt)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));

# %%
class OptimizationCallback:
    def __init__(self):
        self.iteration = 0
        self.history = {'iter':[], 'fval':[]}

    def __call__(self, xk):
        self.iteration += 1
        fval = obj_fn(xk)
        self.history['iter'].append(self.iteration)
        self.history['fval'].append(fval)
        print_freq = 100
        if self.iteration % print_freq == 0:
            print(f"Iteration: {self.iteration:05d}, Objective: {fval:.2e}")

params_vfm = np.array(params_gt[0])[None,:]
params_vfm[0,-1] = 1.0
params_vfm = np.repeat(params_vfm, len(elem_X), axis=0)
params_vfm, unravel = ravel_pytree(params_vfm)


callback = OptimizationCallback()
sol = minimize(obj_fn, jac = g, x0=params_vfm, options={'maxiter':5000, 'gtol':1e-12}, callback=callback, method='CG')

fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(callback.history['iter'], callback.history['fval'])
ax[0].set(xlabel='Iteration', ylabel='Objective function')
ax[1].plot(callback.history['iter'], np.log(callback.history['fval']))
ax[1].set(xlabel='Iteration', ylabel='log(Objective function)');
# Out:
# Iteration: 00100, Objective: 1.87e-04
# Iteration: 00200, Objective: 5.27e-05
# Iteration: 00300, Objective: 2.71e-05
# Iteration: 00400, Objective: 1.12e-05
# Iteration: 00500, Objective: 7.02e-06
# Iteration: 00600, Objective: 6.59e-06
# Iteration: 00700, Objective: 6.32e-06
# Iteration: 00800, Objective: 5.91e-06
# Iteration: 00900, Objective: 5.09e-06
# Iteration: 01000, Objective: 4.67e-06
# Iteration: 01100, Objective: 4.58e-06
# Iteration: 01200, Objective: 3.00e-06
# Iteration: 01300, Objective: 2.95e-06
# Iteration: 01400, Objective: 2.79e-06
# Iteration: 01500, Objective: 2.74e-06
# Iteration: 01600, Objective: 2.33e-06
# Iteration: 01700, Objective: 2.02e-06
# Iteration: 01800, Objective: 1.96e-06
# Iteration: 01900, Objective: 1.94e-06
# Iteration: 02000, Objective: 1.20e-06
# Iteration: 02100, Objective: 1.18e-06
# Iteration: 02200, Objective: 1.16e-06
# Iteration: 02300, Objective: 1.06e-06
# Iteration: 02400, Objective: 1.04e-06
# Iteration: 02500, Objective: 1.04e-06
# Iteration: 02600, Objective: 1.03e-06
# Iteration: 02700, Objective: 9.19e-07
# Iteration: 02800, Objective: 8.56e-07
# Iteration: 02900, Objective: 8.39e-07
# Iteration: 03000, Objective: 8.31e-07
# Iteration: 03100, Objective: 8.24e-07
# Iteration: 03200, Objective: 7.92e-07
# Iteration: 03300, Objective: 7.84e-07
# Iteration: 03400, Objective: 7.81e-07
# Iteration: 03500, Objective: 7.66e-07
# Iteration: 03600, Objective: 7.39e-07
# Iteration: 03700, Objective: 7.34e-07
# Iteration: 03800, Objective: 7.26e-07
# Iteration: 03900, Objective: 7.13e-07
# Iteration: 04000, Objective: 5.48e-07
# Iteration: 04100, Objective: 5.46e-07
# Iteration: 04200, Objective: 5.27e-07
# Iteration: 04300, Objective: 5.23e-07
# Iteration: 04400, Objective: 4.89e-07
# Iteration: 04500, Objective: 4.87e-07
# Iteration: 04600, Objective: 4.81e-07
# Iteration: 04700, Objective: 3.88e-07
# Iteration: 04800, Objective: 3.86e-07
# Iteration: 04900, Objective: 3.81e-07
# Iteration: 05000, Objective: 3.79e-07

# %%
params_vfm = unravel(jnp.exp(sol.x))
fig, ax = plt.subplots(figsize=(5,4))
ugrad = F_mean - np.eye(2)
P_vfm = GOH_P_vmap2(ugrad, params_vfm, 2)[:,1,1]
plotmesh(mesh.cells, mesh.points, P_vfm, title='Predicted stress at $\lambda_x$=1.2', ax=ax, extend='both');

# %%
i_vf = 0
W_int_vec, W_ext_vec = get_vworks(params_vfm)
W_int = W_int_vec[:,i_vf]
W_ext = W_ext_vec[:,i_vf]
plt.plot(W_int, '.-', label='internal')
plt.plot(W_ext, '.-', label='external')
plt.legend()
plt.title(str(np.sum((W_int - W_ext)**2)));
