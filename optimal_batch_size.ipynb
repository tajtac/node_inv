# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

b_sizes = [100,     200,    400,    800,    1600,   3200,   6400,   12800,  25600,  51200] #Training with 102400 results in OOM error
t_times = [1.37,    4.32,   5.15,   7.03,   10.32,  19.26,  37.87,  78.96,  161.14, 339.40]

ax.plot(b_sizes, t_times, '.-')
ax.set(xlabel='Batch size [-]', ylabel = 'Training time [m]');
