# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2024)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import pandas as pd
from utils import coords_2_strain_nn_vmap
from utils import train, coords_2_strain_nn
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, plotmesh_updated, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('/home/amir/inverse_prob/O.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])


# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
u_hist_goh=[]
F_hist_goh_gt = []
P_hist_goh_gt = []
for lmb_max in lmb_hist:
    # dirichlet_bc_info = [
    #     [bottom,            top],
    #     [1,                 1 ],
    #     [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max)]
    # ]
    # dirichlet_bc_info = [
    #     [left, right],
    #     [0, 0],
    #     [zero_dirichlet,lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    middle_displacements = []
    for element in mesh.cells:
       element_displacements = u[element,:]
       middle_displacements.append(np.mean(element_displacements, axis=0))
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    u_hist_goh.append(np.array(middle_displacements))
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh_gt.append(F)
    P_hist_goh_gt.append(P)
F_hist_goh_gt = np.array(F_hist_goh_gt)
P_hist_goh_gt = np.array(P_hist_goh_gt)
u_hist_goh = np.array(u_hist_goh)
# Out:
# [08-11 09:55:26][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [08-11 09:55:26][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [08-11 09:55:26][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [08-11 09:55:27][DEBUG] jax_fem: Done pre-computations, took 0.8764185905456543 [s]
# [08-11 09:55:27][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [08-11 09:55:30][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [08-11 09:55:30][DEBUG] jax_fem: Start timing
# [08-11 09:55:30][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:32][DEBUG] jax_fem: Function split_and_compute_cell took 1.5383 seconds
# [08-11 09:55:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:33][DEBUG] jax_fem: Linear guess solve...
# [08-11 09:55:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:33][DEBUG] jax_fem: PETSc linear solve res = 2.804120597507043e-06
# [08-11 09:55:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0374 seconds
# [08-11 09:55:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:33][DEBUG] jax_fem: Before, res l_2 = 0.003115044331343982
# [08-11 09:55:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:33][DEBUG] jax_fem: PETSc linear solve res = 4.265197761724921e-09
# [08-11 09:55:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0410 seconds
# [08-11 09:55:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:33][DEBUG] jax_fem: res l_2 = 6.918703760640068e-06
# [08-11 09:55:33][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:33][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:33][DEBUG] jax_fem: PETSc linear solve res = 3.862768592805902e-12
# [08-11 09:55:33][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:33][DEBUG] jax_fem: Function split_and_compute_cell took 0.0378 seconds
# [08-11 09:55:33][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:33][DEBUG] jax_fem: res l_2 = 5.509094357290201e-11
# [08-11 09:55:33][INFO] jax_fem: Solve took 3.1017873287200928 [s]
# [08-11 09:55:33][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [08-11 09:55:33][DEBUG] jax_fem: min of sol = 0.0
# [08-11 09:55:35][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [08-11 09:55:35][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [08-11 09:55:35][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [08-11 09:55:35][DEBUG] jax_fem: Done pre-computations, took 0.06593632698059082 [s]
# [08-11 09:55:35][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [08-11 09:55:38][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [08-11 09:55:38][DEBUG] jax_fem: Start timing
# [08-11 09:55:38][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.9982 seconds
# [08-11 09:55:39][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:39][DEBUG] jax_fem: Linear guess solve...
# [08-11 09:55:39][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:39][DEBUG] jax_fem: PETSc linear solve res = 3.942662351429631e-06
# [08-11 09:55:39][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:39][DEBUG] jax_fem: Function split_and_compute_cell took 0.0421 seconds
# [08-11 09:55:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:40][DEBUG] jax_fem: Before, res l_2 = 0.005518449789912624
# [08-11 09:55:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:40][DEBUG] jax_fem: PETSc linear solve res = 4.692608116915166e-09
# [08-11 09:55:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0349 seconds
# [08-11 09:55:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:40][DEBUG] jax_fem: res l_2 = 2.0974664721776265e-05
# [08-11 09:55:40][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:40][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:40][DEBUG] jax_fem: PETSc linear solve res = 4.775761539170237e-11
# [08-11 09:55:40][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:40][DEBUG] jax_fem: Function split_and_compute_cell took 0.0327 seconds
# [08-11 09:55:40][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:40][DEBUG] jax_fem: res l_2 = 5.067926830932601e-10
# [08-11 09:55:40][INFO] jax_fem: Solve took 1.3563904762268066 [s]
# [08-11 09:55:40][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [08-11 09:55:40][DEBUG] jax_fem: min of sol = 0.0
# [08-11 09:55:40][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [08-11 09:55:40][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [08-11 09:55:40][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [08-11 09:55:40][DEBUG] jax_fem: Done pre-computations, took 0.05785942077636719 [s]
# [08-11 09:55:40][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [08-11 09:55:43][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [08-11 09:55:43][DEBUG] jax_fem: Start timing
# [08-11 09:55:43][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:44][DEBUG] jax_fem: Function split_and_compute_cell took 0.9349 seconds
# [08-11 09:55:44][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:44][DEBUG] jax_fem: Linear guess solve...
# [08-11 09:55:44][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:44][DEBUG] jax_fem: PETSc linear solve res = 5.090814179065092e-06
# [08-11 09:55:44][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:44][DEBUG] jax_fem: Function split_and_compute_cell took 0.0469 seconds
# [08-11 09:55:44][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:44][DEBUG] jax_fem: Before, res l_2 = 0.008202950402131178
# [08-11 09:55:44][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:44][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:44][DEBUG] jax_fem: PETSc linear solve res = 1.550277060477305e-08
# [08-11 09:55:44][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:44][DEBUG] jax_fem: Function split_and_compute_cell took 0.0440 seconds
# [08-11 09:55:44][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:44][DEBUG] jax_fem: res l_2 = 4.457430027707671e-05
# [08-11 09:55:44][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:44][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:44][DEBUG] jax_fem: PETSc linear solve res = 8.099491363860986e-11
# [08-11 09:55:44][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:44][DEBUG] jax_fem: Function split_and_compute_cell took 0.0378 seconds
# [08-11 09:55:44][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:44][DEBUG] jax_fem: res l_2 = 2.2877461326189266e-09
# [08-11 09:55:44][INFO] jax_fem: Solve took 1.3463923931121826 [s]
# [08-11 09:55:44][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [08-11 09:55:44][DEBUG] jax_fem: min of sol = 0.0
# [08-11 09:55:44][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [08-11 09:55:44][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [08-11 09:55:44][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [08-11 09:55:44][DEBUG] jax_fem: Done pre-computations, took 0.05410361289978027 [s]
# [08-11 09:55:44][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [08-11 09:55:47][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [08-11 09:55:47][DEBUG] jax_fem: Start timing
# [08-11 09:55:47][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.8964 seconds
# [08-11 09:55:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:48][DEBUG] jax_fem: Linear guess solve...
# [08-11 09:55:48][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:48][DEBUG] jax_fem: PETSc linear solve res = 6.2344138722354365e-06
# [08-11 09:55:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.0365 seconds
# [08-11 09:55:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:48][DEBUG] jax_fem: Before, res l_2 = 0.010959471936286215
# [08-11 09:55:48][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:48][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:48][DEBUG] jax_fem: PETSc linear solve res = 2.026852891997358e-08
# [08-11 09:55:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.0357 seconds
# [08-11 09:55:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:48][DEBUG] jax_fem: res l_2 = 7.60415997024158e-05
# [08-11 09:55:48][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:48][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:48][DEBUG] jax_fem: PETSc linear solve res = 1.0224248752867713e-10
# [08-11 09:55:48][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:48][DEBUG] jax_fem: Function split_and_compute_cell took 0.0353 seconds
# [08-11 09:55:48][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:48][DEBUG] jax_fem: res l_2 = 6.657818058646402e-09
# [08-11 09:55:48][INFO] jax_fem: Solve took 1.240039587020874 [s]
# [08-11 09:55:48][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [08-11 09:55:48][DEBUG] jax_fem: min of sol = 0.0
# [08-11 09:55:48][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [08-11 09:55:48][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [08-11 09:55:48][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [08-11 09:55:48][DEBUG] jax_fem: Done pre-computations, took 0.05472922325134277 [s]
# [08-11 09:55:48][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [08-11 09:55:51][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [08-11 09:55:51][DEBUG] jax_fem: Start timing
# [08-11 09:55:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.9574 seconds
# [08-11 09:55:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:52][DEBUG] jax_fem: Linear guess solve...
# [08-11 09:55:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:52][DEBUG] jax_fem: PETSc linear solve res = 7.378013555759292e-06
# [08-11 09:55:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0429 seconds
# [08-11 09:55:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:52][DEBUG] jax_fem: Before, res l_2 = 0.01366815541833411
# [08-11 09:55:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:52][DEBUG] jax_fem: PETSc linear solve res = 1.931552664662326e-08
# [08-11 09:55:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0360 seconds
# [08-11 09:55:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:52][DEBUG] jax_fem: res l_2 = 0.00011234635260997274
# [08-11 09:55:52][DEBUG] jax_fem: Solving linear system with lift solver...
# [08-11 09:55:52][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [08-11 09:55:52][DEBUG] jax_fem: PETSc linear solve res = 1.2353560627895803e-10
# [08-11 09:55:52][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [08-11 09:55:52][DEBUG] jax_fem: Function split_and_compute_cell took 0.0337 seconds
# [08-11 09:55:52][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [08-11 09:55:52][DEBUG] jax_fem: res l_2 = 1.445928100571643e-08
# [08-11 09:55:52][INFO] jax_fem: Solve took 1.3793063163757324 [s]
# [08-11 09:55:52][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [08-11 09:55:52][DEBUG] jax_fem: min of sol = 0.0

# %%
displacements = []
u_hist_noisy=[]
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]

n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 

fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

axes_x = axes_x.flatten()
axes_y = axes_y.flatten()

for idx, (lmb_i, t, u) in enumerate(zip(lmb_hist_plot, t_hist, u_hist_goh)):
    key = random.PRNGKey(int(t**3))
    noise = jax.random.normal(key, shape=u.shape)
    mu=0
    sigma=0.001
    noise=mu + sigma * noise
    noise_scale = 1
    u_noisy = u + noise_scale * noise
    SNR= 10*np.log10(np.sum(np.linalg.norm(u))/np.sum(np.linalg.norm(u_noisy-u)))
    print(SNR)
    u_hist_noisy.append(u_noisy)
    u_noisy_x = u_noisy[:, [0]].flatten()
    u_noisy_y = u_noisy[:, [1]].flatten()

    ax_x = axes_x[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_x, title=f'displacement_x [-]', ax=ax_x)

    ax_y = axes_y[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_y, title=f'displacement_y [-]', ax=ax_y)

    displacements.append(np.array([t * np.ones(len(u)), u_noisy[:, 0], u_noisy[:, 1]]))

for i in range(n_plots, len(axes_x)):
    fig_x.delaxes(axes_x[i])
for i in range(n_plots, len(axes_y)):
    fig_y.delaxes(axes_y[i])

fig_x.tight_layout()
fig_y.tight_layout()

plt.show()
u_hist_noisy=np.array(u_hist_noisy)
displacements = np.hstack(displacements)
# Out:
# 15.012216315869622
# 16.50957920909519
# 17.690688466723334
# 18.516014234999798
# 19.2789573712261

# %% [markdown]
# #### FDM calculation of the F based on displacement

# %%
### assuming we have a square domain where everything is symmetric wrt x and y
def richardson_derivative(Z, h):
    """Calculates the derivatives using finite difference and Richardson extrapolation for step size h."""
    Z_x = np.zeros_like(Z)
    Z_y = np.zeros_like(Z)
    rows, cols = Z.shape
    for i in range(rows):
        for j in range(cols):
            if i == 0:  
                Z_y[i, j] = (Z[i + 1, j] - Z[i, j]) / h
            elif i == rows - 1:  
                Z_y[i, j] = (Z[i, j] - Z[i - 1, j]) / h
            else:  
                dy_h = (Z[i + 1, j] - Z[i - 1, j]) / (2 * h)
                
        
                f_y_plus_h_half = (Z[i + 1, j] + Z[i, j]) / 2
                f_y_minus_h_half = (Z[i - 1, j] + Z[i, j]) / 2
                
                dy_h_over_2 = (f_y_plus_h_half - f_y_minus_h_half) / h

               
                # Z_y[i, j] = (4 * dy_h_over_2 - dy_h) / 3
                Z_y[i, j] = dy_h
            if j == 0: 
                Z_x[i, j] = (Z[i, j + 1] - Z[i, j]) / h
            elif j == cols - 1: 
                Z_x[i, j] = (Z[i, j] - Z[i, j - 1]) / h
            else:  
                dx_h = (Z[i, j + 1] - Z[i, j - 1]) / (2 * h)
                
                f_x_plus_h_half = (Z[i, j + 1] + Z[i, j]) / 2
                f_x_minus_h_half = (Z[i, j - 1] + Z[i, j]) / 2
                
                dx_h_over_2 = (f_x_plus_h_half - f_x_minus_h_half) / h

                #Z_x[i, j] = (4 * dx_h_over_2 - dx_h) / 3
                Z_x[i, j] = dx_h

    return Z_x,Z_y
X_grid=elem_X[:,0].reshape((Nx,Ny)).T
Y_grid=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
u_hist_for_derivative=[]
for ii in range(u_hist_goh.shape[0]):
        u1=u_hist_noisy[ii,:,:]
        ux_grid=np.zeros((Nx,Ny))
        uy_grid=np.zeros((Nx,Ny))
        id_mesh=0
        for i in range(Nx):
            for j in range(Ny):
                ux_grid[j,i]=u1[id_mesh,0]
                uy_grid[j,i]=u1[id_mesh,1]
                id_mesh+=1
        u_hist_for_derivative.append([X_grid,Y_grid,ux_grid,uy_grid])
F_num_calculated=np.zeros_like(F_hist_goh_gt)
for ii in range(len(u_hist_for_derivative)):
           a,b,ux_grid,uy_grid=u_hist_for_derivative[ii]
           #print(ux_grid)
           uxx,uxy=richardson_derivative(ux_grid,1/Nx)
           #print('derivative')
           #print(uxx)
           uyx,uyy=richardson_derivative(uy_grid,1/Nx)
           id_mesh=0
           for i in range(uxx.shape[0]):
                for j in range(uxx.shape[1]):
                     F_num_calculated[ii,id_mesh, :,:]=np.array([[uxx[j,i]+1,uxy[j,i]],[uyx[j,i],uyy[j,i]+1]])
                     id_mesh+=1
#print(uy_grid.T[::-1,:])
# plt.scatter(elem_X[:,0], elem_X[:,1])
# a=elem_X[:,0].reshape((Nx,Ny)).T
# b=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
# print(a)
# print(b)

# %% [markdown]
# #### calculation of the error with respect to F_gt without noise

# %%
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
id_for_range=0
for idx, (t, F_gt, F) in enumerate(zip(t_hist, F_hist_goh_gt, F_num_calculated)):
    if id_for_range==n_cols:
        id_for_range=0
    ax_x = axes_x[idx]
    F_error = np.linalg.norm(F_gt-F, axis=(1, 2))
    label = fr'$|F_{{gt}}-F_{{FDM}}|^2,\ \text{{time}}={t+1}$'
    plotmesh(mesh.cells, mesh.points, F_error,title=label, ax=ax_x)
    #F_noisy=F+noise
    #strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
#F_hist_goh.shape

# %% [markdown]
# #### plot based on $F_{FDM}$

# %%
fig, axes = plt.subplots(1,5,figsize=(20,4))
strains = []
t_hist = np.arange(len(lmb_hist))
F_hist_goh = []
for t, F, P, ax in zip(t_hist, F_num_calculated, P_hist_goh_gt, axes):
    F_noisy=F
    F_hist_goh.append(F_noisy)

    E = E_fun(F_noisy)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T

    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps, title=r'Max. Princip. Strain [-],$F_{FDM}$', ax=ax); 
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F_noisy[:,0,0], F_noisy[:,0,1], F_noisy[:,1,0], F_noisy[:,1,1]]))
strains = np.hstack(strains)

# %% [markdown]
# ### interpolation of the $F_{FDM}$

# %%
# instead of using a 2D spline, use a NN to get the strain field for a given (x,y)
def loss_coords_2_strain(params, X, key):
    params_fwd=[ff_params, params]
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params_fwd)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 100 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = nn_params

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X,elem_X])
inp = np.hstack([X, strains.T])
coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)
# Out:
# it 1000, train loss = 4.984516e-04
# it 2000, train loss = 4.843833e-04
# it 3000, train loss = 4.038866e-04
# it 4000, train loss = 4.505997e-04
# it 5000, train loss = 4.442349e-04
# it 6000, train loss = 4.120996e-04
# it 7000, train loss = 4.769746e-04
# it 8000, train loss = 4.305131e-04
# it 9000, train loss = 4.543031e-04
# it 10000, train loss = 3.800466e-04
# it 11000, train loss = 3.996723e-04
# it 12000, train loss = 4.189887e-04
# it 13000, train loss = 4.105115e-04
# it 14000, train loss = 4.276935e-04
# it 15000, train loss = 4.086490e-04
# it 16000, train loss = 4.462988e-04
# it 17000, train loss = 4.072501e-04
# it 18000, train loss = 4.562405e-04
# it 19000, train loss = 4.176977e-04
# it 20000, train loss = 4.007029e-04
# it 21000, train loss = 3.868996e-04
# it 22000, train loss = 4.291857e-04
# it 23000, train loss = 4.155268e-04
# it 24000, train loss = 4.457458e-04
# it 25000, train loss = 4.055104e-04
# it 26000, train loss = 4.039370e-04
# it 27000, train loss = 4.148306e-04
# it 28000, train loss = 4.056289e-04
# it 29000, train loss = 4.175680e-04
# it 30000, train loss = 4.477512e-04
# it 31000, train loss = 3.725336e-04
# it 32000, train loss = 4.139858e-04
# it 33000, train loss = 4.440719e-04
# it 34000, train loss = 3.752085e-04
# it 35000, train loss = 4.258807e-04
# it 36000, train loss = 3.962130e-04
# it 37000, train loss = 4.233221e-04
# it 38000, train loss = 4.252008e-04
# it 39000, train loss = 4.396112e-04
# it 40000, train loss = 4.066409e-04
# it 41000, train loss = 4.348048e-04
# it 42000, train loss = 4.260992e-04
# it 43000, train loss = 3.955414e-04
# it 44000, train loss = 3.681880e-04
# it 45000, train loss = 3.908364e-04
# it 46000, train loss = 4.498733e-04
# it 47000, train loss = 4.289349e-04
# it 48000, train loss = 4.091326e-04
# it 49000, train loss = 4.110372e-04
# it 50000, train loss = 3.682524e-04
# it 51000, train loss = 3.794216e-04
# it 52000, train loss = 3.955085e-04
# it 53000, train loss = 3.983505e-04
# it 54000, train loss = 3.795580e-04
# it 55000, train loss = 4.100545e-04
# it 56000, train loss = 4.336513e-04
# it 57000, train loss = 4.233547e-04
# it 58000, train loss = 4.249046e-04
# it 59000, train loss = 3.766905e-04
# it 60000, train loss = 3.974680e-04
# it 61000, train loss = 4.327812e-04
# it 62000, train loss = 3.815510e-04
# it 63000, train loss = 3.964069e-04
# it 64000, train loss = 3.975891e-04
# it 65000, train loss = 4.225914e-04
# it 66000, train loss = 4.094516e-04
# it 67000, train loss = 3.812471e-04
# it 68000, train loss = 3.871036e-04
# it 69000, train loss = 3.891300e-04
# it 70000, train loss = 4.266266e-04
# it 71000, train loss = 4.076367e-04
# it 72000, train loss = 3.870056e-04
# it 73000, train loss = 3.575814e-04
# it 74000, train loss = 4.095247e-04
# it 75000, train loss = 3.868828e-04
# it 76000, train loss = 3.531006e-04
# it 77000, train loss = 4.317206e-04
# it 78000, train loss = 3.821424e-04
# it 79000, train loss = 3.962225e-04
# it 80000, train loss = 4.046739e-04
# it 81000, train loss = 3.810728e-04
# it 82000, train loss = 3.804360e-04
# it 83000, train loss = 3.903265e-04
# it 84000, train loss = 3.855972e-04
# it 85000, train loss = 4.051029e-04
# it 86000, train loss = 4.123896e-04
# it 87000, train loss = 3.471001e-04
# it 88000, train loss = 3.848921e-04
# it 89000, train loss = 3.989572e-04
# it 90000, train loss = 3.946795e-04
# it 91000, train loss = 3.605892e-04
# it 92000, train loss = 3.574982e-04
# it 93000, train loss = 3.698380e-04
# it 94000, train loss = 3.903992e-04
# it 95000, train loss = 3.746206e-04
# it 96000, train loss = 3.779706e-04
# it 97000, train loss = 4.049570e-04
# it 98000, train loss = 4.107144e-04
# it 99000, train loss = 3.786573e-04
# it 100000, train loss = 4.129797e-04

# %% [markdown]
# ####

# %% [markdown]
# #### plot for NN interpolation of $F_{FDM}$

# %%
coord_2_strain_params=[ff_params, coord_2_strain_params]

# %%
natural_brown_cmap = LinearSegmentedColormap.from_list(
    "natural_brown",
    [ "#f7eae7", "#754732" ],  # dark brown → light brown → pale peach
    N=256)
fig, axes = plt.subplots(1,5,figsize=(20,4))
for t in t_hist:
    ax = axes[t]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    plotmesh(mesh.cells, mesh.points, mps, title='MPS Reconstructed using NN', ax=ax,ec='None',cmap=natural_brown_cmap);

# %% [markdown]
# #### calculation of the error of $F_{NN}$ wrt $F_{gt}$

# %%
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
id_for_range=0
F_hist_goh = []
for idx, (t,F_gt) in enumerate(zip(t_hist,F_hist_goh_gt)):
    if id_for_range==n_cols:
        id_for_range=0
    ax_x = axes_x[idx]
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F_NN = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    F_hist_goh.append(F_NN)
    F_error = np.linalg.norm(F_gt-F_NN, axis=(1, 2))
    label = fr'$|F_{{gt}}-F_{{NN}}|^2,\ \text{{time}}={t+1}$'
    plotmesh(mesh.cells, mesh.points, F_error,title=label, ax=ax_x,ec='None',cmap=natural_brown_cmap)
    #F_noisy=F+noise
    #strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
F_hist_goh=np.array(F_hist_goh)

# %% [markdown]
# #### calculation of SNR

# %%
for idx, (t,F_gt) in enumerate(zip(t_hist,F_hist_goh_gt)):
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F_NN = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    SNR= 10*np.log10(np.sum(np.linalg.norm(F_gt, axis=(1, 2)))/np.sum(np.linalg.norm(F_gt-F_NN, axis=(1, 2))))
    print(SNR)
# Out:
# 19.383309981301636
# 20.18213945607553
# 19.97676875346078
# 19.35659265880305
# 18.943408197334712

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh_gt[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh_gt[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh_gt[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh_gt[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %% [markdown]
# #### saving  and reading info for interolated and ground-truth data

# %%
# with open('params_for_cluster_ring_noisy_p001_biaxial_test_prob_FDM_key2024.npy' ,'wb') as f:
#     pickle.dump([coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains,u_hist_goh,
#                  bd_X, lmb_hist, P_hist_goh_gt,F_hist_goh, t_hist,len(rgt_bd_elems),len(top_bd_elems )], f)

# %%
with open('params_for_cluster_ring_noisy_p001_biaxial_test_prob_FDM_key2024.npy', 'rb') as f:
    coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains,u_hist_goh,\
                 bd_X, lmb_hist, P_hist_goh_gt,F_hist_goh, t_hist,len_rgt_bd_elems,len_top_bd_elems  = pickle.load(f)

# %% [markdown]
# #### pretraining NODE's params to regenerate average stress

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 2.935541e-02
# it 2000, train loss = 1.142016e-02
# it 3000, train loss = 5.039301e-03
# it 4000, train loss = 3.706293e-04
# it 5000, train loss = 6.488133e-05
# it 6000, train loss = 6.399393e-05
# it 7000, train loss = 6.238558e-05
# it 8000, train loss = 5.889662e-05
# it 9000, train loss = 5.189652e-05
# it 10000, train loss = 4.252281e-05
# it 11000, train loss = 3.236638e-05
# it 12000, train loss = 2.351640e-05
# it 13000, train loss = 2.282714e-05
# it 14000, train loss = 2.265480e-05
# it 15000, train loss = 2.246907e-05
# it 16000, train loss = 2.231236e-05
# it 17000, train loss = 2.211690e-05
# it 18000, train loss = 2.197184e-05
# it 19000, train loss = 2.184983e-05
# it 20000, train loss = 2.263991e-05

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.39153 0.52634 0.65125 0.76631 0.87347] [0.37784 0.50607 0.62371 0.73087 0.82941]
# pr P_xx & P_yy:  [0.39337 0.52251 0.6487  0.77107 0.86989] [0.38021 0.50215 0.621   0.73504 0.82668]

# %% [markdown]
# #### pretraining the hyper network to generate params of NODE, which is homogeneous at this point

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.571064e-04
# it 2000, train loss = 4.334183e-05
# it 3000, train loss = 1.783100e-05
# it 4000, train loss = 8.706608e-06
# it 5000, train loss = 4.563308e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %% [markdown]
# #### second pretraining of the hyper network to acount for non-homogeneous deformation gradient

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y

# %%
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):

    P_pred = get_P_vmap(XYt_colloc[:,0],XYt_colloc[:,1], XYt_colloc[:,2], Lambda_params, coord_2_strain_params, NODE_w_unravel)
    P_xx = P_xx_mean[jnp.array(XYt_colloc[:,2], int)]
    P_yy = P_yy_mean[jnp.array(XYt_colloc[:,2], int)]

    loss_P = jnp.mean((P_pred[0] - P_xx)**2 + (P_pred[3] - P_yy)**2)
    # loss_F = 0.0
    
    return loss_P

lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 50000, print_freq=100, batch_size=3000)
# Out:
# it 1, val loss = 1.398744e-01
# it 101, val loss = 3.782492e-03
# it 201, val loss = 2.496505e-03
# it 301, val loss = 1.913759e-03
# it 401, val loss = 1.649768e-03
# it 501, val loss = 1.509452e-03
# it 601, val loss = 1.557092e-03
# it 701, val loss = 1.488166e-03
# it 801, val loss = 1.316308e-03
# it 901, val loss = 1.554887e-03
# it 1001, val loss = 1.188939e-03
# it 1101, val loss = 1.092372e-03
# it 1201, val loss = 1.131180e-03
# it 1301, val loss = 1.001176e-03
# it 1401, val loss = 1.320586e-03
# it 1501, val loss = 1.404936e-03
# it 1601, val loss = 1.149308e-03
# it 1701, val loss = 1.000549e-03
# it 1801, val loss = 1.132818e-03
# it 1901, val loss = 8.684035e-04
# it 2001, val loss = 8.573221e-04
# it 2101, val loss = 9.980043e-04
# it 2201, val loss = 8.562589e-04
# it 2301, val loss = 8.637945e-04
# it 2401, val loss = 8.311902e-04
# it 2501, val loss = 7.791802e-04
# it 2601, val loss = 8.561800e-04
# it 2701, val loss = 1.086541e-03
# it 2801, val loss = 7.856462e-04
# it 2901, val loss = 1.028353e-03
# it 3001, val loss = 7.443027e-04
# it 3101, val loss = 7.436291e-04
# it 3201, val loss = 7.458862e-04
# it 3301, val loss = 7.671093e-04
# it 3401, val loss = 7.081068e-04
# it 3501, val loss = 7.013522e-04
# it 3601, val loss = 7.418770e-04
# it 3701, val loss = 7.154748e-04
# it 3801, val loss = 6.872483e-04
# it 3901, val loss = 7.608270e-04
# it 4001, val loss = 6.958821e-04
# it 4101, val loss = 7.164321e-04
# it 4201, val loss = 6.973713e-04
# it 4301, val loss = 6.559077e-04
# it 4401, val loss = 6.641039e-04
# it 4501, val loss = 7.422397e-04
# it 4601, val loss = 6.740770e-04
# it 4701, val loss = 8.847360e-04
# it 4801, val loss = 6.399923e-04
# it 4901, val loss = 6.037764e-04
# it 5001, val loss = 6.469475e-04
# it 5101, val loss = 5.815482e-04
# it 5201, val loss = 6.499197e-04
# it 5301, val loss = 6.759556e-04
# it 5401, val loss = 6.017451e-04
# it 5501, val loss = 6.263513e-04
# it 5601, val loss = 5.941339e-04
# it 5701, val loss = 6.066737e-04
# it 5801, val loss = 5.710719e-04
# it 5901, val loss = 5.828920e-04
# it 6001, val loss = 5.634521e-04
# it 6101, val loss = 5.534888e-04
# it 6201, val loss = 6.174049e-04
# it 6301, val loss = 7.734356e-04
# it 6401, val loss = 5.985383e-04
# it 6501, val loss = 5.926542e-04
# it 6601, val loss = 5.448674e-04
# it 6701, val loss = 6.578516e-04
# it 6801, val loss = 5.578710e-04
# it 6901, val loss = 6.427434e-04
# it 7001, val loss = 5.221900e-04
# it 7101, val loss = 5.190035e-04
# it 7201, val loss = 5.303981e-04
# it 7301, val loss = 7.058461e-04
# it 7401, val loss = 6.051800e-04
# it 7501, val loss = 6.370815e-04
# it 7601, val loss = 5.629751e-04
# it 7701, val loss = 5.463113e-04
# it 7801, val loss = 6.150163e-04
# it 7901, val loss = 5.676416e-04
# it 8001, val loss = 5.604778e-04
# it 8101, val loss = 5.506615e-04
# it 8201, val loss = 6.700805e-04
# it 8301, val loss = 5.449806e-04
# it 8401, val loss = 5.524025e-04
# it 8501, val loss = 5.146487e-04
# it 8601, val loss = 5.449825e-04
# it 8701, val loss = 6.510165e-04
# it 8801, val loss = 5.276895e-04
# it 8901, val loss = 5.128144e-04
# it 9001, val loss = 5.832418e-04
# it 9101, val loss = 4.940468e-04
# it 9201, val loss = 5.189575e-04
# it 9301, val loss = 6.059064e-04
# it 9401, val loss = 4.883192e-04
# it 9501, val loss = 5.499672e-04
# it 9601, val loss = 5.080159e-04
# it 9701, val loss = 6.308924e-04
# it 9801, val loss = 4.964482e-04
# it 9901, val loss = 4.970220e-04
# it 10001, val loss = 4.743753e-04
# it 10101, val loss = 4.955770e-04
# it 10201, val loss = 5.164944e-04
# it 10301, val loss = 5.180832e-04
# it 10401, val loss = 4.985076e-04
# it 10501, val loss = 5.365556e-04
# it 10601, val loss = 4.852044e-04
# it 10701, val loss = 8.702657e-04
# it 10801, val loss = 4.946923e-04
# it 10901, val loss = 5.397502e-04
# it 11001, val loss = 5.480964e-04
# it 11101, val loss = 4.455560e-04
# it 11201, val loss = 5.012263e-04
# it 11301, val loss = 5.028751e-04
# it 11401, val loss = 4.888888e-04
# it 11501, val loss = 4.704154e-04
# it 11601, val loss = 4.637630e-04
# it 11701, val loss = 4.555705e-04
# it 11801, val loss = 5.027416e-04
# it 11901, val loss = 4.938419e-04
# it 12001, val loss = 5.141732e-04
# it 12101, val loss = 4.357790e-04
# it 12201, val loss = 5.216477e-04
# it 12301, val loss = 4.722246e-04
# it 12401, val loss = 4.445259e-04
# it 12501, val loss = 4.517753e-04
# it 12601, val loss = 4.524435e-04
# it 12701, val loss = 6.465975e-04
# it 12801, val loss = 5.002178e-04
# it 12901, val loss = 4.332889e-04
# it 13001, val loss = 5.030635e-04
# it 13101, val loss = 4.758959e-04
# it 13201, val loss = 4.779768e-04
# it 13301, val loss = 4.991685e-04
# it 13401, val loss = 4.555910e-04
# it 13501, val loss = 4.469235e-04
# it 13601, val loss = 4.509778e-04
# it 13701, val loss = 5.597354e-04
# it 13801, val loss = 4.924051e-04
# it 13901, val loss = 5.247986e-04
# it 14001, val loss = 4.570241e-04
# it 14101, val loss = 4.636237e-04
# it 14201, val loss = 5.416692e-04
# it 14301, val loss = 4.683589e-04
# it 14401, val loss = 4.475006e-04
# it 14501, val loss = 7.120152e-04
# it 14601, val loss = 5.148944e-04
# it 14701, val loss = 4.158293e-04
# it 14801, val loss = 4.901234e-04
# it 14901, val loss = 4.655799e-04
# it 15001, val loss = 5.402681e-04
# it 15101, val loss = 4.533482e-04
# it 15201, val loss = 4.531358e-04
# it 15301, val loss = 4.689150e-04
# it 15401, val loss = 4.304113e-04
# it 15501, val loss = 4.638491e-04
# it 15601, val loss = 5.113487e-04
# it 15701, val loss = 4.913938e-04
# it 15801, val loss = 4.631028e-04
# it 15901, val loss = 4.303084e-04
# it 16001, val loss = 4.672377e-04
# it 16101, val loss = 4.293034e-04
# it 16201, val loss = 4.103233e-04
# it 16301, val loss = 4.346779e-04
# it 16401, val loss = 4.492899e-04
# it 16501, val loss = 4.556233e-04
# it 16601, val loss = 4.322461e-04
# it 16701, val loss = 4.961814e-04
# it 16801, val loss = 4.771402e-04
# it 16901, val loss = 4.697798e-04
# it 17001, val loss = 4.059977e-04
# it 17101, val loss = 4.482819e-04
# it 17201, val loss = 4.363181e-04
# it 17301, val loss = 4.615434e-04
# it 17401, val loss = 4.336291e-04
# it 17501, val loss = 4.400587e-04
# it 17601, val loss = 4.503388e-04
# it 17701, val loss = 4.525828e-04
# it 17801, val loss = 4.428606e-04
# it 17901, val loss = 4.642797e-04
# it 18001, val loss = 3.987182e-04
# it 18101, val loss = 4.727995e-04
# it 18201, val loss = 4.418075e-04
# it 18301, val loss = 3.887582e-04
# it 18401, val loss = 5.678192e-04
# it 18501, val loss = 4.204187e-04
# it 18601, val loss = 4.246175e-04
# it 18701, val loss = 4.352204e-04
# it 18801, val loss = 4.428487e-04
# it 18901, val loss = 4.056816e-04
# it 19001, val loss = 4.307162e-04
# it 19101, val loss = 4.041713e-04
# it 19201, val loss = 5.310048e-04
# it 19301, val loss = 4.568141e-04
# it 19401, val loss = 4.422952e-04
# it 19501, val loss = 4.160887e-04
# it 19601, val loss = 3.975259e-04
# it 19701, val loss = 4.239891e-04
# it 19801, val loss = 4.110117e-04
# it 19901, val loss = 4.195450e-04
# it 20001, val loss = 4.116451e-04
# it 20101, val loss = 4.293410e-04
# it 20201, val loss = 4.134045e-04
# it 20301, val loss = 5.856079e-04
# it 20401, val loss = 4.900921e-04
# it 20501, val loss = 4.333702e-04
# it 20601, val loss = 4.534599e-04
# it 20701, val loss = 4.562388e-04
# it 20801, val loss = 4.024862e-04
# it 20901, val loss = 3.881974e-04
# it 21001, val loss = 4.110429e-04
# it 21101, val loss = 4.125477e-04
# it 21201, val loss = 4.254798e-04
# it 21301, val loss = 4.385372e-04
# it 21401, val loss = 4.052315e-04
# it 21501, val loss = 4.014036e-04
# it 21601, val loss = 5.039132e-04
# it 21701, val loss = 3.827299e-04
# it 21801, val loss = 4.322165e-04
# it 21901, val loss = 4.282621e-04
# it 22001, val loss = 4.284870e-04
# it 22101, val loss = 3.961411e-04
# it 22201, val loss = 4.401175e-04
# it 22301, val loss = 4.307107e-04
# it 22401, val loss = 4.405882e-04
# it 22501, val loss = 4.228684e-04
# it 22601, val loss = 4.162095e-04
# it 22701, val loss = 4.153250e-04
# it 22801, val loss = 4.207144e-04
# it 22901, val loss = 3.633881e-04
# it 23001, val loss = 3.785825e-04
# it 23101, val loss = 3.722997e-04
# it 23201, val loss = 4.122643e-04
# it 23301, val loss = 3.802547e-04
# it 23401, val loss = 4.361940e-04
# it 23501, val loss = 3.618519e-04
# it 23601, val loss = 3.852871e-04
# it 23701, val loss = 4.092194e-04
# it 23801, val loss = 4.829877e-04
# it 23901, val loss = 4.929243e-04
# it 24001, val loss = 4.356864e-04
# it 24101, val loss = 3.829154e-04
# it 24201, val loss = 3.894357e-04
# it 24301, val loss = 4.167687e-04
# it 24401, val loss = 3.936838e-04
# it 24501, val loss = 3.932052e-04
# it 24601, val loss = 3.342564e-04
# it 24701, val loss = 3.671921e-04
# it 24801, val loss = 3.836001e-04
# it 24901, val loss = 4.094121e-04
# it 25001, val loss = 3.780527e-04
# it 25101, val loss = 3.905056e-04
# it 25201, val loss = 3.755722e-04
# it 25301, val loss = 4.593549e-04
# it 25401, val loss = 3.776153e-04
# it 25501, val loss = 3.482125e-04
# it 25601, val loss = 4.788613e-04
# it 25701, val loss = 4.798049e-04
# it 25801, val loss = 4.131413e-04
# it 25901, val loss = 3.803162e-04
# it 26001, val loss = 4.947722e-04
# it 26101, val loss = 4.226532e-04
# it 26201, val loss = 4.474403e-04
# it 26301, val loss = 3.741802e-04
# it 26401, val loss = 3.740254e-04
# it 26501, val loss = 3.950235e-04
# it 26601, val loss = 3.805625e-04
# it 26701, val loss = 3.699898e-04
# it 26801, val loss = 3.653235e-04
# it 26901, val loss = 3.531266e-04
# it 27001, val loss = 3.747462e-04
# it 27101, val loss = 4.228519e-04
# it 27201, val loss = 3.644228e-04
# it 27301, val loss = 3.952247e-04
# it 27401, val loss = 3.509655e-04
# it 27501, val loss = 3.818579e-04
# it 27601, val loss = 3.391042e-04
# it 27701, val loss = 3.718618e-04
# it 27801, val loss = 3.754746e-04
# it 27901, val loss = 4.408424e-04
# it 28001, val loss = 3.951047e-04
# it 28101, val loss = 3.825614e-04
# it 28201, val loss = 3.496270e-04
# it 28301, val loss = 3.799268e-04
# it 28401, val loss = 3.899118e-04
# it 28501, val loss = 3.568573e-04
# it 28601, val loss = 4.151744e-04
# it 28701, val loss = 3.752468e-04
# it 28801, val loss = 4.139671e-04
# it 28901, val loss = 3.349181e-04
# it 29001, val loss = 3.635093e-04
# it 29101, val loss = 3.901307e-04
# it 29201, val loss = 3.838217e-04
# it 29301, val loss = 4.073543e-04
# it 29401, val loss = 3.512144e-04
# it 29501, val loss = 4.412239e-04
# it 29601, val loss = 4.466567e-04
# it 29701, val loss = 3.528635e-04
# it 29801, val loss = 3.899303e-04
# it 29901, val loss = 4.192698e-04
# it 30001, val loss = 4.423466e-04
# it 30101, val loss = 3.946944e-04
# it 30201, val loss = 3.443105e-04
# it 30301, val loss = 3.854157e-04
# it 30401, val loss = 4.379723e-04
# it 30501, val loss = 3.546229e-04
# it 30601, val loss = 3.613152e-04
# it 30701, val loss = 3.622292e-04
# it 30801, val loss = 3.345746e-04
# it 30901, val loss = 3.652084e-04
# it 31001, val loss = 3.591111e-04
# it 31101, val loss = 3.479206e-04
# it 31201, val loss = 3.494460e-04
# it 31301, val loss = 3.538176e-04
# it 31401, val loss = 3.731371e-04
# it 31501, val loss = 3.968442e-04
# it 31601, val loss = 3.571692e-04
# it 31701, val loss = 3.513181e-04
# it 31801, val loss = 4.730638e-04
# it 31901, val loss = 4.273716e-04
# it 32001, val loss = 3.756431e-04
# it 32101, val loss = 3.604352e-04
# it 32201, val loss = 3.494575e-04
# it 32301, val loss = 4.075119e-04
# it 32401, val loss = 3.273431e-04
# it 32501, val loss = 3.455904e-04
# it 32601, val loss = 3.874781e-04
# it 32701, val loss = 3.520449e-04
# it 32801, val loss = 3.755570e-04
# it 32901, val loss = 3.547050e-04
# it 33001, val loss = 3.312716e-04
# it 33101, val loss = 3.550033e-04
# it 33201, val loss = 3.514794e-04
# it 33301, val loss = 4.317102e-04
# it 33401, val loss = 3.326851e-04
# it 33501, val loss = 3.473485e-04
# it 33601, val loss = 3.588937e-04
# it 33701, val loss = 3.624066e-04
# it 33801, val loss = 3.450709e-04
# it 33901, val loss = 3.462747e-04
# it 34001, val loss = 3.496335e-04
# it 34101, val loss = 3.877887e-04
# it 34201, val loss = 3.650514e-04
# it 34301, val loss = 4.144399e-04
# it 34401, val loss = 3.542297e-04
# it 34501, val loss = 3.732685e-04
# it 34601, val loss = 3.983395e-04
# it 34701, val loss = 3.480081e-04
# it 34801, val loss = 3.825961e-04
# it 34901, val loss = 3.224468e-04
# it 35001, val loss = 3.429776e-04
# it 35101, val loss = 3.657419e-04
# it 35201, val loss = 3.505745e-04
# it 35301, val loss = 3.478989e-04
# it 35401, val loss = 3.256247e-04
# it 35501, val loss = 3.574161e-04
# it 35601, val loss = 3.374192e-04
# it 35701, val loss = 3.446927e-04
# it 35801, val loss = 3.752410e-04
# it 35901, val loss = 3.737068e-04
# it 36001, val loss = 3.457985e-04
# it 36101, val loss = 3.369083e-04
# it 36201, val loss = 3.468187e-04
# it 36301, val loss = 3.895172e-04
# it 36401, val loss = 3.341469e-04
# it 36501, val loss = 3.646760e-04
# it 36601, val loss = 3.615804e-04
# it 36701, val loss = 3.284204e-04
# it 36801, val loss = 3.171212e-04
# it 36901, val loss = 3.175831e-04
# it 37001, val loss = 3.683154e-04
# it 37101, val loss = 3.330402e-04
# it 37201, val loss = 3.325985e-04
# it 37301, val loss = 3.844905e-04
# it 37401, val loss = 3.802379e-04
# it 37501, val loss = 3.504006e-04
# it 37601, val loss = 3.846594e-04
# it 37701, val loss = 3.895997e-04
# it 37801, val loss = 3.844202e-04
# it 37901, val loss = 4.694077e-04
# it 38001, val loss = 3.343721e-04
# it 38101, val loss = 3.515831e-04
# it 38201, val loss = 3.765421e-04
# it 38301, val loss = 3.744124e-04
# it 38401, val loss = 3.294544e-04
# it 38501, val loss = 3.303924e-04
# it 38601, val loss = 3.775407e-04
# it 38701, val loss = 4.257157e-04
# it 38801, val loss = 3.296496e-04
# it 38901, val loss = 3.527454e-04
# it 39001, val loss = 3.681593e-04
# it 39101, val loss = 3.407412e-04
# it 39201, val loss = 3.667303e-04
# it 39301, val loss = 3.122037e-04
# it 39401, val loss = 3.353672e-04
# it 39501, val loss = 3.835283e-04
# it 39601, val loss = 3.205018e-04
# it 39701, val loss = 3.535700e-04
# it 39801, val loss = 2.950124e-04
# it 39901, val loss = 3.825995e-04
# it 40001, val loss = 3.184457e-04
# it 40101, val loss = 3.670784e-04
# it 40201, val loss = 3.360577e-04
# it 40301, val loss = 3.247842e-04
# it 40401, val loss = 3.090666e-04
# it 40501, val loss = 3.473795e-04
# it 40601, val loss = 3.313171e-04
# it 40701, val loss = 4.021770e-04
# it 40801, val loss = 3.373925e-04
# it 40901, val loss = 3.876813e-04
# it 41001, val loss = 3.402609e-04
# it 41101, val loss = 3.120806e-04
# it 41201, val loss = 3.627293e-04
# it 41301, val loss = 3.299322e-04
# it 41401, val loss = 3.003715e-04
# it 41501, val loss = 3.192048e-04
# it 41601, val loss = 3.319677e-04
# it 41701, val loss = 3.840965e-04
# it 41801, val loss = 3.838581e-04
# it 41901, val loss = 4.178081e-04
# it 42001, val loss = 3.456302e-04
# it 42101, val loss = 3.494765e-04
# it 42201, val loss = 3.359092e-04
# it 42301, val loss = 3.327013e-04
# it 42401, val loss = 3.196684e-04
# it 42501, val loss = 3.405159e-04
# it 42601, val loss = 3.900031e-04
# it 42701, val loss = 3.543106e-04
# it 42801, val loss = 3.345039e-04
# it 42901, val loss = 3.954336e-04
# it 43001, val loss = 3.469813e-04
# it 43101, val loss = 3.254635e-04
# it 43201, val loss = 3.438214e-04
# it 43301, val loss = 3.239607e-04
# it 43401, val loss = 3.228102e-04
# it 43501, val loss = 3.849697e-04
# it 43601, val loss = 4.772383e-04
# it 43701, val loss = 3.241176e-04
# it 43801, val loss = 3.435549e-04
# it 43901, val loss = 3.673990e-04
# it 44001, val loss = 3.390025e-04
# it 44101, val loss = 3.164302e-04
# it 44201, val loss = 3.401396e-04
# it 44301, val loss = 3.466034e-04
# it 44401, val loss = 3.702654e-04
# it 44501, val loss = 3.651614e-04
# it 44601, val loss = 2.788681e-04
# it 44701, val loss = 3.187638e-04
# it 44801, val loss = 3.294570e-04
# it 44901, val loss = 3.682925e-04
# it 45001, val loss = 3.596627e-04
# it 45101, val loss = 3.162447e-04
# it 45201, val loss = 3.337005e-04
# it 45301, val loss = 3.833546e-04
# it 45401, val loss = 3.199833e-04
# it 45501, val loss = 3.079418e-04
# it 45601, val loss = 3.276605e-04
# it 45701, val loss = 3.530377e-04
# it 45801, val loss = 3.405483e-04
# it 45901, val loss = 3.151273e-04
# it 46001, val loss = 3.255545e-04
# it 46101, val loss = 4.251976e-04
# it 46201, val loss = 3.117735e-04
# it 46301, val loss = 3.296774e-04
# it 46401, val loss = 3.700782e-04
# it 46501, val loss = 3.325252e-04
# it 46601, val loss = 3.502150e-04
# it 46701, val loss = 3.344603e-04
# it 46801, val loss = 3.683849e-04
# it 46901, val loss = 3.498022e-04
# it 47001, val loss = 3.141128e-04
# it 47101, val loss = 3.348080e-04
# it 47201, val loss = 3.398445e-04
# it 47301, val loss = 3.175876e-04
# it 47401, val loss = 3.583036e-04
# it 47501, val loss = 3.180547e-04
# it 47601, val loss = 3.441641e-04
# it 47701, val loss = 3.246622e-04
# it 47801, val loss = 4.082057e-04
# it 47901, val loss = 3.145855e-04
# it 48001, val loss = 2.969536e-04
# it 48101, val loss = 3.596931e-04
# it 48201, val loss = 3.326993e-04
# it 48301, val loss = 3.372882e-04
# it 48401, val loss = 3.831485e-04
# it 48501, val loss = 3.059586e-04
# it 48601, val loss = 2.979439e-04
# it 48701, val loss = 3.503589e-04
# it 48801, val loss = 3.205995e-04
# it 48901, val loss = 3.298903e-04
# it 49001, val loss = 3.300394e-04
# it 49101, val loss = 3.367608e-04
# it 49201, val loss = 3.516125e-04
# it 49301, val loss = 3.301682e-04
# it 49401, val loss = 3.178672e-04
# it 49501, val loss = 3.185132e-04
# it 49601, val loss = 2.839631e-04
# it 49701, val loss = 3.323765e-04
# it 49801, val loss = 3.195708e-04
# it 49901, val loss = 3.652296e-04

# %% [markdown]
# #### saving data of hyper network after second pretraining to plot the results

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_p001_biaxial_tests_displacement_second_pretraining.pickle', 'wb') as f:
    pickle.dump([Lambda_params,val_loss, metrics], f)

# %%
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y

# %% [markdown]
# #### here is the main training

# %%
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    return loss_Div + loss_F

lr = 1e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 20000, print_freq=1000, batch_size=3000)

with open('/home/amir/inverse_prob/params_for_noise_tuning/ring_biaxial_noisy_p001_prob_displacement_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)
# Out:
# 2024-12-09 23:12:28.062315: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 4m15.578039066s
#
# ********************************
# [Compiling module jit_step_colloc] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# it 1, val loss = 6.472240e+00
# it 1001, val loss = 5.243335e+01
# it 2001, val loss = 9.817775e+00
# it 3001, val loss = 7.916563e+01
# it 4001, val loss = 8.593162e+01
# it 5001, val loss = 7.153461e+01
# it 6001, val loss = 6.124680e+01
# it 7001, val loss = 3.507262e+01
# it 8001, val loss = 2.647987e+01
# it 9001, val loss = 4.359458e+01
# it 10001, val loss = 2.192706e+01
# it 11001, val loss = 3.225078e+01
# it 12001, val loss = 2.403427e+02
# it 13001, val loss = 1.892577e+02
# it 14001, val loss = 1.836115e+02
# it 15001, val loss = 1.564505e+02
# it 16001, val loss = 1.278812e+02
# it 17001, val loss = 8.972151e+01
# it 18001, val loss = 6.050385e+01
# it 19001, val loss = 5.171165e+01

# %% [markdown]
# ### plot loss for main training

# %%
plt.plot(val_loss)

# %% [markdown]
# ## 3. Test

# %% [markdown]
# #### pretraining plots

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/ring_biaxial_noisy_p001_prob_displacement_post.npy', 'rb') as f:
   [mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist]=pickle.load(f)
# with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_p001_biaxial_tests_displacement_second_pretraining.pickle', 'rb') as f:
#     [Lambda_params,val_loss, metrics]=pickle.load(f)

# %% [markdown]
# #### plots for the inverse problem

# %%
# Stiffness across the domain
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
fig, axes = plt.subplots(2,5,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0],ec='None'); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend,ec='None');

# %%
mat1_params = coords_2_params_gt([0.5,0.9])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.2)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.5, 0.9]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
mat1_params = coords_2_params_gt([0.5,0.9])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.2)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.5, 0.9]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[1,1])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[1,1])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{yy}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
