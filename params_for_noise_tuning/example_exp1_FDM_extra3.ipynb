# %% [markdown]
# ### The idea behind this notebook:
# Let a NN learn the u (displacement) field directly, rather than learning F.

# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd

from utils import train, coords_2_strain_nn, nn_fpass
from utils import train_colloc_parallel as train_colloc, init_params_nn, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_iso, init_params_iso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity, merge_c_s_params_iso, split_c_s_params_iso
from fem import plotmesh, plotmesh_updated, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))


with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/image_88_info.npy', 'rb') as f:
    _,_,_,P_xx_gt,P_yy_gt = pickle.load(f)
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/image88_disp.npy', 'rb') as f:
    x,y,ux_hist,uy_hist = pickle.load(f)
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/_image88_temp.npy', 'rb') as f:
    E_hist_dic = pickle.load(f)
uy_hist=-uy_hist 

x1 = 4
x2 = 50
y1 = 2
y2 = 48
out = []
for aux in E_hist_dic:
    out.append(aux.transpose([2,0,1]).reshape([51,51,2,2]).transpose([1,0,2,3])[x1:x2,y1:y2,:,:].reshape([-1,2,2])) # I know. wtf?
E_hist_dic = np.array(out)
elem_X = np.stack([x.flatten(),y.flatten()]).T


# we don't need to use all of that data
i1 = 10
i2 = None
skip = 40
P_xx_gt = jnp.array(P_xx_gt[i1:i2:skip])
P_yy_gt = jnp.array(P_yy_gt[i1:i2:skip])
ux_hist = jnp.array(ux_hist[i1:i2:skip])
uy_hist = jnp.array(uy_hist[i1:i2:skip])

E_hist_dic = E_hist_dic[i1:i2:skip]
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %%
P_yy_gt
# Out:
# Array([0.33164, 1.13442, 1.80407, 2.40157, 2.95055], dtype=float64)

# %%
E_hist_dic.shape
# Out:
# (5, 2116, 2, 2)

# %%
E_hist_dic.shape
# Out:
# (5, 2116, 2, 2)

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = x.shape[0], x.shape[1]
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
range_minmax=np.zeros((2,2))
disps_norm = []
n_panels = 5
for i in range(len(ux_hist)):
    if i==0:
        range_minmax[0,0]=np.min(ux_hist[i])
        range_minmax[0,1]=np.max(ux_hist[i])
        range_minmax[1,0]=np.min(uy_hist[i])
        range_minmax[1,1]=np.max(uy_hist[i])
    else:
        range_minmax[0,0]=np.min(np.array([range_minmax[0,0],np.min(ux_hist[i])]))
        range_minmax[0,1]=np.max(np.array([range_minmax[0,1],np.max(ux_hist[i])]))
        range_minmax[1,0]=np.min(np.array([range_minmax[1,0],np.min(uy_hist[i])]))
        range_minmax[1,1]=np.max(np.array([range_minmax[1,1],np.max(uy_hist[i])]))

# %%
len(ux_hist)
# Out:
# 5

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = x.shape[0], x.shape[1]
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])

disps_norm = []
n_panels = 5
fig, axes = plt.subplots(2,n_panels,figsize=(5*n_panels,8))
t_hist = np.arange(len(ux_hist))
disps_x_mean = []
disps_x_stdv = []
disps_y_mean = []
disps_y_stdv = []
for i in range(len(ux_hist)):
    t = t_hist[i]
    plotmesh_updated(mesh.cells, mesh.points, ux_hist[i].flatten(), \
                     range_minmax[0,0],range_minmax[0,1],title='Displacement in x', ax=axes[0,i], ec='None'); 
    plotmesh_updated(mesh.cells, mesh.points, uy_hist[i].flatten(), \
                     range_minmax[1,0],range_minmax[1,1],title='Displacement in y', ax=axes[1,i], ec='None'); 

    temp1 = ux_hist[i].flatten()
    temp2 = uy_hist[i].flatten()
    disps_x_mean.append(temp1.mean())
    disps_x_stdv.append(temp1.std())
    disps_y_mean.append(temp2.mean())
    disps_y_stdv.append(temp2.std())

    temp1 = (temp1 - temp1.mean())/temp1.std()
    temp2 = (temp2 - temp2.mean())/temp2.std()

    disps_norm.append(np.array([t*np.ones(len(temp1)), temp1, temp2]))
disps_norm = np.hstack(disps_norm)
disps_x_mean = jnp.hstack(disps_x_mean)
disps_x_stdv = jnp.hstack(disps_x_stdv)
disps_y_mean = jnp.hstack(disps_y_mean)
disps_y_stdv = jnp.hstack(disps_y_stdv)

# %%
ux_hist=np.array(ux_hist)
uy_hist=np.array(uy_hist)
X_grid=elem_X[:,0].reshape((Nx,Ny)).T
Y_grid=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
u_hist_for_derivative=[]
for ii in range(ux_hist.shape[0]):
        ux_hist
        u_hist_for_derivative.append([X_grid,Y_grid,ux_hist[ii,:,:],uy_hist[ii,:,:]])

# %%
def richardson_derivative(Z, h):
    """Calculates the derivatives using finite difference and Richardson extrapolation for step size h."""
    Z_x = np.zeros_like(Z)
    Z_y = np.zeros_like(Z)
    rows, cols = Z.shape
    for i in range(rows):
        for j in range(cols):
            if i == 0:  
                Z_y[i, j] = (Z[i + 1, j] - Z[i, j]) / h
            elif i == rows - 1:  
                Z_y[i, j] = (Z[i, j] - Z[i - 1, j]) / h
            else:  
                dy_h = (Z[i + 1, j] - Z[i - 1, j]) / (2 * h)
                
        
                f_y_plus_h_half = (Z[i + 1, j] + Z[i, j]) / 2
                f_y_minus_h_half = (Z[i - 1, j] + Z[i, j]) / 2
                
                dy_h_over_2 = (f_y_plus_h_half - f_y_minus_h_half) / h

               
                #Z_y[i, j] = (4 * dy_h_over_2 - dy_h) / 3
                Z_y[i, j] = dy_h
            if j == 0: 
                Z_x[i, j] = (Z[i, j + 1] - Z[i, j]) / h
            elif j == cols - 1: 
                Z_x[i, j] = (Z[i, j] - Z[i, j - 1]) / h
            else:  
                dx_h = (Z[i, j + 1] - Z[i, j - 1]) / (2 * h)
                
                f_x_plus_h_half = (Z[i, j + 1] + Z[i, j]) / 2
                f_x_minus_h_half = (Z[i, j - 1] + Z[i, j]) / 2
                
                dx_h_over_2 = (f_x_plus_h_half - f_x_minus_h_half) / h

                #Z_x[i, j] = (4 * dx_h_over_2 - dx_h) / 3
                Z_x[i, j] = dx_h

    return Z_x,Z_y
F_with_FDM=np.zeros((5,46*46,2,2))
for ii in range(len(u_hist_for_derivative)):
           a,b,ux_grid,uy_grid=u_hist_for_derivative[ii]
           #print(ux_grid)
           uxx,uxy=richardson_derivative(ux_grid.T,1/(Nx-1))
           #print('derivative')
           #print(uxx)
           uyx,uyy=richardson_derivative(uy_grid.T,1/(Nx-1))
           id_mesh=0
           for i in range(uxx.shape[1]):
                for j in range(uxx.shape[0]):
                     F_with_FDM[ii,id_mesh, :,:]=np.array([[uxx[j,i]+1,uxy[j,i]],[uyx[j,i],uyy[j,i]+1]])
                     id_mesh+=1
#print(uy_grid.T[::-1,:])
# plt.scatter(elem_X[:,0], elem_X[:,1])
# a=elem_X[:,0].reshape((Nx,Ny)).T
# b=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
# print(a)
# print(b)

# %%
#F_mean = []
fig, axes = plt.subplots(2,5,figsize=(25,8))
for t in t_hist:
    # inp = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    # F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn2(inp, coord_2_strain_params).T
    F=F_with_FDM[t,:,:]
    # F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    #F_mean.append(F)
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps2 = np.maximum(E_11, E_22)

    if t < 5:
        plotmesh(mesh.cells, mesh.points, mps2, title='MPS Reconstructed using FDM', ax=axes[0][t], ec='None'); 


    
    # ground truth
    E = E_hist_dic[t]
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)

    if t < 5:
        plotmesh(mesh.cells, mesh.points, mps, title='MPS from DIC', ax=axes[1][t], ec='None'); 
# F_mean = np.array(F_mean).mean(axis=1)
# F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean = F_mean[:,0,0], F_mean[:,1,1], F_mean[:,0,1], F_mean[:,1,0]

# %% [markdown]
# #### interpolation of FDM

# %%
strains = []
t_hist = np.arange(5)
F_hist_goh = []
for t in t_hist:
    F_noisy=F_with_FDM[t,:,:]
    strains.append(np.array([t*np.ones(len(F)), F_noisy[:,0,0], F_noisy[:,0,1], F_noisy[:,1,0], F_noisy[:,1,1]]))
strains = np.hstack(strains)

# %%
strains.shape
# Out:
# (5, 10580)

# %%
def loss_coords_2_strain(params, X, key):
    params_fwd=[ff_params, params]
    inp, out_gt = X[:,:3], X[:,3:] #inp: x,y,lmb and out_gt=eps_xx, eps_yy
    t = inp[:,2:3]
    out_pr = coords_2_strain_nn(inp, params_fwd)
    out_gt = out_gt/(t+1) #dividing by t+1 just for some regularization
    out_pr = out_pr/(t+1) #dividing by t+1 just for some regularization
    return jnp.mean((out_pr-out_gt)**2)

n_ff = 100 # 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5
nn_layers = [2*n_ff+1,40,40,4]
nn_params = init_params_nn(nn_layers, key)
coord_2_strain_params = nn_params

opt_init, opt_update, get_params = optimizers.adam(5.e-4)
opt_state = opt_init(coord_2_strain_params)

X = np.vstack([elem_X, elem_X, elem_X, elem_X,elem_X])
inp = np.hstack([X, strains.T])
#coord_2_strain_params, train_loss, _ = train(loss_coords_2_strain, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000, batch_size=1000)

# %% [markdown]
# #### plot interpolation and  comparison of $MPS_{gt}$ and $MPS_{NN}$

# %%
coord_2_strain_params=[ff_params, coord_2_strain_params]

# %%
range_minmax=np.zeros((2,))
for t in t_hist:
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps1 = np.maximum(E_11, E_22)
    if t==0:
        range_minmax[0]=np.min(mps1)
        range_minmax[1]=np.max(mps1)
    else:
        range_minmax[0]=np.min(np.array([range_minmax[0],np.min(mps1)]))
        range_minmax[1]=np.max(np.array([range_minmax[1],np.max(mps1)]))

# %%
F_mean = []
fig, axes = plt.subplots(2,5,figsize=(25,8))
for t in t_hist:
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    F_mean.append(F )
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps1 = np.maximum(E_11, E_22)

    #plotmesh(mesh.cells, mesh.points, mps1, title='MPS Reconstructed using NN', ax=axes[0][t],ec='None')
    plotmesh_updated(mesh.cells, mesh.points, mps1, range_minmax[0],range_minmax[1],title='MPS Reconstructed using NN', ax=axes[0][t],ec='None')
    E = E_hist_dic[t]
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)
    
    plotmesh(mesh.cells, mesh.points, mps, title='MPS from DIC', ax=axes[1][t], ec='None'); 

    #plotmesh(mesh.cells, mesh.points,np.lin, title='MPS from DIC', ax=axes[1][t], ec='None'); 
F_mean = np.array(F_mean).mean(axis=1)
F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean = F_mean[:,0,0], F_mean[:,1,1], F_mean[:,0,1], F_mean[:,1,0]

# %%
fig, axes = plt.subplots(1,5,figsize=(25,8))
for t in t_hist:
    aux = np.hstack([elem_X, t*np.ones_like(elem_X[:,:1])])
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(aux, coord_2_strain_params).T
    F = np.stack([F_xx, F_xy, F_yx, F_yy]).T.reshape([-1,2,2])
    
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps1 = np.maximum(E_11, E_22)

    E = E_hist_dic[t]
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    mps = np.maximum(E_11, E_22)
    
    for_error=np.abs(mps-mps1)

    plotmesh(mesh.cells, mesh.points, for_error, title=r'$|mps_{NN}-mps_{DIC}|$', ax=axes[t], ec='None');

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/Experimental_Extra3.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params,t_hist, F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean], f)

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/Experimental_Extra3.npy', 'rb') as f:
    coord_2_strain_params, t_hist, F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean = pickle.load(f)

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %%
def loss_stress(Lambda_params, X, key): # X consists of 5 columns: X, Y, lmb (time), ux, uy.
    t = X[2:3].astype(int)
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(X[:3][None,:], coord_2_strain_params).T
    phi = ff_nn(X[:2][None,:], Lambda_params)
    node_params = merge_c_s_params_iso(common_params, unravel(phi.flatten()))
    
    model = NODE_model_iso(node_params)
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr - P_xx_gt[t])**2 + (P_yy_pr-P_yy_gt[t])**2)
loss_stress_vmap = lambda a, b, c: np.mean(vmap(loss_stress, in_axes=(None,0,None))(a, b, c))

key = random.PRNGKey(10)
n_neurons = 4
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_iso(common_layers, sample_layers, key)
common_params, sample_params = split_c_s_params_iso(node_params)
phi, unravel = ravel_pytree(sample_params)
n_phi = len(phi)


n_ff = 100
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,100,50,50,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)
print("Shape of inp:", inp.shape)
inp2=inp[:7220,:]
Lambda_params, train_loss, _ = train(loss_stress_vmap, inp, get_params, opt_update, opt_state, key, nIter = 10000, print_freq=10, batch_size=10000)
# Out:
# Shape of inp: (10580, 7)
# it 10, train loss = 5.093066e-01
# it 20, train loss = 3.486727e-01
# it 30, train loss = 3.214001e-01
# it 40, train loss = 3.017738e-01
# it 50, train loss = 2.801973e-01
# it 60, train loss = 2.814954e-01
# it 70, train loss = 2.713981e-01
# it 80, train loss = 2.747259e-01
# it 90, train loss = 2.635672e-01
# it 100, train loss = 2.612118e-01
# it 110, train loss = 2.644597e-01
# it 120, train loss = 2.589394e-01
# it 130, train loss = 2.562217e-01
# it 140, train loss = 2.671218e-01
# it 150, train loss = 2.543759e-01
# it 160, train loss = 2.465395e-01
# it 170, train loss = 2.491232e-01
# it 180, train loss = 2.540198e-01
# it 190, train loss = 2.500482e-01
# it 200, train loss = 2.487006e-01
# it 210, train loss = 2.497860e-01
# it 220, train loss = 2.395945e-01
# it 230, train loss = 2.461040e-01
# it 240, train loss = 2.464294e-01
# it 250, train loss = 2.462704e-01
# it 260, train loss = 2.445427e-01
# it 270, train loss = 2.409764e-01
# it 280, train loss = 2.501556e-01
# it 290, train loss = 2.491715e-01
# it 300, train loss = 2.438731e-01
# it 310, train loss = 2.343304e-01
# it 320, train loss = 2.449248e-01
# it 330, train loss = 2.459364e-01
# it 340, train loss = 2.456213e-01
# it 350, train loss = 2.430012e-01
# it 360, train loss = 2.448120e-01
# it 370, train loss = 2.455279e-01
# it 380, train loss = 2.420332e-01
# it 390, train loss = 2.425677e-01
# it 400, train loss = 2.401462e-01
# it 410, train loss = 2.435254e-01
# it 420, train loss = 2.461168e-01
# it 430, train loss = 2.391372e-01
# it 440, train loss = 2.388377e-01
# it 450, train loss = 2.428707e-01
# it 460, train loss = 2.385410e-01
# it 470, train loss = 2.398711e-01
# it 480, train loss = 2.435049e-01
# it 490, train loss = 2.387151e-01
# it 500, train loss = 2.379051e-01
# it 510, train loss = 2.416890e-01
# it 520, train loss = 2.401850e-01
# it 530, train loss = 2.463408e-01
# it 540, train loss = 2.437797e-01
# it 550, train loss = 2.439473e-01
# it 560, train loss = 2.397938e-01
# it 570, train loss = 2.378549e-01
# it 580, train loss = 2.375643e-01
# it 590, train loss = 2.425369e-01
# it 600, train loss = 2.404425e-01
# it 610, train loss = 2.425175e-01
# it 620, train loss = 2.413935e-01
# it 630, train loss = 2.462917e-01
# it 640, train loss = 2.393052e-01
# it 650, train loss = 2.372947e-01
# it 660, train loss = 2.415711e-01
# it 670, train loss = 2.429266e-01
# it 680, train loss = 2.401788e-01
# it 690, train loss = 2.403173e-01
# it 700, train loss = 2.462546e-01
# it 710, train loss = 2.393613e-01
# it 720, train loss = 2.410660e-01
# it 730, train loss = 2.402529e-01
# it 740, train loss = 2.399694e-01
# it 750, train loss = 2.424702e-01
# it 760, train loss = 2.390631e-01
# it 770, train loss = 2.453254e-01
# it 780, train loss = 2.383457e-01
# it 790, train loss = 2.377445e-01
# it 800, train loss = 2.431283e-01
# it 810, train loss = 2.434712e-01
# it 820, train loss = 2.391936e-01
# it 830, train loss = 2.440143e-01
# it 840, train loss = 2.413110e-01
# it 850, train loss = 2.400562e-01
# it 860, train loss = 2.474554e-01
# it 870, train loss = 2.378580e-01
# it 880, train loss = 2.354441e-01
# it 890, train loss = 2.337448e-01
# it 900, train loss = 2.395311e-01
# it 910, train loss = 2.362280e-01
# it 920, train loss = 2.410894e-01
# it 930, train loss = 2.445597e-01
# it 940, train loss = 2.412551e-01
# it 950, train loss = 2.434255e-01
# it 960, train loss = 2.468286e-01
# it 970, train loss = 2.378437e-01
# it 980, train loss = 2.397033e-01
# it 990, train loss = 2.417618e-01
# it 1000, train loss = 2.401208e-01
# it 1010, train loss = 2.414336e-01
# it 1020, train loss = 2.386203e-01
# it 1030, train loss = 2.458383e-01
# it 1040, train loss = 2.436089e-01
# it 1050, train loss = 2.438258e-01
# it 1060, train loss = 2.423171e-01
# it 1070, train loss = 2.425733e-01
# it 1080, train loss = 2.441226e-01
# it 1090, train loss = 2.456560e-01
# it 1100, train loss = 2.401276e-01
# it 1110, train loss = 2.451503e-01
# it 1120, train loss = 2.382263e-01
# it 1130, train loss = 2.439346e-01
# it 1140, train loss = 2.377452e-01
# it 1150, train loss = 2.403037e-01
# it 1160, train loss = 2.407099e-01
# it 1170, train loss = 2.400025e-01
# it 1180, train loss = 2.365760e-01
# it 1190, train loss = 2.417240e-01
# it 1200, train loss = 2.415487e-01
# it 1210, train loss = 2.409909e-01
# it 1220, train loss = 2.402800e-01
# it 1230, train loss = 2.425008e-01
# it 1240, train loss = 2.493293e-01
# it 1250, train loss = 2.450078e-01
# it 1260, train loss = 2.376786e-01
# it 1270, train loss = 2.398172e-01
# it 1280, train loss = 2.390827e-01
# it 1290, train loss = 2.467323e-01
# it 1300, train loss = 2.392823e-01
# it 1310, train loss = 2.409673e-01
# it 1320, train loss = 2.401653e-01
# it 1330, train loss = 2.404048e-01
# it 1340, train loss = 2.379812e-01
# it 1350, train loss = 2.476094e-01
# it 1360, train loss = 2.355548e-01
# it 1370, train loss = 2.374128e-01
# it 1380, train loss = 2.425187e-01
# it 1390, train loss = 2.410425e-01
# it 1400, train loss = 2.428221e-01
# it 1410, train loss = 2.337123e-01
# it 1420, train loss = 2.422730e-01
# it 1430, train loss = 2.357170e-01
# it 1440, train loss = 2.399789e-01
# it 1450, train loss = 2.429615e-01
# it 1460, train loss = 2.429588e-01
# it 1470, train loss = 2.439977e-01
# it 1480, train loss = 2.401284e-01
# it 1490, train loss = 2.396364e-01
# it 1500, train loss = 2.396925e-01
# it 1510, train loss = 2.423158e-01
# it 1520, train loss = 2.468205e-01
# it 1530, train loss = 2.386218e-01
# it 1540, train loss = 2.338868e-01
# it 1550, train loss = 2.405690e-01
# it 1560, train loss = 2.430882e-01
# it 1570, train loss = 2.383972e-01
# it 1580, train loss = 2.399427e-01
# it 1590, train loss = 2.412338e-01
# it 1600, train loss = 2.404037e-01
# it 1610, train loss = 2.414867e-01
# it 1620, train loss = 2.344853e-01
# it 1630, train loss = 2.405653e-01
# it 1640, train loss = 2.346558e-01
# it 1650, train loss = 2.401566e-01
# it 1660, train loss = 2.391549e-01
# it 1670, train loss = 2.356891e-01
# it 1680, train loss = 2.415034e-01
# it 1690, train loss = 2.420204e-01
# it 1700, train loss = 2.330345e-01
# it 1710, train loss = 2.387574e-01
# it 1720, train loss = 2.440446e-01
# it 1730, train loss = 2.373018e-01
# it 1740, train loss = 2.410274e-01
# it 1750, train loss = 2.464476e-01
# it 1760, train loss = 2.410513e-01
# it 1770, train loss = 2.378134e-01
# it 1780, train loss = 2.430790e-01
# it 1790, train loss = 2.360763e-01
# it 1800, train loss = 2.437829e-01
# it 1810, train loss = 2.440617e-01
# it 1820, train loss = 2.351454e-01
# it 1830, train loss = 2.424633e-01
# it 1840, train loss = 2.363752e-01
# it 1850, train loss = 2.393311e-01
# it 1860, train loss = 2.383372e-01
# it 1870, train loss = 2.391156e-01
# it 1880, train loss = 2.402110e-01
# it 1890, train loss = 2.392734e-01
# it 1900, train loss = 2.448644e-01
# it 1910, train loss = 2.386553e-01
# it 1920, train loss = 2.368439e-01
# it 1930, train loss = 2.390620e-01
# it 1940, train loss = 2.376648e-01
# it 1950, train loss = 2.387794e-01
# it 1960, train loss = 2.409680e-01
# it 1970, train loss = 2.388454e-01
# it 1980, train loss = 2.372484e-01
# it 1990, train loss = 2.407521e-01
# it 2000, train loss = 2.439011e-01
# it 2010, train loss = 2.390858e-01
# it 2020, train loss = 2.376262e-01
# it 2030, train loss = 2.376993e-01
# it 2040, train loss = 2.382993e-01
# it 2050, train loss = 2.451170e-01
# it 2060, train loss = 2.432066e-01
# it 2070, train loss = 2.425043e-01
# it 2080, train loss = 2.426221e-01
# it 2090, train loss = 2.370327e-01
# it 2100, train loss = 2.329292e-01
# it 2110, train loss = 2.362133e-01
# it 2120, train loss = 2.360640e-01
# it 2130, train loss = 2.353613e-01
# it 2140, train loss = 2.406525e-01
# it 2150, train loss = 2.409167e-01
# it 2160, train loss = 2.330845e-01
# it 2170, train loss = 2.421121e-01
# it 2180, train loss = 2.357517e-01
# it 2190, train loss = 2.378817e-01
# it 2200, train loss = 2.436345e-01
# it 2210, train loss = 2.450447e-01
# it 2220, train loss = 2.401874e-01
# it 2230, train loss = 2.374754e-01
# it 2240, train loss = 2.374832e-01
# it 2250, train loss = 2.380626e-01
# it 2260, train loss = 2.399390e-01
# it 2270, train loss = 2.476427e-01
# it 2280, train loss = 2.413397e-01
# it 2290, train loss = 2.453124e-01
# it 2300, train loss = 2.424237e-01
# it 2310, train loss = 2.411234e-01
# it 2320, train loss = 2.405699e-01
# it 2330, train loss = 2.430056e-01
# it 2340, train loss = 2.356315e-01
# it 2350, train loss = 2.369130e-01
# it 2360, train loss = 2.479587e-01
# it 2370, train loss = 2.506552e-01
# it 2380, train loss = 2.454903e-01
# it 2390, train loss = 2.379284e-01
# it 2400, train loss = 2.452849e-01
# it 2410, train loss = 2.398401e-01
# it 2420, train loss = 2.368922e-01
# it 2430, train loss = 2.419211e-01
# it 2440, train loss = 2.427415e-01
# it 2450, train loss = 2.466965e-01
# it 2460, train loss = 2.361521e-01
# it 2470, train loss = 2.354590e-01
# it 2480, train loss = 2.409637e-01
# it 2490, train loss = 2.362506e-01
# it 2500, train loss = 2.385951e-01
# it 2510, train loss = 2.386000e-01
# it 2520, train loss = 2.479612e-01
# it 2530, train loss = 2.364629e-01
# it 2540, train loss = 2.396896e-01
# it 2550, train loss = 2.432255e-01
# it 2560, train loss = 2.379346e-01
# it 2570, train loss = 2.387883e-01
# it 2580, train loss = 2.424507e-01
# it 2590, train loss = 2.417240e-01
# it 2600, train loss = 2.369310e-01
# it 2610, train loss = 2.367292e-01
# it 2620, train loss = 2.357138e-01
# it 2630, train loss = 2.397676e-01
# it 2640, train loss = 2.363031e-01
# it 2650, train loss = 2.421161e-01
# it 2660, train loss = 2.368359e-01
# it 2670, train loss = 2.380764e-01
# it 2680, train loss = 2.407486e-01
# it 2690, train loss = 2.362489e-01
# it 2700, train loss = 2.457265e-01
# it 2710, train loss = 2.420175e-01
# it 2720, train loss = 2.384926e-01
# it 2730, train loss = 2.374830e-01
# it 2740, train loss = 2.422473e-01
# it 2750, train loss = 2.337957e-01
# it 2760, train loss = 2.306157e-01
# it 2770, train loss = 2.458170e-01
# it 2780, train loss = 2.355429e-01
# it 2790, train loss = 2.378930e-01
# it 2800, train loss = 2.425073e-01
# it 2810, train loss = 2.431246e-01
# it 2820, train loss = 2.382975e-01
# it 2830, train loss = 2.389199e-01
# it 2840, train loss = 2.377091e-01
# it 2850, train loss = 2.396583e-01
# it 2860, train loss = 2.386190e-01
# it 2870, train loss = 2.408618e-01
# it 2880, train loss = 2.358657e-01
# it 2890, train loss = 2.331388e-01
# it 2900, train loss = 2.364149e-01
# it 2910, train loss = 2.379702e-01
# it 2920, train loss = 2.417499e-01
# it 2930, train loss = 2.449236e-01
# it 2940, train loss = 2.348794e-01
# it 2950, train loss = 2.424388e-01
# it 2960, train loss = 2.389938e-01
# it 2970, train loss = 2.395356e-01
# it 2980, train loss = 2.369448e-01
# it 2990, train loss = 2.397417e-01
# it 3000, train loss = 2.439310e-01
# it 3010, train loss = 2.405703e-01
# it 3020, train loss = 2.393384e-01
# it 3030, train loss = 2.448790e-01
# it 3040, train loss = 2.434931e-01
# it 3050, train loss = 2.407679e-01
# it 3060, train loss = 2.446979e-01
# it 3070, train loss = 2.451685e-01
# it 3080, train loss = 2.352347e-01
# it 3090, train loss = 2.403136e-01
# it 3100, train loss = 2.389973e-01
# it 3110, train loss = 2.398150e-01
# it 3120, train loss = 2.460921e-01
# it 3130, train loss = 2.427461e-01
# it 3140, train loss = 2.369632e-01
# it 3150, train loss = 2.412244e-01
# it 3160, train loss = 2.449342e-01
# it 3170, train loss = 2.404819e-01
# it 3180, train loss = 2.414099e-01
# it 3190, train loss = 2.505502e-01
# it 3200, train loss = 2.421665e-01
# it 3210, train loss = 2.395137e-01
# it 3220, train loss = 2.383574e-01
# it 3230, train loss = 2.371760e-01
# it 3240, train loss = 2.425289e-01
# it 3250, train loss = 2.380593e-01
# it 3260, train loss = 2.443379e-01
# it 3270, train loss = 2.438218e-01
# it 3280, train loss = 2.512766e-01
# it 3290, train loss = 2.456354e-01
# it 3300, train loss = 2.400820e-01
# it 3310, train loss = 2.456603e-01
# it 3320, train loss = 2.363001e-01
# it 3330, train loss = 2.353841e-01
# it 3340, train loss = 2.391831e-01
# it 3350, train loss = 2.424169e-01
# it 3360, train loss = 2.378421e-01
# it 3370, train loss = 2.452915e-01
# it 3380, train loss = 2.464174e-01
# it 3390, train loss = 2.376742e-01
# it 3400, train loss = 2.398267e-01
# it 3410, train loss = 2.461758e-01
# it 3420, train loss = 2.431862e-01
# it 3430, train loss = 2.429052e-01
# it 3440, train loss = 2.371704e-01
# it 3450, train loss = 2.420060e-01
# it 3460, train loss = 2.447417e-01
# it 3470, train loss = 2.445238e-01
# it 3480, train loss = 2.407251e-01
# it 3490, train loss = 2.472409e-01
# it 3500, train loss = 2.368122e-01
# it 3510, train loss = 2.439046e-01
# it 3520, train loss = 2.398528e-01
# it 3530, train loss = 2.374724e-01
# it 3540, train loss = 2.436077e-01
# it 3550, train loss = 2.407059e-01
# it 3560, train loss = 2.414540e-01
# it 3570, train loss = 2.440251e-01
# it 3580, train loss = 2.341792e-01
# it 3590, train loss = 2.406206e-01
# it 3600, train loss = 2.383822e-01
# it 3610, train loss = 2.406458e-01
# it 3620, train loss = 2.412985e-01
# it 3630, train loss = 2.469704e-01
# it 3640, train loss = 2.454490e-01
# it 3650, train loss = 2.402182e-01
# it 3660, train loss = 2.440164e-01
# it 3670, train loss = 2.373598e-01
# it 3680, train loss = 2.391125e-01
# it 3690, train loss = 2.408289e-01
# it 3700, train loss = 2.330463e-01
# it 3710, train loss = 2.400828e-01
# it 3720, train loss = 2.378767e-01
# it 3730, train loss = 2.427303e-01
# it 3740, train loss = 2.367486e-01
# it 3750, train loss = 2.345535e-01
# it 3760, train loss = 2.435611e-01
# it 3770, train loss = 2.446209e-01
# it 3780, train loss = 2.395290e-01
# it 3790, train loss = 2.428521e-01
# it 3800, train loss = 2.440190e-01
# it 3810, train loss = 2.433294e-01
# it 3820, train loss = 2.396005e-01
# it 3830, train loss = 2.423106e-01
# it 3840, train loss = 2.371199e-01
# it 3850, train loss = 2.387314e-01
# it 3860, train loss = 2.373152e-01
# it 3870, train loss = 2.344989e-01
# it 3880, train loss = 2.384740e-01
# it 3890, train loss = 2.400117e-01
# it 3900, train loss = 2.453759e-01
# it 3910, train loss = 2.470993e-01
# it 3920, train loss = 2.469470e-01
# it 3930, train loss = 2.451729e-01
# it 3940, train loss = 2.355174e-01
# it 3950, train loss = 2.423267e-01
# it 3960, train loss = 2.376138e-01
# it 3970, train loss = 2.465904e-01
# it 3980, train loss = 2.410273e-01
# it 3990, train loss = 2.384839e-01
# it 4000, train loss = 2.420545e-01
# it 4010, train loss = 2.395350e-01
# it 4020, train loss = 2.485063e-01
# it 4030, train loss = 2.421440e-01
# it 4040, train loss = 2.465707e-01
# it 4050, train loss = 2.365449e-01
# it 4060, train loss = 2.404908e-01
# it 4070, train loss = 2.370607e-01
# it 4080, train loss = 2.409956e-01
# it 4090, train loss = 2.395012e-01
# it 4100, train loss = 2.395200e-01
# it 4110, train loss = 2.406627e-01
# it 4120, train loss = 2.455753e-01
# it 4130, train loss = 2.463084e-01
# it 4140, train loss = 2.360803e-01
# it 4150, train loss = 2.450216e-01
# it 4160, train loss = 2.392741e-01
# it 4170, train loss = 2.396378e-01
# it 4180, train loss = 2.309254e-01
# it 4190, train loss = 2.399936e-01
# it 4200, train loss = 2.408787e-01
# it 4210, train loss = 2.449252e-01
# it 4220, train loss = 2.467436e-01
# it 4230, train loss = 2.436437e-01
# it 4240, train loss = 2.378744e-01
# it 4250, train loss = 2.431838e-01
# it 4260, train loss = 2.398782e-01
# it 4270, train loss = 2.431809e-01
# it 4280, train loss = 2.405646e-01
# it 4290, train loss = 2.413900e-01
# it 4300, train loss = 2.410118e-01
# it 4310, train loss = 2.345029e-01
# it 4320, train loss = 2.439066e-01
# it 4330, train loss = 2.378738e-01
# it 4340, train loss = 2.488035e-01
# it 4350, train loss = 2.363252e-01
# it 4360, train loss = 2.430702e-01
# it 4370, train loss = 2.429578e-01
# it 4380, train loss = 2.425376e-01
# it 4390, train loss = 2.427951e-01
# it 4400, train loss = 2.347501e-01
# it 4410, train loss = 2.403064e-01
# it 4420, train loss = 2.362400e-01
# it 4430, train loss = 2.365175e-01
# it 4440, train loss = 2.412016e-01
# it 4450, train loss = 2.431762e-01
# it 4460, train loss = 2.458911e-01
# it 4470, train loss = 2.375252e-01
# it 4480, train loss = 2.349417e-01
# it 4490, train loss = 2.362180e-01
# it 4500, train loss = 2.359781e-01
# it 4510, train loss = 2.421182e-01
# it 4520, train loss = 2.376349e-01
# it 4530, train loss = 2.460118e-01
# it 4540, train loss = 2.371034e-01
# it 4550, train loss = 2.324704e-01
# it 4560, train loss = 2.445400e-01
# it 4570, train loss = 2.332778e-01
# it 4580, train loss = 2.405712e-01
# it 4590, train loss = 2.409399e-01
# it 4600, train loss = 2.439987e-01
# it 4610, train loss = 2.392116e-01
# it 4620, train loss = 2.417307e-01
# it 4630, train loss = 2.447329e-01
# it 4640, train loss = 2.408585e-01
# it 4650, train loss = 2.412434e-01
# it 4660, train loss = 2.394094e-01
# it 4670, train loss = 2.334892e-01
# it 4680, train loss = 2.412526e-01
# it 4690, train loss = 2.494320e-01
# it 4700, train loss = 2.398590e-01
# it 4710, train loss = 2.403672e-01
# it 4720, train loss = 2.411525e-01
# it 4730, train loss = 2.341118e-01
# it 4740, train loss = 2.452668e-01
# it 4750, train loss = 2.446858e-01
# it 4760, train loss = 2.415726e-01
# it 4770, train loss = 2.390369e-01
# it 4780, train loss = 2.332152e-01
# it 4790, train loss = 2.394911e-01
# it 4800, train loss = 2.355561e-01
# it 4810, train loss = 2.448123e-01
# it 4820, train loss = 2.415758e-01
# it 4830, train loss = 2.395914e-01
# it 4840, train loss = 2.413770e-01
# it 4850, train loss = 2.430847e-01
# it 4860, train loss = 2.441936e-01
# it 4870, train loss = 2.418143e-01
# it 4880, train loss = 2.401090e-01
# it 4890, train loss = 2.409499e-01
# it 4900, train loss = 2.383959e-01
# it 4910, train loss = 2.471196e-01
# it 4920, train loss = 2.406326e-01
# it 4930, train loss = 2.428902e-01
# it 4940, train loss = 2.430004e-01
# it 4950, train loss = 2.491871e-01
# it 4960, train loss = 2.425252e-01
# it 4970, train loss = 2.411447e-01
# it 4980, train loss = 2.380616e-01
# it 4990, train loss = 2.469978e-01
# it 5000, train loss = 2.386012e-01
# it 5010, train loss = 2.392898e-01
# it 5020, train loss = 2.421937e-01
# it 5030, train loss = 2.407256e-01
# it 5040, train loss = 2.437101e-01
# it 5050, train loss = 2.438148e-01
# it 5060, train loss = 2.406041e-01
# it 5070, train loss = 2.355734e-01
# it 5080, train loss = 2.407783e-01
# it 5090, train loss = 2.370117e-01
# it 5100, train loss = 2.391206e-01
# it 5110, train loss = 2.403791e-01
# it 5120, train loss = 2.369657e-01
# it 5130, train loss = 2.421841e-01
# it 5140, train loss = 2.409538e-01
# it 5150, train loss = 2.369800e-01
# it 5160, train loss = 2.439283e-01
# it 5170, train loss = 2.465881e-01
# it 5180, train loss = 2.387944e-01
# it 5190, train loss = 2.426692e-01
# it 5200, train loss = 2.402712e-01
# it 5210, train loss = 2.413044e-01
# it 5220, train loss = 2.481899e-01
# it 5230, train loss = 2.370398e-01
# it 5240, train loss = 2.379726e-01
# it 5250, train loss = 2.329087e-01
# it 5260, train loss = 2.447268e-01
# it 5270, train loss = 2.402163e-01
# it 5280, train loss = 2.378551e-01
# it 5290, train loss = 2.372164e-01
# it 5300, train loss = 2.435224e-01
# it 5310, train loss = 2.385379e-01
# it 5320, train loss = 2.473081e-01
# it 5330, train loss = 2.396630e-01
# it 5340, train loss = 2.390937e-01
# it 5350, train loss = 2.393269e-01
# it 5360, train loss = 2.389381e-01
# it 5370, train loss = 2.339017e-01
# it 5380, train loss = 2.405534e-01
# it 5390, train loss = 2.421018e-01
# it 5400, train loss = 2.424637e-01
# it 5410, train loss = 2.371085e-01
# it 5420, train loss = 2.328177e-01
# it 5430, train loss = 2.355209e-01
# it 5440, train loss = 2.401229e-01
# it 5450, train loss = 2.418479e-01
# it 5460, train loss = 2.425370e-01
# it 5470, train loss = 2.465925e-01
# it 5480, train loss = 2.402494e-01
# it 5490, train loss = 2.432618e-01
# it 5500, train loss = 2.381519e-01
# it 5510, train loss = 2.431473e-01
# it 5520, train loss = 2.440542e-01
# it 5530, train loss = 2.389076e-01
# it 5540, train loss = 2.462002e-01
# it 5550, train loss = 2.413397e-01
# it 5560, train loss = 2.379869e-01
# it 5570, train loss = 2.373126e-01
# it 5580, train loss = 2.361907e-01
# it 5590, train loss = 2.390585e-01
# it 5600, train loss = 2.357299e-01
# it 5610, train loss = 2.366712e-01
# it 5620, train loss = 2.419584e-01
# it 5630, train loss = 2.349860e-01
# it 5640, train loss = 2.349453e-01
# it 5650, train loss = 2.381877e-01
# it 5660, train loss = 2.383743e-01
# it 5670, train loss = 2.383532e-01
# it 5680, train loss = 2.449576e-01
# it 5690, train loss = 2.439012e-01
# it 5700, train loss = 2.351430e-01
# it 5710, train loss = 2.352964e-01
# it 5720, train loss = 2.417614e-01
# it 5730, train loss = 2.408372e-01
# it 5740, train loss = 2.343237e-01
# it 5750, train loss = 2.376390e-01
# it 5760, train loss = 2.416752e-01
# it 5770, train loss = 2.392605e-01
# it 5780, train loss = 2.384471e-01
# it 5790, train loss = 2.427500e-01
# it 5800, train loss = 2.400598e-01
# it 5810, train loss = 2.404833e-01
# it 5820, train loss = 2.431213e-01
# it 5830, train loss = 2.440251e-01
# it 5840, train loss = 2.494065e-01
# it 5850, train loss = 2.423497e-01
# it 5860, train loss = 2.360317e-01
# it 5870, train loss = 2.425169e-01
# it 5880, train loss = 2.459533e-01
# it 5890, train loss = 2.445100e-01
# it 5900, train loss = 2.379444e-01
# it 5910, train loss = 2.374468e-01
# it 5920, train loss = 2.363308e-01
# it 5930, train loss = 2.441413e-01
# it 5940, train loss = 2.372640e-01
# it 5950, train loss = 2.416301e-01
# it 5960, train loss = 2.360580e-01
# it 5970, train loss = 2.359698e-01
# it 5980, train loss = 2.413671e-01
# it 5990, train loss = 2.362594e-01
# it 6000, train loss = 2.425376e-01
# it 6010, train loss = 2.386010e-01
# it 6020, train loss = 2.429719e-01
# it 6030, train loss = 2.419610e-01
# it 6040, train loss = 2.471422e-01
# it 6050, train loss = 2.383611e-01
# it 6060, train loss = 2.475766e-01
# it 6070, train loss = 2.390372e-01
# it 6080, train loss = 2.469804e-01
# it 6090, train loss = 2.397973e-01
# it 6100, train loss = 2.386571e-01
# it 6110, train loss = 2.354158e-01
# it 6120, train loss = 2.367773e-01
# it 6130, train loss = 2.348165e-01
# it 6140, train loss = 2.355848e-01
# it 6150, train loss = 2.388721e-01
# it 6160, train loss = 2.456628e-01
# it 6170, train loss = 2.407335e-01
# it 6180, train loss = 2.395440e-01
# it 6190, train loss = 2.403315e-01
# it 6200, train loss = 2.408425e-01
# it 6210, train loss = 2.432658e-01
# it 6220, train loss = 2.410366e-01
# it 6230, train loss = 2.396476e-01
# it 6240, train loss = 2.414835e-01
# it 6250, train loss = 2.399226e-01
# it 6260, train loss = 2.346619e-01
# it 6270, train loss = 2.474428e-01
# it 6280, train loss = 2.347562e-01
# it 6290, train loss = 2.445530e-01
# it 6300, train loss = 2.390300e-01
# it 6310, train loss = 2.360465e-01
# it 6320, train loss = 2.442403e-01
# it 6330, train loss = 2.378957e-01
# it 6340, train loss = 2.348790e-01
# it 6350, train loss = 2.355727e-01
# it 6360, train loss = 2.420126e-01
# it 6370, train loss = 2.387059e-01
# it 6380, train loss = 2.409039e-01
# it 6390, train loss = 2.333735e-01
# it 6400, train loss = 2.421435e-01
# it 6410, train loss = 2.453926e-01
# it 6420, train loss = 2.448199e-01
# it 6430, train loss = 2.348088e-01
# it 6440, train loss = 2.405991e-01
# it 6450, train loss = 2.486186e-01
# it 6460, train loss = 2.373723e-01
# it 6470, train loss = 2.368092e-01
# it 6480, train loss = 2.366140e-01
# it 6490, train loss = 2.426265e-01
# it 6500, train loss = 2.410782e-01
# it 6510, train loss = 2.359437e-01
# it 6520, train loss = 2.475761e-01
# it 6530, train loss = 2.412594e-01
# it 6540, train loss = 2.501862e-01
# it 6550, train loss = 2.467048e-01
# it 6560, train loss = 2.438346e-01
# it 6570, train loss = 2.415911e-01
# it 6580, train loss = 2.378261e-01
# it 6590, train loss = 2.399651e-01
# it 6600, train loss = 2.434004e-01
# it 6610, train loss = 2.388077e-01
# it 6620, train loss = 2.369744e-01
# it 6630, train loss = 2.367463e-01
# it 6640, train loss = 2.421875e-01
# it 6650, train loss = 2.418861e-01
# it 6660, train loss = 2.403368e-01
# it 6670, train loss = 2.425705e-01
# it 6680, train loss = 2.341606e-01
# it 6690, train loss = 2.462345e-01
# it 6700, train loss = 2.420051e-01
# it 6710, train loss = 2.419252e-01
# it 6720, train loss = 2.405931e-01
# it 6730, train loss = 2.430014e-01
# it 6740, train loss = 2.449579e-01
# it 6750, train loss = 2.372172e-01
# it 6760, train loss = 2.376519e-01
# it 6770, train loss = 2.376391e-01
# it 6780, train loss = 2.374715e-01
# it 6790, train loss = 2.435774e-01
# it 6800, train loss = 2.376876e-01
# it 6810, train loss = 2.413167e-01
# it 6820, train loss = 2.436836e-01
# it 6830, train loss = 2.426805e-01
# it 6840, train loss = 2.408309e-01
# it 6850, train loss = 2.438732e-01
# it 6860, train loss = 2.426341e-01
# it 6870, train loss = 2.401423e-01
# it 6880, train loss = 2.446441e-01
# it 6890, train loss = 2.344631e-01
# it 6900, train loss = 2.306651e-01
# it 6910, train loss = 2.402347e-01
# it 6920, train loss = 2.364808e-01
# it 6930, train loss = 2.489557e-01
# it 6940, train loss = 2.423587e-01
# it 6950, train loss = 2.313543e-01
# it 6960, train loss = 2.392800e-01
# it 6970, train loss = 2.412965e-01
# it 6980, train loss = 2.422138e-01
# it 6990, train loss = 2.395375e-01
# it 7000, train loss = 2.372630e-01
# it 7010, train loss = 2.340236e-01
# it 7020, train loss = 2.446030e-01
# it 7030, train loss = 2.443074e-01
# it 7040, train loss = 2.368844e-01
# it 7050, train loss = 2.396280e-01
# it 7060, train loss = 2.381064e-01
# it 7070, train loss = 2.393722e-01
# it 7080, train loss = 2.373672e-01
# it 7090, train loss = 2.450735e-01
# it 7100, train loss = 2.474642e-01
# it 7110, train loss = 2.447700e-01
# it 7120, train loss = 2.386445e-01
# it 7130, train loss = 2.410073e-01
# it 7140, train loss = 2.391988e-01
# it 7150, train loss = 2.441667e-01
# it 7160, train loss = 2.320560e-01
# it 7170, train loss = 2.411262e-01
# it 7180, train loss = 2.390495e-01
# it 7190, train loss = 2.450017e-01
# it 7200, train loss = 2.430115e-01
# it 7210, train loss = 2.384741e-01
# it 7220, train loss = 2.390823e-01
# it 7230, train loss = 2.358277e-01
# it 7240, train loss = 2.370662e-01
# it 7250, train loss = 2.405839e-01
# it 7260, train loss = 2.458072e-01
# it 7270, train loss = 2.464285e-01
# it 7280, train loss = 2.439118e-01
# it 7290, train loss = 2.421251e-01
# it 7300, train loss = 2.375330e-01
# it 7310, train loss = 2.396581e-01
# it 7320, train loss = 2.369869e-01
# it 7330, train loss = 2.365525e-01
# it 7340, train loss = 2.387306e-01
# it 7350, train loss = 2.341273e-01
# it 7360, train loss = 2.413917e-01
# it 7370, train loss = 2.383500e-01
# it 7380, train loss = 2.355295e-01
# it 7390, train loss = 2.407925e-01
# it 7400, train loss = 2.400187e-01
# it 7410, train loss = 2.395944e-01
# it 7420, train loss = 2.397414e-01
# it 7430, train loss = 2.345517e-01
# it 7440, train loss = 2.407348e-01
# it 7450, train loss = 2.400242e-01
# it 7460, train loss = 2.380910e-01
# it 7470, train loss = 2.413886e-01
# it 7480, train loss = 2.371354e-01
# it 7490, train loss = 2.381926e-01
# it 7500, train loss = 2.436788e-01
# it 7510, train loss = 2.371924e-01
# it 7520, train loss = 2.383265e-01
# it 7530, train loss = 2.397407e-01
# it 7540, train loss = 2.365099e-01
# it 7550, train loss = 2.413283e-01
# it 7560, train loss = 2.348990e-01
# it 7570, train loss = 2.344835e-01
# it 7580, train loss = 2.319926e-01
# it 7590, train loss = 2.425323e-01
# it 7600, train loss = 2.465540e-01
# it 7610, train loss = 2.436366e-01
# it 7620, train loss = 2.369274e-01
# it 7630, train loss = 2.421361e-01
# it 7640, train loss = 2.350751e-01
# it 7650, train loss = 2.450639e-01
# it 7660, train loss = 2.448008e-01
# it 7670, train loss = 2.433090e-01
# it 7680, train loss = 2.387364e-01
# it 7690, train loss = 2.367037e-01
# it 7700, train loss = 2.432529e-01
# it 7710, train loss = 2.429889e-01
# it 7720, train loss = 2.396593e-01
# it 7730, train loss = 2.423262e-01
# it 7740, train loss = 2.350456e-01
# it 7750, train loss = 2.405658e-01
# it 7760, train loss = 2.386095e-01
# it 7770, train loss = 2.365915e-01
# it 7780, train loss = 2.369698e-01
# it 7790, train loss = 2.431488e-01
# it 7800, train loss = 2.375385e-01
# it 7810, train loss = 2.426906e-01
# it 7820, train loss = 2.382137e-01
# it 7830, train loss = 2.370686e-01
# it 7840, train loss = 2.362727e-01
# it 7850, train loss = 2.416197e-01
# it 7860, train loss = 2.366386e-01
# it 7870, train loss = 2.423465e-01
# it 7880, train loss = 2.373241e-01
# it 7890, train loss = 2.337975e-01
# it 7900, train loss = 2.433158e-01
# it 7910, train loss = 2.478621e-01
# it 7920, train loss = 2.364201e-01
# it 7930, train loss = 2.449131e-01
# it 7940, train loss = 2.366987e-01
# it 7950, train loss = 2.335527e-01
# it 7960, train loss = 2.489746e-01
# it 7970, train loss = 2.425784e-01
# it 7980, train loss = 2.435957e-01
# it 7990, train loss = 2.393052e-01
# it 8000, train loss = 2.389451e-01
# it 8010, train loss = 2.341424e-01
# it 8020, train loss = 2.382680e-01
# it 8030, train loss = 2.400413e-01
# it 8040, train loss = 2.468888e-01
# it 8050, train loss = 2.442469e-01
# it 8060, train loss = 2.347691e-01
# it 8070, train loss = 2.404822e-01
# it 8080, train loss = 2.412594e-01
# it 8090, train loss = 2.418726e-01
# it 8100, train loss = 2.472246e-01
# it 8110, train loss = 2.425778e-01
# it 8120, train loss = 2.342848e-01
# it 8130, train loss = 2.407375e-01
# it 8140, train loss = 2.344211e-01
# it 8150, train loss = 2.395850e-01
# it 8160, train loss = 2.400878e-01
# it 8170, train loss = 2.383438e-01
# it 8180, train loss = 2.424589e-01
# it 8190, train loss = 2.365837e-01
# it 8200, train loss = 2.422025e-01
# it 8210, train loss = 2.421495e-01
# it 8220, train loss = 2.411310e-01
# it 8230, train loss = 2.417365e-01
# it 8240, train loss = 2.445599e-01
# it 8250, train loss = 2.488842e-01
# it 8260, train loss = 2.397625e-01
# it 8270, train loss = 2.354459e-01
# it 8280, train loss = 2.425684e-01
# it 8290, train loss = 2.464489e-01
# it 8300, train loss = 2.318305e-01
# it 8310, train loss = 2.458153e-01
# it 8320, train loss = 2.329271e-01
# it 8330, train loss = 2.524517e-01
# it 8340, train loss = 2.407921e-01
# it 8350, train loss = 2.394510e-01
# it 8360, train loss = 2.390401e-01
# it 8370, train loss = 2.385137e-01
# it 8380, train loss = 2.439416e-01
# it 8390, train loss = 2.492344e-01
# it 8400, train loss = 2.377293e-01
# it 8410, train loss = 2.359792e-01
# it 8420, train loss = 2.362714e-01
# it 8430, train loss = 2.402921e-01
# it 8440, train loss = 2.472309e-01
# it 8450, train loss = 2.398933e-01
# it 8460, train loss = 2.398061e-01
# it 8470, train loss = 2.401291e-01
# it 8480, train loss = 2.418618e-01
# it 8490, train loss = 2.393023e-01
# it 8500, train loss = 2.480399e-01
# it 8510, train loss = 2.447812e-01
# it 8520, train loss = 2.452467e-01
# it 8530, train loss = 2.468913e-01
# it 8540, train loss = 2.426828e-01
# it 8550, train loss = 2.346845e-01
# it 8560, train loss = 2.425723e-01
# it 8570, train loss = 2.420317e-01
# it 8580, train loss = 2.384670e-01
# it 8590, train loss = 2.355366e-01
# it 8600, train loss = 2.379069e-01
# it 8610, train loss = 2.407943e-01
# it 8620, train loss = 2.426831e-01
# it 8630, train loss = 2.370206e-01
# it 8640, train loss = 2.389975e-01
# it 8650, train loss = 2.448891e-01
# it 8660, train loss = 2.447259e-01
# it 8670, train loss = 2.470351e-01
# it 8680, train loss = 2.447673e-01
# it 8690, train loss = 2.433672e-01
# it 8700, train loss = 2.339637e-01
# it 8710, train loss = 2.406863e-01
# it 8720, train loss = 2.456508e-01
# it 8730, train loss = 2.392303e-01
# it 8740, train loss = 2.395988e-01
# it 8750, train loss = 2.362550e-01
# it 8760, train loss = 2.397737e-01
# it 8770, train loss = 2.369275e-01
# it 8780, train loss = 2.437330e-01
# it 8790, train loss = 2.443462e-01
# it 8800, train loss = 2.321096e-01
# it 8810, train loss = 2.397241e-01
# it 8820, train loss = 2.366584e-01
# it 8830, train loss = 2.412046e-01
# it 8840, train loss = 2.403692e-01
# it 8850, train loss = 2.401993e-01
# it 8860, train loss = 2.408715e-01
# it 8870, train loss = 2.419878e-01
# it 8880, train loss = 2.399529e-01
# it 8890, train loss = 2.465727e-01
# it 8900, train loss = 2.442660e-01
# it 8910, train loss = 2.409976e-01
# it 8920, train loss = 2.390948e-01
# it 8930, train loss = 2.401687e-01
# it 8940, train loss = 2.479982e-01
# it 8950, train loss = 2.359058e-01
# it 8960, train loss = 2.379068e-01
# it 8970, train loss = 2.360251e-01
# it 8980, train loss = 2.404051e-01
# it 8990, train loss = 2.367286e-01
# it 9000, train loss = 2.353173e-01
# it 9010, train loss = 2.434455e-01
# it 9020, train loss = 2.414301e-01
# it 9030, train loss = 2.457477e-01
# it 9040, train loss = 2.415524e-01
# it 9050, train loss = 2.369941e-01
# it 9060, train loss = 2.407360e-01
# it 9070, train loss = 2.390852e-01
# it 9080, train loss = 2.378518e-01
# it 9090, train loss = 2.398690e-01
# it 9100, train loss = 2.394776e-01
# it 9110, train loss = 2.412361e-01
# it 9120, train loss = 2.417762e-01
# it 9130, train loss = 2.410584e-01
# it 9140, train loss = 2.428195e-01
# it 9150, train loss = 2.461125e-01
# it 9160, train loss = 2.335412e-01
# it 9170, train loss = 2.407403e-01
# it 9180, train loss = 2.463186e-01
# it 9190, train loss = 2.371224e-01
# it 9200, train loss = 2.483751e-01
# it 9210, train loss = 2.404861e-01
# it 9220, train loss = 2.386195e-01
# it 9230, train loss = 2.462943e-01
# it 9240, train loss = 2.396891e-01
# it 9250, train loss = 2.432974e-01
# it 9260, train loss = 2.441701e-01
# it 9270, train loss = 2.402552e-01
# it 9280, train loss = 2.421574e-01
# it 9290, train loss = 2.382769e-01
# it 9300, train loss = 2.346775e-01
# it 9310, train loss = 2.431996e-01
# it 9320, train loss = 2.401412e-01
# it 9330, train loss = 2.424667e-01
# it 9340, train loss = 2.425386e-01
# it 9350, train loss = 2.324446e-01
# it 9360, train loss = 2.402442e-01
# it 9370, train loss = 2.356605e-01
# it 9380, train loss = 2.384823e-01
# it 9390, train loss = 2.331434e-01
# it 9400, train loss = 2.390806e-01
# it 9410, train loss = 2.373907e-01
# it 9420, train loss = 2.404180e-01
# it 9430, train loss = 2.475537e-01
# it 9440, train loss = 2.365922e-01
# it 9450, train loss = 2.453378e-01
# it 9460, train loss = 2.421048e-01
# it 9470, train loss = 2.496876e-01
# it 9480, train loss = 2.355424e-01
# it 9490, train loss = 2.421894e-01
# it 9500, train loss = 2.420582e-01
# it 9510, train loss = 2.405972e-01
# it 9520, train loss = 2.422131e-01
# it 9530, train loss = 2.382989e-01
# it 9540, train loss = 2.462429e-01
# it 9550, train loss = 2.417985e-01
# it 9560, train loss = 2.461543e-01
# it 9570, train loss = 2.365460e-01
# it 9580, train loss = 2.443670e-01
# it 9590, train loss = 2.422618e-01
# it 9600, train loss = 2.394090e-01
# it 9610, train loss = 2.409762e-01
# it 9620, train loss = 2.459412e-01
# it 9630, train loss = 2.361707e-01
# it 9640, train loss = 2.416689e-01
# it 9650, train loss = 2.446653e-01
# it 9660, train loss = 2.437922e-01
# it 9670, train loss = 2.430603e-01
# it 9680, train loss = 2.402194e-01
# it 9690, train loss = 2.380612e-01
# it 9700, train loss = 2.398656e-01
# it 9710, train loss = 2.366270e-01
# it 9720, train loss = 2.388242e-01
# it 9730, train loss = 2.413301e-01
# it 9740, train loss = 2.453726e-01
# it 9750, train loss = 2.395261e-01
# it 9760, train loss = 2.370473e-01
# it 9770, train loss = 2.430127e-01
# it 9780, train loss = 2.388045e-01
# it 9790, train loss = 2.386675e-01
# it 9800, train loss = 2.420191e-01
# it 9810, train loss = 2.441375e-01
# it 9820, train loss = 2.424395e-01
# it 9830, train loss = 2.390188e-01
# it 9840, train loss = 2.414543e-01
# it 9850, train loss = 2.371510e-01
# it 9860, train loss = 2.457924e-01
# it 9870, train loss = 2.420135e-01
# it 9880, train loss = 2.374975e-01
# it 9890, train loss = 2.430559e-01
# it 9900, train loss = 2.440248e-01
# it 9910, train loss = 2.428179e-01
# it 9920, train loss = 2.350461e-01
# it 9930, train loss = 2.417160e-01
# it 9940, train loss = 2.384201e-01
# it 9950, train loss = 2.323174e-01
# it 9960, train loss = 2.483176e-01
# it 9970, train loss = 2.353316e-01
# it 9980, train loss = 2.416475e-01
# it 9990, train loss = 2.389737e-01
# it 10000, train loss = 2.433318e-01

# %%
NODE_w_unravel = lambda params: NODE_model_iso(merge_c_s_params_iso(common_params, unravel(params)))

# Stiffness across the domain
fig, axes = plt.subplots(1,4,figsize=(20,4))

for F_xx, F_yy, F_xy, F_yx, ax in zip(F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean, axes.T):
    F = np.array([[F_xx, F_xy],
                  [F_yx, F_yy]])
    ugrad = F - np.eye(2)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_pr = []
    for params_pr_i in params_pr:
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[1,1])
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at $F_{yy}=$' + str(F_yy), ax=ax, ec='None');

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_extra3_pre.npy', 'wb') as f:
    pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, P_xx_gt, P_yy_gt,
                 bd_X, t_hist, disps_x_mean, disps_x_stdv, disps_y_mean, disps_y_stdv, Nx, Ny], f)

# %% [markdown]
# ## 2. Retrain

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_extra3_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, P_xx_gt, P_yy_gt, \
                 bd_X, t_hist, disps_x_mean, disps_x_stdv, disps_y_mean, disps_y_stdv, Nx, Ny = pickle.load(f)

common_params, sample_params = split_c_s_params_iso(node_params)
_, unravel = ravel_pytree(sample_params)
NODE_w_unravel = lambda params: NODE_model_iso(merge_c_s_params_iso(common_params, unravel(params)))

# %%
# with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_stiff2_pre_for_cluster.npy', 'wb') as f:
#     pickle.dump([coord_2_strain_params, node_params, Lambda_params, mesh.points, elem_X, P_xx_gt, P_yy_gt,
#                  bd_X, t_hist, disps_x_mean, disps_x_stdv, disps_y_mean, disps_y_stdv, Nx, Ny], f)

# %%
# Train
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_extra3_pre.npy', 'rb') as f:
    coord_2_strain_params, node_params, Lambda_params, mesh, elem_X, P_xx_gt, P_yy_gt, \
                 bd_X, t_hist, disps_x_mean, disps_x_stdv, disps_y_mean, disps_y_stdv, Nx, Ny = pickle.load(f)
def get_P(X, Y, t, Lambda_params, coord_2_strain_params, model):
    F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

get_Pxx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P(X, Y, t, a, b, c)[3]

Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)

@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc
@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y
a1 = 1.0
a2 = 1.0
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        P_rgt, P_top, P_lft, P_bot = F_rgt/Ny, F_top/Nx, F_lft/Ny, F_bot/Nx
        Px = P_xx_gt[jnp.array(t, int)]
        Py = P_yy_gt[jnp.array(t, int)]
        return None, a2*((P_rgt-Px)**2 + (P_top-Py)**2 + (P_lft-Px)**2 + (P_bot-Py)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

# lr = 1e-4
lr = optimizers.exponential_decay(1e-5, 5000, 0.9)
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 10000, print_freq=1000, batch_size=1000)
# Out:
# it 1, val loss = 5.426145e-01
# it 1001, val loss = 1.554670e-01
# it 2001, val loss = 9.332217e-02
# it 3001, val loss = 7.502026e-02

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_extra3_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, P_xx_gt, P_yy_gt, node_params, Lambda_params, val_loss, metrics, t_hist, F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean], f)

# %%
plt.plot(np.log(val_loss))

# %% [markdown]
# ## 3. Test

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/AM_extra3_post.npy', 'rb') as f:
    mesh, elem_X, P_xx_gt, P_yy_gt, node_params, Lambda_params, val_loss, metrics, t_hist, F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean= pickle.load(f)
common_params, sample_params = split_c_s_params_iso(node_params)
_, unravel = ravel_pytree(sample_params)
NODE_w_unravel = lambda params: NODE_model_iso(merge_c_s_params_iso(common_params, unravel(params)))

# %%
cell_type = get_meshio_cell_type('QUAD4')
Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh2 = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
elem_X = mesh2.points[mesh2.cells].mean(axis=1)

# %%
# Stiffness across the domain
fig, axes = plt.subplots(1,4,figsize=(20,8))
lmb_hist = [1.01929, 1.02728, 1.03531, 1.0433 , 1.05132]

extents = [[0.018, 0.021],
           [0.07, 0.08],
           [0.115, 0.13],
           [0.155, 0.17]]
for F_xx, F_yy, F_xy, F_yx, ax, extent in zip(F_xx_mean, F_yy_mean, F_xy_mean, F_yx_mean, axes.T, extents):
    F = np.array([[F_xx, F_xy],
                  [F_yx, F_yy]])
    ugrad = F - np.eye(2)

    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_pr = []
    for params_pr_i in params_pr:
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[1,1])
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at $F_{yy}=$' + str(F_yy), ax=ax, ec='None'); 


# p1 = np.array([[0.50, 0.37]])
# p2 = np.array([[0.85, 0.60]])
# axes[1,3].plot(p1[:,0], p1[:,1], 'ro')
# axes[1,3].plot(p2[:,0], p2[:,1], 'ro')

# %%
p1 = np.array([[0.3, 0.4]])
p2 = np.array([[0.9, 0.4]])
with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/soft_homo.npy', 'rb') as f:
    x,y,F_hist_mtrx,_,force_mtrx = pickle.load(f)
F_hist_mtrx = F_hist_mtrx.mean(axis=1)

with open('/home/amir/inverse_prob/params_for_noise_tuning/manu/stiff2_homo.npy', 'rb') as f:
    x,y,F_hist_incl,_,force_incl = pickle.load(f)
F_hist_incl = F_hist_incl.mean(axis=1)

fig, ax = plt.subplots()
ax.plot(F_hist_mtrx[:,1,1], force_mtrx, label='Matrix (gt)',color='red')
ax.plot(F_hist_incl[:,1,1], force_incl, label='Inclusion (gt)',color='magenta')
# ax.set(xlabel='$F_{xx}$ [-]', ylabel='Force [N]')
ax.set_xlabel(r'$F_{xX}$',fontsize=15)
ax.set_ylabel(r'Force [N]',fontsize=15)
ax.legend(); 


p1_data = []
p2_data = []
# for F_xx, F_xy, F_yx, F_yy in zip(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean):
for F in F_hist_mtrx:
    F_xx, F_xy, F_yx, F_yy = F[0,0], F[0,1], F[1,0], F[1,1]
    F = np.array([[F_xx, F_xy],
                  [F_yx, F_yy]])
    ugrad = F - np.eye(2)

    params_p1 = ff_nn(p1, Lambda_params)[0]
    p1_data.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_p1, 2)[1,1])

    params_p2 = ff_nn(p2, Lambda_params)[0]
    p2_data.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_p2, 2)[1,1])


fig.gca().set_prop_cycle(None)
ax.plot(F_hist_mtrx[:,1,1], p2_data, '--', label='Matrix (pr)',color='green')
ax.plot(F_hist_mtrx[:,1,1], p1_data, '--', label='Inclusion (pr)',color='lime')
ax.tick_params(axis='both', labelsize=14)
ax.legend()
