# %%
import os
n_cores = 4
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count={}'.format(n_cores)

from jax import config
config.update("jax_enable_x64", True)

import jax
import jax.numpy as jnp
import numpy as np
import pickle
from jax import jit, vmap, grad, jacrev
from jax.lax import cond, scan
import jax.random as random
key = random.PRNGKey(2022)
import jax.example_libraries.optimizers as optimizers
from jax.flatten_util import ravel_pytree
from jax.sharding import PositionalSharding
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd
from utils import coords_2_strain_nn_vmap
from utils import train, coords_2_strain_nn, siren_fpass
from utils import train_colloc_parallel as train_colloc, init_params_nn, init_params_siren, ff_nn, divergence, bd_forces, a1, a2, lr
from utils_hyperelasticity import NODE, init_layers, NODE_model_aniso, init_params_aniso, GOH_model, eval_Cauchy, eval_Cauchy_vmap, eval_P, eval_P_vmap
from utils_hyperelasticity import ThreeDElasticity
from fem import plotmesh, plotmesh_updated, fe_solver_2D, vahid_anisohyper_inv, apply_bc_biax

from jax_fem.core import FEM
from jax_fem.solver import solver
from jax_fem.utils import save_sol
from jax_fem.generate_mesh import box_mesh, get_meshio_cell_type, Mesh, rectangle_mesh

from PIL import Image, ImageFilter
from jaxinterp2d import interp2d

E_fun = vmap(lambda F: 0.5*(F.T@F - jnp.eye(2)))

# %% [markdown]
# ## 1. Generate data + pretraining

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)
Nx, Ny = 100, 100
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])
image = Image.open('/home/amir/inverse_prob/O.png')
# image = image.filter(ImageFilter.GaussianBlur(radius=60))
plt.imshow(image)
image = image.rotate(-90)
image = np.array(image)
image = image.mean(axis=2)
image = image/image.max()

pts_x = np.linspace(0,1,image.shape[0])
pts_y = np.linspace(0,1,image.shape[1])

def coords_2_params_gt(xy):
    x, y = xy
    c = interp2d(x,y,pts_x,pts_y,image)
    return jnp.stack([0.5,0.10,0.20,0.1,0.0]) + c*jnp.stack([0.2,0.02,0.04,0.0,0.0])

# %%
GOH_P_vmap = vmap(ThreeDElasticity(GOH_model).ugrad_2_P, in_axes=(0, 0, None))
class HyperElasticity(FEM):
    def get_tensor_map(self):
        return lambda u_grad, params: ThreeDElasticity(GOH_model).ugrad_2_P(u_grad, params, self.dim)
    
    def set_params(self, params_vec):
        self.internal_vars['laplace'] = [params_vec]

# %%
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])

# Functions to identify the boundary nodes
def bottom(point):
    return jnp.isclose(point[1], 0., atol=1e-5)
def left(point):
    return jnp.isclose(point[0], 0., atol=1e-5)
def top(point):
    return jnp.isclose(point[1], Ly, atol=1e-5)
def right(point):
    return jnp.isclose(point[0], Lx, atol=1e-5)
def bottom_left(point):
    return jnp.logical_and(jnp.logical_and(bottom(point), left(point)), jnp.isclose(point[2], 0., atol=1e-5))


# Functions to assign dirichlet BCs
def zero_dirichlet(point):
    return 0.
def lmbx_max_dirichlet(point, lmbx_max):
    return Lx*lmbx_max - 1.0
def lmby_max_dirichlet(point, lmby_max):
    return Ly*lmby_max - 1.0


lmb_hist = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_elem = Nx*Ny
u_hist_goh=[]
F_hist_goh_gt = []
P_hist_goh_gt = []
for lmb_max in lmb_hist:
    # dirichlet_bc_info = [
    #     [bottom,            top],
    #     [1,                 1 ],
    #     [zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max)]
    # ]
    # dirichlet_bc_info = [
    #     [left, right],
    #     [0, 0],
    #     [zero_dirichlet,lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    dirichlet_bc_info = [
        [bottom,            left,           top,                                        right,                                  ],
        [1,                 0,              1,                                          0,                                      ],
        [zero_dirichlet,    zero_dirichlet, lambda p: lmby_max_dirichlet(p, lmb_max),   lambda p: lmbx_max_dirichlet(p, lmb_max)]]
    problem = HyperElasticity(mesh,
                            vec=2,
                            dim=2,
                            ele_type=ele_type,
                            dirichlet_bc_info=dirichlet_bc_info)
    elem_X = problem.get_physical_quad_points().mean(1)

    # params = vmap(coords_2_params_gt)(elem_X)
    params = []
    for xy in elem_X:
        params.append(coords_2_params_gt(xy))
    params = np.expand_dims(params, 1)
    params_vec = jnp.repeat(params, axis=1, repeats=4)
    problem.set_params(params_vec)


    u = solver(problem, use_petsc=True)
    middle_displacements = []
    for element in mesh.cells:
       element_displacements = u[element,:]
       middle_displacements.append(np.mean(element_displacements, axis=0))
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    u_hist_goh.append(np.array(middle_displacements))
    u_grad = np.mean(problem.sol_to_grad(u), axis=1)
    F = u_grad + np.eye(2)

    P = GOH_P_vmap(u_grad, params_vec[:,0,:], 2)
    
    F_hist_goh_gt.append(F)
    P_hist_goh_gt.append(P)
F_hist_goh_gt = np.array(F_hist_goh_gt)
P_hist_goh_gt = np.array(P_hist_goh_gt)
u_hist_goh = np.array(u_hist_goh)
# Out:
# [10-23 02:26:44][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-23 02:26:44][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-23 02:26:44][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-23 02:26:44][DEBUG] jax_fem: Done pre-computations, took 0.0517580509185791 [s]
# [10-23 02:26:44][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-23 02:26:49][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-23 02:26:49][DEBUG] jax_fem: Start timing
# [10-23 02:26:49][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:51][DEBUG] jax_fem: Function split_and_compute_cell took 1.5847 seconds
# [10-23 02:26:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:51][DEBUG] jax_fem: Linear guess solve...
# [10-23 02:26:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:51][DEBUG] jax_fem: PETSc linear solve res = 9.492041927642487e-07
# [10-23 02:26:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.0402 seconds
# [10-23 02:26:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:51][DEBUG] jax_fem: Before, res l_2 = 0.0009216769784098309
# [10-23 02:26:51][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:26:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:51][DEBUG] jax_fem: PETSc linear solve res = 3.0609988802076327e-09
# [10-23 02:26:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.0395 seconds
# [10-23 02:26:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:51][DEBUG] jax_fem: res l_2 = 1.1977821378827656e-06
# [10-23 02:26:51][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:26:51][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:51][DEBUG] jax_fem: PETSc linear solve res = 2.4473007653491214e-12
# [10-23 02:26:51][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:51][DEBUG] jax_fem: Function split_and_compute_cell took 0.0418 seconds
# [10-23 02:26:51][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:51][DEBUG] jax_fem: res l_2 = 3.64165772031814e-12
# [10-23 02:26:51][INFO] jax_fem: Solve took 2.021099090576172 [s]
# [10-23 02:26:51][DEBUG] jax_fem: max of sol = 0.055439999999999934
# [10-23 02:26:51][DEBUG] jax_fem: min of sol = 0.0
# [10-23 02:26:51][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-23 02:26:51][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-23 02:26:51][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-23 02:26:51][DEBUG] jax_fem: Done pre-computations, took 0.040349483489990234 [s]
# [10-23 02:26:51][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-23 02:26:57][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-23 02:26:57][DEBUG] jax_fem: Start timing
# [10-23 02:26:57][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:59][DEBUG] jax_fem: Function split_and_compute_cell took 1.5050 seconds
# [10-23 02:26:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:59][DEBUG] jax_fem: Linear guess solve...
# [10-23 02:26:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:59][DEBUG] jax_fem: PETSc linear solve res = 1.334604376417072e-06
# [10-23 02:26:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0407 seconds
# [10-23 02:26:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:59][DEBUG] jax_fem: Before, res l_2 = 0.001996919662279909
# [10-23 02:26:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:26:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:59][DEBUG] jax_fem: PETSc linear solve res = 1.1629928071943836e-08
# [10-23 02:26:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0381 seconds
# [10-23 02:26:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:59][DEBUG] jax_fem: res l_2 = 5.622804459416235e-06
# [10-23 02:26:59][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:26:59][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:26:59][DEBUG] jax_fem: PETSc linear solve res = 1.3107085823933744e-11
# [10-23 02:26:59][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:26:59][DEBUG] jax_fem: Function split_and_compute_cell took 0.0414 seconds
# [10-23 02:26:59][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:26:59][DEBUG] jax_fem: res l_2 = 5.982647941544437e-11
# [10-23 02:26:59][INFO] jax_fem: Solve took 1.9667730331420898 [s]
# [10-23 02:26:59][DEBUG] jax_fem: max of sol = 0.07794999999999996
# [10-23 02:26:59][DEBUG] jax_fem: min of sol = 0.0
# [10-23 02:26:59][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-23 02:26:59][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-23 02:26:59][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-23 02:26:59][DEBUG] jax_fem: Done pre-computations, took 0.04509925842285156 [s]
# [10-23 02:26:59][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-23 02:27:05][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-23 02:27:05][DEBUG] jax_fem: Start timing
# [10-23 02:27:05][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:07][DEBUG] jax_fem: Function split_and_compute_cell took 1.4772 seconds
# [10-23 02:27:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:07][DEBUG] jax_fem: Linear guess solve...
# [10-23 02:27:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:07][DEBUG] jax_fem: PETSc linear solve res = 1.723257603449373e-06
# [10-23 02:27:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0392 seconds
# [10-23 02:27:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:07][DEBUG] jax_fem: Before, res l_2 = 0.00346712873658895
# [10-23 02:27:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:07][DEBUG] jax_fem: PETSc linear solve res = 8.342633354745415e-09
# [10-23 02:27:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0377 seconds
# [10-23 02:27:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:07][DEBUG] jax_fem: res l_2 = 1.6871273653778703e-05
# [10-23 02:27:07][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:07][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:07][DEBUG] jax_fem: PETSc linear solve res = 3.1049678992372207e-11
# [10-23 02:27:07][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:07][DEBUG] jax_fem: Function split_and_compute_cell took 0.0409 seconds
# [10-23 02:27:07][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:07][DEBUG] jax_fem: res l_2 = 5.168836434706702e-10
# [10-23 02:27:07][INFO] jax_fem: Solve took 1.8911352157592773 [s]
# [10-23 02:27:07][DEBUG] jax_fem: max of sol = 0.1006499999999999
# [10-23 02:27:07][DEBUG] jax_fem: min of sol = 0.0
# [10-23 02:27:07][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-23 02:27:07][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-23 02:27:07][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-23 02:27:07][DEBUG] jax_fem: Done pre-computations, took 0.043079376220703125 [s]
# [10-23 02:27:07][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-23 02:27:13][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-23 02:27:13][DEBUG] jax_fem: Start timing
# [10-23 02:27:13][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:14][DEBUG] jax_fem: Function split_and_compute_cell took 1.3901 seconds
# [10-23 02:27:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:14][DEBUG] jax_fem: Linear guess solve...
# [10-23 02:27:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:14][DEBUG] jax_fem: PETSc linear solve res = 2.11036992355908e-06
# [10-23 02:27:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0399 seconds
# [10-23 02:27:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:14][DEBUG] jax_fem: Before, res l_2 = 0.005291705281408901
# [10-23 02:27:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:14][DEBUG] jax_fem: PETSc linear solve res = 1.612297014057509e-08
# [10-23 02:27:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0428 seconds
# [10-23 02:27:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:14][DEBUG] jax_fem: res l_2 = 3.91708689928427e-05
# [10-23 02:27:14][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:14][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:14][DEBUG] jax_fem: PETSc linear solve res = 2.064796171563913e-10
# [10-23 02:27:14][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:14][DEBUG] jax_fem: Function split_and_compute_cell took 0.0380 seconds
# [10-23 02:27:14][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:14][DEBUG] jax_fem: res l_2 = 2.759507841042043e-09
# [10-23 02:27:14][INFO] jax_fem: Solve took 1.8010566234588623 [s]
# [10-23 02:27:14][DEBUG] jax_fem: max of sol = 0.12325999999999993
# [10-23 02:27:14][DEBUG] jax_fem: min of sol = 0.0
# [10-23 02:27:15][DEBUG] jax_fem: Computing shape function values, gradients, etc.
# [10-23 02:27:15][DEBUG] jax_fem: ele_type = QUAD4, quad_points.shape = (num_quads, dim) = (4, 2)
# [10-23 02:27:15][DEBUG] jax_fem: face_quad_points.shape = (num_faces, num_face_quads, dim) = (4, 2, 2)
# [10-23 02:27:15][DEBUG] jax_fem: Done pre-computations, took 0.04995417594909668 [s]
# [10-23 02:27:15][INFO] jax_fem: Solving a problem with 2500 cells, 2601x2 = 5202 dofs.
# [10-23 02:27:20][DEBUG] jax_fem: Calling the row elimination solver for imposing Dirichlet B.C.
# [10-23 02:27:20][DEBUG] jax_fem: Start timing
# [10-23 02:27:20][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:22][DEBUG] jax_fem: Function split_and_compute_cell took 1.4393 seconds
# [10-23 02:27:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:22][DEBUG] jax_fem: Linear guess solve...
# [10-23 02:27:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:22][DEBUG] jax_fem: PETSc linear solve res = 2.497482242340437e-06
# [10-23 02:27:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0413 seconds
# [10-23 02:27:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:22][DEBUG] jax_fem: Before, res l_2 = 0.0074570566014241875
# [10-23 02:27:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:22][DEBUG] jax_fem: PETSc linear solve res = 2.7053147331571813e-08
# [10-23 02:27:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0381 seconds
# [10-23 02:27:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:22][DEBUG] jax_fem: res l_2 = 7.758624358300668e-05
# [10-23 02:27:22][DEBUG] jax_fem: Solving linear system with lift solver...
# [10-23 02:27:22][DEBUG] jax_fem: PETSc - Solving with ksp_type = bcgsl, pc = ilu
# [10-23 02:27:22][DEBUG] jax_fem: PETSc linear solve res = 2.195255080946353e-10
# [10-23 02:27:22][DEBUG] jax_fem: Computing cell Jacobian and cell residual...
# [10-23 02:27:22][DEBUG] jax_fem: Function split_and_compute_cell took 0.0361 seconds
# [10-23 02:27:22][DEBUG] jax_fem: Creating sparse matrix with scipy...
# [10-23 02:27:22][DEBUG] jax_fem: res l_2 = 1.070252793384724e-08
# [10-23 02:27:22][INFO] jax_fem: Solve took 1.841745138168335 [s]
# [10-23 02:27:22][DEBUG] jax_fem: max of sol = 0.14586999999999994
# [10-23 02:27:22][DEBUG] jax_fem: min of sol = 0.0

# %%
displacements = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]

n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 

fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

axes_x = axes_x.flatten()
axes_y = axes_y.flatten()

for idx, (lmb_i, t, u) in enumerate(zip(lmb_hist_plot, t_hist, u_hist_goh)):
    key = random.PRNGKey(t)
    noise = jax.random.normal(key, shape=u.shape)
    mu=0
    sigma=0.0005
    noise=mu + sigma * noise
    noise_scale = 0
    u_noisy = u + noise_scale * noise
    u_noisy_x = u_noisy[:, [0]].flatten()
    u_noisy_y = u_noisy[:, [1]].flatten()

    ax_x = axes_x[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_x, title=f'displacement_x [-]', ax=ax_x)

    ax_y = axes_y[idx]
    plotmesh(mesh.cells, mesh.points, u_noisy_y, title=f'displacement_y [-]', ax=ax_y)

    displacements.append(np.array([t * np.ones(len(u)), u_noisy[:, 0], u_noisy[:, 1]]))

for i in range(n_plots, len(axes_x)):
    fig_x.delaxes(axes_x[i])
for i in range(n_plots, len(axes_y)):
    fig_y.delaxes(axes_y[i])

fig_x.tight_layout()
fig_y.tight_layout()

plt.show()

displacements = np.hstack(displacements)

# %%
### assuming we have a square domain where everything is symmetric wrt x and y
def richardson_derivative(Z, h):
    """Calculates the derivatives using finite difference and Richardson extrapolation for step size h."""
    Z_x = np.zeros_like(Z)
    Z_y = np.zeros_like(Z)
    rows, cols = Z.shape
    for i in range(rows):
        for j in range(cols):
            if i == 0:  
                Z_y[i, j] = (Z[i + 1, j] - Z[i, j]) / h
            elif i == rows - 1:  
                Z_y[i, j] = (Z[i, j] - Z[i - 1, j]) / h
            else:  
                dy_h = (Z[i + 1, j] - Z[i - 1, j]) / (2 * h)
                
        
                f_y_plus_h_half = (Z[i + 1, j] + Z[i, j]) / 2
                f_y_minus_h_half = (Z[i - 1, j] + Z[i, j]) / 2
                
                dy_h_over_2 = (f_y_plus_h_half - f_y_minus_h_half) / h

               
                # Z_y[i, j] = (4 * dy_h_over_2 - dy_h) / 3
                Z_y[i, j] = dy_h
            if j == 0: 
                Z_x[i, j] = (Z[i, j + 1] - Z[i, j]) / h
            elif j == cols - 1: 
                Z_x[i, j] = (Z[i, j] - Z[i, j - 1]) / h
            else:  
                dx_h = (Z[i, j + 1] - Z[i, j - 1]) / (2 * h)
                
                f_x_plus_h_half = (Z[i, j + 1] + Z[i, j]) / 2
                f_x_minus_h_half = (Z[i, j - 1] + Z[i, j]) / 2
                
                dx_h_over_2 = (f_x_plus_h_half - f_x_minus_h_half) / h

                #Z_x[i, j] = (4 * dx_h_over_2 - dx_h) / 3
                Z_x[i, j] = dx_h

    return Z_x,Z_y
X_grid=elem_X[:,0].reshape((Nx,Ny)).T
Y_grid=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
u_hist_for_derivative=[]
for ii in range(u_hist_goh.shape[0]):
        u1=u_hist_goh[ii,:,:]
        ux_grid=np.zeros((Nx,Ny))
        uy_grid=np.zeros((Nx,Ny))
        id_mesh=0
        for i in range(Nx):
            for j in range(Ny):
                ux_grid[j,i]=u1[id_mesh,0]
                uy_grid[j,i]=u1[id_mesh,1]
                id_mesh+=1
        u_hist_for_derivative.append([X_grid,Y_grid,ux_grid,uy_grid])
F_num_calculated=np.zeros_like(F_hist_goh_gt)
for ii in range(len(u_hist_for_derivative)):
           a,b,ux_grid,uy_grid=u_hist_for_derivative[ii]
           #print(ux_grid)
           uxx,uxy=richardson_derivative(ux_grid,1/Nx)
           #print('derivative')
           #print(uxx)
           uyx,uyy=richardson_derivative(uy_grid,1/Nx)
           id_mesh=0
           for i in range(uxx.shape[0]):
                for j in range(uxx.shape[1]):
                     F_num_calculated[ii,id_mesh, :,:]=np.array([[uxx[j,i]+1,uxy[j,i]],[uyx[j,i],uyy[j,i]+1]])
                     id_mesh+=1
#print(uy_grid.T[::-1,:])
# plt.scatter(elem_X[:,0], elem_X[:,1])
# a=elem_X[:,0].reshape((Nx,Ny)).T
# b=elem_X[:,1].reshape((Nx,Ny)).T[::-1,:]
# print(a)
# print(b)

# %% [markdown]
# #### calculation of the error of richardson derivative with ground truth

# %%
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
id_for_range=0
for idx, (t, F_gt, F) in enumerate(zip(t_hist, F_hist_goh_gt, F_num_calculated)):
    if id_for_range==n_cols:
        id_for_range=0
    ax_x = axes_x[idx]
    F_error = np.linalg.norm(F_gt-F, axis=(1, 2))
    label = fr'$|F_{{gt}}-F_{{NN}}|^2,\ \text{{time}}={t+1}$'
    plotmesh(mesh.cells, mesh.points, F_error,title=label, ax=ax_x)
    #F_noisy=F+noise
    #strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
#F_hist_goh.shape

# %%
strains = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
for idx, (t, F) in enumerate(zip(t_hist, F_num_calculated)):
    if id_for_range==n_cols:
        id_for_range=0
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    ax_x = axes_x[idx]
    mps = np.maximum(E_11, E_22)
    plotmesh(mesh.cells, mesh.points, mps,title='Max. Princip. Strain [-]', ax=ax_x)
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
strains_gt = np.hstack(strains)

# %%
print(F_hist_goh_gt.max())
print(F_num_calculated.max())
# Out:
# 1.2415569566277689
# 1.2316180979034934

# %%
F_hist_goh_gt.shape
# Out:
# (5, 100, 2, 2)

# %% [markdown]
# #### interpolating displacement with SIREN architecture

# %%
def loss_coords_2_disp(nn_params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] # X consists of 5 columns: X, Y, lmb (time), ux, uy. The first 3 are inputs of the NN and the last 2 the outputs.
    out_pr =siren_fpass(inp, nn_params)
    return jnp.mean((out_pr-out_gt)**2)
n_inp = 3 # x, y, t

nn_layers = [n_inp,40,40,2] # +1 because t is not fed into the fourier features part
nn_params = init_params_siren(nn_layers, key)

# lr = optimizers.exponential_decay(8e-4, 10000, 0.9)
lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
# lr = 5e-4
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init(nn_params)

X = np.vstack([elem_X]*len(u_hist_goh))
inp = np.hstack([X, displacements.T])
nn_params, train_loss, _ = train(loss_coords_2_disp, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000)
coord_2_strain_params = [nn_params]
# Out:
# it 1000, train loss = 8.609863e-04
# it 2000, train loss = 2.376755e-04
# it 3000, train loss = 1.016340e-04
# it 4000, train loss = 5.105754e-05
# it 5000, train loss = 2.690557e-05
# it 6000, train loss = 1.466696e-05
# it 7000, train loss = 8.383290e-06
# it 8000, train loss = 5.020549e-06
# it 9000, train loss = 3.158569e-06
# it 10000, train loss = 2.028514e-06
# it 11000, train loss = 3.106729e-06
# it 12000, train loss = 3.574615e-06
# it 13000, train loss = 7.793371e-07
# it 14000, train loss = 5.991841e-07
# it 15000, train loss = 5.939198e-07
# it 16000, train loss = 4.289856e-07
# it 17000, train loss = 3.615985e-07
# it 18000, train loss = 4.159484e-07
# it 19000, train loss = 3.077446e-07
# it 20000, train loss = 4.446739e-07
# it 21000, train loss = 3.475332e-07
# it 22000, train loss = 4.030712e-07
# it 23000, train loss = 5.089397e-07
# it 24000, train loss = 5.615326e-07
# it 25000, train loss = 3.061015e-07
# it 26000, train loss = 1.772825e-07
# it 27000, train loss = 4.387551e-07
# it 28000, train loss = 2.030104e-07
# it 29000, train loss = 3.327309e-07
# it 30000, train loss = 4.372547e-07
# it 31000, train loss = 3.487374e-07
# it 32000, train loss = 1.258704e-07
# it 33000, train loss = 2.070656e-07
# it 34000, train loss = 8.360684e-07
# it 35000, train loss = 1.928293e-07
# it 36000, train loss = 3.444363e-07
# it 37000, train loss = 3.744296e-07
# it 38000, train loss = 1.788989e-07
# it 39000, train loss = 1.937508e-07
# it 40000, train loss = 1.181326e-07
# it 41000, train loss = 1.141583e-07
# it 42000, train loss = 1.205059e-07
# it 43000, train loss = 9.840246e-08
# it 44000, train loss = 2.454138e-07
# it 45000, train loss = 1.189392e-07
# it 46000, train loss = 1.183296e-07
# it 47000, train loss = 2.726965e-07
# it 48000, train loss = 4.275970e-07
# it 49000, train loss = 1.031396e-07
# it 50000, train loss = 8.438915e-08
# it 51000, train loss = 1.459854e-07
# it 52000, train loss = 1.019147e-07
# it 53000, train loss = 1.727451e-07
# it 54000, train loss = 1.385351e-07
# it 55000, train loss = 7.527288e-08
# it 56000, train loss = 4.900995e-07
# it 57000, train loss = 2.592895e-07
# it 58000, train loss = 7.537644e-08
# it 59000, train loss = 3.821333e-07
# it 60000, train loss = 1.670088e-07
# it 61000, train loss = 1.428406e-07
# it 62000, train loss = 9.567048e-08
# it 63000, train loss = 8.056224e-08
# it 64000, train loss = 2.646991e-07
# it 65000, train loss = 6.951779e-08
# it 66000, train loss = 3.335438e-07
# it 67000, train loss = 7.027209e-08
# it 68000, train loss = 6.738225e-08
# it 69000, train loss = 1.569101e-07
# it 70000, train loss = 6.861111e-08
# it 71000, train loss = 2.944185e-07
# it 72000, train loss = 6.560959e-08
# it 73000, train loss = 1.298818e-07
# it 74000, train loss = 1.948271e-07
# it 75000, train loss = 7.080556e-08
# it 76000, train loss = 7.357748e-08
# it 77000, train loss = 6.158513e-08
# it 78000, train loss = 8.901710e-08
# it 79000, train loss = 7.691561e-08
# it 80000, train loss = 1.067382e-07
# it 81000, train loss = 6.404922e-08
# it 82000, train loss = 6.991307e-08
# it 83000, train loss = 7.762816e-08
# it 84000, train loss = 5.719874e-08
# it 85000, train loss = 1.325521e-07
# it 86000, train loss = 7.544471e-08
# it 87000, train loss = 1.757237e-07
# it 88000, train loss = 5.851129e-08
# it 89000, train loss = 5.552657e-08
# it 90000, train loss = 7.300818e-08
# it 91000, train loss = 1.046934e-07
# it 92000, train loss = 8.923297e-08
# it 93000, train loss = 5.471855e-08
# it 94000, train loss = 6.344138e-08
# it 95000, train loss = 5.216590e-08
# it 96000, train loss = 5.448293e-08
# it 97000, train loss = 7.039974e-08
# it 98000, train loss = 9.055639e-08
# it 99000, train loss = 6.086745e-08
# it 100000, train loss = 7.941394e-08

# %% [markdown]
# #### interpolating an NN for displacement field

# %%
def loss_coords_2_disp(nn_params, X, key):
    inp, out_gt = X[:,:3], X[:,3:] # X consists of 5 columns: X, Y, lmb (time), ux, uy. The first 3 are inputs of the NN and the last 2 the outputs.
    out_pr = coords_2_strain_nn(inp, [ff_params, nn_params])
    return jnp.mean((out_pr-out_gt)**2)
n_ff = 200# 10 cosines and 10 sines in the fourier features
n_inp = 2 # x, y
ff_params = np.random.normal(size=n_inp*n_ff).reshape([n_inp,n_ff])*0.5

nn_layers = [2*n_ff+1,40,40,2] # +1 because t is not fed into the fourier features part
nn_params = init_params_nn(nn_layers, key)

# lr = optimizers.exponential_decay(8e-4, 10000, 0.9)
lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
# lr = 5e-4
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init(nn_params)

X = np.vstack([elem_X]*len(u_hist_goh))
inp = np.hstack([X, displacements.T])
nn_params, train_loss, _ = train(loss_coords_2_disp, inp, get_params, opt_update, opt_state, key, nIter = 100000, print_freq=1000)
coord_2_strain_params = [ff_params, nn_params]
# Out:
# it 1000, train loss = 1.659025e-05
# it 2000, train loss = 3.393030e-05
# it 3000, train loss = 3.441446e-06
# it 4000, train loss = 2.894824e-06
# it 5000, train loss = 2.251631e-06
# it 6000, train loss = 9.703601e-07
# it 7000, train loss = 5.778109e-06
# it 8000, train loss = 3.102557e-06
# it 9000, train loss = 5.558561e-07
# it 10000, train loss = 1.455991e-06
# it 11000, train loss = 1.643560e-06
# it 12000, train loss = 4.211748e-07
# it 13000, train loss = 6.746574e-06
# it 14000, train loss = 8.825783e-06
# it 15000, train loss = 8.973807e-07
# it 16000, train loss = 8.778083e-07
# it 17000, train loss = 1.936966e-05
# it 18000, train loss = 3.452954e-07
# it 19000, train loss = 4.283754e-07
# it 20000, train loss = 3.302462e-07
# it 21000, train loss = 2.874469e-06
# it 22000, train loss = 2.102117e-07
# it 23000, train loss = 2.994483e-06
# it 24000, train loss = 4.401915e-06
# it 25000, train loss = 6.910990e-07
# it 26000, train loss = 2.777142e-07
# it 27000, train loss = 6.701762e-06
# it 28000, train loss = 1.166907e-06
# it 29000, train loss = 2.531646e-07
# it 30000, train loss = 2.030445e-06
# it 31000, train loss = 1.203753e-06
# it 32000, train loss = 2.425129e-06
# it 33000, train loss = 2.466529e-07
# it 34000, train loss = 1.364928e-07
# it 35000, train loss = 2.595508e-07
# it 36000, train loss = 2.810243e-06
# it 37000, train loss = 1.857458e-06
# it 38000, train loss = 3.903689e-06
# it 39000, train loss = 3.798766e-07
# it 40000, train loss = 4.628657e-07
# it 41000, train loss = 1.880726e-07
# it 42000, train loss = 2.496053e-06
# it 43000, train loss = 2.416001e-07
# it 44000, train loss = 3.628377e-06
# it 45000, train loss = 1.184524e-07
# it 46000, train loss = 1.534483e-07
# it 47000, train loss = 1.725416e-07
# it 48000, train loss = 3.023726e-07
# it 49000, train loss = 2.133632e-07
# it 50000, train loss = 2.120410e-06
# it 51000, train loss = 3.651287e-07
# it 52000, train loss = 1.210496e-07
# it 53000, train loss = 1.467099e-07
# it 54000, train loss = 4.542538e-07
# it 55000, train loss = 5.537097e-07
# it 56000, train loss = 1.283726e-05
# it 57000, train loss = 8.565911e-08
# it 58000, train loss = 3.803568e-07
# it 59000, train loss = 1.202468e-07
# it 60000, train loss = 6.637954e-06
# it 61000, train loss = 1.301227e-07
# it 62000, train loss = 9.450035e-08
# it 63000, train loss = 8.158609e-07
# it 64000, train loss = 9.440532e-08
# it 65000, train loss = 1.604645e-06
# it 66000, train loss = 6.202475e-07
# it 67000, train loss = 3.587179e-07
# it 68000, train loss = 2.590236e-06
# it 69000, train loss = 1.814248e-07
# it 70000, train loss = 6.156678e-08
# it 71000, train loss = 6.293112e-08
# it 72000, train loss = 1.688900e-07
# it 73000, train loss = 1.058619e-07
# it 74000, train loss = 1.303162e-06
# it 75000, train loss = 6.880103e-08
# it 76000, train loss = 3.664114e-06
# it 77000, train loss = 4.727672e-07
# it 78000, train loss = 1.268309e-07
# it 79000, train loss = 2.528392e-07
# it 80000, train loss = 1.710739e-06
# it 81000, train loss = 2.637340e-07
# it 82000, train loss = 7.471381e-08
# it 83000, train loss = 6.430285e-08
# it 84000, train loss = 5.414719e-08
# it 85000, train loss = 1.406616e-07
# it 86000, train loss = 3.344958e-07
# it 87000, train loss = 1.076567e-06
# it 88000, train loss = 2.156534e-06
# it 89000, train loss = 1.147985e-06
# it 90000, train loss = 2.223347e-07
# it 91000, train loss = 1.687195e-06
# it 92000, train loss = 5.052986e-08
# it 93000, train loss = 5.754756e-08
# it 94000, train loss = 4.297169e-06
# it 95000, train loss = 3.636905e-07
# it 96000, train loss = 3.931519e-08
# it 97000, train loss = 7.844779e-08
# it 98000, train loss = 5.196824e-07
# it 99000, train loss = 3.229322e-07
# it 100000, train loss = 3.734327e-07

# %%
#coord_2_displacement_params=coord_2_strain_params

# %% [markdown]
# ### Calculation of F and P from NN interpolated on displacement

# %%
def displacement_intpo(x1,x2,x3,ff_params,nn_params):
  inp=jnp.hstack((x1,x2,x3))
  return siren_fpass(inp, nn_params)
X, Y = elem_X[:,[0]],elem_X[:,[1]]
du1_dx1 =grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[0], argnums=0)
du1_dx2=grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[0], argnums=1)

du2_dx1 =grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[1], argnums=0)
du2_dx2=grad(lambda x1, x2, t: displacement_intpo(x1,x2,t,ff_params,nn_params)[1], argnums=1)
vmap_du1_dx1 = vmap(du1_dx1, in_axes=(0, 0, 0))
vmap_du1_dx2 = vmap(du1_dx2, in_axes=(0, 0, 0))
vmap_du2_dx1 = vmap(du2_dx1 , in_axes=(0, 0, 0))
vmap_du2_dx2 = vmap(du2_dx2, in_axes=(0, 0, 0))
F_hist_goh=[]
P_hist_goh=[]
for t in t_hist:
  #print((t*t_sam).shape)
  us_grad=jnp.hstack((vmap_du1_dx1(X,Y,t*jnp.ones_like(X)),vmap_du1_dx2(X,Y,t*jnp.ones_like(X)),vmap_du2_dx1(X,Y,t*jnp.ones_like(X)),vmap_du2_dx2(X,Y,t*jnp.ones_like(X))))
  F_hist_goh.append(us_grad.reshape((n_elem,2,2))+np.eye(2))
  P = GOH_P_vmap(us_grad.reshape((n_elem,2,2)), params_vec[:,0,:], 2)
  P_hist_goh.append(P)

F_hist_goh = np.array(F_hist_goh)
P_hist_goh = np.array(P_hist_goh)

# %% [markdown]
# #### Plot MPS from calculated F from interpolated NN on displacement

# %%
strains = []
t_hist = np.arange(len(u_hist_goh))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
c_range=np.ones((n_cols,2))
c_range[:,[0]]=100000*c_range[:,[0]]
c_range[:,[1]]=-100000*c_range[:,[1]]
id_for_range=0
for i in range(n_rows):
    for j in range(n_cols):
        F=F_hist_goh[id_for_range,:,:,:]
        E = E_fun(F)
        evals, efuns = jnp.linalg.eigh(E)
        E_11, E_22 = evals.T
        ax_x = axes_x[idx]
        mps = np.maximum(E_11, E_22)
        c_range[j,0]=min(c_range[j,0],np.min(mps))
        c_range[j,1]=max(c_range[j,1],np.max(mps))
        id_for_range+=1
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
for idx, (t, F, P) in enumerate(zip(t_hist, F_hist_goh, P_hist_goh)):
    if id_for_range==n_cols:
        id_for_range=0
    E = E_fun(F)
    evals, efuns = jnp.linalg.eigh(E)
    E_11, E_22 = evals.T
    ax_x = axes_x[idx]
    mps = np.maximum(E_11, E_22)
    plotmesh_updated(mesh.cells, mesh.points, mps, c_range[id_for_range,0], c_range[id_for_range,1],title='Max. Princip. Strain [-]', ax=ax_x)
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
strains_gt = np.hstack(strains)
#print(c_range)

# %% [markdown]
# ###  plot for norm error

# %%
n_plots = len(u_hist_goh)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
for idx, (t, F_gt, F) in enumerate(zip(t_hist, F_hist_goh_gt, F_hist_goh)):
    if id_for_range==n_cols:
        id_for_range=0
    ax_x = axes_x[idx]
    F_error = np.linalg.norm(F_gt-F, axis=(1, 2))
    label = fr'$|F_{{gt}}-F_{{NN}}|^2,\ \text{{time}}={t+1}$'
    plotmesh(mesh.cells, mesh.points, F_error,title=label, ax=ax_x)
    #F_noisy=F+noise
    strains.append(np.array([t*np.ones(len(F)), F[:,0,0], F[:,0,1], F[:,1,0], F[:,1,1]]))
    id_for_range+=1
F_hist_goh.shape
# Out:
# (5, 2500, 2, 2)

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/tuning_noise_prob_noiseless_biaxial_test_displacement.npy' ,'wb') as f:
    pickle.dump([coord_2_displacement_params,F_hist_goh,F_hist_goh_gt,P_hist_goh,P_hist_goh_gt, strains_gt,u_hist_goh], f)

# %%
# identify the boundaries
rgt_bd_elems = []
top_bd_elems = []
lft_bd_elems = []
bot_bd_elems = []
for i, e in enumerate(mesh.cells):
    if any([mesh.points[e[i],0]>0.99 for i in range(4)]):
        rgt_bd_elems.append(i)
    if any([mesh.points[e[i],1]>0.99 for i in range(4)]):
        top_bd_elems.append(i)
    if any([mesh.points[e[i],0]<0.01 for i in range(4)]):
        lft_bd_elems.append(i)
    if any([mesh.points[e[i],1]<0.01 for i in range(4)]):
        bot_bd_elems.append(i)

# get the reaction forces by integrating the stresses of the boundary elements
rgt_bd_frc = np.sum(P_hist_goh[:,rgt_bd_elems,0,0], axis=1)
lft_bd_frc = np.sum(P_hist_goh[:,lft_bd_elems,0,0], axis=1)
top_bd_frc = np.sum(P_hist_goh[:,top_bd_elems,1,1], axis=1)
bot_bd_frc = np.sum(P_hist_goh[:,bot_bd_elems,1,1], axis=1)
Force_x = jnp.array(0.5*(rgt_bd_frc + lft_bd_frc))
Force_y = jnp.array(0.5*(top_bd_frc + bot_bd_frc))

# get the center points of the elements
rgt_bd_X = elem_X[rgt_bd_elems]
top_bd_X = elem_X[top_bd_elems]
lft_bd_X = elem_X[lft_bd_elems]
bot_bd_X = elem_X[bot_bd_elems]
bd_X = rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X

# %% [markdown]
# #### saving  and reading info for interolated and ground-truth data

# %%
with open('params_for_cluster_ring_noisy_biaxial_test_prob_displacement.npy' ,'wb') as f:
    pickle.dump([coord_2_displacement_params,coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y, strains_gt,strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist,len(rgt_bd_elems),len(top_bd_elems )], f)

# %%
with open('params_for_cluster_ring_noisy_biaxial_test_prob_displacement.npy', 'rb') as f:
    coord_2_displacement_params,coord_2_strain_params, mesh.points,elem_X, Force_x, Force_y,strains_gt,strains, bd_X, \
                 lmb_hist, P_hist_goh, F_hist_goh, t_hist,len_rgt_bd_elems,len_top_bd_elems  = pickle.load(f)

# %% [markdown]
# #### pretraining NODE's params to regenerate average stress

# %%
# Homogenize the strains
F_xx_mean = np.mean(F_hist_goh[:,:,0,0], axis=1)
F_xy_mean = np.mean(F_hist_goh[:,:,0,1], axis=1)
F_yx_mean = np.mean(F_hist_goh[:,:,1,0], axis=1)
F_yy_mean = np.mean(F_hist_goh[:,:,1,1], axis=1)

P_xx_mean = Force_x/len(rgt_bd_elems)
P_yy_mean = Force_y/len(top_bd_elems)
inputs = np.array([F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, P_xx_mean, P_yy_mean]).T

n_neurons = 4
# Define the loss function for when training all params
@jit
def loss_stress(params, x, key):
    model = NODE_model_aniso(params)
    F_xx, F_xy, F_yx, F_yy, P_xx_gt, P_yy_gt = x.T
    P = eval_P_vmap(F_xx, F_xy, F_yx, F_yy, model)
    P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
    return np.mean((P_xx_pr-P_xx_gt)**2+(P_yy_pr-P_yy_gt)**2)

# Initialize NODEs and the optimizer
key = random.PRNGKey(0)
common_layers = [1, n_neurons, n_neurons]
sample_layers = [n_neurons,1]
node_params = init_params_aniso(common_layers, sample_layers, key)
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(node_params)

# Train
node_params, train_loss, _ = train(loss_stress, inputs, get_params, opt_update, opt_state, key, nIter = 20000, print_freq=1000)
# Out:
# it 1000, train loss = 3.599940e-02
# it 2000, train loss = 1.453014e-02
# it 3000, train loss = 2.843493e-03
# it 4000, train loss = 9.165830e-05
# it 5000, train loss = 8.756928e-05
# it 6000, train loss = 7.932610e-05
# it 7000, train loss = 6.071274e-05
# it 8000, train loss = 3.270196e-05
# it 9000, train loss = 2.670201e-05
# it 10000, train loss = 2.649072e-05
# it 11000, train loss = 2.631283e-05
# it 12000, train loss = 2.613874e-05
# it 13000, train loss = 2.595457e-05
# it 14000, train loss = 2.580780e-05
# it 15000, train loss = 2.566097e-05
# it 16000, train loss = 2.551556e-05
# it 17000, train loss = 2.537966e-05
# it 18000, train loss = 2.525751e-05
# it 19000, train loss = 2.514613e-05
# it 20000, train loss = 2.504232e-05

# %%
mymodel = NODE_model_aniso(node_params)
P = eval_P_vmap(F_xx_mean, F_xy_mean, F_yx_mean, F_yy_mean, mymodel)
P_xx_pr, P_yy_pr = P[:,0,0], P[:,1,1]
print('gt P_xx & P_yy: ', P_xx_mean, P_yy_mean)
print('pr P_xx & P_yy: ', P_xx_pr, P_yy_pr)
# Out:
# gt P_xx & P_yy:  [0.45007 0.56603 0.67762 0.77818 0.858  ] [0.38967 0.49767 0.60706 0.70722 0.78614]
# pr P_xx & P_yy:  [0.44626 0.57057 0.67899 0.77432 0.85937] [0.38808 0.50254 0.60636 0.70144 0.7895 ]

# %% [markdown]
# #### pretraining the hyper network to generate params of NODE, which is homogeneous at this point

# %%
# Fit a function Λ that maps x,y ∈ [0,1] to the individual-specific parameters of this NODE with a maximum variance of, say, 1%
phi, unravel = ravel_pytree(node_params)
n_phi = len(phi)

# ff_params = coord_2_strain_params[0]
# ff_nn2 = lambda x, nn_params: ff_nn(x, [ff_params, nn_params])
def loss_Lambda(params, inp, key):
    out_pr = ff_nn(inp, params)
    return jnp.mean((out_pr-phi)**2)

n_ff = 40
ff_params = np.random.normal(size=2*n_ff).reshape([2,n_ff])
nn_layers = [2*n_ff,40,40,n_phi]
nn_params = init_params_nn(nn_layers, key)
Lambda_params = [ff_params, nn_params]
opt_init, opt_update, get_params = optimizers.adam(5.e-4) #Original: 1.e-4
opt_state = opt_init(Lambda_params)

inp = np.array(np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))).reshape([2,-1]).T
Lambda_params, train_loss, _ = train(loss_Lambda, inp, get_params, opt_update, opt_state, key, nIter = 5000, print_freq=1000)
# Out:
# it 1000, train loss = 1.169067e-04
# it 2000, train loss = 3.343240e-05
# it 3000, train loss = 1.414452e-05
# it 4000, train loss = 7.054122e-06
# it 5000, train loss = 3.764022e-06

# %%
fig, ax = plt.subplots()
ax.plot(phi, 'r.-')
for y in np.linspace(0,1,4):
    for x in np.linspace(0,1,10):
        params = ff_nn(np.array([x,y]).reshape([1,-1]), Lambda_params)
        ax.plot(params[0])

# %% [markdown]
# #### second pretraining of the hyper network to acount for non-homogeneous deformation gradient

# %%
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
def get_P_from_dis(X, Y, t, Lambda_params, coord_2_displacement_params, model):
    

    du1_dx1 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[0], argnums=0)
    du1_dx2 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[0], argnums=1)
    du2_dx1 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[1], argnums=0)
    du2_dx2 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[1], argnums=1)
    
    u_xx=du1_dx1(X,Y,t)
    u_xy=du1_dx2(X,Y,t)
    u_yx=du2_dx1(X,Y,t)
    u_yy=du2_dx2(X,Y,t)
    #F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[u_xx, u_xy],[u_yx, u_yy]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_vmap = vmap(get_P_from_dis, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))

# %%
a1 = 10000
@jit
def loss(Lambda_params, XYt_colloc):

    P_pred = get_P_vmap(XYt_colloc[:,0],XYt_colloc[:,1], XYt_colloc[:,2], Lambda_params, coord_2_strain_params, NODE_w_unravel)
    P_xx = P_xx_mean[jnp.array(XYt_colloc[:,2], int)]
    P_yy = P_yy_mean[jnp.array(XYt_colloc[:,2], int)]

    loss_P = jnp.mean((P_pred[0] - P_xx)**2 + (P_pred[3] - P_yy)**2)
    # loss_F = 0.0
    
    return loss_P

lr = optimizers.exponential_decay(1e-3, 10000, 0.9)
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 50000, print_freq=100, batch_size=3000)
# Out:
# it 1, val loss = 7.756763e-02
# it 101, val loss = 1.178910e-03
# it 201, val loss = 5.048059e-04
# it 301, val loss = 3.856813e-04
# it 401, val loss = 3.352105e-04
# it 501, val loss = 2.957355e-04
# it 601, val loss = 2.488328e-04
# it 701, val loss = 2.098667e-04
# it 801, val loss = 1.983509e-04
# it 901, val loss = 1.539086e-04
# it 1001, val loss = 1.320303e-04
# it 1101, val loss = 1.723871e-04
# it 1201, val loss = 1.843849e-04
# it 1301, val loss = 1.040267e-04
# it 1401, val loss = 1.099133e-04
# it 1501, val loss = 1.020377e-04
# it 1601, val loss = 1.058772e-04
# it 1701, val loss = 1.110917e-04
# it 1801, val loss = 8.376032e-05
# it 1901, val loss = 8.448195e-05
# it 2001, val loss = 9.318539e-05
# it 2101, val loss = 9.628503e-05
# it 2201, val loss = 1.958529e-04
# it 2301, val loss = 1.459733e-04
# it 2401, val loss = 9.783105e-05
# it 2501, val loss = 8.241872e-05
# it 2601, val loss = 7.379846e-05
# it 2701, val loss = 2.337598e-04
# it 2801, val loss = 2.553273e-04
# it 2901, val loss = 8.126995e-05
# it 3001, val loss = 8.041173e-05
# it 3101, val loss = 1.426256e-04
# it 3201, val loss = 1.284782e-04
# it 3301, val loss = 7.141247e-05
# it 3401, val loss = 1.445381e-04
# it 3501, val loss = 2.267540e-04
# it 3601, val loss = 7.734906e-05
# it 3701, val loss = 8.294982e-05
# it 3801, val loss = 1.201843e-04
# it 3901, val loss = 6.251266e-05
# it 4001, val loss = 6.108117e-05
# it 4101, val loss = 1.405561e-04
# it 4201, val loss = 1.037500e-04
# it 4301, val loss = 7.632897e-05
# it 4401, val loss = 5.994831e-05
# it 4501, val loss = 2.072462e-04
# it 4601, val loss = 1.792750e-04
# it 4701, val loss = 1.586650e-04
# it 4801, val loss = 7.076694e-05
# it 4901, val loss = 8.513867e-05
# it 5001, val loss = 7.907766e-05
# it 5101, val loss = 6.085493e-05
# it 5201, val loss = 1.009143e-04
# it 5301, val loss = 5.967967e-05
# it 5401, val loss = 5.958011e-05
# it 5501, val loss = 1.028128e-04
# it 5601, val loss = 7.524491e-05
# it 5701, val loss = 1.034120e-04
# it 5801, val loss = 6.850498e-05
# it 5901, val loss = 6.389992e-05
# it 6001, val loss = 1.792985e-04
# it 6101, val loss = 9.421548e-05
# it 6201, val loss = 2.187206e-04
# it 6301, val loss = 3.014012e-04
# it 6401, val loss = 7.955809e-05
# it 6501, val loss = 1.067141e-04
# it 6601, val loss = 1.526097e-04
# it 6701, val loss = 5.682253e-05
# it 6801, val loss = 1.021150e-04
# it 6901, val loss = 7.461100e-05
# it 7001, val loss = 6.805171e-05
# it 7101, val loss = 9.645974e-05
# it 7201, val loss = 4.962381e-05
# it 7301, val loss = 5.567419e-05
# it 7401, val loss = 8.897403e-05
# it 7501, val loss = 7.766861e-05
# it 7601, val loss = 5.454202e-05
# it 7701, val loss = 4.803420e-05
# it 7801, val loss = 7.721359e-05
# it 7901, val loss = 5.622333e-05
# it 8001, val loss = 5.196946e-05
# it 8101, val loss = 7.238426e-05
# it 8201, val loss = 5.491730e-05
# it 8301, val loss = 5.908063e-05
# it 8401, val loss = 4.802459e-05
# it 8501, val loss = 6.179217e-05
# it 8601, val loss = 6.943764e-05
# it 8701, val loss = 3.999302e-05
# it 8801, val loss = 5.577387e-05
# it 8901, val loss = 9.043914e-05
# it 9001, val loss = 4.578568e-05
# it 9101, val loss = 5.119996e-05
# it 9201, val loss = 4.611559e-05
# it 9301, val loss = 1.171382e-04
# it 9401, val loss = 4.076944e-05
# it 9501, val loss = 5.951059e-05
# it 9601, val loss = 5.131703e-05
# it 9701, val loss = 1.119268e-04
# it 9801, val loss = 3.877011e-05
# it 9901, val loss = 1.407431e-04
# it 10001, val loss = 2.149734e-04
# it 10101, val loss = 5.520649e-05
# it 10201, val loss = 4.361903e-05
# it 10301, val loss = 7.987926e-05
# it 10401, val loss = 1.340547e-04
# it 10501, val loss = 8.153202e-05
# it 10601, val loss = 1.094102e-04
# it 10701, val loss = 5.755988e-05
# it 10801, val loss = 7.104463e-05
# it 10901, val loss = 7.719927e-05
# it 11001, val loss = 7.639910e-05
# it 11101, val loss = 5.087468e-05
# it 11201, val loss = 4.724411e-05
# it 11301, val loss = 9.135428e-05
# it 11401, val loss = 4.180398e-05
# it 11501, val loss = 5.466349e-05
# it 11601, val loss = 4.076243e-05
# it 11701, val loss = 7.871495e-05
# it 11801, val loss = 3.290292e-05
# it 11901, val loss = 4.324300e-05
# it 12001, val loss = 3.737978e-05
# it 12101, val loss = 1.022495e-04
# it 12201, val loss = 5.826559e-05
# it 12301, val loss = 4.154291e-05
# it 12401, val loss = 6.442349e-05
# it 12501, val loss = 4.395012e-05
# it 12601, val loss = 1.362017e-04
# it 12701, val loss = 4.977113e-05
# it 12801, val loss = 8.613943e-05
# it 12901, val loss = 5.389343e-05
# it 13001, val loss = 5.058002e-05
# it 13101, val loss = 9.757367e-05
# it 13201, val loss = 7.388731e-05
# it 13301, val loss = 8.478849e-05
# it 13401, val loss = 1.394287e-04
# it 13501, val loss = 3.836561e-05
# it 13601, val loss = 1.619735e-04
# it 13701, val loss = 7.783236e-05
# it 13801, val loss = 3.411299e-05
# it 13901, val loss = 5.870616e-05
# it 14001, val loss = 1.202665e-04
# it 14101, val loss = 8.588083e-05
# it 14201, val loss = 3.846300e-05
# it 14301, val loss = 3.151057e-05
# it 14401, val loss = 8.383232e-05
# it 14501, val loss = 4.303226e-05
# it 14601, val loss = 5.607115e-05
# it 14701, val loss = 4.025667e-05
# it 14801, val loss = 4.267844e-05
# it 14901, val loss = 4.989508e-05
# it 15001, val loss = 2.816911e-05
# it 15101, val loss = 5.663449e-05
# it 15201, val loss = 5.269622e-05
# it 15301, val loss = 5.189532e-05
# it 15401, val loss = 6.553587e-05
# it 15501, val loss = 1.015752e-04
# it 15601, val loss = 6.689721e-05
# it 15701, val loss = 6.202105e-05
# it 15801, val loss = 6.643662e-05
# it 15901, val loss = 1.673761e-04
# it 16001, val loss = 9.653869e-05
# it 16101, val loss = 3.486247e-05
# it 16201, val loss = 4.070265e-05
# it 16301, val loss = 3.949880e-05
# it 16401, val loss = 4.174769e-05
# it 16501, val loss = 7.517877e-05
# it 16601, val loss = 1.271260e-04
# it 16701, val loss = 6.502528e-05
# it 16801, val loss = 1.236007e-04
# it 16901, val loss = 4.229240e-05
# it 17001, val loss = 4.403565e-05
# it 17101, val loss = 4.424763e-05
# it 17201, val loss = 3.840341e-05
# it 17301, val loss = 1.008099e-04
# it 17401, val loss = 3.515763e-05
# it 17501, val loss = 3.407799e-05
# it 17601, val loss = 8.446308e-05
# it 17701, val loss = 1.063216e-04
# it 17801, val loss = 2.878464e-05
# it 17901, val loss = 9.906546e-05
# it 18001, val loss = 6.008435e-05
# it 18101, val loss = 6.594123e-05
# it 18201, val loss = 3.314281e-05
# it 18301, val loss = 4.794241e-05
# it 18401, val loss = 9.745278e-05
# it 18501, val loss = 1.077486e-04
# it 18601, val loss = 6.795402e-05
# it 18701, val loss = 5.429189e-05
# it 18801, val loss = 3.679284e-05
# it 18901, val loss = 9.127871e-05
# it 19001, val loss = 4.369044e-05
# it 19101, val loss = 1.901036e-04
# it 19201, val loss = 2.941374e-05
# it 19301, val loss = 7.240612e-05
# it 19401, val loss = 7.281200e-05
# it 19501, val loss = 9.214882e-05
# it 19601, val loss = 6.489868e-05
# it 19701, val loss = 1.086008e-04
# it 19801, val loss = 3.326311e-05
# it 19901, val loss = 3.353210e-05
# it 20001, val loss = 1.033755e-04
# it 20101, val loss = 3.624174e-05
# it 20201, val loss = 6.875794e-05
# it 20301, val loss = 1.074078e-04
# it 20401, val loss = 5.042781e-05
# it 20501, val loss = 2.992216e-05
# it 20601, val loss = 8.227497e-05
# it 20701, val loss = 5.863786e-05
# it 20801, val loss = 5.979333e-05
# it 20901, val loss = 1.006735e-04
# it 21001, val loss = 3.661114e-05
# it 21101, val loss = 1.150438e-04
# it 21201, val loss = 3.222664e-05
# it 21301, val loss = 9.057148e-05
# it 21401, val loss = 7.015653e-05
# it 21501, val loss = 9.106410e-05
# it 21601, val loss = 3.886806e-05
# it 21701, val loss = 2.660117e-05
# it 21801, val loss = 4.681197e-05
# it 21901, val loss = 3.793101e-05
# it 22001, val loss = 5.091420e-05
# it 22101, val loss = 8.479459e-05
# it 22201, val loss = 2.939724e-05
# it 22301, val loss = 5.266023e-05
# it 22401, val loss = 2.454999e-05
# it 22501, val loss = 9.983936e-05
# it 22601, val loss = 8.848697e-05
# it 22701, val loss = 2.427702e-05
# it 22801, val loss = 7.588957e-05
# it 22901, val loss = 6.046210e-05
# it 23001, val loss = 6.661538e-05
# it 23101, val loss = 7.706130e-05
# it 23201, val loss = 1.047484e-04
# it 23301, val loss = 3.482057e-05
# it 23401, val loss = 7.734500e-05
# it 23501, val loss = 5.915918e-05
# it 23601, val loss = 7.018876e-05
# it 23701, val loss = 3.318037e-05
# it 23801, val loss = 4.468000e-05
# it 23901, val loss = 6.368474e-05
# it 24001, val loss = 9.621687e-05
# it 24101, val loss = 3.350287e-05
# it 24201, val loss = 4.045158e-05
# it 24301, val loss = 1.197185e-04
# it 24401, val loss = 1.280590e-04
# it 24501, val loss = 5.967454e-05
# it 24601, val loss = 2.785360e-05
# it 24701, val loss = 7.231565e-05
# it 24801, val loss = 6.983600e-05
# it 24901, val loss = 5.793917e-05
# it 25001, val loss = 6.906352e-05
# it 25101, val loss = 6.994355e-05
# it 25201, val loss = 3.447445e-05
# it 25301, val loss = 2.704182e-05
# it 25401, val loss = 2.911892e-05
# it 25501, val loss = 3.300902e-05
# it 25601, val loss = 1.102532e-04
# it 25701, val loss = 1.876233e-04
# it 25801, val loss = 7.367202e-05
# it 25901, val loss = 2.813828e-05
# it 26001, val loss = 4.180184e-05
# it 26101, val loss = 5.314317e-05
# it 26201, val loss = 4.248730e-05
# it 26301, val loss = 3.387496e-05
# it 26401, val loss = 4.310632e-05
# it 26501, val loss = 9.108129e-05
# it 26601, val loss = 3.689443e-05
# it 26701, val loss = 4.971126e-05
# it 26801, val loss = 2.835817e-05
# it 26901, val loss = 1.068550e-04
# it 27001, val loss = 1.905053e-05
# it 27101, val loss = 2.331758e-05
# it 27201, val loss = 6.677484e-05
# it 27301, val loss = 6.281194e-05
# it 27401, val loss = 8.661693e-05
# it 27501, val loss = 5.861240e-05
# it 27601, val loss = 5.590508e-05
# it 27701, val loss = 5.003356e-05
# it 27801, val loss = 2.682859e-05
# it 27901, val loss = 7.254421e-05
# it 28001, val loss = 7.487804e-05
# it 28101, val loss = 2.191392e-05
# it 28201, val loss = 5.225970e-05
# it 28301, val loss = 3.381425e-05
# it 28401, val loss = 6.762231e-05
# it 28501, val loss = 7.644279e-05
# it 28601, val loss = 1.318528e-04
# it 28701, val loss = 4.635841e-05
# it 28801, val loss = 1.540450e-04
# it 28901, val loss = 7.490820e-05
# it 29001, val loss = 5.548994e-05
# it 29101, val loss = 8.245657e-05
# it 29201, val loss = 7.397708e-05
# it 29301, val loss = 5.019567e-05
# it 29401, val loss = 8.346765e-05
# it 29501, val loss = 6.407208e-05
# it 29601, val loss = 2.964595e-05
# it 29701, val loss = 4.335308e-05
# it 29801, val loss = 7.460371e-05
# it 29901, val loss = 3.517104e-05
# it 30001, val loss = 6.369767e-05
# it 30101, val loss = 8.740005e-05
# it 30201, val loss = 6.652944e-05
# it 30301, val loss = 4.166058e-05
# it 30401, val loss = 3.312635e-05
# it 30501, val loss = 2.231196e-05
# it 30601, val loss = 2.332752e-05
# it 30701, val loss = 1.403339e-04
# it 30801, val loss = 4.075302e-05
# it 30901, val loss = 4.563476e-05
# it 31001, val loss = 7.601065e-05
# it 31101, val loss = 2.175763e-05
# it 31201, val loss = 3.250187e-05
# it 31301, val loss = 9.157917e-05
# it 31401, val loss = 6.262532e-05
# it 31501, val loss = 8.308252e-05
# it 31601, val loss = 6.408259e-05
# it 31701, val loss = 4.114715e-05
# it 31801, val loss = 2.861420e-05
# it 31901, val loss = 2.896665e-05
# it 32001, val loss = 2.646835e-05
# it 32101, val loss = 9.062588e-05
# it 32201, val loss = 3.871713e-05
# it 32301, val loss = 8.615439e-05
# it 32401, val loss = 2.792234e-05
# it 32501, val loss = 3.903827e-05
# it 32601, val loss = 3.352586e-05
# it 32701, val loss = 5.096389e-05
# it 32801, val loss = 2.736976e-05
# it 32901, val loss = 3.550382e-05
# it 33001, val loss = 3.466242e-05
# it 33101, val loss = 4.794155e-05
# it 33201, val loss = 3.625426e-05
# it 33301, val loss = 9.359341e-05
# it 33401, val loss = 3.595665e-05
# it 33501, val loss = 2.310659e-05
# it 33601, val loss = 3.671274e-05
# it 33701, val loss = 2.578005e-05
# it 33801, val loss = 5.596358e-05
# it 33901, val loss = 2.315904e-05
# it 34001, val loss = 1.604421e-04
# it 34101, val loss = 5.907892e-05
# it 34201, val loss = 2.098467e-05
# it 34301, val loss = 6.478830e-05
# it 34401, val loss = 6.741859e-05
# it 34501, val loss = 7.471016e-05
# it 34601, val loss = 5.503301e-05
# it 34701, val loss = 4.674850e-05
# it 34801, val loss = 3.512242e-05
# it 34901, val loss = 4.386849e-05
# it 35001, val loss = 4.182738e-05
# it 35101, val loss = 3.440958e-05
# it 35201, val loss = 6.649205e-05
# it 35301, val loss = 2.553002e-05
# it 35401, val loss = 1.286104e-04
# it 35501, val loss = 3.679873e-05
# it 35601, val loss = 5.440491e-05
# it 35701, val loss = 3.904031e-05
# it 35801, val loss = 5.102591e-05
# it 35901, val loss = 5.297217e-05
# it 36001, val loss = 4.036443e-05
# it 36101, val loss = 2.466198e-05
# it 36201, val loss = 3.365654e-05
# it 36301, val loss = 2.815021e-05
# it 36401, val loss = 3.538511e-05
# it 36501, val loss = 2.803630e-05
# it 36601, val loss = 2.771951e-05
# it 36701, val loss = 9.312126e-05
# it 36801, val loss = 3.027437e-05
# it 36901, val loss = 4.423983e-05
# it 37001, val loss = 1.215689e-04
# it 37101, val loss = 4.203823e-05
# it 37201, val loss = 6.926585e-05
# it 37301, val loss = 2.435464e-05
# it 37401, val loss = 2.607612e-05
# it 37501, val loss = 2.179288e-05
# it 37601, val loss = 2.336204e-05
# it 37701, val loss = 3.365308e-05
# it 37801, val loss = 8.311624e-05
# it 37901, val loss = 5.437959e-05
# it 38001, val loss = 2.795227e-05
# it 38101, val loss = 3.617276e-05
# it 38201, val loss = 1.990208e-05
# it 38301, val loss = 7.497410e-05
# it 38401, val loss = 7.371299e-05
# it 38501, val loss = 6.527515e-05
# it 38601, val loss = 2.618986e-05
# it 38701, val loss = 2.392466e-05
# it 38801, val loss = 4.072669e-05
# it 38901, val loss = 2.936063e-05
# it 39001, val loss = 5.997126e-05
# it 39101, val loss = 2.884133e-05
# it 39201, val loss = 4.903246e-05
# it 39301, val loss = 2.095209e-05
# it 39401, val loss = 6.647278e-05
# it 39501, val loss = 2.321395e-05
# it 39601, val loss = 2.243052e-05
# it 39701, val loss = 8.288810e-05
# it 39801, val loss = 2.714620e-05
# it 39901, val loss = 5.822111e-05
# it 40001, val loss = 2.268899e-05
# it 40101, val loss = 5.402894e-05
# it 40201, val loss = 3.525628e-05
# it 40301, val loss = 2.253602e-05
# it 40401, val loss = 3.289846e-05
# it 40501, val loss = 6.870113e-05
# it 40601, val loss = 3.567867e-05
# it 40701, val loss = 3.431464e-05
# it 40801, val loss = 4.851337e-05
# it 40901, val loss = 5.803731e-05
# it 41001, val loss = 2.526276e-05
# it 41101, val loss = 2.783208e-05
# it 41201, val loss = 4.362106e-05
# it 41301, val loss = 3.910685e-05
# it 41401, val loss = 2.061203e-05
# it 41501, val loss = 3.593992e-05
# it 41601, val loss = 2.823329e-05
# it 41701, val loss = 2.340789e-05
# it 41801, val loss = 6.383803e-05
# it 41901, val loss = 3.622328e-05
# it 42001, val loss = 3.791095e-05
# it 42101, val loss = 3.239151e-05
# it 42201, val loss = 3.602545e-05
# it 42301, val loss = 4.152553e-05
# it 42401, val loss = 2.068157e-05
# it 42501, val loss = 1.979519e-05
# it 42601, val loss = 3.578592e-05
# it 42701, val loss = 3.271860e-05
# it 42801, val loss = 1.678346e-05
# it 42901, val loss = 2.166599e-05
# it 43001, val loss = 5.986877e-05
# it 43101, val loss = 2.943950e-05
# it 43201, val loss = 5.940990e-05
# it 43301, val loss = 5.594028e-05
# it 43401, val loss = 2.543408e-05
# it 43501, val loss = 3.447516e-05
# it 43601, val loss = 1.251857e-04
# it 43701, val loss = 4.805798e-05
# it 43801, val loss = 3.259985e-05
# it 43901, val loss = 4.171234e-05
# it 44001, val loss = 5.708777e-05
# it 44101, val loss = 3.258243e-05
# it 44201, val loss = 4.323566e-05
# it 44301, val loss = 3.026074e-05
# it 44401, val loss = 5.376860e-05
# it 44501, val loss = 3.028522e-05
# it 44601, val loss = 4.498282e-05
# it 44701, val loss = 2.303340e-05
# it 44801, val loss = 2.299515e-05
# it 44901, val loss = 1.944318e-05
# it 45001, val loss = 6.528140e-05
# it 45101, val loss = 2.002544e-05
# it 45201, val loss = 5.844869e-05
# it 45301, val loss = 3.279087e-05
# it 45401, val loss = 4.620382e-05
# it 45501, val loss = 3.237446e-05
# it 45601, val loss = 4.984276e-05
# it 45701, val loss = 4.626410e-05
# it 45801, val loss = 2.204933e-05
# it 45901, val loss = 3.902419e-05
# it 46001, val loss = 3.141052e-05
# it 46101, val loss = 4.192770e-05
# it 46201, val loss = 2.503493e-05
# it 46301, val loss = 4.707721e-05
# it 46401, val loss = 2.276390e-05
# it 46501, val loss = 2.884646e-05
# it 46601, val loss = 3.406011e-05
# it 46701, val loss = 3.795958e-05
# it 46801, val loss = 2.510529e-05
# it 46901, val loss = 7.024273e-05
# it 47001, val loss = 2.288884e-05
# it 47101, val loss = 3.722498e-05
# it 47201, val loss = 5.063649e-05
# it 47301, val loss = 3.920489e-05
# it 47401, val loss = 6.403934e-05
# it 47501, val loss = 5.425852e-05
# it 47601, val loss = 4.750265e-05
# it 47701, val loss = 2.862894e-05
# it 47801, val loss = 2.748426e-05
# it 47901, val loss = 9.506079e-05
# it 48001, val loss = 2.383733e-05
# it 48101, val loss = 7.363855e-05
# it 48201, val loss = 3.925858e-05
# it 48301, val loss = 1.982766e-05
# it 48401, val loss = 4.861554e-05
# it 48501, val loss = 1.012676e-04
# it 48601, val loss = 2.264269e-05
# it 48701, val loss = 2.712816e-05
# it 48801, val loss = 5.916973e-05
# it 48901, val loss = 6.782119e-05
# it 49001, val loss = 6.951833e-05
# it 49101, val loss = 8.172578e-05
# it 49201, val loss = 4.426562e-05
# it 49301, val loss = 6.283023e-05
# it 49401, val loss = 1.949771e-05
# it 49501, val loss = 5.123084e-05
# it 49601, val loss = 5.098576e-05
# it 49701, val loss = 4.564382e-05
# it 49801, val loss = 9.677419e-05
# it 49901, val loss = 3.537854e-05

# %% [markdown]
# #### saving data of hyper network after second pretraining to plot the results

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_biaxial_noiseless_tests_displacement_second_pretraining.pickle', 'wb') as f:
    pickle.dump([Lambda_params,val_loss, metrics], f)

# %% [markdown]
# #### saving all data before the main training of the inverse problem

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_biaxial_noiseless_tests_displacement_pre.npy', 'wb') as f:
    pickle.dump([coord_2_displacement_params,coord_2_strain_params, node_params, Lambda_params,mesh.points, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist], f)

# %% [markdown]
# #### training of the inverse problem based on interploation on displacement

# %%
def get_P_from_dis(X, Y, t, Lambda_params, coord_2_displacement_params, model):
    

    du1_dx1 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[0], argnums=0)
    du1_dx2 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[0], argnums=1)
    du2_dx1 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[1], argnums=0)
    du2_dx2 =grad(lambda X_,Y_,t_:coords_2_strain_nn_vmap(jnp.hstack((X_, Y_, t_)), coord_2_displacement_params)[1], argnums=1)
    
    u_xx=du1_dx1(X,Y,t)
    u_xy=du1_dx2(X,Y,t)
    u_yx=du2_dx1(X,Y,t)
    u_yy=du2_dx2(X,Y,t)
    #F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[u_xx, u_xy],[u_yx, u_yy]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_Pxx = lambda X, Y, t, a, b, c: get_P_from_dis(X, Y, t, a, b, c)[0]
get_Pyx = lambda X, Y, t, a, b, c: get_P_from_dis(X, Y, t, a, b, c)[1]
get_Pxy = lambda X, Y, t, a, b, c: get_P_from_dis(X, Y, t, a, b, c)[2]
get_Pyy = lambda X, Y, t, a, b, c: get_P_from_dis(X, Y, t, a, b, c)[3]
get_P_vmap = vmap(get_P_from_dis, in_axes=(0,0,0,None,None,None), out_axes=(0,0,0,0))
Grad_Pxx_X = vmap(grad(get_Pxx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0) # should return dsgm_xx/dx
Grad_Pyx_X = vmap(grad(get_Pyx, argnums=0), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pxy_Y = vmap(grad(get_Pyx, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
Grad_Pyy_Y = vmap(grad(get_Pyy, argnums=1), in_axes=(0,0,0,None,None,None), out_axes=0)
@partial(jit, static_argnums=(3,))
def divergence(Lambda_params, XYt, c2s_params, model):
    dPxx_dX = Grad_Pxx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPxy_dY = Grad_Pxy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyx_dX = Grad_Pyx_X(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    dPyy_dY = Grad_Pyy_Y(XYt[:,0], XYt[:,1], XYt[:,2], Lambda_params, c2s_params, model)
    
    Div_X = jnp.mean(dPxx_dX + dPxy_dY)
    Div_Y = jnp.mean(dPyx_dX + dPyy_dY)
    return Div_X, Div_Y
@partial(jit, static_argnums=(4,))
def bd_forces(Lambda_params, t, bd_X, c2s_params, model):
    rgt_bd_X, top_bd_X, lft_bd_X, bot_bd_X = bd_X
    rgt_bd_P = get_P_vmap(rgt_bd_X[:,0], rgt_bd_X[:,1], t*jnp.ones_like(rgt_bd_X[:,0]), Lambda_params, c2s_params, model)
    top_bd_P = get_P_vmap(top_bd_X[:,0], top_bd_X[:,1], t*jnp.ones_like(top_bd_X[:,0]), Lambda_params, c2s_params, model)
    lft_bd_P = get_P_vmap(lft_bd_X[:,0], lft_bd_X[:,1], t*jnp.ones_like(lft_bd_X[:,0]), Lambda_params, c2s_params, model)
    bot_bd_P = get_P_vmap(bot_bd_X[:,0], bot_bd_X[:,1], t*jnp.ones_like(bot_bd_X[:,0]), Lambda_params, c2s_params, model)

    rgt_bd_frc = jnp.sum(rgt_bd_P[0]*1.0) # Assume area of edge = 1.0
    top_bd_frc = jnp.sum(top_bd_P[3]*1.0)
    lft_bd_frc = jnp.sum(lft_bd_P[0]*1.0)
    bot_bd_frc = jnp.sum(bot_bd_P[3]*1.0)
    return rgt_bd_frc, top_bd_frc, lft_bd_frc, bot_bd_frc

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_biaxial_noiseless_tests_displacement_pre.npy', 'rb') as f:
   [coord_2_displacement_params,coord_2_strain_params, node_params, Lambda_params,mesh_points, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist]=pickle.load(f)

# %% [markdown]
# #### here is the main training

# %%
# Train
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
a1 = 1000
@jit
def loss(Lambda_params, XYt_colloc):
    Div_x, Div_y = divergence(Lambda_params, XYt_colloc, coord_2_strain_params, NODE_w_unravel)
    loss_Div = a1*(Div_x**2 + Div_y**2)

    def bd_forces_loss(_, t):
        F_rgt, F_top, F_lft, F_bot = bd_forces(Lambda_params, t, bd_X, coord_2_strain_params, NODE_w_unravel)
        Fx = Force_x[jnp.array(t, int)]
        Fy = Force_y[jnp.array(t, int)]
        return None, a2*((F_rgt-Fx)**2 + (F_top-Fy)**2 + (F_lft-Fx)**2 + (F_bot-Fy)**2)
    loss_F = jnp.mean(scan(bd_forces_loss, init=None, xs=t_hist)[1])
    # loss_F = 0.0
    
    return loss_Div + loss_F

lr = .3e-4
sharding = PositionalSharding(jax.devices()).reshape(n_cores, 1)
opt_init, opt_update, get_params = optimizers.adam(lr) 
opt_state = opt_init(Lambda_params)

node_X_ext = jnp.hstack([mesh.points, t_hist[-1]*np.ones_like(mesh.points[:,:1])])
metric1 = lambda params, X:  bd_forces(params, t_hist[-1], bd_X, coord_2_strain_params, NODE_w_unravel)
metric2 = lambda params, X: divergence(params, node_X_ext, coord_2_strain_params, NODE_w_unravel)

Lambda_params, val_loss, metrics = train_colloc(loss, [mesh.points, t_hist], get_params, opt_update, opt_state, 
                                            key, sharding, 'cross', nIter = 40000, print_freq=1000, batch_size=1000)

with open('/home/amir/inverse_prob/params_for_noise_tuning/ring_biaxial_noiseless_prob_displacement_post.npy', 'wb') as f:
    pickle.dump([mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist], f)

# %% [markdown]
# ### plot loss for main training

# %%
plt.plot(val_loss)

# %% [markdown]
# ## 3. Test

# %% [markdown]
# #### pretraining plots

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_biaxial_noiseless_tests_displacement_second_pretraining.pickle', 'rb') as f:
    [Lambda_params,val_loss, metrics]=pickle.load(f)

# %% [markdown]
# ### stress plots for constant F

# %%
def get_P_pretraining_plot(F, X,Y,Lambda_params, model):
    F_xx=F[0,0]
    F_xy=F[0,1]
    F_yx=F[1,0]
    F_yy=F[1,1]
    #F_xx, F_xy, F_yx, F_yy = coords_2_strain_nn_ff(jnp.array([X,Y,t])[None,:], coord_2_strain_params).flatten()
    # get NODE individual-specific params, phi, from the Lambda NN
    Lambda_inp = jnp.array([X,Y]).reshape([-1,2])
    phi = ff_nn_ff(Lambda_inp, Lambda_params).flatten()
    # Make predictions with this NODE
    ugrad = jnp.array([[F_xx-1.0, F_xy],[F_yx, F_yy-1.0]])
    P = ThreeDElasticity(model).ugrad_2_P(ugrad, phi, 2)
    return P[0,0], P[1,0], P[0,1], P[1,1]
get_P_pretraining_plot_vmap = vmap(get_P_pretraining_plot, in_axes=(0,0,0,None,None), out_axes=(0,0,0,0))
lmb_hist_plot = [1.05544, 1.07795, 1.10065, 1.12326, 1.14587]
t_hist = len(lmb_hist_plot )
n_plots = len(lmb_hist_plot)  
n_cols = 5
n_rows = (n_plots + n_cols - 1) // n_cols 
t_hist =np.arange(0, t_hist)
# c_range=np.ones((n_cols,2))
# c_range[:,[0]]=100000*c_range[:,[0]]
# c_range[:,[1]]=-100000*c_range[:,[1]]
ff_nn_ff = lambda x, params: ff_nn(x, params)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_y = axes_y.flatten()
for lam in lmb_hist_plot:
    ax_x = axes_x[id_for_range]
    ax_y = axes_y[id_for_range]
    uniform_F= lam *np.eye(2).reshape(1, 2, 2)
    uniform_F_batch= np.repeat(uniform_F, elem_X.shape[0], axis=0)
    P_xx, P_xy,P_yx,P_yy=get_P_pretraining_plot_vmap(uniform_F_batch, elem_X[:,0],elem_X[:,1],Lambda_params,NODE_w_unravel)
    title=fr'$P_{{xx}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_xx,title=title, ax=ax_x)
    title=fr'$P_{{yy}}$,time={id_for_range}'
    plotmesh(mesh.cells, mesh.points, P_yy,title=title, ax=ax_y)
    id_for_range+=1

# %% [markdown]
# ### stress plots with F obtained after NN interploation of displacements

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/biaxial_noisy_biaxial_noiseless_tests_displacement_pre.npy', 'rb') as f:
   [coord_2_displacement_params,coord_2_strain_params, node_params, Lambda_params,mesh.points, elem_X, Force_x, Force_y, strains,
                 bd_X, lmb_hist, P_hist_goh, F_hist_goh, t_hist]=pickle.load(f)

# %%
coords_2_strain_nn_ff = lambda x, params: coords_2_strain_nn(x, params)
ff_nn_ff = lambda x, params: ff_nn(x, params)
id_for_range=0
fig_x, axes_x = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
fig_y, axes_y = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))
axes_x = axes_x.flatten()
axes_y = axes_y.flatten()
for idx, (t, F) in enumerate(zip(t_hist,F_hist_goh)):
    if id_for_range==n_cols:
        id_for_range=0
    t=t_hist[idx]
    Pxx,Pxy,Pyx,Pyy=get_P_pretraining_plot_vmap(F,elem_X[:,0],elem_X[:,1], Lambda_params,NODE_w_unravel)
    ax_x = axes_x[idx]
    ax_y = axes_y[idx]
    title=fr'$P_{{xx}}$,time={idx}'
    plotmesh(mesh.cells, mesh.points, Pxx,title=title, ax=ax_x)
    title=fr'$P_{{yy}}$,time={idx}'
    plotmesh(mesh.cells, mesh.points, Pyy,title=title, ax=ax_y)

# %%
with open('ring_noisy_biaxial_test_prob_displacement_post.npy', 'rb') as f:
    elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist = pickle.load(f)
_, unravel = ravel_pytree(node_params)
NODE_w_unravel = lambda params: NODE_model_aniso(unravel(params))
ele_type = 'QUAD4'
cell_type = get_meshio_cell_type(ele_type)

Nx, Ny = 50, 50
Lx, Ly = 1.0, 1.0
meshio_mesh = rectangle_mesh(Nx=Nx, Ny=Ny, domain_x=Lx, domain_y=Ly)
mesh = Mesh(meshio_mesh.points, meshio_mesh.cells_dict[cell_type])

# %%
fig, ax = plt.subplots()
ax.plot(val_loss)
ax.set(xlabel='Iteration', ylabel='Validation loss')
# Out:
# [Text(0.5, 0, 'Iteration'), Text(0, 0.5, 'Validation loss')]

# %%
with open('/home/amir/inverse_prob/params_for_noise_tuning/ring_biaxial_noiseless_prob_displacement_post.npy', 'rb') as f:
    [mesh, elem_X, strains, Force_x, Force_y, node_params, Lambda_params, val_loss, metrics, t_hist, lmb_hist]=pickle.load(f)

# %% [markdown]
# #### plots for the inverse problem

# %%
# Stiffness across the domain
fig, axes = plt.subplots(2,5,figsize=(20,8))
for lmb, ax in zip(lmb_hist, axes.T):
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])

    params_gt = []
    for xy in elem_X:
        params_gt.append(coords_2_params_gt(xy))
    params_gt = np.array(params_gt)
    params_pr = ff_nn(elem_X, Lambda_params)

    c_elem_gt = []
    c_elem_pr = []
    for params_gt_i, params_pr_i in zip(params_gt, params_pr):
        c_elem_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, params_gt_i, 2)[0,0])
        c_elem_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, params_pr_i, 2)[0,0])
    
    plotmesh(mesh.cells, mesh.points, c_elem_gt, title='gt stress at {}'.format(str(lmb)), ax=ax[0]); 
    extent = [np.min(c_elem_gt), np.max(c_elem_gt)]
    if extent[0] > np.min(c_elem_pr) and extent[1] < np.max(c_elem_pr):
        extend='both'
    elif extent[0] > np.min(c_elem_pr):
        extend='min'
    elif extent[1] < np.max(c_elem_pr):
        extend='max'
    plotmesh(mesh.cells, mesh.points, c_elem_pr, title='pr stress at {}'.format(str(lmb)), ax=ax[1], extent=extent, extend=extend);

# %%
mat1_params = coords_2_params_gt([0.5,0.9])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.2)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.5, 0.9]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[0,0])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[0,0])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{xx}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
mat1_params = coords_2_params_gt([0.5,0.9])
mat2_params = coords_2_params_gt([0.5,0.5])
mat1_P_gt = []
mat2_P_gt = []
mat1_P_pr = []
mat2_P_pr = []
# lmb_hist2 = [1.0, 1.005, 1.01, 1.02, 1.03, 1.04, 1.05, 1.10, 1.15, 1.20, 1.25, 1.30, 1.35]
lmb_hist2 = np.linspace(1,1.2)
for lmb in lmb_hist2:
    ugrad = jnp.array([[lmb-1.0, 0.0], [0.0, lmb-1.0]])
    mat1_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat1_params, 2)[0,0])
    mat2_P_gt.append(ThreeDElasticity(GOH_model).ugrad_2_P(ugrad, mat2_params, 2)[0,0])

    mat1_params_pr = ff_nn(np.array([0.5, 0.9]), Lambda_params)
    mat2_params_pr = ff_nn(np.array([0.5, 0.5]), Lambda_params)
    mat1_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat1_params_pr, 2)[1,1])
    mat2_P_pr.append(ThreeDElasticity(NODE_w_unravel).ugrad_2_P(ugrad, mat2_params_pr, 2)[1,1])

fig, ax = plt.subplots(figsize=(5,4))
ax.plot(lmb_hist2, mat1_P_gt, label='mat 1 (gt)')
ax.plot(lmb_hist2, mat2_P_gt, label='mat 2 (gt)')

fig.gca().set_prop_cycle(None)
ax.plot(lmb_hist2, mat1_P_pr, '--', label='mat 1 (pr)')
ax.plot(lmb_hist2, mat2_P_pr, '--', label='mat 2 (pr)')

ax.legend()
ax.set(xlabel='$\lambda$', ylabel='$P_{yy}$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
